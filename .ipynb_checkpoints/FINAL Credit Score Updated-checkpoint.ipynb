# %% [markdown]
# # Credit Score Classification

# %% [markdown]
# # Problem Statement:

# %% [markdown]
# To develop a predictive model for classifying individuals into credit score categories based on their financial data and other relevant factors. Accurate credit scoring is crucial for the financial institutions to assess the reliability of applicants and manage risk effectively as it leads to less default.

# %%
# Importing Related Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# Libraries for KNN IMPUTER 
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler

# %%
# Reading the file
df = pd.read_csv('train.csv')

# %%
print('Rows:',df.shape[0])
print('Columns:',df.shape[1])
# Out:
# Rows: 100000
# Columns: 28

# %%
# Displaying First 5 Rows of the data
df.head()
# Out:
#        ID Customer_ID     Month           Name   Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265  Scientist
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0      19114.12            1824.843333                  3  ...           _
# 1      19114.12                    NaN                  3  ...        Good
# 2      19114.12                    NaN                  3  ...        Good
# 3      19114.12                    NaN                  3  ...        Good
# 4      19114.12            1824.843333                  3  ...        Good
#
#    Outstanding_Debt Credit_Utilization_Ratio     Credit_History_Age  \
# 0            809.98                26.822620  22 Years and 1 Months
# 1            809.98                31.944960                    NaN
# 2            809.98                28.609352  22 Years and 3 Months
# 3            809.98                31.377862  22 Years and 4 Months
# 4            809.98                24.797347  22 Years and 5 Months
#
#    Payment_of_Min_Amount Total_EMI_per_month Amount_invested_monthly  \
# 0                     No           49.574949       80.41529543900253
# 1                     No           49.574949      118.28022162236736
# 2                     No           49.574949         81.699521264648
# 3                     No           49.574949       199.4580743910713
# 4                     No           49.574949      41.420153086217326
#
#                   Payment_Behaviour     Monthly_Balance Credit_Score
# 0   High_spent_Small_value_payments  312.49408867943663         Good
# 1    Low_spent_Large_value_payments  284.62916249607184         Good
# 2   Low_spent_Medium_value_payments   331.2098628537912         Good
# 3    Low_spent_Small_value_payments  223.45130972736786         Good
# 4  High_spent_Medium_value_payments  341.48923103222177         Good
#
# [5 rows x 28 columns]

# %%
# Checking for the null columns
df.isnull().sum()
# Out:
# ID                              0
# Customer_ID                     0
# Month                           0
# Name                         9985
# Age                             0
# SSN                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary       15002
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                11408
# Delay_from_due_date             0
# Num_of_Delayed_Payment       7002
# Changed_Credit_Limit            0
# Num_Credit_Inquiries         1965
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age           9030
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly      4479
# Payment_Behaviour               0
# Monthly_Balance              1200
# Credit_Score                    0
# dtype: int64

# %%
# Five point summary of the Numerical columns
df.describe().T
# Out:
#                              count         mean          std         min  \
# Monthly_Inhand_Salary      84998.0  4194.170850  3183.686167  303.645417
# Num_Bank_Accounts         100000.0    17.091280   117.404834   -1.000000
# Num_Credit_Card           100000.0    22.474430   129.057410    0.000000
# Interest_Rate             100000.0    72.466040   466.422621    1.000000
# Delay_from_due_date       100000.0    21.068780    14.860104   -5.000000
# Num_Credit_Inquiries       98035.0    27.754251   193.177339    0.000000
# Credit_Utilization_Ratio  100000.0    32.285173     5.116875   20.000000
# Total_EMI_per_month       100000.0  1403.118217  8306.041270    0.000000
#
#                                   25%          50%          75%           max
# Monthly_Inhand_Salary     1625.568229  3093.745000  5957.448333  15204.633333
# Num_Bank_Accounts            3.000000     6.000000     7.000000   1798.000000
# Num_Credit_Card              4.000000     5.000000     7.000000   1499.000000
# Interest_Rate                8.000000    13.000000    20.000000   5797.000000
# Delay_from_due_date         10.000000    18.000000    28.000000     67.000000
# Num_Credit_Inquiries         3.000000     6.000000     9.000000   2597.000000
# Credit_Utilization_Ratio    28.052567    32.305784    36.496663     50.000000
# Total_EMI_per_month         30.306660    69.249473   161.224249  82331.000000

# %%
# Summary of Categorical Columns
df.describe(include = object).T
# Out:
#                           count  unique                               top  \
# ID                       100000  100000                            0x1602
# Customer_ID              100000   12500                         CUS_0xd40
# Month                    100000       8                           January
# Name                      90015   10139                            Langep
# Age                      100000    1788                                38
# SSN                      100000   12501                         #F%$D@*&8
# Occupation               100000      16                           _______
# Annual_Income            100000   18940                          36585.12
# Num_of_Loan              100000     434                                 3
# Type_of_Loan              88592    6260                     Not Specified
# Num_of_Delayed_Payment    92998     749                                19
# Changed_Credit_Limit     100000    4384                                 _
# Credit_Mix               100000       4                          Standard
# Outstanding_Debt         100000   13178                           1360.45
# Credit_History_Age        90970     404            15 Years and 11 Months
# Payment_of_Min_Amount    100000       3                               Yes
# Amount_invested_monthly   95521   91049                         __10000__
# Payment_Behaviour        100000       7    Low_spent_Small_value_payments
# Monthly_Balance           98800   98792  __-333333333333333333333333333__
# Credit_Score             100000       3                          Standard
#
#                           freq
# ID                           1
# Customer_ID                  8
# Month                    12500
# Name                        44
# Age                       2833
# SSN                       5572
# Occupation                7062
# Annual_Income               16
# Num_of_Loan              14386
# Type_of_Loan              1408
# Num_of_Delayed_Payment    5327
# Changed_Credit_Limit      2091
# Credit_Mix               36479
# Outstanding_Debt            24
# Credit_History_Age         446
# Payment_of_Min_Amount    52326
# Amount_invested_monthly   4305
# Payment_Behaviour        25513
# Monthly_Balance              9
# Credit_Score             53174

# %% [markdown]
# # Data cleaning

# %%
# Checking for the unique value count in Customer_ID
df.Customer_ID.nunique()
# Out:
# 12500

# %%
# Splitting the sub category and getting the count of Type_of_Loan 

len(df.Type_of_Loan[0].split(','))
# Out:
# 4

# %%
# Treating the noise in the Num_of_Loan

df.Num_of_Loan =df.Num_of_Loan.str.replace('_','')
df.Num_of_Loan = df.Num_of_Loan.replace('-','')

# %%
df.Num_of_Loan.isnull().sum()
# Out:
# 0

# %%
df.Num_of_Loan.dtype
# Out:
# dtype('O')

# %%
# Exploring Num_of_Loan column for more possible noise

df.Num_of_Loan.unique()

# Num of loan has many absurd values so we will not use it and remove it
# Out:
# array(['4', '1', '3', '967', '-100', '0', '2', '7', '5', '6', '8', '9',
#        '1464', '622', '352', '472', '1017', '945', '146', '563', '341',
#        '444', '720', '1485', '49', '737', '1106', '466', '728', '313',
#        '843', '597', '617', '119', '663', '640', '92', '1019', '501',
#        '1302', '39', '716', '848', '931', '1214', '186', '424', '1001',
#        '1110', '1152', '457', '1433', '1187', '52', '1480', '1047',
#        '1035', '1347', '33', '193', '699', '329', '1451', '484', '132',
#        '649', '995', '545', '684', '1135', '1094', '1204', '654', '58',
#        '348', '614', '1363', '323', '1406', '1348', '430', '153', '1461',
#        '905', '1312', '1424', '1154', '95', '1353', '1228', '819', '1006',
#        '795', '359', '1209', '590', '696', '1185', '1465', '911', '1181',
#        '70', '816', '1369', '143', '1416', '455', '55', '1096', '1474',
#        '420', '1131', '904', '89', '1259', '527', '1241', '449', '983',
#        '418', '319', '23', '238', '638', '138', '235', '280', '1070',
#        '1484', '274', '494', '1459', '404', '1354', '1495', '1391', '601',
#        '1313', '1319', '898', '231', '752', '174', '961', '1046', '834',
#        '284', '438', '288', '1463', '1151', '719', '198', '1015', '855',
#        '841', '392', '1444', '103', '1320', '745', '172', '252', '630',
#        '241', '31', '405', '1217', '1030', '1257', '137', '157', '164',
#        '1088', '1236', '777', '1048', '613', '330', '1439', '321', '661',
#        '952', '939', '562', '1202', '302', '943', '394', '955', '1318',
#        '936', '781', '100', '1329', '1365', '860', '217', '191', '32',
#        '282', '351', '1387', '757', '416', '833', '292', '1225', '1227',
#        '639', '859', '243', '267', '510', '332', '996', '311', '492',
#        '820', '336', '123', '540', '131', '1311', '1441', '895', '891',
#        '50', '940', '935', '596', '29', '1182', '1129', '1014', '251',
#        '365', '291', '1447', '742', '1085', '148', '462', '832', '881',
#        '1412', '785', '1127', '910', '538', '999', '733', '101', '237',
#        '87', '659', '633', '387', '447', '629', '831', '1384', '773',
#        '621', '1419', '289', '285', '1393', '27', '1359', '1482', '1189',
#        '1294', '201', '579', '814', '141', '581', '1171', '295', '290',
#        '433', '679', '1040', '1054', '1430', '1023', '1077', '1457',
#        '1150', '701', '1382', '889', '437', '372', '1222', '126', '1159',
#        '868', '19', '1297', '227', '190', '809', '1216', '1074', '571',
#        '520', '1274', '1340', '991', '316', '697', '926', '873', '1002',
#        '378', '65', '875', '867', '548', '652', '1372', '606', '1036',
#        '1300', '17', '1178', '802', '1219', '1271', '1137', '1496', '439',
#        '196', '636', '192', '228', '1053', '229', '753', '1296', '1371',
#        '254', '863', '464', '515', '838', '1160', '1289', '1298', '799',
#        '182', '574', '242', '415', '869', '958', '54', '1265', '656',
#        '275', '778', '208', '147', '350', '507', '463', '497', '927',
#        '653', '662', '529', '635', '1027', '897', '1039', '1345', '924',
#        '1279', '546', '1112', '1210', '526', '300', '1103', '504', '136',
#        '1400', '78', '686', '1091', '344', '215', '84', '628', '1470',
#        '968', '1478', '83', '1196', '1307', '1132', '1008', '917', '657',
#        '56', '18', '41', '801', '978', '216', '349', '966'], dtype=object)

# %%
# Now we will try to find out the possible pattern through Type_of_Loan.

df[df.Type_of_Loan.notnull()]
# Out:
#             ID Customer_ID     Month           Name   Age          SSN  \
# 0       0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265
# 1       0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265
# 2       0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265
# 3       0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265
# 4       0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265
# ...        ...         ...       ...            ...   ...          ...
# 99995  0x25fe9  CUS_0x942c     April          Nicks    25  078-73-5990
# 99996  0x25fea  CUS_0x942c       May          Nicks    25  078-73-5990
# 99997  0x25feb  CUS_0x942c      June          Nicks    25  078-73-5990
# 99998  0x25fec  CUS_0x942c      July          Nicks    25  078-73-5990
# 99999  0x25fed  CUS_0x942c    August          Nicks    25  078-73-5990
#
#       Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0      Scientist      19114.12            1824.843333                  3  ...
# 1      Scientist      19114.12                    NaN                  3  ...
# 2      Scientist      19114.12                    NaN                  3  ...
# 3      Scientist      19114.12                    NaN                  3  ...
# 4      Scientist      19114.12            1824.843333                  3  ...
# ...          ...           ...                    ...                ...  ...
# 99995   Mechanic      39628.99            3359.415833                  4  ...
# 99996   Mechanic      39628.99            3359.415833                  4  ...
# 99997   Mechanic      39628.99            3359.415833                  4  ...
# 99998   Mechanic      39628.99            3359.415833                  4  ...
# 99999   Mechanic     39628.99_            3359.415833                  4  ...
#
#        Credit_Mix  Outstanding_Debt Credit_Utilization_Ratio  \
# 0               _            809.98                26.822620
# 1            Good            809.98                31.944960
# 2            Good            809.98                28.609352
# 3            Good            809.98                31.377862
# 4            Good            809.98                24.797347
# ...           ...               ...                      ...
# 99995           _            502.38                34.663572
# 99996           _            502.38                40.565631
# 99997        Good            502.38                41.255522
# 99998        Good            502.38                33.638208
# 99999        Good            502.38                34.192463
#
#            Credit_History_Age  Payment_of_Min_Amount Total_EMI_per_month  \
# 0       22 Years and 1 Months                     No           49.574949
# 1                         NaN                     No           49.574949
# 2       22 Years and 3 Months                     No           49.574949
# 3       22 Years and 4 Months                     No           49.574949
# 4       22 Years and 5 Months                     No           49.574949
# ...                       ...                    ...                 ...
# 99995   31 Years and 6 Months                     No           35.104023
# 99996   31 Years and 7 Months                     No           35.104023
# 99997   31 Years and 8 Months                     No           35.104023
# 99998   31 Years and 9 Months                     No           35.104023
# 99999  31 Years and 10 Months                     No           35.104023
#
#       Amount_invested_monthly                 Payment_Behaviour  \
# 0           80.41529543900253   High_spent_Small_value_payments
# 1          118.28022162236736    Low_spent_Large_value_payments
# 2             81.699521264648   Low_spent_Medium_value_payments
# 3           199.4580743910713    Low_spent_Small_value_payments
# 4          41.420153086217326  High_spent_Medium_value_payments
# ...                       ...                               ...
# 99995       60.97133255718485   High_spent_Large_value_payments
# 99996       54.18595028760385  High_spent_Medium_value_payments
# 99997       24.02847744864441   High_spent_Large_value_payments
# 99998      251.67258219721603    Low_spent_Large_value_payments
# 99999       167.1638651610451                            !@9#%8
#
#           Monthly_Balance Credit_Score
# 0      312.49408867943663         Good
# 1      284.62916249607184         Good
# 2       331.2098628537912         Good
# 3      223.45130972736786         Good
# 4      341.48923103222177         Good
# ...                   ...          ...
# 99995          479.866228         Poor
# 99996           496.65161         Poor
# 99997          516.809083         Poor
# 99998          319.164979     Standard
# 99999          393.673696         Poor
#
# [88592 rows x 28 columns]

# %%
# Generating a new column by deriving values through the segmentation of data in Type_of_Loan

list = []
for i in range(df.shape[0]):
    if pd.isna(df.iloc[i,13]) == True:
        list.append(np.nan)
    else:
        list.append(len(df.Type_of_Loan[i].split(',')))

# %%
list = pd.Series(list)
df['Num_of_loan2'] = list

# %%
## cleaning credit history age and converting it into number
extracted_Data = df['Credit_History_Age'].str.extract(r'(\d+) Years and (\d+) Months')

# %%
df['Credit_History_Age'] = extracted_Data[0]+'.'+extracted_Data[1]
#converted extracted date to year.months
#now we can either round off or remove month

# %%
df['Age'] = df.Age.str.replace('-','')
#cleaning age

# %%
df['Age'] = df.Age.str.replace('_','')
#now we have cleaned age

# %%
#as age has no null value we will try to change it to int
df['Age'] = df.Age.astype(int)

# %%
## Treating Annual Income
df.Annual_Income.value_counts()
# Out:
# 36585.12     16
# 20867.67     16
# 17273.83     16
# 9141.63      15
# 33029.66     15
#              ..
# 20269.93_     1
# 15157.25_     1
# 44955.64_     1
# 76650.12_     1
# 4262933.0     1
# Name: Annual_Income, Length: 18940, dtype: int64

# %%
df.Annual_Income = df.Annual_Income.str.replace('_','')

# %%
df.Annual_Income = df.Annual_Income.str.replace('-','')

# %%
df.Annual_Income = df.Annual_Income.astype(float)
df.Annual_Income.dtype
# Out:
# dtype('float64')

# %%
#now we take up amount invested monthly
df.Amount_invested_monthly.value_counts()
# Out:
# __10000__             4305
# 0.0                    169
# 80.41529543900253        1
# 36.66235139442514        1
# 89.7384893604547         1
#                       ...
# 36.541908593249026       1
# 93.45116318631192        1
# 140.80972223052834       1
# 38.73937670100975        1
# 167.1638651610451        1
# Name: Amount_invested_monthly, Length: 91049, dtype: int64

# %%
#cleaning Amount_invested_monthly
df.Amount_invested_monthly = df.Amount_invested_monthly.str.replace('_','').replace('-','')

# %%
df.Amount_invested_monthly = df.Amount_invested_monthly.astype(float)
#after cleaning we convert it to float

# %%
df.Monthly_Balance = df.Monthly_Balance.str.replace('_','').replace('-','')

# %%
df.Monthly_Balance = df.Monthly_Balance.astype(float)

# %%
df.Num_of_Delayed_Payment = df.Num_of_Delayed_Payment.str.replace('_','').replace('-','')

df.Num_of_Delayed_Payment = df.Num_of_Delayed_Payment.astype(float)

# %%
df.Num_Credit_Inquiries = df.Num_Credit_Inquiries.astype(float)

# %%
df.Credit_History_Age = df.Credit_History_Age.astype(float)

# %%
df.Outstanding_Debt.value_counts()
#now we will clean it
# Out:
# 1360.45     24
# 460.46      23
# 1151.7      23
# 1109.03     23
# 467.7       16
#             ..
# 245.46_      1
# 645.77_      1
# 174.79_      1
# 1181.13_     1
# 1013.53_     1
# Name: Outstanding_Debt, Length: 13178, dtype: int64

# %%
df.Outstanding_Debt = df.Outstanding_Debt.str.replace('_','').replace('-','')
df.Outstanding_Debt = df.Outstanding_Debt.astype(float)

# %%
#now we will take up changed credit limit
df.Changed_Credit_Limit.value_counts()
# Out:
# _                     2091
# 8.22                   133
# 11.5                   127
# 11.32                  126
# 7.35                   121
#                       ...
# -1.84                    1
# 0.8899999999999999       1
# 28.06                    1
# 1.5599999999999996       1
# 21.17                    1
# Name: Changed_Credit_Limit, Length: 4384, dtype: int64

# %%
df.Changed_Credit_Limit = df.Changed_Credit_Limit.str.replace('_','')

df.Changed_Credit_Limit[df.Changed_Credit_Limit == ''] = np.nan

df.Changed_Credit_Limit = df.Changed_Credit_Limit.astype('float')

# %%
##all the data has been cleaned of junk characters and variables, now we will begin with missing values and garbage cleaning

# %% [markdown]
# # Garbage and Missing value treatment

# %%
df["Num_of_loan2"].isnull().sum()
# Out:
# 11408

# %%
df.Num_of_loan2.value_counts()
# Out:
# 3.0    15752
# 2.0    15712
# 4.0    15456
# 1.0    11128
# 6.0     8144
# 7.0     7680
# 5.0     7528
# 9.0     3856
# 8.0     3336
# Name: Num_of_loan2, dtype: int64

# %%
# Filling null values in the Num_of_loan2 column by replacing them with zeros obtained from the old loan column(Num_of_Loan).

df.loc[(df.Num_of_loan2.isnull()) & (df.Num_of_Loan == '0'), 'Num_of_loan2'] = 0

# %%
#df['Num_of_loan2'] = df['Num_of_loan2'].astype(int)
# after fixing null values we will covert to int

# %%
df.loc[(df.Num_of_loan2.isnull())]

#we can remove these 478 remaining values as they have no pattern or nothong
# Out:
#             ID Customer_ID   Month                  Name  Age          SSN  \
# 34      0x1634  CUS_0x1cdb   March                Deepaa   21  615-06-7821
# 39      0x1639  CUS_0x1cdb  August                Deepaa   21  615-06-7821
# 180     0x170e  CUS_0xac86     May                 Nickb   20  028-16-4402
# 327     0x17e9  CUS_0xb5ff  August                 Nateg   33  060-81-1328
# 355     0x1815  CUS_0xaedb   April          Olivia Oranr   19  272-47-1135
# ...        ...         ...     ...                   ...  ...          ...
# 99611  0x25da9  CUS_0x2829   April        Alistair Barre   31  172-85-1573
# 99612  0x25daa  CUS_0x2829     May        Alistair Barre   32  172-85-1573
# 99630  0x25dc4  CUS_0x738b    July                 Leahh   25  769-44-1950
# 99663  0x25df5  CUS_0x30fc  August  Zoran Radosavljevicl   28  209-55-1275
# 99859  0x25f1d  CUS_0x1285   April               Lauriay   43  540-18-1115
#
#           Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 34         Developer      35547.710            2853.309167                  7
# 39         Developer      35547.710            2853.309167                  7
# 180     Entrepreneur     106733.130            8873.427500                  4
# 327    Media_Manager      12909.895             853.824583                  5
# 355         Musician      85554.030            7185.502500                  4
# ...              ...            ...                    ...                ...
# 99611     Journalist      64901.370            5298.447500                  3
# 99612     Journalist      64901.370            5298.447500                  3
# 99630     Accountant     123828.520            9317.324054                  4
# 99663        Manager      90781.530            7505.127500                  7
# 99859      Architect      10692.160             817.013333                  8
#
#        ...  Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# 34     ...            943.86                 23.462303               30.1
# 39     ...            943.86                 25.862922               31.3
# 180    ...             76.23                 28.820554               33.1
# 327    ...            602.50                 23.579851               17.8
# 355    ...           1095.73                 31.360245               19.1
# ...    ...               ...                       ...                ...
# 99611  ...            442.06                 29.639741               31.1
# 99612  ...            442.06                 37.699808                NaN
# 99630  ...           1288.43                 39.099750               32.7
# 99663  ...            494.51                 36.809951                NaN
# 99859  ...           1350.85                 31.460700               31.8
#
#       Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 34                      Yes             0.000000               173.138651
# 39                      Yes             0.000000               181.330901
# 180                      No             0.000000               345.609135
# 327                      No             0.000000                60.052635
# 355                      No             0.000000               303.664687
# ...                     ...                  ...                      ...
# 99611                   Yes             0.000000               162.171160
# 99612                   Yes             0.000000                97.413190
# 99630                    NM           999.719279                      NaN
# 99663                   Yes             0.000000               688.256875
# 99859                   Yes             0.000000                49.033808
#
#                       Payment_Behaviour  Monthly_Balance Credit_Score  \
# 34      Low_spent_Medium_value_payments       392.192266     Standard
# 39      High_spent_Small_value_payments       364.000016     Standard
# 180    High_spent_Medium_value_payments       791.733615         Good
# 327     Low_spent_Medium_value_payments       305.329824     Standard
# 355      Low_spent_Large_value_payments       684.885563         Good
# ...                                 ...              ...          ...
# 99611  High_spent_Medium_value_payments              NaN     Standard
# 99612   High_spent_Large_value_payments              NaN     Standard
# 99630   Low_spent_Medium_value_payments              NaN         Good
# 99663   Low_spent_Medium_value_payments              NaN     Standard
# 99859    Low_spent_Large_value_payments              NaN     Standard
#
#        Num_of_loan2
# 34              NaN
# 39              NaN
# 180             NaN
# 327             NaN
# 355             NaN
# ...             ...
# 99611           NaN
# 99612           NaN
# 99630           NaN
# 99663           NaN
# 99859           NaN
#
# [478 rows x 29 columns]

# %%
#df.drop(df.loc[(df.Num_of_loan2.isnull())],axis = 0)
#df.shape
#df.Num_of_loan2.dropna()
#df['Num_of_loan2'].dropna(inplace=True,)
#df.drop(df.Num_of_loan2.isnull(), axis = 0).reset_index(drop = True)
df.dropna(subset = 'Num_of_loan2',inplace= True)

# %%
df.Num_of_loan2.isnull().sum()
# Out:
# 0

# %%
df.Num_of_loan2.value_counts()
# Out:
# 3.0    15752
# 2.0    15712
# 4.0    15456
# 1.0    11128
# 0.0    10930
# 6.0     8144
# 7.0     7680
# 5.0     7528
# 9.0     3856
# 8.0     3336
# Name: Num_of_loan2, dtype: int64

# %%
df.isnull().sum()
# we will remove name so no need for imputing null value for name
# type of loan also remove so no need to impute
# Out:
# ID                              0
# Customer_ID                     0
# Month                           0
# Name                         9944
# Age                             0
# SSN                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary       14932
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                10930
# Delay_from_due_date             0
# Num_of_Delayed_Payment       6968
# Changed_Credit_Limit         2083
# Num_Credit_Inquiries         1954
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age           8993
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly      4451
# Payment_Behaviour               0
# Monthly_Balance              2856
# Credit_Score                    0
# Num_of_loan2                    0
# dtype: int64

# %%
##cleaning occupation

# %%
df['Occupation'].value_counts()
# Out:
# _______          7024
# Lawyer           6553
# Architect        6326
# Engineer         6315
# Mechanic         6273
# Scientist        6271
# Accountant       6239
# Media_Manager    6202
# Developer        6197
# Teacher          6186
# Entrepreneur     6146
# Doctor           6069
# Journalist       6054
# Manager          5941
# Musician         5872
# Writer           5854
# Name: Occupation, dtype: int64

# %%
df[df.Occupation == '_______']
# Out:
#             ID Customer_ID     Month              Name  Age          SSN  \
# 8       0x160e  CUS_0x21b1   January   Rick Rothackerj   28  004-07-5839
# 16      0x161a  CUS_0x2dbc   January            Langep   34  486-85-3974
# 18      0x161c  CUS_0x2dbc     March            Langep   34  486-85-3974
# 20      0x161e  CUS_0x2dbc       May            Langep   34  486-85-3974
# 29      0x162b  CUS_0xb891      June            Jasond   55    #F%$D@*&8
# ...        ...         ...       ...               ...  ...          ...
# 99920  0x25f7a  CUS_0x2654   January               enj   37  647-67-8889
# 99935  0x25f8d  CUS_0xb11c    August    Yinka Adegokej   38  546-94-4789
# 99937  0x25f93  CUS_0xad4f  February  Sabina Zawadzkig  500  226-45-0652
# 99943  0x25f99  CUS_0xad4f    August  Sabina Zawadzkig   48  226-45-0652
# 99989  0x25fdf  CUS_0x8600      June    Sarah McBridec   28  031-35-0942
#
#       Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 8        _______       34847.84            3037.986667                  2
# 16       _______      143162.64           12187.220000                  1
# 18       _______      143162.64                    NaN                  1
# 20       _______      143162.64           12187.220000                  1
# 29       _______       30689.89            2612.490833                  2
# ...          ...            ...                    ...                ...
# 99920    _______      139664.96           11777.746667                  3
# 99935    _______       15319.65            1460.637500                  6
# 99937    _______       22620.79            1722.065833                  7
# 99943    _______       22620.79                    NaN                  6
# 99989    _______       20002.88            1929.906667                 10
#
#        ...  Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# 8      ...            605.03                 24.464031              26.70
# 16     ...           1303.01                 28.616735              17.90
# 18     ...           1303.01                 26.519815              17.11
# 20     ...           1303.01                 31.376150              18.10
# 29     ...            632.46                 27.445422              17.80
# ...    ...               ...                       ...                ...
# 99920  ...            365.66                 31.043048              29.70
# 99935  ...           1453.61                 34.557510              11.40
# 99937  ...            642.46                 31.841872                NaN
# 99943  ...            642.46                 34.026427              29.10
# 99989  ...           3571.70                 33.359987               6.10
#
#       Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 8                        No            18.816215               104.291825
# 16                       No           246.992319               168.413703
# 18                       No           246.992319             10000.000000
# 20                       No           246.992319               430.947528
# 29                       No            16.415452                84.952848
# ...                     ...                  ...                      ...
# 99920                   Yes           423.731016               282.782346
# 99935                   Yes            28.182033               191.877779
# 99937                    No             0.000000               105.076293
# 99943                    No             0.000000               205.217280
# 99989                   Yes            60.964772                74.366603
#
#                      Payment_Behaviour  Monthly_Balance Credit_Score  \
# 8       Low_spent_Small_value_payments       470.690627     Standard
# 16                              !@9#%8      1043.315978         Good
# 18     High_spent_Small_value_payments       715.741367         Good
# 20      Low_spent_Large_value_payments       810.782153         Good
# 29     High_spent_Small_value_payments       419.880784     Standard
# ...                                ...              ...          ...
# 99920  High_spent_Large_value_payments              NaN     Standard
# 99935   Low_spent_Small_value_payments              NaN         Poor
# 99937   Low_spent_Large_value_payments              NaN     Standard
# 99943   Low_spent_Small_value_payments              NaN         Poor
# 99989                           !@9#%8              NaN     Standard
#
#        Num_of_loan2
# 8               1.0
# 16              3.0
# 18              3.0
# 20              3.0
# 29              1.0
# ...             ...
# 99920           4.0
# 99935           4.0
# 99937           0.0
# 99943           0.0
# 99989           5.0
#
# [7024 rows x 29 columns]

# %%
df[df.Name == 'Langep']
# Out:
#             ID Customer_ID     Month    Name  Age          SSN  Occupation  \
# 16      0x161a  CUS_0x2dbc   January  Langep   34  486-85-3974     _______
# 18      0x161c  CUS_0x2dbc     March  Langep   34  486-85-3974     _______
# 19      0x161d  CUS_0x2dbc     April  Langep   34  486-85-3974    Engineer
# 20      0x161e  CUS_0x2dbc       May  Langep   34  486-85-3974     _______
# 21      0x161f  CUS_0x2dbc      June  Langep   34  486-85-3974    Engineer
# 23      0x1621  CUS_0x2dbc    August  Langep   34  486-85-3974    Engineer
# 11872   0x5b92  CUS_0xaf95   January  Langep   38  917-87-3520  Accountant
# 11873   0x5b93  CUS_0xaf95  February  Langep   38  917-87-3520     _______
# 11874   0x5b94  CUS_0xaf95     March  Langep   38  917-87-3520  Accountant
# 11875   0x5b95  CUS_0xaf95     April  Langep   38  917-87-3520  Accountant
# 11876   0x5b96  CUS_0xaf95       May  Langep   38  917-87-3520  Accountant
# 11877   0x5b97  CUS_0xaf95      June  Langep   38  917-87-3520  Accountant
# 11878   0x5b98  CUS_0xaf95      July  Langep   39    #F%$D@*&8  Accountant
# 11879   0x5b99  CUS_0xaf95    August  Langep   39  917-87-3520  Accountant
# 44856  0x11cd6  CUS_0x109d   January  Langep  500  260-21-1290      Writer
# 44857  0x11cd7  CUS_0x109d  February  Langep   44  260-21-1290      Writer
# 44858  0x11cd8  CUS_0x109d     March  Langep   45    #F%$D@*&8      Writer
# 44859  0x11cd9  CUS_0x109d     April  Langep   45  260-21-1290      Writer
# 44860  0x11cda  CUS_0x109d       May  Langep   45  260-21-1290      Writer
# 44861  0x11cdb  CUS_0x109d      June  Langep   45  260-21-1290      Writer
# 44862  0x11cdc  CUS_0x109d      July  Langep   45  260-21-1290      Writer
# 44863  0x11cdd  CUS_0x109d    August  Langep   45  260-21-1290      Writer
# 53272  0x14e26  CUS_0x4854   January  Langep   44  564-50-3217  Accountant
# 53273  0x14e27  CUS_0x4854  February  Langep   44  564-50-3217  Accountant
# 53274  0x14e28  CUS_0x4854     March  Langep   44  564-50-3217  Accountant
# 53275  0x14e29  CUS_0x4854     April  Langep   44  564-50-3217  Accountant
# 53276  0x14e2a  CUS_0x4854       May  Langep   44  564-50-3217  Accountant
# 53277  0x14e2b  CUS_0x4854      June  Langep   44    #F%$D@*&8  Accountant
# 53278  0x14e2c  CUS_0x4854      July  Langep   44  564-50-3217  Accountant
# 53279  0x14e2d  CUS_0x4854    August  Langep   44  564-50-3217  Accountant
# 61376  0x17da2  CUS_0xba1c   January  Langep   32  419-82-4747      Lawyer
# 61377  0x17da3  CUS_0xba1c  February  Langep   32  419-82-4747      Lawyer
# 61378  0x17da4  CUS_0xba1c     March  Langep   32  419-82-4747      Lawyer
# 61379  0x17da5  CUS_0xba1c     April  Langep   32  419-82-4747      Lawyer
# 61381  0x17da7  CUS_0xba1c      June  Langep   32  419-82-4747      Lawyer
# 61382  0x17da8  CUS_0xba1c      July  Langep   32  419-82-4747      Lawyer
# 61383  0x17da9  CUS_0xba1c    August  Langep   33  419-82-4747      Lawyer
# 76872  0x1d86e  CUS_0x7a96   January  Langep   29  255-67-1198     Manager
# 76873  0x1d86f  CUS_0x7a96  February  Langep   29  255-67-1198     Manager
# 76874  0x1d870  CUS_0x7a96     March  Langep   29  255-67-1198     Manager
# 76875  0x1d871  CUS_0x7a96     April  Langep   29  255-67-1198     Manager
# 76876  0x1d872  CUS_0x7a96       May  Langep   30  255-67-1198     Manager
# 76878  0x1d874  CUS_0x7a96      July  Langep   30  255-67-1198     Manager
# 76879  0x1d875  CUS_0x7a96    August  Langep   30  255-67-1198     Manager
#
#        Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 16        143162.640           12187.220000                  1  ...
# 18        143162.640                    NaN                  1  ...
# 19        143162.640           12187.220000                  1  ...
# 20        143162.640           12187.220000                  1  ...
# 21        143162.640           12187.220000                  1  ...
# 23        143162.640           12187.220000                  1  ...
# 11872      10418.045             994.170417                  9  ...
# 11873      10418.045             994.170417                  9  ...
# 11874      10418.045             994.170417                  9  ...
# 11875      10418.045             994.170417                  9  ...
# 11876      10418.045             994.170417                  9  ...
# 11877      10418.045             994.170417                  9  ...
# 11878      10418.045                    NaN                  9  ...
# 11879      10418.045             994.170417                  9  ...
# 44856      49140.870            4377.072500                 10  ...
# 44857      49140.870            4377.072500                 10  ...
# 44858      49140.870            4377.072500                232  ...
# 44859      49140.870            4377.072500                 10  ...
# 44860      49140.870            4377.072500                 10  ...
# 44861      49140.870            4377.072500                 10  ...
# 44862      49140.870            4377.072500                 10  ...
# 44863      49140.870            4377.072500                 10  ...
# 53272      66012.280            5400.023333                 10  ...
# 53273      66012.280            5400.023333                 10  ...
# 53274      66012.280                    NaN                 10  ...
# 53275      66012.280            5400.023333                 10  ...
# 53276      66012.280                    NaN                 10  ...
# 53277      66012.280            5400.023333                 10  ...
# 53278      66012.280            5400.023333                 10  ...
# 53279      66012.280            5400.023333                 10  ...
# 61376      41757.440            3317.786667                  6  ...
# 61377      41757.440            3317.786667                  6  ...
# 61378      41757.440                    NaN                  6  ...
# 61379      41757.440            3317.786667                  6  ...
# 61381      41757.440            3317.786667                  6  ...
# 61382      41757.440            3317.786667                  6  ...
# 61383      41757.440                    NaN                  6  ...
# 76872      24424.700            2051.391667                  8  ...
# 76873      24424.700            2051.391667                  8  ...
# 76874      24424.700            2051.391667                  8  ...
# 76875      24424.700            2051.391667                  8  ...
# 76876      24424.700            2051.391667                  8  ...
# 76878      24424.700                    NaN                  8  ...
# 76879      24424.700            2051.391667                  8  ...
#
#        Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# 16              1303.01                 28.616735              17.90
# 18              1303.01                 26.519815              17.11
# 19              1303.01                 39.501648                NaN
# 20              1303.01                 31.376150              18.10
# 21              1303.01                 39.783993              18.20
# 23              1303.01                 38.374753              18.40
# 11872           3599.97                 25.100129               8.70
# 11873           3599.97                 39.090271               8.80
# 11874           3599.97                 34.731204                NaN
# 11875           3599.97                 23.725047               8.10
# 11876           3599.97                 29.596306               8.11
# 11877           3599.97                 25.640773               9.00
# 11878           3599.97                 24.789920               9.10
# 11879           3599.97                 26.751006               9.20
# 44856           2950.80                 28.875662                NaN
# 44857           2950.80                 25.294527               6.00
# 44858           2950.80                 34.142258               6.10
# 44859           2950.80                 26.586091               6.20
# 44860           2950.80                 40.657363               6.30
# 44861           2950.80                 28.706417               6.40
# 44862           2950.80                 28.446317               6.50
# 44863           2950.80                 31.163786               6.60
# 53272           3696.36                 38.731936              13.70
# 53273           3696.36                 38.395068              13.80
# 53274           3696.36                 33.302369              13.90
# 53275           3696.36                 39.774138              13.10
# 53276           3696.36                 26.076722              13.11
# 53277           3696.36                 23.408542              14.00
# 53278           3696.36                 27.893745              14.10
# 53279           3696.36                 29.570505              14.20
# 61376           1360.45                 33.287966              17.40
# 61377           1360.45                 34.432490              17.50
# 61378           1360.45                 34.007853              17.60
# 61379           1360.45                 25.616749              17.70
# 61381           1360.45                 38.816413              17.90
# 61382           1360.45                 28.265031              17.10
# 61383           1360.45                 37.542362              17.11
# 76872            626.57                 26.238410              22.20
# 76873            626.57                 27.436075              22.30
# 76874            626.57                 35.133788              22.40
# 76875            626.57                 38.554934              22.50
# 76876            626.57                 26.159936              22.60
# 76878            626.57                 29.053649              22.80
# 76879            626.57                 41.621925              22.90
#
#       Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 16                       No           246.992319               168.413703
# 18                       No           246.992319             10000.000000
# 19                       No           246.992319               825.216270
# 20                       No           246.992319               430.947528
# 21                       No           246.992319               257.808099
# 23                       No           246.992319             10000.000000
# 11872                   Yes            27.594591                38.346524
# 11873                   Yes            27.594591                91.720676
# 11874                    NM            27.594591               107.005518
# 11875                   Yes            27.594591                49.791413
# 11876                   Yes            27.594591                39.661098
# 11877                   Yes         54106.000000                88.849888
# 11878                   Yes            27.594591                83.308248
# 11879                   Yes            27.594591                30.093083
# 44856                    NM           154.172426               113.594707
# 44857                   Yes           154.172426                      NaN
# 44858                   Yes           154.172426               177.298309
# 44859                    NM           154.172426               102.231219
# 44860                   Yes           154.172426               112.356043
# 44861                   Yes           154.172426               226.731296
# 44862                   Yes           154.172426               269.190939
# 44863                    NM           154.172426               301.593795
# 53272                   Yes           227.301860             10000.000000
# 53273                   Yes           227.301860               302.328788
# 53274                   Yes           227.301860               285.728217
# 53275                   Yes           227.301860               226.804565
# 53276                   Yes           227.301860                      NaN
# 53277                   Yes           227.301860               353.263028
# 53278                   Yes           227.301860               219.868867
# 53279                   Yes           227.301860               118.053016
# 61376                   Yes           100.069628                35.226764
# 61377                   Yes           100.069628               116.263980
# 61378                   Yes           100.069628                66.570683
# 61379                   Yes           100.069628                31.565207
# 61381                    NM           100.069628                79.967735
# 61382                   Yes           100.069628               248.389449
# 61383                   Yes           100.069628               117.109002
# 76872                   Yes             0.000000                      NaN
# 76873                    NM             0.000000                34.482412
# 76874                   Yes             0.000000                33.299352
# 76875                   Yes             0.000000                67.214001
# 76876                   Yes             0.000000                48.404571
# 76878                   Yes             0.000000               198.737512
# 76879                   Yes             0.000000                      NaN
#
#                       Payment_Behaviour  Monthly_Balance Credit_Score  \
# 16                               !@9#%8      1043.315978         Good
# 18      High_spent_Small_value_payments       715.741367         Good
# 19      Low_spent_Medium_value_payments       426.513411         Good
# 20       Low_spent_Large_value_payments       810.782153         Good
# 21     High_spent_Medium_value_payments       963.921581         Good
# 23      High_spent_Small_value_payments       895.494583     Standard
# 11872    Low_spent_Small_value_payments       323.475926     Standard
# 11873    Low_spent_Large_value_payments       250.101775     Standard
# 11874    Low_spent_Small_value_payments       254.816932     Standard
# 11875    Low_spent_Small_value_payments       312.031038     Standard
# 11876                            !@9#%8       322.161353     Standard
# 11877    Low_spent_Small_value_payments       272.972562     Standard
# 11878    Low_spent_Small_value_payments       278.514203     Standard
# 11879   Low_spent_Medium_value_payments       321.729368     Standard
# 44856   High_spent_Large_value_payments       409.940117     Standard
# 44857                            !@9#%8       361.536898     Standard
# 44858   High_spent_Small_value_payments       366.236515     Standard
# 44859   High_spent_Large_value_payments       421.303604     Standard
# 44860   High_spent_Small_value_payments       431.178781     Standard
# 44861   High_spent_Small_value_payments       316.803528     Standard
# 44862   High_spent_Small_value_payments       274.343885     Standard
# 44863    Low_spent_Small_value_payments       271.941029     Standard
# 53272  High_spent_Medium_value_payments       441.231197     Standard
# 53273   High_spent_Small_value_payments       270.371686     Standard
# 53274    Low_spent_Small_value_payments       316.972257     Standard
# 53275    Low_spent_Small_value_payments       375.895908     Standard
# 53276    Low_spent_Small_value_payments              NaN     Standard
# 53277   High_spent_Small_value_payments       219.437445     Standard
# 53278    Low_spent_Large_value_payments       362.831606     Standard
# 53279  High_spent_Medium_value_payments       444.647458     Standard
# 61376                            !@9#%8       436.482274         Poor
# 61377  High_spent_Medium_value_payments       365.445059         Poor
# 61378                            !@9#%8       425.138356         Poor
# 61379   High_spent_Large_value_payments       440.143831     Standard
# 61381   High_spent_Large_value_payments       391.741304         Poor
# 61382    Low_spent_Small_value_payments       273.319589         Poor
# 61383   High_spent_Small_value_payments       374.600037         Poor
# 76872    Low_spent_Small_value_payments       336.324382     Standard
# 76873   High_spent_Large_value_payments       410.656754     Standard
# 76874  High_spent_Medium_value_payments       421.839814     Standard
# 76875    Low_spent_Large_value_payments       407.925166     Standard
# 76876   High_spent_Small_value_payments       416.734596     Standard
# 76878    Low_spent_Small_value_payments       296.401654     Standard
# 76879                            !@9#%8       364.518337     Standard
#
#        Num_of_loan2
# 16              3.0
# 18              3.0
# 19              3.0
# 20              3.0
# 21              3.0
# 23              3.0
# 11872           6.0
# 11873           6.0
# 11874           6.0
# 11875           6.0
# 11876           6.0
# 11877           6.0
# 11878           6.0
# 11879           6.0
# 44856           6.0
# 44857           6.0
# 44858           6.0
# 44859           6.0
# 44860           6.0
# 44861           6.0
# 44862           6.0
# 44863           6.0
# 53272           6.0
# 53273           6.0
# 53274           6.0
# 53275           6.0
# 53276           6.0
# 53277           6.0
# 53278           6.0
# 53279           6.0
# 61376           3.0
# 61377           3.0
# 61378           3.0
# 61379           3.0
# 61381           3.0
# 61382           3.0
# 61383           3.0
# 76872           0.0
# 76873           0.0
# 76874           0.0
# 76875           0.0
# 76876           0.0
# 76878           0.0
# 76879           0.0
#
# [44 rows x 29 columns]

# %%
df[df.Customer_ID == 'CUS_0xb11c']
# Out:
#             ID Customer_ID     Month            Name  Age          SSN  \
# 99928  0x25f86  CUS_0xb11c   January  Yinka Adegokej   38  546-94-4789
# 99929  0x25f87  CUS_0xb11c  February  Yinka Adegokej   38  546-94-4789
# 99930  0x25f88  CUS_0xb11c     March  Yinka Adegokej   38  546-94-4789
# 99931  0x25f89  CUS_0xb11c     April  Yinka Adegokej   38  546-94-4789
# 99932  0x25f8a  CUS_0xb11c       May  Yinka Adegokej   38  546-94-4789
# 99933  0x25f8b  CUS_0xb11c      June  Yinka Adegokej   38  546-94-4789
# 99934  0x25f8c  CUS_0xb11c      July  Yinka Adegokej   38  546-94-4789
# 99935  0x25f8d  CUS_0xb11c    August  Yinka Adegokej   38  546-94-4789
#
#       Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 99928    Manager       15319.65                    NaN                  6
# 99929    Manager       15319.65              1460.6375                  6
# 99930    Manager       15319.65              1460.6375                  6
# 99931    Manager       15319.65              1460.6375                  6
# 99932    Manager       15319.65              1460.6375                  6
# 99933    Manager       15319.65              1460.6375                  6
# 99934    Manager       15319.65              1460.6375                  6
# 99935    _______       15319.65              1460.6375                  6
#
#        ...  Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# 99928  ...           1453.61                 36.518222              10.90
# 99929  ...           1453.61                 39.705561              10.10
# 99930  ...           1453.61                 37.266724              10.11
# 99931  ...           1453.61                 34.243058              11.00
# 99932  ...           1453.61                 25.539990              11.10
# 99933  ...           1453.61                 24.846424              11.20
# 99934  ...           1453.61                 38.987835                NaN
# 99935  ...           1453.61                 34.557510              11.40
#
#       Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 99928                   Yes            28.182033               167.888435
# 99929                   Yes            28.182033               162.662497
# 99930                   Yes            28.182033                91.565818
# 99931                   Yes            28.182033                 0.000000
# 99932                   Yes            28.182033                89.757305
# 99933                   Yes            28.182033                45.611718
# 99934                   Yes            28.182033                70.241785
# 99935                   Yes            28.182033               191.877779
#
#                      Payment_Behaviour  Monthly_Balance Credit_Score  \
# 99928   Low_spent_Small_value_payments              NaN         Poor
# 99929   Low_spent_Small_value_payments              NaN         Poor
# 99930  Low_spent_Medium_value_payments              NaN         Poor
# 99931  High_spent_Large_value_payments              NaN     Standard
# 99932   Low_spent_Small_value_payments              NaN     Standard
# 99933  High_spent_Small_value_payments              NaN     Standard
# 99934   Low_spent_Large_value_payments              NaN         Poor
# 99935   Low_spent_Small_value_payments              NaN         Poor
#
#        Num_of_loan2
# 99928           4.0
# 99929           4.0
# 99930           4.0
# 99931           4.0
# 99932           4.0
# 99933           4.0
# 99934           4.0
# 99935           4.0
#
# [8 rows x 29 columns]

# %%
##create function
#customner ID of person who has ---- in occupation
#   check for other occupation of that same person
#   if not ---- then replace occupation else impute null

# customner ID of person who has --- or null or abnormal value
# them check for same id where not null or not ---- and fill value form there
import warnings
warnings.filterwarnings('ignore')

# %%
df[df.Occupation == '_______'].shape
# Out:
# (7024, 29)

# %% [raw]
# #for i in df.Customer_ID[df.Occupation == '_______']:
# #    for j in df.Occupation[(df.Customer_ID ==i) & (df.Occupation != '_______')]:
# #        df.Occupation[(df.Customer_ID == i) & (df.Occupation == '_______')] = j
#     #rint(i)

# %%
job=""
for i in df.Customer_ID[df.Occupation == '_______']:
    job = df.Occupation[(df.Customer_ID ==i) & (df.Occupation != '_______')].unique()
    df.Occupation[df.Customer_ID == i] = job 
    #rint(i)

# %%
#df.Occupation[df.Customer_ID == 'CUS_0x6649']
df.Occupation[(df.Customer_ID == 'CUS_0xbffe') & (df.Occupation != '_______')]
# Out:
# 224    Architect
# 225    Architect
# 226    Architect
# 227    Architect
# 228    Architect
# 229    Architect
# 230    Architect
# 231    Architect
# Name: Occupation, dtype: object

# %%
#job = df.Occupation[(df.Customer_ID == 'CUS_0x6649') & (df.Occupation != '_______')]
#job
df.Occupation[df.Customer_ID == 'CUS_0x6649']
# Out:
# 608    Mechanic
# 609    Mechanic
# 610    Mechanic
# 611    Mechanic
# 612    Mechanic
# 613    Mechanic
# 614    Mechanic
# 615    Mechanic
# Name: Occupation, dtype: object

# %%
Credit_Age = df[df.Credit_History_Age.isnull()]

# %%
df.loc[df.Name == 'Langep', ['Customer_ID','Month', 'Credit_History_Age']]
# Out:
#       Customer_ID     Month  Credit_History_Age
# 16     CUS_0x2dbc   January               17.90
# 18     CUS_0x2dbc     March               17.11
# 19     CUS_0x2dbc     April                 NaN
# 20     CUS_0x2dbc       May               18.10
# 21     CUS_0x2dbc      June               18.20
# 23     CUS_0x2dbc    August               18.40
# 11872  CUS_0xaf95   January                8.70
# 11873  CUS_0xaf95  February                8.80
# 11874  CUS_0xaf95     March                 NaN
# 11875  CUS_0xaf95     April                8.10
# 11876  CUS_0xaf95       May                8.11
# 11877  CUS_0xaf95      June                9.00
# 11878  CUS_0xaf95      July                9.10
# 11879  CUS_0xaf95    August                9.20
# 44856  CUS_0x109d   January                 NaN
# 44857  CUS_0x109d  February                6.00
# 44858  CUS_0x109d     March                6.10
# 44859  CUS_0x109d     April                6.20
# 44860  CUS_0x109d       May                6.30
# 44861  CUS_0x109d      June                6.40
# 44862  CUS_0x109d      July                6.50
# 44863  CUS_0x109d    August                6.60
# 53272  CUS_0x4854   January               13.70
# 53273  CUS_0x4854  February               13.80
# 53274  CUS_0x4854     March               13.90
# 53275  CUS_0x4854     April               13.10
# 53276  CUS_0x4854       May               13.11
# 53277  CUS_0x4854      June               14.00
# 53278  CUS_0x4854      July               14.10
# 53279  CUS_0x4854    August               14.20
# 61376  CUS_0xba1c   January               17.40
# 61377  CUS_0xba1c  February               17.50
# 61378  CUS_0xba1c     March               17.60
# 61379  CUS_0xba1c     April               17.70
# 61381  CUS_0xba1c      June               17.90
# 61382  CUS_0xba1c      July               17.10
# 61383  CUS_0xba1c    August               17.11
# 76872  CUS_0x7a96   January               22.20
# 76873  CUS_0x7a96  February               22.30
# 76874  CUS_0x7a96     March               22.40
# 76875  CUS_0x7a96     April               22.50
# 76876  CUS_0x7a96       May               22.60
# 76878  CUS_0x7a96      July               22.80
# 76879  CUS_0x7a96    August               22.90

# %%
df.loc[df.Name == 'Aaron Maashoh', ['Customer_ID','Month', 'Credit_History_Age']]
# Out:
#   Customer_ID     Month  Credit_History_Age
# 0   CUS_0xd40   January                22.1
# 1   CUS_0xd40  February                 NaN
# 2   CUS_0xd40     March                22.3
# 3   CUS_0xd40     April                22.4
# 4   CUS_0xd40       May                22.5
# 5   CUS_0xd40      June                22.6
# 6   CUS_0xd40      July                22.7

# %%
df.isnull().sum()
# Out:
# ID                              0
# Customer_ID                     0
# Month                           0
# Name                         9944
# Age                             0
# SSN                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary       14932
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                10930
# Delay_from_due_date             0
# Num_of_Delayed_Payment       6968
# Changed_Credit_Limit         2083
# Num_Credit_Inquiries         1954
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age           8993
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly      4451
# Payment_Behaviour               0
# Monthly_Balance              2856
# Credit_Score                    0
# Num_of_loan2                    0
# dtype: int64

# %%
df.Num_of_Delayed_Payment
# Out:
# 0        7.0
# 1        NaN
# 2        7.0
# 3        4.0
# 4        NaN
#         ...
# 99995    7.0
# 99996    7.0
# 99997    6.0
# 99998    NaN
# 99999    6.0
# Name: Num_of_Delayed_Payment, Length: 99522, dtype: float64

# %%
df.isnull().sum()
# Out:
# ID                              0
# Customer_ID                     0
# Month                           0
# Name                         9944
# Age                             0
# SSN                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary       14932
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                10930
# Delay_from_due_date             0
# Num_of_Delayed_Payment       6968
# Changed_Credit_Limit         2083
# Num_Credit_Inquiries         1954
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age           8993
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly      4451
# Payment_Behaviour               0
# Monthly_Balance              2856
# Credit_Score                    0
# Num_of_loan2                    0
# dtype: int64

# %%
# Credit_History_Age - Knn
# Num_of_Delayed_Payment, Num_Credit_Inquiry, Amount_Invested_Monthly, Monthly_Balance

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# ID                           0.000000
# Customer_ID                  0.000000
# Month                        0.000000
# Name                         9.991761
# Age                          0.000000
# SSN                          0.000000
# Occupation                   0.000000
# Annual_Income                0.000000
# Monthly_Inhand_Salary       15.003718
# Num_Bank_Accounts            0.000000
# Num_Credit_Card              0.000000
# Interest_Rate                0.000000
# Num_of_Loan                  0.000000
# Type_of_Loan                10.982496
# Delay_from_due_date          0.000000
# Num_of_Delayed_Payment       7.001467
# Changed_Credit_Limit         2.093005
# Num_Credit_Inquiries         1.963385
# Credit_Mix                   0.000000
# Outstanding_Debt             0.000000
# Credit_Utilization_Ratio     0.000000
# Credit_History_Age           9.036193
# Payment_of_Min_Amount        0.000000
# Total_EMI_per_month          0.000000
# Amount_invested_monthly      4.472378
# Payment_Behaviour            0.000000
# Monthly_Balance              2.869717
# Credit_Score                 0.000000
# Num_of_loan2                 0.000000
# dtype: float64

# %%
df.Credit_Utilization_Ratio.describe()
# Out:
# count    99522.000000
# mean        32.280320
# std          5.114569
# min         20.000000
# 25%         28.047791
# 50%         32.301553
# 75%         36.491825
# max         50.000000
# Name: Credit_Utilization_Ratio, dtype: float64

# %%
df.Credit_Mix.value_counts()
# Out:
# Standard    36285
# Good        24130
# _           20118
# Bad         18989
# Name: Credit_Mix, dtype: int64

# %%
# Checking for the garbage values and taking necessary steps to clean it

df.Payment_Behaviour.value_counts()
# Out:
# Low_spent_Small_value_payments      25439
# High_spent_Medium_value_payments    17457
# Low_spent_Medium_value_payments     13793
# High_spent_Large_value_payments     13626
# High_spent_Small_value_payments     11280
# Low_spent_Large_value_payments      10376
# !@9#%8                               7551
# Name: Payment_Behaviour, dtype: int64

# %%
df[df["Payment_Behaviour"]=="!@9#%8"]
# Out:
#             ID Customer_ID    Month            Name  Age          SSN  \
# 5       0x1607   CUS_0xd40     June   Aaron Maashoh   23  821-00-0265
# 16      0x161a  CUS_0x2dbc  January          Langep   34  486-85-3974
# 32      0x1632  CUS_0x1cdb  January          Deepaa   21  615-06-7821
# 47      0x1645  CUS_0x95ee   August              Np   31  612-70-8987
# 54      0x1650  CUS_0x284a     July          Nadiaq   34    #F%$D@*&8
# ...        ...         ...      ...             ...  ...          ...
# 99947  0x25fa1  CUS_0x51b3    April             NaN   33  837-85-9800
# 99980  0x25fd2  CUS_0xaf61      May  Chris Wickhamm   49  133-16-7738
# 99982  0x25fd4  CUS_0xaf61     July  Chris Wickhamm   50  133-16-7738
# 99989  0x25fdf  CUS_0x8600     June  Sarah McBridec   28  031-35-0942
# 99999  0x25fed  CUS_0x942c   August           Nicks   25  078-73-5990
#
#           Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 5          Scientist       19114.12                    NaN                  3
# 16          Engineer      143162.64           12187.220000                  1
# 32         Developer       35547.71            2853.309167                  7
# 47            Lawyer       73928.46            5988.705000                  4
# 54            Lawyer    10909427.00                    NaN                  0
# ...              ...            ...                    ...                ...
# 99947  Media_Manager       59146.36            4908.863333                  2
# 99980         Writer       37188.10            3097.008333                  1
# 99982         Writer       37188.10            3097.008333                  1
# 99989      Architect       20002.88            1929.906667                 10
# 99999       Mechanic       39628.99            3359.415833                  4
#
#        ...  Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# 5      ...            809.98                 27.262259               22.6
# 16     ...           1303.01                 28.616735               17.9
# 32     ...            943.86                 39.797764               30.8
# 47     ...            548.20                 31.580990               32.6
# 54     ...            352.16                 26.947565               31.1
# ...    ...               ...                       ...                ...
# 99947  ...            418.03                 28.091458               20.4
# 99980  ...            620.64                 27.495263               30.1
# 99982  ...            620.64                 38.850680               30.3
# 99989  ...           3571.70                 33.359987                6.1
# 99999  ...            502.38                 34.192463               31.1
#
#       Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 5                        No            49.574949                62.430172
# 16                       No           246.992319               168.413703
# 32                      Yes             0.000000               276.725394
# 47                       No             0.000000                42.635590
# 54                       No           911.220179               930.391898
# ...                     ...                  ...                      ...
# 99947                    No            26.778419               183.584149
# 99980                    No            84.205949                78.497727
# 99982                    No            84.205949                82.825572
# 99989                   Yes            60.964772                74.366603
# 99999                    No            35.104023               167.163865
#
#        Payment_Behaviour  Monthly_Balance Credit_Score  Num_of_loan2
# 5                 !@9#%8       340.479212         Good           4.0
# 16                !@9#%8      1043.315978         Good           3.0
# 32                !@9#%8       288.605522     Standard           0.0
# 47                !@9#%8       796.234910         Good           0.0
# 54                !@9#%8       326.241830         Good           2.0
# ...                  ...              ...          ...           ...
# 99947             !@9#%8              NaN     Standard           1.0
# 99980             !@9#%8              NaN     Standard           3.0
# 99982             !@9#%8              NaN         Good           3.0
# 99989             !@9#%8              NaN     Standard           5.0
# 99999             !@9#%8              NaN         Poor           2.0
#
# [7551 rows x 29 columns]

# %%
df[df["Customer_ID"]=="CUS_0x2dbc"]
# Out:
#         ID Customer_ID     Month    Name  Age          SSN Occupation  \
# 16  0x161a  CUS_0x2dbc   January  Langep   34  486-85-3974   Engineer
# 17  0x161b  CUS_0x2dbc  February     NaN   34  486-85-3974   Engineer
# 18  0x161c  CUS_0x2dbc     March  Langep   34  486-85-3974   Engineer
# 19  0x161d  CUS_0x2dbc     April  Langep   34  486-85-3974   Engineer
# 20  0x161e  CUS_0x2dbc       May  Langep   34  486-85-3974   Engineer
# 21  0x161f  CUS_0x2dbc      June  Langep   34  486-85-3974   Engineer
# 22  0x1620  CUS_0x2dbc      July     NaN   34  486-85-3974   Engineer
# 23  0x1621  CUS_0x2dbc    August  Langep   34  486-85-3974   Engineer
#
#     Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 16      143162.64               12187.22                  1  ...
# 17      143162.64               12187.22                  1  ...
# 18      143162.64                    NaN                  1  ...
# 19      143162.64               12187.22                  1  ...
# 20      143162.64               12187.22                  1  ...
# 21      143162.64               12187.22                  1  ...
# 22      143162.64               12187.22                  1  ...
# 23      143162.64               12187.22                  1  ...
#
#     Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# 16           1303.01                 28.616735              17.90
# 17           1303.01                 41.702573              17.10
# 18           1303.01                 26.519815              17.11
# 19           1303.01                 39.501648                NaN
# 20           1303.01                 31.376150              18.10
# 21           1303.01                 39.783993              18.20
# 22           1303.01                 38.068624              18.30
# 23           1303.01                 38.374753              18.40
#
#    Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 16                    No           246.992319               168.413703
# 17                    No           246.992319               232.860384
# 18                    No           246.992319             10000.000000
# 19                    No           246.992319               825.216270
# 20                    No           246.992319               430.947528
# 21                    No           246.992319               257.808099
# 22                    No           246.992319               263.174163
# 23                    No           246.992319             10000.000000
#
#                    Payment_Behaviour  Monthly_Balance Credit_Score  \
# 16                            !@9#%8      1043.315978         Good
# 17   High_spent_Small_value_payments       998.869297         Good
# 18   High_spent_Small_value_payments       715.741367         Good
# 19   Low_spent_Medium_value_payments       426.513411         Good
# 20    Low_spent_Large_value_payments       810.782153         Good
# 21  High_spent_Medium_value_payments       963.921581         Good
# 22   High_spent_Small_value_payments       968.555517     Standard
# 23   High_spent_Small_value_payments       895.494583     Standard
#
#     Num_of_loan2
# 16           3.0
# 17           3.0
# 18           3.0
# 19           3.0
# 20           3.0
# 21           3.0
# 22           3.0
# 23           3.0
#
# [8 rows x 29 columns]

# %%
#df[df["Customer_ID"]=="CUS_0x1cdb"]
df.loc[df.Customer_ID == 'CUS_0x1cdb', ['Customer_ID','Credit_Utilization_Ratio', 'Credit_Mix',"Payment_Behaviour"]]

# Trying to find pattern in order to fill the garbage value in Payment_Behaviour columns "!@9#%8"
# Out:
#    Customer_ID  Credit_Utilization_Ratio Credit_Mix  \
# 32  CUS_0x1cdb                 39.797764   Standard
# 33  CUS_0x1cdb                 27.020360   Standard
# 35  CUS_0x1cdb                 28.924954          _
# 36  CUS_0x1cdb                 41.776187          _
# 37  CUS_0x1cdb                 29.217556   Standard
# 38  CUS_0x1cdb                 26.263823   Standard
#
#                    Payment_Behaviour
# 32                            !@9#%8
# 33  High_spent_Medium_value_payments
# 35  High_spent_Medium_value_payments
# 36   High_spent_Small_value_payments
# 37  High_spent_Medium_value_payments
# 38    Low_spent_Small_value_payments

# %%
#df[df["Customer_ID"]=="CUS_0x95ee"]
df.loc[df.Customer_ID == 'CUS_0x95ee', ['Customer_ID','Credit_Utilization_Ratio', 'Credit_Mix',"Payment_Behaviour"]]
# Out:
#    Customer_ID  Credit_Utilization_Ratio Credit_Mix  \
# 40  CUS_0x95ee                 39.962685       Good
# 41  CUS_0x95ee                 42.769864       Good
# 42  CUS_0x95ee                 40.712187       Good
# 43  CUS_0x95ee                 30.201658       Good
# 44  CUS_0x95ee                 26.333310          _
# 45  CUS_0x95ee                 35.275437       Good
# 46  CUS_0x95ee                 36.624791          _
# 47  CUS_0x95ee                 31.580990       Good
#
#                    Payment_Behaviour
# 40   High_spent_Large_value_payments
# 41   Low_spent_Medium_value_payments
# 42  High_spent_Medium_value_payments
# 43    Low_spent_Small_value_payments
# 44    Low_spent_Large_value_payments
# 45    Low_spent_Large_value_payments
# 46   High_spent_Small_value_payments
# 47                            !@9#%8

# %%
df.Payment_Behaviour.value_counts(normalize=True)
# Out:
# Low_spent_Small_value_payments      0.255612
# High_spent_Medium_value_payments    0.175408
# Low_spent_Medium_value_payments     0.138592
# High_spent_Large_value_payments     0.136914
# High_spent_Small_value_payments     0.113342
# Low_spent_Large_value_payments      0.104258
# !@9#%8                              0.075873
# Name: Payment_Behaviour, dtype: float64

# %%
pb = ""
for i in df.Customer_ID[df["Payment_Behaviour"]=="!@9#%8"]:
    pb = df.Payment_Behaviour[df["Customer_ID"] ==i].mode()[0]
    df.Payment_Behaviour[(df["Customer_ID"] == i) & (df["Payment_Behaviour"]=="!@9#%8")] = pb

# %%
# Successfully imputed the garbage values inside the Payment_Behaviour column

df.Payment_Behaviour.value_counts(normalize= True)
# Out:
# Low_spent_Small_value_payments      0.275437
# High_spent_Medium_value_payments    0.189074
# High_spent_Large_value_payments     0.148791
# Low_spent_Medium_value_payments     0.144149
# High_spent_Small_value_payments     0.117612
# Low_spent_Large_value_payments      0.107695
# !@9#%8                              0.017242
# Name: Payment_Behaviour, dtype: float64

# %%
#now the left value will be filled with mode of all the given value( As the garbage value is just 1.7%)

# %%
df.Payment_Behaviour[df["Payment_Behaviour"]=="!@9#%8"] = df.Payment_Behaviour.mode()[0]

# %%
pd.set_option('display.max_columns', None)

# %%
df.Payment_Behaviour.value_counts(normalize= True)
# Out:
# Low_spent_Small_value_payments      0.292679
# High_spent_Medium_value_payments    0.189074
# High_spent_Large_value_payments     0.148791
# Low_spent_Medium_value_payments     0.144149
# High_spent_Small_value_payments     0.117612
# Low_spent_Large_value_payments      0.107695
# Name: Payment_Behaviour, dtype: float64

# %%
df.Credit_Mix.value_counts()
# Out:
# Standard    36285
# Good        24130
# _           20118
# Bad         18989
# Name: Credit_Mix, dtype: int64

# %%
df.tail()
# Out:
#             ID Customer_ID   Month   Name  Age          SSN Occupation  \
# 99995  0x25fe9  CUS_0x942c   April  Nicks   25  078-73-5990   Mechanic
# 99996  0x25fea  CUS_0x942c     May  Nicks   25  078-73-5990   Mechanic
# 99997  0x25feb  CUS_0x942c    June  Nicks   25  078-73-5990   Mechanic
# 99998  0x25fec  CUS_0x942c    July  Nicks   25  078-73-5990   Mechanic
# 99999  0x25fed  CUS_0x942c  August  Nicks   25  078-73-5990   Mechanic
#
#        Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 99995       39628.99            3359.415833                  4
# 99996       39628.99            3359.415833                  4
# 99997       39628.99            3359.415833                  4
# 99998       39628.99            3359.415833                  4
# 99999       39628.99            3359.415833                  4
#
#        Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 99995                6              7           2
# 99996                6              7           2
# 99997                6           5729           2
# 99998                6              7           2
# 99999                6              7           2
#
#                       Type_of_Loan  Delay_from_due_date  \
# 99995  Auto Loan, and Student Loan                   23
# 99996  Auto Loan, and Student Loan                   18
# 99997  Auto Loan, and Student Loan                   27
# 99998  Auto Loan, and Student Loan                   20
# 99999  Auto Loan, and Student Loan                   18
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 99995                     7.0                  11.5                   3.0
# 99996                     7.0                  11.5                   3.0
# 99997                     6.0                  11.5                   3.0
# 99998                     NaN                  11.5                   3.0
# 99999                     6.0                  11.5                   3.0
#
#       Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 99995          _            502.38                 34.663572
# 99996          _            502.38                 40.565631
# 99997       Good            502.38                 41.255522
# 99998       Good            502.38                 33.638208
# 99999       Good            502.38                 34.192463
#
#        Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 99995                31.6                    No            35.104023
# 99996                31.7                    No            35.104023
# 99997                31.8                    No            35.104023
# 99998                31.9                    No            35.104023
# 99999                31.1                    No            35.104023
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 99995                60.971333   High_spent_Large_value_payments
# 99996                54.185950  High_spent_Medium_value_payments
# 99997                24.028477   High_spent_Large_value_payments
# 99998               251.672582    Low_spent_Large_value_payments
# 99999               167.163865   High_spent_Large_value_payments
#
#        Monthly_Balance Credit_Score  Num_of_loan2
# 99995              NaN         Poor           2.0
# 99996              NaN         Poor           2.0
# 99997              NaN         Poor           2.0
# 99998              NaN     Standard           2.0
# 99999              NaN         Poor           2.0

# %%
df.Credit_Mix.value_counts()
# Out:
# Standard    36285
# Good        24130
# _           20118
# Bad         18989
# Name: Credit_Mix, dtype: int64

# %%
df.Credit_Mix.value_counts(normalize=True)
# Out:
# Standard    0.364593
# Good        0.242459
# _           0.202146
# Bad         0.190802
# Name: Credit_Mix, dtype: float64

# %%
# Treating the garbage value in Credit_Mix columnn ("_")

cm = ""
for i in df.Customer_ID[df["Credit_Mix"]=="_"]:
    cm = df.Credit_Mix[df.Customer_ID == i].mode()[0]
    df.Credit_Mix[(df["Customer_ID"] == i) & (df["Credit_Mix"]=="_")] = cm

# %%
df.Credit_Mix.value_counts(normalize= True)
# Out:
# Standard    0.454633
# Good        0.301039
# Bad         0.237184
# _           0.007144
# Name: Credit_Mix, dtype: float64

# %%
 df.Credit_Mix[df["Credit_Mix"]=="_"] =  df.Credit_Mix.mode()[0]

# %%
df.Credit_Mix.value_counts(normalize= True)
# Out:
# Standard    0.461777
# Good        0.301039
# Bad         0.237184
# Name: Credit_Mix, dtype: float64

# %%
df.isnull().sum()
# Out:
# ID                              0
# Customer_ID                     0
# Month                           0
# Name                         9944
# Age                             0
# SSN                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary       14932
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                10930
# Delay_from_due_date             0
# Num_of_Delayed_Payment       6968
# Changed_Credit_Limit         2083
# Num_Credit_Inquiries         1954
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age           8993
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly      4451
# Payment_Behaviour               0
# Monthly_Balance              2856
# Credit_Score                    0
# Num_of_loan2                    0
# dtype: int64

# %%
#now we fix missing values
df.Amount_invested_monthly
# Out:
# 0         80.415295
# 1        118.280222
# 2         81.699521
# 3        199.458074
# 4         41.420153
#             ...
# 99995     60.971333
# 99996     54.185950
# 99997     24.028477
# 99998    251.672582
# 99999    167.163865
# Name: Amount_invested_monthly, Length: 99522, dtype: float64

# %%
#we will fill it by knnimputer or deleting

# %%
df.Monthly_Balance.value_counts()
# Out:
# -3.333333e+26    9
#  3.124941e+02    1
#  4.865402e+02    1
#  4.625841e+02    1
#  4.272824e+02    1
#                 ..
#  2.465517e+02    1
#  3.548036e+02    1
#  2.584044e+02    1
#  2.012762e+02    1
#  2.146149e+02    1
# Name: Monthly_Balance, Length: 96658, dtype: int64

# %%
#df[(df.Monthly_Balance.isnull()) & (df.Customer_ID == 'CUS_0x942c')]
# we will fill this with KNNimputer

# %%
df[df.Num_Credit_Inquiries.isnull()].head()
#KNN imputer and no has no garbeage
# Out:
#          ID Customer_ID     Month       Name  Age          SSN    Occupation  \
# 18   0x161c  CUS_0x2dbc     March     Langep   34  486-85-3974      Engineer
# 47   0x1645  CUS_0x95ee    August         Np   31  612-70-8987        Lawyer
# 113  0x16ab   CUS_0xff4  February        NaN  500  655-05-7666  Entrepreneur
# 115  0x16ad   CUS_0xff4     April  Poornimaf   37  655-05-7666  Entrepreneur
# 187  0x1719  CUS_0x5b48     April        NaN   32  706-95-0150        Lawyer
#
#      Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 18      143162.640                    NaN                  1                5
# 47       73928.460            5988.705000                  4                5
# 113      25546.260                    NaN                  8                7
# 115      25546.260            2415.855000                  8                7
# 187      12600.445             782.037083                  5                5
#
#      Interest_Rate Num_of_Loan  \
# 18               8           3
# 47               8           0
# 113             14           5
# 115             14           5
# 187             10           3
#
#                                           Type_of_Loan  Delay_from_due_date  \
# 18             Auto Loan, Auto Loan, and Not Specified                    8
# 47                                                 NaN                    8
# 113  Not Specified, Student Loan, Student Loan, Cre...                   16
# 115  Not Specified, Student Loan, Student Loan, Cre...                   16
# 187      Not Specified, Student Loan, and Student Loan                   25
#
#      Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 18                      7.0                 11.10                   NaN
# 47                      7.0                 10.14                   NaN
# 113                    13.0                  7.83                   NaN
# 115                    10.0                  7.83                   NaN
# 187                    18.0                 15.79                   NaN
#
#     Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 18        Good           1303.01                 26.519815
# 47        Good            548.20                 31.580990
# 113   Standard            758.44                 29.711376
# 115   Standard            758.44                 35.946278
# 187   Standard            569.80                 28.819407
#
#      Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 18                17.11                    No           246.992319
# 47                32.60                    No             0.000000
# 113               18.30                   Yes           101.328637
# 115               18.50                   Yes           101.328637
# 187               12.60                   Yes         33746.000000
#
#      Amount_invested_monthly                 Payment_Behaviour  \
# 18              10000.000000   High_spent_Small_value_payments
# 47                 42.635590    Low_spent_Large_value_payments
# 113               300.323232    Low_spent_Small_value_payments
# 115                83.714750  High_spent_Medium_value_payments
# 187                31.149198   Low_spent_Medium_value_payments
#
#      Monthly_Balance Credit_Score  Num_of_loan2
# 18        715.741367         Good           3.0
# 47        796.234910         Good           0.0
# 113       129.933631     Standard           5.0
# 115       306.542112     Standard           5.0
# 187       300.994163         Poor           3.0

# %%
df.isnull().sum()
# Out:
# ID                              0
# Customer_ID                     0
# Month                           0
# Name                         9944
# Age                             0
# SSN                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary       14932
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                10930
# Delay_from_due_date             0
# Num_of_Delayed_Payment       6968
# Changed_Credit_Limit         2083
# Num_Credit_Inquiries         1954
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age           8993
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly      4451
# Payment_Behaviour               0
# Monthly_Balance              2856
# Credit_Score                    0
# Num_of_loan2                    0
# dtype: int64

# %%
df[df.Num_of_Delayed_Payment.isnull()]
# Out:
#             ID Customer_ID     Month            Name  Age          SSN  \
# 1       0x1603   CUS_0xd40  February   Aaron Maashoh   23  821-00-0265
# 4       0x1606   CUS_0xd40       May   Aaron Maashoh   23  821-00-0265
# 30      0x162c  CUS_0xb891      July          Jasond   55  072-31-6145
# 32      0x1632  CUS_0x1cdb   January          Deepaa   21  615-06-7821
# 33      0x1633  CUS_0x1cdb  February          Deepaa   21  615-06-7821
# ...        ...         ...       ...             ...  ...          ...
# 99973  0x25fc7   CUS_0xf16      June             NaN   45  868-70-2218
# 99974  0x25fc8   CUS_0xf16      July  Maria Sheahanb   45  868-70-2218
# 99992  0x25fe6  CUS_0x942c   January           Nicks   24  078-73-5990
# 99993  0x25fe7  CUS_0x942c  February           Nicks   25  078-73-5990
# 99998  0x25fec  CUS_0x942c      July           Nicks   25  078-73-5990
#
#           Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 1          Scientist       19114.12                    NaN                  3
# 4          Scientist       19114.12            1824.843333                  3
# 30      Entrepreneur       30689.89            2612.490833                  2
# 32         Developer       35547.71            2853.309167                  7
# 33         Developer       35547.71                    NaN                  7
# ...              ...            ...                    ...                ...
# 99973  Media_Manager       16680.35            1528.029167                  1
# 99974  Media_Manager       16680.35            1528.029167                  1
# 99992       Mechanic       39628.99            3359.415833                  4
# 99993       Mechanic       39628.99            3359.415833                  4
# 99998       Mechanic       39628.99            3359.415833                  4
#
#        Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 1                    4              3           4
# 4                    4              3           4
# 30                   5              4           1
# 32                   5              5           0
# 33                   5              5           0
# ...                ...            ...         ...
# 99973                1              5           4
# 99974                1              5           4
# 99992                6              7           2
# 99993                6              7           2
# 99998                6              7           2
#
#                                             Type_of_Loan  Delay_from_due_date  \
# 1      Auto Loan, Credit-Builder Loan, Personal Loan,...                   -1
# 4      Auto Loan, Credit-Builder Loan, Personal Loan,...                    6
# 30                                         Not Specified                    5
# 32                                                   NaN                    5
# 33                                                   NaN                    9
# ...                                                  ...                  ...
# 99973  Payday Loan, Student Loan, Mortgage Loan, and ...                    1
# 99974  Payday Loan, Student Loan, Mortgage Loan, and ...                    1
# 99992                        Auto Loan, and Student Loan                   23
# 99993                        Auto Loan, and Student Loan                   23
# 99998                        Auto Loan, and Student Loan                   20
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 1                         NaN                 11.27                   4.0
# 4                         NaN                 11.27                   4.0
# 30                        NaN                  1.99                   4.0
# 32                        NaN                  2.58                   4.0
# 33                        NaN                  2.58                   4.0
# ...                       ...                   ...                   ...
# 99973                     NaN                  0.69                   8.0
# 99974                     NaN                 11.69                   8.0
# 99992                     NaN                  9.50                   3.0
# 99993                     NaN                 11.50                   3.0
# 99998                     NaN                 11.50                   3.0
#
#       Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 1           Good            809.98                 31.944960
# 4           Good            809.98                 24.797347
# 30          Good            632.46                 26.056395
# 32      Standard            943.86                 39.797764
# 33      Standard            943.86                 27.020360
# ...          ...               ...                       ...
# 99973       Good            897.16                 24.972853
# 99974       Good            897.16                 36.166925
# 99992       Good            502.38                 32.991333
# 99993       Good            502.38                 29.135447
# 99998       Good            502.38                 33.638208
#
#        Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 1                     NaN                    No            49.574949
# 4                    22.5                    No            49.574949
# 30                   17.9                    No            16.415452
# 32                   30.8                   Yes             0.000000
# 33                   30.9                    NM             0.000000
# ...                   ...                   ...                  ...
# 99973                21.6                    No            41.113561
# 99974                21.7                    No            41.113561
# 99992                31.3                    No            35.104023
# 99993                31.4                    No         58638.000000
# 99998                31.9                    No            35.104023
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 1                   118.280222    Low_spent_Large_value_payments
# 4                    41.420153  High_spent_Medium_value_payments
# 30                   71.283675    Low_spent_Large_value_payments
# 32                  276.725394  High_spent_Medium_value_payments
# 33                   74.443641  High_spent_Medium_value_payments
# ...                        ...                               ...
# 99973             10000.000000    Low_spent_Small_value_payments
# 99974                      NaN    Low_spent_Small_value_payments
# 99992               401.196481    Low_spent_Small_value_payments
# 99993               180.733095   Low_spent_Medium_value_payments
# 99998               251.672582    Low_spent_Large_value_payments
#
#        Monthly_Balance Credit_Score  Num_of_loan2
# 1           284.629162         Good           4.0
# 4           341.489231         Good           4.0
# 30          443.549957     Standard           1.0
# 32          288.605522     Standard           0.0
# 33          460.887276     Standard           0.0
# ...                ...          ...           ...
# 99973              NaN         Good           4.0
# 99974              NaN         Good           4.0
# 99992              NaN         Poor           2.0
# 99993              NaN     Standard           2.0
# 99998              NaN     Standard           2.0
#
# [6968 rows x 29 columns]

# %%
df[df.Credit_History_Age.isnull()]
#it has no garbage value only missing so do knn imputer
# Out:
#             ID Customer_ID     Month             Name  Age          SSN  \
# 1       0x1603   CUS_0xd40  February    Aaron Maashoh   23  821-00-0265
# 7       0x1609   CUS_0xd40    August              NaN   23    #F%$D@*&8
# 19      0x161d  CUS_0x2dbc     April           Langep   34  486-85-3974
# 40      0x163e  CUS_0x95ee   January               Np   31  612-70-8987
# 42      0x1640  CUS_0x95ee     March               Np   31  612-70-8987
# ...        ...         ...       ...              ...  ...          ...
# 99944  0x25f9e  CUS_0x51b3   January            Ryana   33  837-85-9800
# 99963  0x25fb9  CUS_0x372c     April  Lucia Mutikanik  500  340-85-7301
# 99968  0x25fc2   CUS_0xf16   January   Maria Sheahanb   44    #F%$D@*&8
# 99975  0x25fc9   CUS_0xf16    August   Maria Sheahanb   45  868-70-2218
# 99990  0x25fe0  CUS_0x8600      July   Sarah McBridec   28  031-35-0942
#
#           Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 1          Scientist       19114.12                    NaN                  3
# 7          Scientist       19114.12            1824.843333                  3
# 19          Engineer      143162.64           12187.220000                  1
# 40            Lawyer       73928.46                    NaN                  4
# 42            Lawyer       73928.46            5988.705000                  4
# ...              ...            ...                    ...                ...
# 99944  Media_Manager       59146.36                    NaN                  2
# 99963         Lawyer       42903.79                    NaN                  0
# 99968  Media_Manager       16680.35            1528.029167                  1
# 99975  Media_Manager       16680.35                    NaN                  1
# 99990      Architect       20002.88            1929.906667                 10
#
#        Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 1                    4              3           4
# 7                    4              3           4
# 19                   5              8           3
# 40                1288              8           0
# 42                   5              8           0
# ...                ...            ...         ...
# 99944                5              6           1
# 99963                4              6           1
# 99968                1              5           4
# 99975                1              5           4
# 99990                8             29           5
#
#                                             Type_of_Loan  Delay_from_due_date  \
# 1      Auto Loan, Credit-Builder Loan, Personal Loan,...                   -1
# 7      Auto Loan, Credit-Builder Loan, Personal Loan,...                    3
# 19               Auto Loan, Auto Loan, and Not Specified                    8
# 40                                                   NaN                   12
# 42                                                   NaN                    8
# ...                                                  ...                  ...
# 99944                                      Personal Loan                    8
# 99963                                      Not Specified                   14
# 99968  Payday Loan, Student Loan, Mortgage Loan, and ...                    4
# 99975  Payday Loan, Student Loan, Mortgage Loan, and ...                    1
# 99990  Personal Loan, Auto Loan, Mortgage Loan, Stude...                   33
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 1                         NaN                 11.27                   4.0
# 7                         6.0                 11.27                   4.0
# 19                        5.0                  9.10                   3.0
# 40                       10.0                 10.14                   2.0
# 42                        7.0                 10.14                   2.0
# ...                       ...                   ...                   ...
# 99944                     6.0                  6.68                   2.0
# 99963                     0.0                  5.10                   1.0
# 99968                     0.0                  5.69                   4.0
# 99975                     0.0                  5.69                   8.0
# 99990                    26.0                 18.31                   9.0
#
#       Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 1           Good            809.98                 31.944960
# 7           Good            809.98                 23.933795
# 19          Good           1303.01                 39.501648
# 40          Good            548.20                 39.962685
# 42          Good            548.20                 40.712187
# ...          ...               ...                       ...
# 99944       Good            418.03                 34.720661
# 99963       Good           1079.48                 30.625298
# 99968       Good            897.16                 39.868572
# 99975       Good            897.16                 41.212367
# 99990        Bad           3571.70                 25.123535
#
#        Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 1                     NaN                    No            49.574949
# 7                     NaN                    No            49.574949
# 19                    NaN                    No           246.992319
# 40                    NaN                    No         15015.000000
# 42                    NaN                    No             0.000000
# ...                   ...                   ...                  ...
# 99944                 NaN                    No            26.778419
# 99963                 NaN                    No            34.975457
# 99968                 NaN                    NM            41.113561
# 99975                 NaN                    No            41.113561
# 99990                 NaN                   Yes            60.964772
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 1                   118.280222    Low_spent_Large_value_payments
# 7                    24.785217  High_spent_Medium_value_payments
# 19                  825.216270   Low_spent_Medium_value_payments
# 40                   98.674410   High_spent_Large_value_payments
# 42                  150.059734  High_spent_Medium_value_payments
# ...                        ...                               ...
# 99944               606.436542    Low_spent_Small_value_payments
# 99963                31.193919   High_spent_Large_value_payments
# 99968                52.951978   High_spent_Small_value_payments
# 99975                70.805550    Low_spent_Large_value_payments
# 99990               173.275503    Low_spent_Large_value_payments
#
#        Monthly_Balance Credit_Score  Num_of_loan2
# 1           284.629162         Good           4.0
# 7           358.124168     Standard           4.0
# 19          426.513411         Good           3.0
# 40          740.196090         Good           0.0
# 42          698.810766         Good           0.0
# ...                ...          ...           ...
# 99944              NaN     Standard           1.0
# 99963              NaN     Standard           1.0
# 99968              NaN         Good           4.0
# 99975              NaN         Good           4.0
# 99990              NaN     Standard           5.0
#
# [8993 rows x 29 columns]

# %%
df.Customer_ID.nunique()
# Out:
# 12500

# %%
df.ID.nunique()
# Out:
# 99522

# %%
df.Outstanding_Debt.value_counts()
# Out:
# 1151.70    24
# 1109.03    24
# 460.46     24
# 1360.45    24
# 217.92     16
#            ..
# 39.68       6
# 80.09       6
# 936.59      5
# 581.67      5
# 1041.07     5
# Name: Outstanding_Debt, Length: 12203, dtype: int64

# %%
df.Changed_Credit_Limit.value_counts()
# Out:
#  8.22     133
#  11.50    126
#  11.32    126
#  10.06    121
#  7.35     120
#          ...
#  0.86       1
# -4.65       1
#  25.46      1
#  0.68       1
#  21.17      1
# Name: Changed_Credit_Limit, Length: 4380, dtype: int64

# %%
df.Changed_Credit_Limit = np.round(df.Changed_Credit_Limit,2)

# %%
df.Changed_Credit_Limit.isnull().sum()
#we will impute this using KNN imputer
# Out:
# 2083

# %%
#now we will drop the unnecessary and redundant columns

# %%
df.isnull().sum()
df.drop(['Name','Monthly_Inhand_Salary','Num_of_Loan','Type_of_Loan','ID','SSN'],axis = 1,inplace= True)

# %%
df.Num_of_loan2.isnull().sum()
# Out:
# 0

# %%
df.select_dtypes(include= np.number)
# Out:
#        Age  Annual_Income  Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  \
# 0       23       19114.12                  3                4              3
# 1       23       19114.12                  3                4              3
# 2      500       19114.12                  3                4              3
# 3       23       19114.12                  3                4              3
# 4       23       19114.12                  3                4              3
# ...    ...            ...                ...              ...            ...
# 99995   25       39628.99                  4                6              7
# 99996   25       39628.99                  4                6              7
# 99997   25       39628.99                  4                6           5729
# 99998   25       39628.99                  4                6              7
# 99999   25       39628.99                  4                6              7
#
#        Delay_from_due_date  Num_of_Delayed_Payment  Changed_Credit_Limit  \
# 0                        3                     7.0                 11.27
# 1                       -1                     NaN                 11.27
# 2                        3                     7.0                   NaN
# 3                        5                     4.0                  6.27
# 4                        6                     NaN                 11.27
# ...                    ...                     ...                   ...
# 99995                   23                     7.0                 11.50
# 99996                   18                     7.0                 11.50
# 99997                   27                     6.0                 11.50
# 99998                   20                     NaN                 11.50
# 99999                   18                     6.0                 11.50
#
#        Num_Credit_Inquiries  Outstanding_Debt  Credit_Utilization_Ratio  \
# 0                       4.0            809.98                 26.822620
# 1                       4.0            809.98                 31.944960
# 2                       4.0            809.98                 28.609352
# 3                       4.0            809.98                 31.377862
# 4                       4.0            809.98                 24.797347
# ...                     ...               ...                       ...
# 99995                   3.0            502.38                 34.663572
# 99996                   3.0            502.38                 40.565631
# 99997                   3.0            502.38                 41.255522
# 99998                   3.0            502.38                 33.638208
# 99999                   3.0            502.38                 34.192463
#
#        Credit_History_Age  Total_EMI_per_month  Amount_invested_monthly  \
# 0                    22.1            49.574949                80.415295
# 1                     NaN            49.574949               118.280222
# 2                    22.3            49.574949                81.699521
# 3                    22.4            49.574949               199.458074
# 4                    22.5            49.574949                41.420153
# ...                   ...                  ...                      ...
# 99995                31.6            35.104023                60.971333
# 99996                31.7            35.104023                54.185950
# 99997                31.8            35.104023                24.028477
# 99998                31.9            35.104023               251.672582
# 99999                31.1            35.104023               167.163865
#
#        Monthly_Balance  Num_of_loan2
# 0           312.494089           4.0
# 1           284.629162           4.0
# 2           331.209863           4.0
# 3           223.451310           4.0
# 4           341.489231           4.0
# ...                ...           ...
# 99995              NaN           2.0
# 99996              NaN           2.0
# 99997              NaN           2.0
# 99998              NaN           2.0
# 99999              NaN           2.0
#
# [99522 rows x 16 columns]

# %%
df.select_dtypes(include= object)
# Out:
#       Customer_ID     Month Occupation Credit_Mix Payment_of_Min_Amount  \
# 0       CUS_0xd40   January  Scientist       Good                    No
# 1       CUS_0xd40  February  Scientist       Good                    No
# 2       CUS_0xd40     March  Scientist       Good                    No
# 3       CUS_0xd40     April  Scientist       Good                    No
# 4       CUS_0xd40       May  Scientist       Good                    No
# ...           ...       ...        ...        ...                   ...
# 99995  CUS_0x942c     April   Mechanic       Good                    No
# 99996  CUS_0x942c       May   Mechanic       Good                    No
# 99997  CUS_0x942c      June   Mechanic       Good                    No
# 99998  CUS_0x942c      July   Mechanic       Good                    No
# 99999  CUS_0x942c    August   Mechanic       Good                    No
#
#                       Payment_Behaviour Credit_Score
# 0       High_spent_Small_value_payments         Good
# 1        Low_spent_Large_value_payments         Good
# 2       Low_spent_Medium_value_payments         Good
# 3        Low_spent_Small_value_payments         Good
# 4      High_spent_Medium_value_payments         Good
# ...                                 ...          ...
# 99995   High_spent_Large_value_payments         Poor
# 99996  High_spent_Medium_value_payments         Poor
# 99997   High_spent_Large_value_payments         Poor
# 99998    Low_spent_Large_value_payments     Standard
# 99999   High_spent_Large_value_payments         Poor
#
# [99522 rows x 7 columns]

# %%
df.isnull().sum()
#all these null values will be filled with KNN imputer after all the absurd or junk values are dealt with
# Out:
# Customer_ID                    0
# Month                          0
# Age                            0
# Occupation                     0
# Annual_Income                  0
# Num_Bank_Accounts              0
# Num_Credit_Card                0
# Interest_Rate                  0
# Delay_from_due_date            0
# Num_of_Delayed_Payment      6968
# Changed_Credit_Limit        2083
# Num_Credit_Inquiries        1954
# Credit_Mix                     0
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Credit_History_Age          8993
# Payment_of_Min_Amount          0
# Total_EMI_per_month            0
# Amount_invested_monthly     4451
# Payment_Behaviour              0
# Monthly_Balance             2856
# Credit_Score                   0
# Num_of_loan2                   0
# dtype: int64

# %%
df.head()
# Out:
#   Customer_ID     Month  Age Occupation  Annual_Income  Num_Bank_Accounts  \
# 0   CUS_0xd40   January   23  Scientist       19114.12                  3
# 1   CUS_0xd40  February   23  Scientist       19114.12                  3
# 2   CUS_0xd40     March  500  Scientist       19114.12                  3
# 3   CUS_0xd40     April   23  Scientist       19114.12                  3
# 4   CUS_0xd40       May   23  Scientist       19114.12                  3
#
#    Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 0                4              3                    3
# 1                4              3                   -1
# 2                4              3                    3
# 3                4              3                    5
# 4                4              3                    6
#
#    Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 0                     7.0                 11.27                   4.0
# 1                     NaN                 11.27                   4.0
# 2                     7.0                   NaN                   4.0
# 3                     4.0                  6.27                   4.0
# 4                     NaN                 11.27                   4.0
#
#   Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 0       Good            809.98                 26.822620                22.1
# 1       Good            809.98                 31.944960                 NaN
# 2       Good            809.98                 28.609352                22.3
# 3       Good            809.98                 31.377862                22.4
# 4       Good            809.98                 24.797347                22.5
#
#   Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 0                    No            49.574949                80.415295
# 1                    No            49.574949               118.280222
# 2                    No            49.574949                81.699521
# 3                    No            49.574949               199.458074
# 4                    No            49.574949                41.420153
#
#                   Payment_Behaviour  Monthly_Balance Credit_Score  \
# 0   High_spent_Small_value_payments       312.494089         Good
# 1    Low_spent_Large_value_payments       284.629162         Good
# 2   Low_spent_Medium_value_payments       331.209863         Good
# 3    Low_spent_Small_value_payments       223.451310         Good
# 4  High_spent_Medium_value_payments       341.489231         Good
#
#    Num_of_loan2
# 0           4.0
# 1           4.0
# 2           4.0
# 3           4.0
# 4           4.0

# %%
df.Monthly_Balance.value_counts()
# Out:
# -3.333333e+26    9
#  3.124941e+02    1
#  4.865402e+02    1
#  4.625841e+02    1
#  4.272824e+02    1
#                 ..
#  2.465517e+02    1
#  3.548036e+02    1
#  2.584044e+02    1
#  2.012762e+02    1
#  2.146149e+02    1
# Name: Monthly_Balance, Length: 96658, dtype: int64

# %%
cat_cols = ['Customer_ID','Month','Occupation','Credit_Mix','Payment_of_Min_Amount','Payment_Behaviour','Credit_Score',
            'Num_Bank_Accounts','Num_Credit_Card','Interest_Rate','Num_of_Delayed_Payment','Num_Credit_Inquiries',
           'Num_of_loan2']

# %%
num_cols = ['Age', 'Annual_Income', 'Delay_from_due_date','Changed_Credit_Limit','Outstanding_Debt',
           'Credit_Utilization_Ratio', 'Credit_History_Age', 'Total_EMI_per_month',
           'Amount_invested_monthly', 'Monthly_Balance']

# %%
df.Monthly_Balance[df.Monthly_Balance < 0] = np.nan

# %%
##KNN imputer to fill num values

sc = StandardScaler()

# %%
scaled_data = pd.DataFrame(sc.fit_transform(df[num_cols]),columns = num_cols)    

scaled_data.isnull().sum()
# Out:
# Age                            0
# Annual_Income                  0
# Delay_from_due_date            0
# Changed_Credit_Limit        2083
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Credit_History_Age          8993
# Total_EMI_per_month            0
# Amount_invested_monthly     4451
# Monthly_Balance             2865
# dtype: int64

# %%
scaled_data.Monthly_Balance.value_counts()
# Out:
# -0.417429    1
#  0.399379    1
# -0.703800    1
#  0.286951    1
#  0.121278    1
#             ..
# -0.726900    1
# -0.218868    1
# -0.671275    1
# -0.939381    1
# -0.876781    1
# Name: Monthly_Balance, Length: 96657, dtype: int64

# %%
from sklearn.impute import KNNImputer   

kn = KNNImputer()

# %%
knn_imputer = pd.DataFrame(kn.fit_transform(scaled_data), columns = scaled_data.columns)

# %%
knn_imputer.isnull().sum()
# Out:
# Age                         0
# Annual_Income               0
# Delay_from_due_date         0
# Changed_Credit_Limit        0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Monthly_Balance             0
# dtype: int64

# %%
new_data = pd.DataFrame(sc.inverse_transform(knn_imputer), columns = knn_imputer.columns)

# %%
new_data.isnull().sum()
# Out:
# Age                         0
# Annual_Income               0
# Delay_from_due_date         0
# Changed_Credit_Limit        0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Monthly_Balance             0
# dtype: int64

# %%
cat_data = df[cat_cols]
cat_data.shape
# Out:
# (99522, 13)

# %%
new_data.reset_index(drop=True, inplace=True)
cat_data.reset_index(drop=True, inplace=True)
# Concatenate them along columns (axis=1)
df1 = pd.concat([new_data,cat_data], axis=1)

# %%
df1.Monthly_Balance.value_counts()
# Out:
# 444.372118    2
# 422.696954    2
# 230.204225    2
# 247.389787    2
# 392.118254    2
#              ..
# 364.013997    1
# 264.554377    1
# 235.539689    1
# 337.725739    1
# 446.382819    1
# Name: Monthly_Balance, Length: 99507, dtype: int64

# %%
df1.isnull().sum()
# Out:
# Age                            0
# Annual_Income                  0
# Delay_from_due_date            0
# Changed_Credit_Limit           0
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Credit_History_Age             0
# Total_EMI_per_month            0
# Amount_invested_monthly        0
# Monthly_Balance                0
# Customer_ID                    0
# Month                          0
# Occupation                     0
# Credit_Mix                     0
# Payment_of_Min_Amount          0
# Payment_Behaviour              0
# Credit_Score                   0
# Num_Bank_Accounts              0
# Num_Credit_Card                0
# Interest_Rate                  0
# Num_of_Delayed_Payment      6968
# Num_Credit_Inquiries        1954
# Num_of_loan2                   0
# dtype: int64

# %%
#now we will fix num_credit_inquiries

df1.Num_Credit_Inquiries.value_counts()
# Out:
# 4.0       11194
# 3.0        8810
# 6.0        8084
# 7.0        8034
# 2.0        7958
#           ...
# 2245.0        1
# 470.0         1
# 1662.0        1
# 1312.0        1
# 74.0          1
# Name: Num_Credit_Inquiries, Length: 1215, dtype: int64

# %%
nci = ""
for i in df1.Customer_ID[df1.Num_Credit_Inquiries.isnull()]:
    nci = df1.Num_Credit_Inquiries[(df1.Customer_ID ==i) & (df1.Num_Credit_Inquiries.notnull())]
    df1.Num_Credit_Inquiries[(df1.Customer_ID == i) & (df1.Num_Credit_Inquiries.isnull())] = nci.mode()[0]

# %%
df1.Num_Credit_Inquiries.value_counts()
# Out:
# 4.0       11456
# 3.0        9003
# 6.0        8232
# 7.0        8192
# 2.0        8147
#           ...
# 2245.0        1
# 470.0         1
# 1662.0        1
# 1312.0        1
# 74.0          1
# Name: Num_Credit_Inquiries, Length: 1215, dtype: int64

# %%
df1.Num_of_Delayed_Payment.value_counts()
#now we will treat delayed payment
# Out:
# 19.0      5459
# 17.0      5394
# 16.0      5292
# 10.0      5284
# 15.0      5212
#           ...
# 1530.0       1
# 1502.0       1
# 4075.0       1
# 3845.0       1
# 2047.0       1
# Name: Num_of_Delayed_Payment, Length: 707, dtype: int64

# %%
ndp = ""
for i in df1.Customer_ID[df1.Num_of_Delayed_Payment.isnull()]:
    ndp = df1.Num_of_Delayed_Payment[(df1.Customer_ID ==i) & (df1.Num_of_Delayed_Payment.notnull())]
    df1.Num_of_Delayed_Payment[(df1.Customer_ID == i) & (df1.Num_of_Delayed_Payment.isnull())] = ndp.mode()[0]

# %%
df1.isnull().sum()
# Out:
# Age                         0
# Annual_Income               0
# Delay_from_due_date         0
# Changed_Credit_Limit        0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Monthly_Balance             0
# Customer_ID                 0
# Month                       0
# Occupation                  0
# Credit_Mix                  0
# Payment_of_Min_Amount       0
# Payment_Behaviour           0
# Credit_Score                0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Delayed_Payment      0
# Num_Credit_Inquiries        0
# Num_of_loan2                0
# dtype: int64

# %%
#Univariate analysis

# %%
##Now we will check for outliers using boxplot
t=1
plt.figure(figsize=(12,10))
for i in num_cols:
    plt.subplot(4,3,t)
    sns.boxplot(df1[i], orient='h')
    plt.title(i)
    t+=1
    
plt.tight_layout()
plt.show()

# %%
t=1
plt.figure(figsize=(50,40))
for i in cat_cols:
    if i != 'Customer_ID':
        plt.subplot(4,3,t)
        sns.countplot(x=df1[i])
        plt.title(i)
        t+=1
    
plt.tight_layout()
plt.show()

# %% [markdown]
# # Outlier Treatment

# %%
df1.describe().T
# Out:
#                             count           mean           std         min  \
# Age                       99522.0     119.338830  6.838422e+02    14.00000
# Annual_Income             99522.0  176341.409950  1.429806e+06  7005.93000
# Delay_from_due_date       99522.0      21.102178  1.487707e+01    -5.00000
# Changed_Credit_Limit      99522.0      10.399898  6.754144e+00    -6.49000
# Outstanding_Debt          99522.0    1429.372736  1.156621e+03     0.23000
# Credit_Utilization_Ratio  99522.0      32.280320  5.114569e+00    20.00000
# Credit_History_Age        99522.0      18.340838  8.165603e+00     0.10000
# Total_EMI_per_month       99522.0    1405.185237  8.310992e+03     0.00000
# Amount_invested_monthly   99522.0     639.815899  2.009407e+03     0.00000
# Monthly_Balance           99522.0     400.792004  2.112368e+02     0.00776
# Num_Bank_Accounts         99522.0      17.067010  1.172050e+02    -1.00000
# Num_Credit_Card           99522.0      22.459617  1.289731e+02     0.00000
# Interest_Rate             99522.0      72.395390  4.659099e+02     1.00000
# Num_of_Delayed_Payment    99522.0      29.696560  2.181426e+02    -3.00000
# Num_Credit_Inquiries      99522.0      27.320763  1.913099e+02     0.00000
# Num_of_loan2              99522.0       3.549848  2.439911e+00     0.00000
#
#                                    25%           50%           75%  \
# Age                          25.000000     33.000000     42.000000
# Annual_Income             19433.480000  37550.740000  72699.660000
# Delay_from_due_date          10.000000     18.000000     28.000000
# Changed_Credit_Limit          5.400000      9.410000     14.790000
# Outstanding_Debt            566.860000   1167.860000   1954.620000
# Credit_Utilization_Ratio     28.047791     32.301553     36.491825
# Credit_History_Age           12.100000     18.300000     24.800000
# Total_EMI_per_month          30.759834     69.602920    161.978219
# Amount_invested_monthly      76.276973    138.486512    272.906396
# Monthly_Balance             270.165851    336.443610    468.148108
# Num_Bank_Accounts             3.000000      6.000000      7.000000
# Num_Credit_Card               4.000000      5.000000      7.000000
# Interest_Rate                 8.000000     14.000000     20.000000
# Num_of_Delayed_Payment        9.000000     14.000000     18.000000
# Num_Credit_Inquiries          3.000000      6.000000      9.000000
# Num_of_loan2                  2.000000      3.000000      5.000000
#
#                                    max
# Age                       8.698000e+03
# Annual_Income             2.419806e+07
# Delay_from_due_date       6.700000e+01
# Changed_Credit_Limit      3.697000e+01
# Outstanding_Debt          4.998070e+03
# Credit_Utilization_Ratio  5.000000e+01
# Credit_History_Age        3.380000e+01
# Total_EMI_per_month       8.233100e+04
# Amount_invested_monthly   1.000000e+04
# Monthly_Balance           1.602041e+03
# Num_Bank_Accounts         1.798000e+03
# Num_Credit_Card           1.499000e+03
# Interest_Rate             5.797000e+03
# Num_of_Delayed_Payment    4.397000e+03
# Num_Credit_Inquiries      2.597000e+03
# Num_of_loan2              9.000000e+00

# %%
# we have already done for num_of_loan2 , creadit_history_age in the above missing values segment.

# %%
# as age has anomalous data we will try to check for age as value are absurd with ranging uptio 1000
#-----------for every name check other entries with same name----------

df1.Age[df1.Age < 100].unique()
# Out:
# array([23., 28., 34., 54., 55., 21., 31., 33., 30., 24., 44., 45., 40.,
#        41., 32., 35., 36., 39., 37., 20., 46., 26., 42., 19., 48., 38.,
#        43., 22., 16., 18., 15., 27., 25., 14., 17., 47., 53., 56., 29.,
#        49., 51., 50., 52., 99., 95.])

# %%
#now we will make these values null and try to impute them

# Doing Treatment for the age Column

df1.Age[df1['Age']>100] = np.nan

# %%
df1['Age'].isnull().sum()
# Out:
# 2760

# %%
df1.Age[df1.Age.isnull()]
# Out:
# 2       NaN
# 54      NaN
# 111     NaN
# 120     NaN
# 216     NaN
#          ..
# 99435   NaN
# 99459   NaN
# 99472   NaN
# 99485   NaN
# 99494   NaN
# Name: Age, Length: 2760, dtype: float64

# %%
age=""
Age1=""
for i in df1.Customer_ID[df1.Age.isnull()]:
    age = df1.Age[(df1.Customer_ID ==i) & (df1.Age.notnull())]
    Age1 = age.to_list()
    df1.Age[df1.Customer_ID == i] = Age1[0]

# %%
# successfully Treated the Null Valuedf.Age.isnull()]
df1.Age.isnull().sum()
# Out:
# 0

# %%
## Annual_income

# %%
df1.Annual_Income.value_counts()
#here people have some
# Out:
# 9141.63        16
# 17273.83       16
# 36585.12       16
# 40341.16       16
# 20867.67       16
#                ..
# 15048753.00     1
# 20056517.00     1
# 1724659.00      1
# 6397485.00      1
# 9389456.00      1
# Name: Annual_Income, Length: 13482, dtype: int64

# %%
df1[df1.Annual_Income < 0]
# Out:
# Empty DataFrame
# Columns: [Age, Annual_Income, Delay_from_due_date, Changed_Credit_Limit, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Total_EMI_per_month, Amount_invested_monthly, Monthly_Balance, Customer_ID, Month, Occupation, Credit_Mix, Payment_of_Min_Amount, Payment_Behaviour, Credit_Score, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Delayed_Payment, Num_Credit_Inquiries, Num_of_loan2]
# Index: []

# %%
#we will keep all these high values as people can earn such high incomes

# %%
df1.Num_Bank_Accounts.value_counts()
#here we can see there are some junk values as a person cannot possibly have 887 or 1221 loans, so we will fix this
# Out:
# 6       12947
# 7       12774
# 8       12712
# 4       12111
# 5       12054
#         ...
# 887         1
# 211         1
# 1221        1
# 753         1
# 697         1
# Name: Num_Bank_Accounts, Length: 940, dtype: int64

# %%
df1[df1.Customer_ID == 'CUS_0x4004']
# Out:
#       Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 261  43.0        58317.0                 18.0                 16.58
# 262  43.0        58317.0                 18.0                 16.58
# 263  44.0        58317.0                 16.0                 10.58
# 264  44.0        58317.0                 18.0                 23.58
# 265  44.0        58317.0                 18.0                 22.58
# 266  44.0        58317.0                 18.0                 16.58
# 267  44.0        58317.0                 18.0                 21.58
# 268  44.0        58317.0                 22.0                 16.58
#
#      Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 261             98.97                 40.411115              13.100
# 262             98.97                 27.806918              13.200
# 263             98.97                 25.832109              13.300
# 264             98.97                 29.766107              20.122
# 265             98.97                 34.192304              13.500
# 266             98.97                 24.665525              13.600
# 267             98.97                 28.260147              13.700
# 268             98.97                 36.763665              13.800
#
#      Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance  \
# 261           149.897199               109.488950       467.088851
# 262           149.897199                83.300408       483.277392
# 263           149.897199                57.951223       498.626577
# 264           149.897199               158.648276       407.929525
# 265           149.897199               180.830573       415.747227
# 266           149.897199                98.880508       467.697293
# 267           149.897199               380.585701       215.992100
# 268           149.897199                59.955987       506.621813
#
#     Customer_ID     Month Occupation Credit_Mix Payment_of_Min_Amount  \
# 261  CUS_0x4004   January     Writer   Standard                   Yes
# 262  CUS_0x4004  February     Writer   Standard                   Yes
# 263  CUS_0x4004     March     Writer   Standard                   Yes
# 264  CUS_0x4004     April     Writer   Standard                   Yes
# 265  CUS_0x4004       May     Writer   Standard                   Yes
# 266  CUS_0x4004      June     Writer   Standard                   Yes
# 267  CUS_0x4004      July     Writer   Standard                   Yes
# 268  CUS_0x4004    August     Writer   Standard                   Yes
#
#                     Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 261  High_spent_Medium_value_payments     Standard                  8
# 262  High_spent_Medium_value_payments     Standard                  8
# 263   High_spent_Large_value_payments     Standard                  8
# 264  High_spent_Medium_value_payments     Standard               1414
# 265   Low_spent_Medium_value_payments     Standard                  8
# 266  High_spent_Medium_value_payments     Standard                  8
# 267   Low_spent_Medium_value_payments     Standard                  8
# 268  High_spent_Medium_value_payments     Standard                  8
#
#      Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 261                5              9                    17.0
# 262                5              9                    20.0
# 263                5              9                    20.0
# 264                5              9                    23.0
# 265                5              9                    20.0
# 266                5              9                    20.0
# 267                5              9                    20.0
# 268                5              9                    20.0
#
#      Num_Credit_Inquiries  Num_of_loan2
# 261                   6.0           6.0
# 262                   6.0           6.0
# 263                   6.0           6.0
# 264                  10.0           6.0
# 265                  10.0           6.0
# 266                  10.0           6.0
# 267                  10.0           6.0
# 268                  10.0           6.0

# %%
df1.Num_Bank_Accounts[(df1.Num_Bank_Accounts > 10) | (df1.Num_Bank_Accounts <0)] = np.nan

#The average number of accounts can vary, but many individuals might have a combination of savings and checking accounts, 
#along with one or two other specialized accounts. 
#Keep in mind that these are general observations, So we have considered 10 as maximum Number of bank accounts.

# %%
df1.Num_Bank_Accounts.isnull().sum()
# Out:
# 1338

# %%
#now we will fill these values using customer id as done in above columns

df1.Num_Bank_Accounts[(df1.Customer_ID =='CUS_0x4004') & (df1.Num_Bank_Accounts.notnull())]
# Out:
# 261    8.0
# 262    8.0
# 263    8.0
# 265    8.0
# 266    8.0
# 267    8.0
# 268    8.0
# Name: Num_Bank_Accounts, dtype: float64

# %%
nba=""
nba1=""
for i in df1.Customer_ID[df1.Num_Bank_Accounts.isnull()]:
    nba = df1.Num_Bank_Accounts[(df1.Customer_ID ==i) & (df1.Num_Bank_Accounts.notnull())]
    nba1 = nba.to_list()
    df1.Num_Bank_Accounts[df1.Customer_ID == i] = nba1[0]

# %%
df1[df1.Customer_ID =='CUS_0x4004']
# Out:
#       Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 261  43.0        58317.0                 18.0                 16.58
# 262  43.0        58317.0                 18.0                 16.58
# 263  44.0        58317.0                 16.0                 10.58
# 264  44.0        58317.0                 18.0                 23.58
# 265  44.0        58317.0                 18.0                 22.58
# 266  44.0        58317.0                 18.0                 16.58
# 267  44.0        58317.0                 18.0                 21.58
# 268  44.0        58317.0                 22.0                 16.58
#
#      Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 261             98.97                 40.411115              13.100
# 262             98.97                 27.806918              13.200
# 263             98.97                 25.832109              13.300
# 264             98.97                 29.766107              20.122
# 265             98.97                 34.192304              13.500
# 266             98.97                 24.665525              13.600
# 267             98.97                 28.260147              13.700
# 268             98.97                 36.763665              13.800
#
#      Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance  \
# 261           149.897199               109.488950       467.088851
# 262           149.897199                83.300408       483.277392
# 263           149.897199                57.951223       498.626577
# 264           149.897199               158.648276       407.929525
# 265           149.897199               180.830573       415.747227
# 266           149.897199                98.880508       467.697293
# 267           149.897199               380.585701       215.992100
# 268           149.897199                59.955987       506.621813
#
#     Customer_ID     Month Occupation Credit_Mix Payment_of_Min_Amount  \
# 261  CUS_0x4004   January     Writer   Standard                   Yes
# 262  CUS_0x4004  February     Writer   Standard                   Yes
# 263  CUS_0x4004     March     Writer   Standard                   Yes
# 264  CUS_0x4004     April     Writer   Standard                   Yes
# 265  CUS_0x4004       May     Writer   Standard                   Yes
# 266  CUS_0x4004      June     Writer   Standard                   Yes
# 267  CUS_0x4004      July     Writer   Standard                   Yes
# 268  CUS_0x4004    August     Writer   Standard                   Yes
#
#                     Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 261  High_spent_Medium_value_payments     Standard                8.0
# 262  High_spent_Medium_value_payments     Standard                8.0
# 263   High_spent_Large_value_payments     Standard                8.0
# 264  High_spent_Medium_value_payments     Standard                8.0
# 265   Low_spent_Medium_value_payments     Standard                8.0
# 266  High_spent_Medium_value_payments     Standard                8.0
# 267   Low_spent_Medium_value_payments     Standard                8.0
# 268  High_spent_Medium_value_payments     Standard                8.0
#
#      Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 261                5              9                    17.0
# 262                5              9                    20.0
# 263                5              9                    20.0
# 264                5              9                    23.0
# 265                5              9                    20.0
# 266                5              9                    20.0
# 267                5              9                    20.0
# 268                5              9                    20.0
#
#      Num_Credit_Inquiries  Num_of_loan2
# 261                   6.0           6.0
# 262                   6.0           6.0
# 263                   6.0           6.0
# 264                  10.0           6.0
# 265                  10.0           6.0
# 266                  10.0           6.0
# 267                  10.0           6.0
# 268                  10.0           6.0

# %%
df1.Num_Bank_Accounts.value_counts()
#now we have fixed num bank accounts
# Out:
# 6.0     13122
# 7.0     12938
# 8.0     12906
# 4.0     12283
# 5.0     12245
# 3.0     11999
# 9.0      5485
# 10.0     5338
# 1.0      4514
# 0.0      4375
# 2.0      4317
# Name: Num_Bank_Accounts, dtype: int64

# %%
#now we will work on num of credit cards

# %%
df1[df1.Num_Credit_Card > 10]
#as we have taken 10 no of accounts so we will take 10 num of credit cards
# Out:
#         Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 10     28.0       34847.84                  3.0                  5.42
# 38     31.0       73928.46                 12.0                 10.14
# 155    32.0       19300.34                 51.0                  9.95
# 161    41.0       19514.88                 30.0                  4.17
# 204    48.0       20787.69                 22.0                  8.13
# ...     ...            ...                  ...                   ...
# 99132  38.0      126514.72                 21.0                 10.64
# 99140  32.0       64901.37                 19.0                  2.94
# 99144  30.0      142560.36                 23.0                 11.22
# 99292  23.0       60015.32                  8.0                 10.47
# 99334  19.0       39977.21                 13.0                  9.62
#
#        Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 10               605.03                 33.224951              26.900
# 38               548.20                 39.962685              29.222
# 155             2430.21                 25.847791              18.700
# 161              881.40                 34.503707              19.600
# 204              614.60                 35.344188              18.500
# ...                 ...                       ...                 ...
# 99132            470.42                 29.696182              29.700
# 99140            442.06                 29.145534              31.500
# 99144            220.75                 34.671699              17.600
# 99292           1095.15                 35.864367              15.300
# 99334            832.09                 39.587650              30.400
#
#        Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance  \
# 10               18.816215                58.515976       466.466476
# 38            15015.000000                98.674410       740.196090
# 155              49.572062                83.447449       288.216656
# 161               0.000000                45.388820       387.435180
# 204              42.221993                21.745531       375.963226
# ...                    ...                      ...              ...
# 99132         61447.000000               902.340388       554.658039
# 99140             0.000000               126.263036       392.167845
# 99144            76.772094               982.946968       258.968122
# 99292           187.008683               241.313632       396.575147
# 99334             0.000000               240.514534       568.872632
#
#       Customer_ID     Month    Occupation Credit_Mix Payment_of_Min_Amount  \
# 10     CUS_0x21b1     March       Teacher       Good                    No
# 38     CUS_0x95ee   January        Lawyer       Good                    No
# 155    CUS_0x4100      June  Entrepreneur        Bad                   Yes
# 161    CUS_0x132f     April      Musician   Standard                    No
# 204    CUS_0x4d43    August  Entrepreneur   Standard                    No
# ...           ...       ...           ...        ...                   ...
# 99132  CUS_0x5d6d      June        Writer   Standard                    No
# 99140  CUS_0x2829    August    Journalist   Standard                   Yes
# 99144  CUS_0xae66     April        Writer   Standard                    No
# 99292  CUS_0xc345  February     Architect   Standard                   Yes
# 99334  CUS_0x64f0     April     Architect       Good                    No
#
#                       Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 10      High_spent_Large_value_payments     Standard                2.0
# 38      High_spent_Large_value_payments         Good                4.0
# 155      Low_spent_Large_value_payments         Poor                6.0
# 161    High_spent_Medium_value_payments         Poor                7.0
# 204     High_spent_Large_value_payments     Standard                8.0
# ...                                 ...          ...                ...
# 99132    Low_spent_Small_value_payments         Good                8.0
# 99140   High_spent_Large_value_payments     Standard                3.0
# 99144    Low_spent_Large_value_payments     Standard                6.0
# 99292    Low_spent_Large_value_payments     Standard                7.0
# 99334    Low_spent_Small_value_payments     Standard                4.0
#
#        Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 10                1385              6                    -1.0
# 38                1288              8                    10.0
# 155               1029             17                    17.0
# 161                488             17                    12.0
# 204               1381             14                    14.0
# ...                ...            ...                     ...
# 99132             1255              5                    19.0
# 99140              232             20                    18.0
# 99144             1430             13                    15.0
# 99292              679             14                     8.0
# 99334              158             11                    10.0
#
#        Num_Credit_Inquiries  Num_of_loan2
# 10                      2.0           1.0
# 38                      2.0           0.0
# 155                     8.0           5.0
# 161                     2.0           0.0
# 204                     3.0           3.0
# ...                     ...           ...
# 99132                   0.0           3.0
# 99140                   3.0           0.0
# 99144                   0.0           1.0
# 99292                 310.0           7.0
# 99334                   4.0           0.0
#
# [2293 rows x 23 columns]

# %%
df1[df1.Num_Credit_Card < 0]
#no person  havong credit card < 0
# Out:
# Empty DataFrame
# Columns: [Age, Annual_Income, Delay_from_due_date, Changed_Credit_Limit, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Total_EMI_per_month, Amount_invested_monthly, Monthly_Balance, Customer_ID, Month, Occupation, Credit_Mix, Payment_of_Min_Amount, Payment_Behaviour, Credit_Score, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Delayed_Payment, Num_Credit_Inquiries, Num_of_loan2]
# Index: []

# %%
df1.Num_Credit_Card[df1.Num_Credit_Card > 10] = np.nan

# %%
df1.Num_Credit_Card.isnull().sum ()
# Out:
# 2293

# %%
ncc=""
ncc1=""
for i in df1.Customer_ID[df1.Num_Credit_Card.isnull()]:
    ncc = df1.Num_Credit_Card[(df1.Customer_ID ==i) & (df1.Num_Credit_Card.notnull())]
    ncc1 = ncc.to_list()
    df1.Num_Credit_Card[df1.Customer_ID == i] = ncc1[0]

# %%
df1.Num_Credit_Card.value_counts()
#now we have fixed the garbage values in num credit card
# Out:
# 5.0     18810
# 7.0     16961
# 6.0     16825
# 4.0     14289
# 3.0     13475
# 8.0      5068
# 10.0     4996
# 9.0      4749
# 1.0      2183
# 2.0      2156
# 0.0        10
# Name: Num_Credit_Card, dtype: int64

# %%
#now we will work oon interest rate
df1.Interest_Rate.value_counts()
# Out:
# 8       4968
# 5       4944
# 6       4686
# 12      4520
# 10      4503
#         ...
# 1899       1
# 2120       1
# 5762       1
# 4372       1
# 5729       1
# Name: Interest_Rate, Length: 1744, dtype: int64

# %%
df1[df1.Interest_Rate > 32].shape[0]
# Out:
# 4992

# %%
df1[df1.Interest_Rate > 33].shape[0]
# Out:
# 3525

# %%
df1[df1.Interest_Rate > 34].shape[0]
# Out:
# 2023

# %%
df1[df1.Interest_Rate > 35].shape[0]
# Out:
# 2023

# %%
df1[df1.Interest_Rate > 36].shape[0]
# Out:
# 2023

# %%
# as we can see after 34% interst rate  the no of entries is constant so we will procedd with 34% and above it all are junk

# %%
df1.Interest_Rate[df1.Interest_Rate > 34] = np.nan

# %%
df1.Interest_Rate.isnull().sum()
# Out:
# 2023

# %%
df1[df1.Interest_Rate.isnull()]
# Out:
#         Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 42     31.0       73928.46                 11.0                 10.14
# 87     33.0       88640.24                  4.0                  3.51
# 165    41.0       19514.88                 26.0                  4.17
# 176    20.0      106733.13                  2.0                  0.86
# 226    40.0       28572.39                 25.0                  4.89
# ...     ...            ...                  ...                   ...
# 99314  54.0       99520.50                  8.0                  4.08
# 99324  16.0       14937.49                 42.0                 21.17
# 99404  31.0    16884797.00                  7.0                 12.57
# 99436  54.0       20059.98                 25.0                  2.97
# 99519  25.0       39628.99                 27.0                 11.50
#
#        Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 42               548.20                 26.333310               32.30
# 87               950.36                 41.036168               25.60
# 165              881.40                 28.781888               19.10
# 176               76.23                 42.070459               32.11
# 226              400.07                 35.693949               30.80
# ...                 ...                       ...                 ...
# 99314            547.21                 38.798114               16.80
# 99324           3699.44                 35.964828               13.30
# 99404            330.60                 38.524095               23.00
# 99436            909.01                 29.204711               16.50
# 99519            502.38                 41.255522               31.80
#
#        Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance  \
# 42                0.000000               177.951836       690.918664
# 87              135.173371               157.174788       674.320507
# 165               0.000000                99.141541       343.682459
# 176               0.000000               172.032829       955.309921
# 226              69.602920               129.264835       312.135495
# ...                    ...                      ...              ...
# 99314           196.528591               147.563516       584.681390
# 99324            50.960878               149.887864       286.486524
# 99404             0.000000             10000.000000       470.586703
# 99436            45.076827               111.567139       492.551069
# 99519            35.104023                24.028477       684.255728
#
#       Customer_ID     Month     Occupation Credit_Mix Payment_of_Min_Amount  \
# 42     CUS_0x95ee       May         Lawyer       Good                    No
# 87     CUS_0xc0ab  February       Engineer       Good                    NM
# 165    CUS_0x132f    August       Musician   Standard                    No
# 176    CUS_0xac86     March   Entrepreneur       Good                    No
# 226    CUS_0xbffe      June      Architect   Standard                   Yes
# ...           ...       ...            ...        ...                   ...
# 99314  CUS_0x62f5    August       Musician       Good                    NM
# 99324  CUS_0x1232  February      Developer        Bad                   Yes
# 99404  CUS_0x47fa     March       Mechanic   Standard                   Yes
# 99436  CUS_0x1619     March  Media_Manager       Good                    No
# 99519  CUS_0x942c      June       Mechanic       Good                    No
#
#                      Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 42      Low_spent_Large_value_payments         Good                4.0
# 87     High_spent_Large_value_payments         Good                3.0
# 165    High_spent_Small_value_payments         Poor                7.0
# 176    High_spent_Large_value_payments         Good                4.0
# 226     Low_spent_Small_value_payments     Standard                6.0
# ...                                ...          ...                ...
# 99314  High_spent_Large_value_payments         Good                3.0
# 99324   Low_spent_Small_value_payments     Standard                8.0
# 99404  High_spent_Small_value_payments     Standard                7.0
# 99436   Low_spent_Large_value_payments         Poor                8.0
# 99519  High_spent_Large_value_payments         Poor                4.0
#
#        Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 42                 5.0            NaN                     7.0
# 87                 6.0            NaN                     2.0
# 165                5.0            NaN                    11.0
# 176                4.0            NaN                     6.0
# 226                3.0            NaN                    11.0
# ...                ...            ...                     ...
# 99314              1.0            NaN                     5.0
# 99324              8.0            NaN                    13.0
# 99404              3.0            NaN                     8.0
# 99436              5.0            NaN                     9.0
# 99519              6.0            NaN                     6.0
#
#        Num_Credit_Inquiries  Num_of_loan2
# 42                      2.0           0.0
# 87                      3.0           2.0
# 165                     4.0           0.0
# 176                     0.0           0.0
# 226                     2.0           3.0
# ...                     ...           ...
# 99314                   5.0           3.0
# 99324                   6.0           7.0
# 99404                   2.0           0.0
# 99436                   3.0           4.0
# 99519                   3.0           2.0
#
# [2023 rows x 23 columns]

# %%
nic = ""
nic1 = ""
for i in df1.Customer_ID[df1.Interest_Rate.isnull()]:
    nic = df1.Interest_Rate[(df1.Customer_ID ==i) & (df1.Interest_Rate.notnull())]
    nic1 = nic.to_list()
    df1.Interest_Rate[df1.Customer_ID == i] = nic1[0]

# %%
df1.Interest_Rate.isnull().sum()
# Out:
# 0

# %%
df1[df1.Customer_ID == 'CUS_0x95ee']
# Out:
#      Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 38  31.0       73928.46                 12.0                 10.14
# 39  31.0       73928.46                  8.0                 10.14
# 40  31.0       73928.46                  8.0                 10.14
# 41  31.0       73928.46                  8.0                 10.14
# 42  31.0       73928.46                 11.0                 10.14
# 43  31.0       73928.46                  7.0                 10.14
# 44  31.0       73928.46                  8.0                  9.14
# 45  31.0       73928.46                  8.0                 10.14
#
#     Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 38             548.2                 39.962685              29.222
# 39             548.2                 42.769864              32.000
# 40             548.2                 40.712187              24.220
# 41             548.2                 30.201658              32.200
# 42             548.2                 26.333310              32.300
# 43             548.2                 35.275437              23.300
# 44             548.2                 36.624791              32.500
# 45             548.2                 31.580990              32.600
#
#     Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance Customer_ID  \
# 38              15015.0                98.674410       740.196090  CUS_0x95ee
# 39                  0.0               172.939214       705.931286  CUS_0x95ee
# 40                  0.0               150.059734       698.810766  CUS_0x95ee
# 41                  0.0               618.202391       270.668109  CUS_0x95ee
# 42                  0.0               177.951836       690.918664  CUS_0x95ee
# 43              15515.0               235.790325       633.080175  CUS_0x95ee
# 44                  0.0               348.509400       510.361100  CUS_0x95ee
# 45                  0.0                42.635590       796.234910  CUS_0x95ee
#
#        Month Occupation Credit_Mix Payment_of_Min_Amount  \
# 38   January     Lawyer       Good                    No
# 39  February     Lawyer       Good                    NM
# 40     March     Lawyer       Good                    No
# 41     April     Lawyer       Good                    No
# 42       May     Lawyer       Good                    No
# 43      June     Lawyer       Good                    No
# 44      July     Lawyer       Good                    No
# 45    August     Lawyer       Good                    No
#
#                    Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 38   High_spent_Large_value_payments         Good                4.0
# 39   Low_spent_Medium_value_payments         Good                4.0
# 40  High_spent_Medium_value_payments         Good                4.0
# 41    Low_spent_Small_value_payments         Good                4.0
# 42    Low_spent_Large_value_payments         Good                4.0
# 43    Low_spent_Large_value_payments         Good                4.0
# 44   High_spent_Small_value_payments     Standard                4.0
# 45    Low_spent_Large_value_payments         Good                4.0
#
#     Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 38              5.0            8.0                    10.0
# 39              5.0            8.0                     7.0
# 40              5.0            8.0                     7.0
# 41              5.0            8.0                     7.0
# 42              5.0            8.0                     7.0
# 43              5.0            8.0                     7.0
# 44              5.0            8.0                     4.0
# 45              5.0            8.0                     7.0
#
#     Num_Credit_Inquiries  Num_of_loan2
# 38                   2.0           0.0
# 39                   2.0           0.0
# 40                   2.0           0.0
# 41                   2.0           0.0
# 42                   2.0           0.0
# 43                   2.0           0.0
# 44                   2.0           0.0
# 45                   2.0           0.0

# %%
df1.Delay_from_due_date.value_counts()
# Out:
#  15.0    3578
#  13.0    3405
#  8.0     3296
#  14.0    3286
#  10.0    3256
#          ...
# -4.0       61
#  65.0      56
# -5.0       33
#  66.0      32
#  67.0      22
# Name: Delay_from_due_date, Length: 73, dtype: int64

# %%
df1[df1.Delay_from_due_date < 0]
# Out:
#         Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 1      23.0       19114.12                 -1.0                 11.27
# 47     34.0      131313.40                 -1.0                 15.34
# 72     44.0       31370.80                 -2.0                  1.76
# 76     45.0       31370.80                 -1.0                  5.76
# 77     45.0       31370.80                 -2.0                  5.76
# ...     ...            ...                  ...                   ...
# 98730  34.0       96047.22                 -2.0                  4.75
# 98888  44.0       19631.26                 -1.0                 17.51
# 98898  31.0       61465.78                 -4.0                  3.17
# 98901  31.0       61465.78                 -5.0                  3.17
# 99190  31.0      146310.68                 -2.0                 11.48
#
#        Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 1                809.98                 31.944960               25.78
# 47               352.16                 31.983710               30.80
# 72               421.43                 31.046418               26.70
# 76               421.43                 22.762202               26.11
# 77               421.43                 37.565053               27.00
# ...                 ...                       ...                 ...
# 98730           1366.21                 34.080533               17.10
# 98888            823.21                 39.130281               32.40
# 98898            608.87                 26.846460               17.10
# 98901            608.87                 25.443676               18.10
# 99190            928.28                 35.389329               22.40
#
#        Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance  \
# 1                49.574949               118.280222       284.629162
# 47              137.644605               698.873271       547.760457
# 72               46.616129               140.820696       375.086508
# 76               46.616129               188.394900       337.512304
# 77               46.616129               252.644827       273.262377
# ...                    ...                      ...              ...
# 98730            49.656727               113.121623       758.559188
# 98888            65.051299               129.026936       500.593178
# 98898            31.650737             10000.000000       311.785035
# 98901            31.650737               493.144096       360.823227
# 99190            72.250125              1186.575073       509.629710
#
#       Customer_ID     Month     Occupation Credit_Mix Payment_of_Min_Amount  \
# 1       CUS_0xd40  February      Scientist       Good                    No
# 47     CUS_0x284a  February         Lawyer       Good                    No
# 72     CUS_0xba08     March     Journalist       Good                    No
# 76     CUS_0xba08      July     Journalist       Good                    No
# 77     CUS_0xba08    August     Journalist       Good                    No
# ...           ...       ...            ...        ...                   ...
# 98730  CUS_0xb59b      July       Mechanic       Good                    No
# 98888  CUS_0x870c      July        Manager       Good                    No
# 98898  CUS_0x163c   January  Media_Manager       Good                    No
# 98901  CUS_0x163c     April  Media_Manager       Good                    No
# 99190   CUS_0xb09     April         Lawyer       Good                    No
#
#                       Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 1        Low_spent_Large_value_payments         Good                3.0
# 47      High_spent_Small_value_payments         Good                0.0
# 72      Low_spent_Medium_value_payments         Good                1.0
# 76       Low_spent_Small_value_payments         Good                1.0
# 77       Low_spent_Small_value_payments         Good                1.0
# ...                                 ...          ...                ...
# 98730  High_spent_Medium_value_payments         Good                3.0
# 98888    Low_spent_Small_value_payments         Good                2.0
# 98898   Low_spent_Medium_value_payments     Standard                2.0
# 98901   Low_spent_Medium_value_payments         Good                2.0
# 99190   Low_spent_Medium_value_payments         Good                5.0
#
#        Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 1                  4.0            3.0                     4.0
# 47                 1.0            8.0                     2.0
# 72                 6.0           12.0                     0.0
# 76                 6.0           12.0                     2.0
# 77                 6.0           12.0                     2.0
# ...                ...            ...                     ...
# 98730              3.0            1.0                     6.0
# 98888              4.0            9.0                     4.0
# 98898              3.0           11.0                    10.0
# 98901              3.0           11.0                    10.0
# 99190              4.0            9.0                     7.0
#
#        Num_Credit_Inquiries  Num_of_loan2
# 1                       4.0           4.0
# 47                      4.0           2.0
# 72                      5.0           2.0
# 76                      5.0           2.0
# 77                      5.0           2.0
# ...                     ...           ...
# 98730                   4.0           1.0
# 98888                   9.0           4.0
# 98898                   0.0           1.0
# 98901                   2.0           1.0
# 99190                   1.0           1.0
#
# [590 rows x 23 columns]

# %%
print(df1.Delay_from_due_date.max())
print(df1.Delay_from_due_date.min())
#This columns look good and all the values are justified so we will move ahead
# Out:
# 67.0
# -5.0

# %%
#now we will treat Num_of_Delayed_Payment

# %%
df1[df1.Num_of_Delayed_Payment == 0]
# Out:
#         Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 13     28.0       34847.84                  3.0                  5.42
# 70     44.0       31370.80                  4.0                  5.76
# 71     44.0       31370.80                  2.0                 -1.24
# 72     44.0       31370.80                 -2.0                  1.76
# 73     44.0       31370.80                  1.0                  5.76
# ...     ...            ...                  ...                   ...
# 99493  44.0       16680.35                  1.0                  5.69
# 99494  44.0       16680.35                  1.0                  5.69
# 99495  44.0       16680.35                  1.0                  0.69
# 99496  44.0       16680.35                  1.0                 11.69
# 99497  44.0       16680.35                  1.0                  5.69
#
#        Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 13               605.03                 33.381010              27.000
# 70               421.43                 29.519353              26.600
# 71               421.43                 28.220481              26.600
# 72               421.43                 31.046418              26.700
# 73               421.43                 30.168030              26.800
# ...                 ...                       ...                 ...
# 99493            897.16                 36.132095              21.400
# 99494            897.16                 37.788217              21.500
# 99495            897.16                 24.972853              21.600
# 99496            897.16                 36.166925              21.700
# 99497            897.16                 41.212367              21.102
#
#        Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance  \
# 13               18.816215                43.477190       481.505262
# 70               46.616129               154.352781       341.554423
# 71               46.616129               298.744469       227.162735
# 72               46.616129               140.820696       375.086508
# 73               46.616129               233.605526       292.301678
# ...                    ...                      ...              ...
# 99493            41.113561               199.988581       535.244051
# 99494            41.113561                64.549748       586.827213
# 99495            41.113561             10000.000000       310.895990
# 99496            41.113561               423.145430       459.001490
# 99497            41.113561                70.805550       434.479756
#
#       Customer_ID     Month     Occupation Credit_Mix Payment_of_Min_Amount  \
# 13     CUS_0x21b1      June        Teacher       Good                    No
# 70     CUS_0xba08   January     Journalist       Good                    NM
# 71     CUS_0xba08  February     Journalist       Good                    No
# 72     CUS_0xba08     March     Journalist       Good                    No
# 73     CUS_0xba08     April     Journalist       Good                    No
# ...           ...       ...            ...        ...                   ...
# 99493   CUS_0xf16     April  Media_Manager       Good                    No
# 99494   CUS_0xf16       May  Media_Manager       Good                    No
# 99495   CUS_0xf16      June  Media_Manager       Good                    No
# 99496   CUS_0xf16      July  Media_Manager       Good                    No
# 99497   CUS_0xf16    August  Media_Manager       Good                    No
#
#                      Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 13     High_spent_Large_value_payments         Good                2.0
# 70     High_spent_Small_value_payments         Good                0.0
# 71      Low_spent_Small_value_payments         Good                1.0
# 72     Low_spent_Medium_value_payments         Good                1.0
# 73      Low_spent_Small_value_payments         Good                1.0
# ...                                ...          ...                ...
# 99493   Low_spent_Small_value_payments         Good                1.0
# 99494   Low_spent_Large_value_payments     Standard                1.0
# 99495   Low_spent_Small_value_payments         Good                1.0
# 99496   Low_spent_Small_value_payments         Good                1.0
# 99497   Low_spent_Large_value_payments         Good                1.0
#
#        Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 13                 4.0            6.0                     0.0
# 70                 5.0           12.0                     0.0
# 71                 6.0           12.0                     0.0
# 72                 6.0           12.0                     0.0
# 73                 6.0           12.0                     0.0
# ...                ...            ...                     ...
# 99493              1.0            5.0                     0.0
# 99494              1.0            5.0                     0.0
# 99495              1.0            5.0                     0.0
# 99496              1.0            5.0                     0.0
# 99497              1.0            5.0                     0.0
#
#        Num_Credit_Inquiries  Num_of_loan2
# 13                      2.0           1.0
# 70                      2.0           2.0
# 71                      2.0           2.0
# 72                      5.0           2.0
# 73                      5.0           2.0
# ...                     ...           ...
# 99493                   8.0           4.0
# 99494                   8.0           4.0
# 99495                   8.0           4.0
# 99496                   8.0           4.0
# 99497                   8.0           4.0
#
# [1751 rows x 23 columns]

# %%
df1.Num_of_Delayed_Payment.isnull().sum()
# Out:
# 0

# %%
df1.Num_of_Delayed_Payment.value_counts()
# Out:
# 19.0      5895
# 17.0      5777
# 10.0      5736
# 16.0      5712
# 15.0      5639
#           ...
# 1530.0       1
# 1502.0       1
# 4075.0       1
# 3845.0       1
# 2047.0       1
# Name: Num_of_Delayed_Payment, Length: 707, dtype: int64

# %%
df1[df1.Num_of_Delayed_Payment > 28]
#after this the number of entries is constant so we will make everything above this null and impute them later with KNN
# Out:
#         Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 249    43.0      18627.640                 31.0                  5.07
# 281    36.0      71681.400                  8.0                 10.44
# 301    36.0      15566.020                 16.0                  9.24
# 403    14.0      39887.220                 59.0                 11.25
# 635    47.0      17787.340                  6.0                  5.65
# ...     ...            ...                  ...                   ...
# 98665  31.0      77633.040                 55.0                 15.48
# 98932  27.0       8968.555                 58.0                 23.83
# 99089  28.0      21471.580                 14.0                  2.00
# 99090  28.0      21471.580                 15.0                 11.00
# 99348  44.0      32625.590                  5.0                  2.55
#
#        Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 249             1793.54                 25.585205               19.10
# 281             1293.02                 40.791137               25.11
# 301             1693.95                 37.409934                7.10
# 403             3119.60                 26.112222               12.60
# 635              730.90                 34.903092               30.00
# ...                 ...                       ...                 ...
# 98665           3392.65                 32.025465                0.90
# 98932           2502.86                 38.044111               11.50
# 99089             68.06                 40.940335               23.90
# 99090             68.06                 31.039063               23.10
# 99348            177.90                 33.861542               28.90
#
#        Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance  \
# 249              65.139488                24.346188       289.244657
# 281              53.923514             10000.000000       358.095400
# 301              43.070520                65.986586       323.259728
# 403             133.470845               153.270725       295.751929
# 635              20.063634                28.516044       325.648156
# ...                    ...                      ...              ...
# 98665           227.777065               106.015126       343.637241
# 98932            57.078833                93.647887       262.846634
# 99089            23.498319                33.192490       568.846759
# 99090            23.498319                12.340388       330.911009
# 99348            73.125008               350.806918       405.926184
#
#       Customer_ID     Month  Occupation Credit_Mix Payment_of_Min_Amount  \
# 249    CUS_0x6048       May    Musician        Bad                   Yes
# 281    CUS_0x9b94       May     Manager   Standard                   Yes
# 301    CUS_0x42ac   January    Musician   Standard                   Yes
# 403    CUS_0xb986  February   Developer        Bad                   Yes
# 635    CUS_0x78e0     April  Accountant   Standard                    NM
# ...           ...       ...         ...        ...                   ...
# 98665  CUS_0xbb53      June      Lawyer        Bad                   Yes
# 98932  CUS_0x7b65     March    Mechanic        Bad                   Yes
# 99089   CUS_0x650     March      Lawyer   Standard                    No
# 99090   CUS_0x650     April      Lawyer   Standard                    No
# 99348  CUS_0x2c0a  February      Doctor       Good                    No
#
#                       Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 249     High_spent_Large_value_payments         Poor                7.0
# 281     High_spent_Large_value_payments         Good                3.0
# 301      Low_spent_Small_value_payments         Poor                8.0
# 403    High_spent_Medium_value_payments         Poor                9.0
# 635    High_spent_Medium_value_payments     Standard                8.0
# ...                                 ...          ...                ...
# 98665   High_spent_Large_value_payments         Poor                7.0
# 98932    Low_spent_Small_value_payments         Poor               10.0
# 99089   High_spent_Small_value_payments     Standard                7.0
# 99090  High_spent_Medium_value_payments     Standard                7.0
# 99348    Low_spent_Small_value_payments     Standard                0.0
#
#        Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 249                7.0           19.0                  3318.0
# 281                6.0           15.0                  3083.0
# 301                5.0           32.0                  1338.0
# 403                9.0           16.0                  3104.0
# 635                4.0           16.0                   183.0
# ...                ...            ...                     ...
# 98665              5.0           34.0                  3336.0
# 98932              8.0           30.0                  3392.0
# 99089              3.0           16.0                  3688.0
# 99090              3.0           16.0                   221.0
# 99348              5.0            8.0                  2047.0
#
#        Num_Credit_Inquiries  Num_of_loan2
# 249                     7.0           6.0
# 281                     0.0           1.0
# 301                     7.0           4.0
# 403                    14.0           5.0
# 635                     0.0           2.0
# ...                     ...           ...
# 98665                   8.0           5.0
# 98932                  12.0           8.0
# 99089                   4.0           2.0
# 99090                   4.0           2.0
# 99348                   3.0           4.0
#
# [731 rows x 23 columns]

# %%
df1.Num_of_Delayed_Payment[df1.Num_of_Delayed_Payment > 28] = np.nan

# %%
# now we have fixed garbage values and rest nan will be filled by mode
df1.Num_of_Delayed_Payment.mode()[0]
# Out:
# 19.0

# %%
df1.Num_of_Delayed_Payment[df1.Num_of_Delayed_Payment.isnull()] = df1.Num_of_Delayed_Payment.mode()[0]

# %%
df1[df1.Num_of_Delayed_Payment.isnull()]
# Out:
# Empty DataFrame
# Columns: [Age, Annual_Income, Delay_from_due_date, Changed_Credit_Limit, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Total_EMI_per_month, Amount_invested_monthly, Monthly_Balance, Customer_ID, Month, Occupation, Credit_Mix, Payment_of_Min_Amount, Payment_Behaviour, Credit_Score, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Delayed_Payment, Num_Credit_Inquiries, Num_of_loan2]
# Index: []

# %%
#now we will work on Changed credit limit

# %%
df1[df1.Changed_Credit_Limit < 0]
# Out:
#         Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 27     55.0       30689.89                  7.0                 -2.01
# 28     55.0       30689.89                  5.0                 -1.01
# 29     55.0       30689.89                  5.0                 -3.01
# 71     44.0       31370.80                  2.0                 -1.24
# 177    20.0      106733.13                  5.0                 -4.14
# ...     ...            ...                  ...                   ...
# 99310  54.0       99520.50                  8.0                 -1.92
# 99349  44.0       32625.59                  5.0                 -0.45
# 99422  33.0       41329.56                  1.0                 -0.34
# 99480  21.0       38321.39                 11.0                 -3.41
# 99483  18.0       42903.79                 14.0                 -0.90
#
#        Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 27               632.46                 38.132348              17.600
# 28               632.46                 41.154317              17.700
# 29               632.46                 27.445422              17.800
# 71               421.43                 28.220481              26.600
# 177               76.23                 25.842548              33.000
# ...                 ...                       ...                 ...
# 99310            547.21                 37.945619              16.400
# 99349            177.90                 39.101560              28.100
# 99422           1245.01                 35.367709              23.542
# 99480            678.57                 28.360351              17.500
# 99483           1079.48                 33.494867              28.200
#
#        Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance  \
# 27               16.415452               272.334037       262.499594
# 28               16.415452             10000.000000       359.374916
# 29               16.415452                84.952848       419.880784
# 71               46.616129               298.744469       227.162735
# 177               0.000000               644.287394       513.055356
# ...                    ...                      ...              ...
# 99310           196.528591               330.362769       559.056606
# 99349            73.125008               111.178599       386.004277
# 99422            20.553577               126.576130       456.699048
# 99480           362.072453               182.067651       391.633583
# 99483            34.975457               163.506811       585.140429
#
#       Customer_ID     Month    Occupation Credit_Mix Payment_of_Min_Amount  \
# 27     CUS_0xb891     April  Entrepreneur       Good                    No
# 28     CUS_0xb891       May  Entrepreneur       Good                    No
# 29     CUS_0xb891      June  Entrepreneur       Good                    No
# 71     CUS_0xba08  February    Journalist       Good                    No
# 177    CUS_0xac86     April  Entrepreneur       Good                    No
# ...           ...       ...           ...        ...                   ...
# 99310  CUS_0x62f5     April      Musician       Good                    NM
# 99349  CUS_0x2c0a     March        Doctor       Good                    NM
# 99422  CUS_0x4986       May  Entrepreneur       Good                    No
# 99480  CUS_0x2084      July     Architect       Good                    No
# 99483  CUS_0x372c  February        Lawyer       Good                    No
#
#                       Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 27       Low_spent_Small_value_payments     Standard                2.0
# 28       Low_spent_Large_value_payments     Standard                2.0
# 29      High_spent_Small_value_payments     Standard                2.0
# 71       Low_spent_Small_value_payments         Good                1.0
# 177      Low_spent_Large_value_payments         Good                4.0
# ...                                 ...          ...                ...
# 99310  High_spent_Medium_value_payments     Standard                3.0
# 99349  High_spent_Medium_value_payments     Standard                0.0
# 99422   Low_spent_Medium_value_payments         Good                2.0
# 99480    Low_spent_Large_value_payments     Standard                4.0
# 99483  High_spent_Medium_value_payments         Good                0.0
#
#        Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 27                 5.0            4.0                     6.0
# 28                 5.0            4.0                     6.0
# 29                 5.0            4.0                     6.0
# 71                 6.0           12.0                     0.0
# 177                4.0            1.0                     7.0
# ...                ...            ...                     ...
# 99310              1.0            5.0                     5.0
# 99349              5.0            8.0                    10.0
# 99422              3.0            7.0                    10.0
# 99480              4.0            3.0                    10.0
# 99483              4.0            6.0                     0.0
#
#        Num_Credit_Inquiries  Num_of_loan2
# 27                      4.0           1.0
# 28                      4.0           1.0
# 29                      4.0           1.0
# 71                      2.0           2.0
# 177                     0.0           0.0
# ...                     ...           ...
# 99310                   3.0           3.0
# 99349                   3.0           4.0
# 99422                   2.0           1.0
# 99480                   3.0           4.0
# 99483                   1.0           1.0
#
# [1577 rows x 23 columns]

# %%
df1.Changed_Credit_Limit.value_counts()
# Out:
# 8.220     137
# 11.500    126
# 11.320    126
# 7.350     122
# 10.060    121
#          ...
# 9.162       1
# 24.388      1
# 30.800      1
# 13.302      1
# 14.514      1
# Name: Changed_Credit_Limit, Length: 5227, dtype: int64

# %%
df1.Changed_Credit_Limit.max()
# Out:
# 36.97

# %%
df1.Changed_Credit_Limit.min()
#it looks good and we will proceed with it and move on
# Out:
# -6.490000000000002

# %%
df1.describe().T
# Out:
#                             count           mean           std         min  \
# Age                       99522.0      33.244137  1.077297e+01    14.00000
# Annual_Income             99522.0  176341.409950  1.429806e+06  7005.93000
# Delay_from_due_date       99522.0      21.102178  1.487707e+01    -5.00000
# Changed_Credit_Limit      99522.0      10.399898  6.754144e+00    -6.49000
# Outstanding_Debt          99522.0    1429.372736  1.156621e+03     0.23000
# Credit_Utilization_Ratio  99522.0      32.280320  5.114569e+00    20.00000
# Credit_History_Age        99522.0      18.340838  8.165603e+00     0.10000
# Total_EMI_per_month       99522.0    1405.185237  8.310992e+03     0.00000
# Amount_invested_monthly   99522.0     639.815899  2.009407e+03     0.00000
# Monthly_Balance           99522.0     400.792004  2.112368e+02     0.00776
# Num_Bank_Accounts         99522.0       5.373616  2.592869e+00     0.00000
# Num_Credit_Card           99522.0       5.536947  2.067098e+00     0.00000
# Interest_Rate             99522.0      14.557776  8.747120e+00     1.00000
# Num_of_Delayed_Payment    99522.0      13.366251  6.300890e+00    -3.00000
# Num_Credit_Inquiries      99522.0      27.320763  1.913099e+02     0.00000
# Num_of_loan2              99522.0       3.549848  2.439911e+00     0.00000
#
#                                    25%           50%           75%  \
# Age                          24.000000     33.000000     42.000000
# Annual_Income             19433.480000  37550.740000  72699.660000
# Delay_from_due_date          10.000000     18.000000     28.000000
# Changed_Credit_Limit          5.400000      9.410000     14.790000
# Outstanding_Debt            566.860000   1167.860000   1954.620000
# Credit_Utilization_Ratio     28.047791     32.301553     36.491825
# Credit_History_Age           12.100000     18.300000     24.800000
# Total_EMI_per_month          30.759834     69.602920    161.978219
# Amount_invested_monthly      76.276973    138.486512    272.906396
# Monthly_Balance             270.165851    336.443610    468.148108
# Num_Bank_Accounts             3.000000      6.000000      7.000000
# Num_Credit_Card               4.000000      5.000000      7.000000
# Interest_Rate                 7.000000     13.000000     20.000000
# Num_of_Delayed_Payment        9.000000     14.000000     18.000000
# Num_Credit_Inquiries          3.000000      6.000000      9.000000
# Num_of_loan2                  2.000000      3.000000      5.000000
#
#                                    max
# Age                       1.000000e+02
# Annual_Income             2.419806e+07
# Delay_from_due_date       6.700000e+01
# Changed_Credit_Limit      3.697000e+01
# Outstanding_Debt          4.998070e+03
# Credit_Utilization_Ratio  5.000000e+01
# Credit_History_Age        3.380000e+01
# Total_EMI_per_month       8.233100e+04
# Amount_invested_monthly   1.000000e+04
# Monthly_Balance           1.602041e+03
# Num_Bank_Accounts         1.000000e+01
# Num_Credit_Card           1.000000e+01
# Interest_Rate             3.400000e+01
# Num_of_Delayed_Payment    2.800000e+01
# Num_Credit_Inquiries      2.597000e+03
# Num_of_loan2              9.000000e+00

# %%
# now we will work on Num_Credit_Inquiries

# %%
df1[df1.Num_Credit_Inquiries < 0]
# Out:
# Empty DataFrame
# Columns: [Age, Annual_Income, Delay_from_due_date, Changed_Credit_Limit, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Total_EMI_per_month, Amount_invested_monthly, Monthly_Balance, Customer_ID, Month, Occupation, Credit_Mix, Payment_of_Min_Amount, Payment_Behaviour, Credit_Score, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Delayed_Payment, Num_Credit_Inquiries, Num_of_loan2]
# Index: []

# %%
df1.Num_Credit_Inquiries.value_counts()
# Out:
# 4.0       11456
# 3.0        9003
# 6.0        8232
# 7.0        8192
# 2.0        8147
#           ...
# 2245.0        1
# 470.0         1
# 1662.0        1
# 1312.0        1
# 74.0          1
# Name: Num_Credit_Inquiries, Length: 1215, dtype: int64

# %%
df1.Num_Credit_Inquiries.max()
# Out:
# 2597.0

# %%
df1[df1.Num_Credit_Inquiries > 17]
#after 17 the change in number of entries is almost constant so we will proceed with it and make other null
# Out:
#         Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 171    42.0      10183.015                 48.0                10.970
# 190    34.0      57983.120                 53.0                 7.270
# 195    34.0      57983.120                 49.0                 7.270
# 231    37.0      39641.540                 61.0                 1.540
# 309    18.0      66567.320                  7.0                 7.670
# ...     ...            ...                  ...                   ...
# 99240  26.0      35793.970                 10.0                 9.920
# 99292  23.0      60015.320                  8.0                10.470
# 99312  54.0      99520.500                  8.0                 4.080
# 99323  16.0      14937.490                 44.0                20.562
# 99394  27.0     118677.540                  4.0                 9.590
#
#        Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 171             1672.43                 25.105403               10.60
# 190             3532.83                 37.873642               12.30
# 195             3532.83                 24.631497               12.80
# 231             2258.73                 27.572863                8.10
# 309              233.79                 34.456272               24.30
# ...                 ...                       ...                 ...
# 99240             82.15                 25.363971               23.40
# 99292           1095.15                 35.864367               15.30
# 99312            547.21                 32.224773               16.60
# 99323           3699.44                 23.574545               13.20
# 99394            995.47                 36.238303               29.11
#
#        Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance  \
# 171              37.588073                73.899861       285.970524
# 190             200.432613               193.873375       327.786678
# 195             200.432613               234.732040       316.928013
# 231             172.382527               198.042123       190.321516
# 309           37602.000000               251.647422       518.190884
# ...                    ...                      ...              ...
# 99240           113.833391               131.207947       396.485710
# 99292           187.008683               241.313632       396.575147
# 99312           196.528591              2326.978527       421.987520
# 99323            50.960878                97.586933       255.717559
# 99394         38424.000000               168.110827       535.843975
#
#       Customer_ID     Month     Occupation Credit_Mix Payment_of_Min_Amount  \
# 171    CUS_0xa16e      June  Media_Manager        Bad                   Yes
# 190    CUS_0xa5f9  February       Mechanic        Bad                   Yes
# 195    CUS_0xa5f9      July       Mechanic        Bad                   Yes
# 231    CUS_0xb681     March        Manager        Bad                   Yes
# 309    CUS_0x571f   January      Developer   Standard                    No
# ...           ...       ...            ...        ...                   ...
# 99240  CUS_0xadbd      June         Doctor       Good                    No
# 99292  CUS_0xc345  February      Architect   Standard                   Yes
# 99312  CUS_0x62f5      June       Musician       Good                    No
# 99323  CUS_0x1232   January      Developer        Bad                   Yes
# 99394  CUS_0x3855   January      Scientist       Good                    No
#
#                       Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 171      Low_spent_Small_value_payments         Poor                7.0
# 190    High_spent_Medium_value_payments     Standard                9.0
# 195     Low_spent_Medium_value_payments     Standard                9.0
# 231     High_spent_Small_value_payments         Poor               10.0
# 309      Low_spent_Small_value_payments     Standard                5.0
# ...                                 ...          ...                ...
# 99240   Low_spent_Medium_value_payments     Standard                5.0
# 99292    Low_spent_Large_value_payments     Standard                7.0
# 99312   High_spent_Large_value_payments         Good                3.0
# 99323    Low_spent_Small_value_payments     Standard                8.0
# 99394   High_spent_Large_value_payments         Good                4.0
#
#        Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 171                5.0           17.0                    24.0
# 190                8.0           31.0                    21.0
# 195                8.0           31.0                    21.0
# 231                8.0           25.0                    15.0
# 309                7.0            5.0                    15.0
# ...                ...            ...                     ...
# 99240              6.0            8.0                    11.0
# 99292              4.0           14.0                     8.0
# 99312              1.0            5.0                     8.0
# 99323              8.0           22.0                    12.0
# 99394              4.0            6.0                    13.0
#
#        Num_Credit_Inquiries  Num_of_loan2
# 171                  1050.0           5.0
# 190                  1044.0           8.0
# 195                  1936.0           8.0
# 231                   568.0           6.0
# 309                  1618.0           2.0
# ...                     ...           ...
# 99240                1361.0           4.0
# 99292                 310.0           7.0
# 99312                  93.0           3.0
# 99323                2209.0           7.0
# 99394                  74.0           4.0
#
# [1640 rows x 23 columns]

# %%
df1.Num_Credit_Inquiries[df1.Num_Credit_Inquiries > 17] = np.nan

#now we have fixed garbage values and will impute them later with mode

# %%
df1.Num_Credit_Inquiries[df1.Num_Credit_Inquiries.isnull()] = df1.Num_Credit_Inquiries.mode()[0]

# %%
df1.Num_Credit_Inquiries.isnull().sum()
# Out:
# 0

# %%
##Now we will fix Outstanding Debt
df1[df1.Outstanding_Debt < 0]
# Out:
# Empty DataFrame
# Columns: [Age, Annual_Income, Delay_from_due_date, Changed_Credit_Limit, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Total_EMI_per_month, Amount_invested_monthly, Monthly_Balance, Customer_ID, Month, Occupation, Credit_Mix, Payment_of_Min_Amount, Payment_Behaviour, Credit_Score, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Delayed_Payment, Num_Credit_Inquiries, Num_of_loan2]
# Index: []

# %%
df1.Outstanding_Debt.value_counts()
# Out:
# 1151.70    24
# 1109.03    24
# 460.46     24
# 1360.45    24
# 217.92     16
#            ..
# 39.68       6
# 80.09       6
# 936.59      5
# 581.67      5
# 1041.07     5
# Name: Outstanding_Debt, Length: 12203, dtype: int64

# %%
df1.Outstanding_Debt.min()
# Out:
# 0.2300000000000182

# %%
df1.Outstanding_Debt.max()
#this column is fine and we will proceed
# Out:
# 4998.07

# %%
#now we will work on Credit_Utilization_Ratio

df1[df1.Credit_Utilization_Ratio < 0]
# Out:
# Empty DataFrame
# Columns: [Age, Annual_Income, Delay_from_due_date, Changed_Credit_Limit, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Total_EMI_per_month, Amount_invested_monthly, Monthly_Balance, Customer_ID, Month, Occupation, Credit_Mix, Payment_of_Min_Amount, Payment_Behaviour, Credit_Score, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Delayed_Payment, Num_Credit_Inquiries, Num_of_loan2]
# Index: []

# %%
df1.Credit_Utilization_Ratio.value_counts()
# Out:
# 26.822620    1
# 31.921515    1
# 36.526143    1
# 33.109420    1
# 37.089624    1
#             ..
# 35.914328    1
# 25.815759    1
# 27.490871    1
# 24.987371    1
# 34.192463    1
# Name: Credit_Utilization_Ratio, Length: 99522, dtype: int64

# %%
df1.Credit_Utilization_Ratio.min()
# Out:
# 20.0

# %%
df1.Credit_Utilization_Ratio.max() 
#this is fine and we will proceed further
# Out:
# 50.00000000000001

# %%
# now we will work on Credit_History_Age

df1[df1.Credit_History_Age < 0]
# Out:
# Empty DataFrame
# Columns: [Age, Annual_Income, Delay_from_due_date, Changed_Credit_Limit, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Total_EMI_per_month, Amount_invested_monthly, Monthly_Balance, Customer_ID, Month, Occupation, Credit_Mix, Payment_of_Min_Amount, Payment_Behaviour, Credit_Score, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Delayed_Payment, Num_Credit_Inquiries, Num_of_loan2]
# Index: []

# %%
df1.Credit_History_Age.value_counts()
# Out:
# 18.100    774
# 17.100    768
# 19.100    752
# 16.100    740
# 15.100    605
#          ...
# 13.084      1
# 15.100      1
# 20.882      1
# 15.342      1
# 28.706      1
# Name: Credit_History_Age, Length: 3625, dtype: int64

# %%
df1.Credit_History_Age.min()
# Out:
# 0.09999999999999787

# %%
df1.Credit_History_Age.max()
#this is fine and we will proceed furter
# Out:
# 33.8

# %%
#now we will work on Total_EMI_per_month

df1[df1.Total_EMI_per_month < 0]
# Out:
# Empty DataFrame
# Columns: [Age, Annual_Income, Delay_from_due_date, Changed_Credit_Limit, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Total_EMI_per_month, Amount_invested_monthly, Monthly_Balance, Customer_ID, Month, Occupation, Credit_Mix, Payment_of_Min_Amount, Payment_Behaviour, Credit_Score, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Delayed_Payment, Num_Credit_Inquiries, Num_of_loan2]
# Index: []

# %%
df1.Total_EMI_per_month.value_counts()
# Out:
# 0.000000        10169
# 49.574949           8
# 64.008959           8
# 69.020960           8
# 250.408881          8
#                 ...
# 22898.000000        1
# 65311.000000        1
# 79218.000000        1
# 18859.000000        1
# 58638.000000        1
# Name: Total_EMI_per_month, Length: 14938, dtype: int64

# %%
df1.Total_EMI_per_month.min()
# Out:
# 0.0

# %%
df1.Total_EMI_per_month.max()
# Out:
# 82331.0

# %%
df1[df1.Total_EMI_per_month > 58638.000000]
# Out:
#         Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 92     33.0       88640.24                  4.0                  3.51
# 304    37.0       15566.02                 17.0                  9.24
# 353    19.0       85554.03                 12.0                  6.43
# 433    22.0       36822.29                 14.0                  5.79
# 540    30.0       30390.44                 15.0                  8.36
# ...     ...            ...                  ...                   ...
# 99012  44.0      145282.24                 30.0                  1.55
# 99132  38.0      126514.72                 21.0                 10.64
# 99425  34.0       41329.56                  2.0                  6.66
# 99430  39.0       87695.34                  5.0                  6.52
# 99492  44.0       16680.35                  1.0                  5.69
#
#        Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 92               950.36                 25.979173              25.110
# 304             1693.95                 25.038052               8.100
# 353             1095.73                 41.513288              19.200
# 433              125.25                 26.612872              23.764
# 540              580.31                 38.001565              24.700
# ...                 ...                       ...                 ...
# 99012           1417.24                 35.210768              23.700
# 99132            470.42                 29.696182              29.700
# 99425           1245.01                 39.866030              23.100
# 99430            361.68                 28.147193              19.500
# 99492            897.16                 30.472041              21.300
#
#        Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance  \
# 92                 80357.0               164.074822       667.420474
# 304                62073.0                94.299317       294.946997
# 353                81050.0                78.798183       879.752067
# 433                81441.0               121.408376       386.043328
# 540                64504.0               169.876374       307.429254
# ...                    ...                      ...              ...
# 99012              79861.0               252.587910       402.203899
# 99132              61447.0               902.340388       554.658039
# 99425              81751.0                92.127237       668.693417
# 99430              65671.0               168.798784       324.794980
# 99492              75011.0                75.504972       488.165125
#
#       Customer_ID    Month     Occupation Credit_Mix Payment_of_Min_Amount  \
# 92     CUS_0xc0ab     July       Engineer       Good                    No
# 304    CUS_0x42ac    April       Musician   Standard                   Yes
# 353    CUS_0xaedb   August       Musician       Good                    No
# 433    CUS_0x4315  January   Entrepreneur   Standard                    No
# 540    CUS_0x74f2      May      Architect   Standard                    No
# ...           ...      ...            ...        ...                   ...
# 99012  CUS_0x862b     June        Manager       Good                    No
# 99132  CUS_0x5d6d     June         Writer   Standard                    No
# 99425  CUS_0x4986   August   Entrepreneur       Good                    No
# 99430  CUS_0xa053      May         Writer       Good                    No
# 99492   CUS_0xf16    March  Media_Manager       Good                    No
#
#                       Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 92      High_spent_Large_value_payments         Good                3.0
# 304      Low_spent_Small_value_payments     Standard                8.0
# 353     High_spent_Large_value_payments         Good                4.0
# 433      Low_spent_Small_value_payments     Standard                8.0
# 540      Low_spent_Large_value_payments     Standard                5.0
# ...                                 ...          ...                ...
# 99012  High_spent_Medium_value_payments         Poor                5.0
# 99132    Low_spent_Small_value_payments         Good                8.0
# 99425  High_spent_Medium_value_payments         Good                2.0
# 99430   High_spent_Large_value_payments     Standard                2.0
# 99492   Low_spent_Medium_value_payments         Good                1.0
#
#        Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 92                 6.0            1.0                     2.0
# 304                5.0           32.0                    20.0
# 353                2.0            3.0                     7.0
# 433                7.0            6.0                    19.0
# 540                6.0            5.0                    18.0
# ...                ...            ...                     ...
# 99012              7.0           10.0                    13.0
# 99132              7.0            5.0                    19.0
# 99425              3.0            7.0                    10.0
# 99430              7.0            7.0                    10.0
# 99492              1.0            5.0                     0.0
#
#        Num_Credit_Inquiries  Num_of_loan2
# 92                      3.0           2.0
# 304                     9.0           4.0
# 353                     3.0           0.0
# 433                     4.0           4.0
# 540                     4.0           4.0
# ...                     ...           ...
# 99012                   4.0           1.0
# 99132                   0.0           3.0
# 99425                   2.0           1.0
# 99430                   6.0           0.0
# 99492                   8.0           4.0
#
# [885 rows x 23 columns]

# %%
df1[df1.Customer_ID == 'CUS_0x942c']
# Out:
#         Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 99514  24.0       39628.99                 23.0                   9.5
# 99515  25.0       39628.99                 23.0                  11.5
# 99516  25.0       39628.99                 20.0                   9.5
# 99517  25.0       39628.99                 23.0                  11.5
# 99518  25.0       39628.99                 18.0                  11.5
# 99519  25.0       39628.99                 27.0                  11.5
# 99520  25.0       39628.99                 20.0                  11.5
# 99521  25.0       39628.99                 18.0                  11.5
#
#        Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 99514            502.38                 32.991333                31.3
# 99515            502.38                 29.135447                31.4
# 99516            502.38                 39.323569                31.5
# 99517            502.38                 34.663572                31.6
# 99518            502.38                 40.565631                31.7
# 99519            502.38                 41.255522                31.8
# 99520            502.38                 33.638208                31.9
# 99521            502.38                 34.192463                31.1
#
#        Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance  \
# 99514            35.104023               401.196481       488.845639
# 99515         58638.000000               180.733095       390.525592
# 99516            35.104023               140.581403       516.303095
# 99517            35.104023                60.971333       414.546031
# 99518            35.104023                54.185950       654.233454
# 99519            35.104023                24.028477       684.255728
# 99520            35.104023               251.672582       426.509782
# 99521            35.104023               167.163865       446.382819
#
#       Customer_ID     Month Occupation Credit_Mix Payment_of_Min_Amount  \
# 99514  CUS_0x942c   January   Mechanic       Good                    No
# 99515  CUS_0x942c  February   Mechanic       Good                    No
# 99516  CUS_0x942c     March   Mechanic       Good                    No
# 99517  CUS_0x942c     April   Mechanic       Good                    No
# 99518  CUS_0x942c       May   Mechanic       Good                    No
# 99519  CUS_0x942c      June   Mechanic       Good                    No
# 99520  CUS_0x942c      July   Mechanic       Good                    No
# 99521  CUS_0x942c    August   Mechanic       Good                    No
#
#                       Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 99514    Low_spent_Small_value_payments         Poor                4.0
# 99515   Low_spent_Medium_value_payments     Standard                4.0
# 99516  High_spent_Medium_value_payments         Poor                4.0
# 99517   High_spent_Large_value_payments         Poor                4.0
# 99518  High_spent_Medium_value_payments         Poor                4.0
# 99519   High_spent_Large_value_payments         Poor                4.0
# 99520    Low_spent_Large_value_payments     Standard                4.0
# 99521   High_spent_Large_value_payments         Poor                4.0
#
#        Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 99514              6.0            7.0                     6.0
# 99515              6.0            7.0                     6.0
# 99516              6.0            7.0                     6.0
# 99517              6.0            7.0                     7.0
# 99518              6.0            7.0                     7.0
# 99519              6.0            7.0                     6.0
# 99520              6.0            7.0                     6.0
# 99521              6.0            7.0                     6.0
#
#        Num_Credit_Inquiries  Num_of_loan2
# 99514                   3.0           2.0
# 99515                   3.0           2.0
# 99516                   3.0           2.0
# 99517                   3.0           2.0
# 99518                   3.0           2.0
# 99519                   3.0           2.0
# 99520                   3.0           2.0
# 99521                   3.0           2.0

# %%
df1[df1.Customer_ID == 'CUS_0xc0ab']
# Out:
#      Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 86  32.0       88640.24                 -1.0                  3.51
# 87  33.0       88640.24                  4.0                  3.51
# 88  33.0       88640.24                  4.0                  3.51
# 89  33.0       88640.24                  4.0                  3.51
# 90  33.0       88640.24                  4.0                  3.51
# 91  33.0       88640.24                  4.0                  3.51
# 92  33.0       88640.24                  4.0                  3.51
# 93  33.0       88640.24                 -1.0                  3.51
#
#     Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 86            950.36                 28.210617               25.50
# 87            950.36                 41.036168               25.60
# 88            950.36                 34.670194               25.70
# 89            950.36                 31.828536               25.80
# 90            950.36                 34.702837               25.90
# 91            950.36                 38.323639               25.10
# 92            950.36                 25.979173               25.11
# 93            950.36                 30.870799               26.00
#
#     Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance Customer_ID  \
# 86           135.173371                98.931764       732.563532  CUS_0xc0ab
# 87           135.173371               157.174788       674.320507  CUS_0xc0ab
# 88           135.173371               298.188911       543.306384  CUS_0xc0ab
# 89           135.173371              2412.332038        86.636120  CUS_0xc0ab
# 90           135.173371               279.618622       561.876674  CUS_0xc0ab
# 91           135.173371               686.126217       195.369079  CUS_0xc0ab
# 92         80357.000000               164.074822       667.420474  CUS_0xc0ab
# 93           135.173371                98.441951       733.053344  CUS_0xc0ab
#
#        Month Occupation Credit_Mix Payment_of_Min_Amount  \
# 86   January   Engineer       Good                    No
# 87  February   Engineer       Good                    NM
# 88     March   Engineer       Good                    No
# 89     April   Engineer       Good                    No
# 90       May   Engineer       Good                    No
# 91      June   Engineer       Good                    No
# 92      July   Engineer       Good                    No
# 93    August   Engineer       Good                    No
#
#                    Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 86   High_spent_Large_value_payments     Standard                3.0
# 87   High_spent_Large_value_payments         Good                3.0
# 88  High_spent_Medium_value_payments     Standard                3.0
# 89    Low_spent_Small_value_payments     Standard                3.0
# 90  High_spent_Medium_value_payments         Good                3.0
# 91    Low_spent_Small_value_payments         Good                3.0
# 92   High_spent_Large_value_payments         Good                3.0
# 93   High_spent_Large_value_payments         Good                3.0
#
#     Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 86              6.0            1.0                     0.0
# 87              6.0            1.0                     2.0
# 88              6.0            1.0                     0.0
# 89              6.0            1.0                     2.0
# 90              6.0            1.0                     2.0
# 91              6.0            1.0                     0.0
# 92              6.0            1.0                     2.0
# 93              6.0            1.0                     2.0
#
#     Num_Credit_Inquiries  Num_of_loan2
# 86                   3.0           2.0
# 87                   3.0           2.0
# 88                   3.0           2.0
# 89                   3.0           2.0
# 90                   3.0           2.0
# 91                   3.0           2.0
# 92                   3.0           2.0
# 93                   3.0           2.0

# %%
df1[df1.Customer_ID == 'CUS_0x5d6d']
# Out:
#         Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 99127  38.0      126514.72                 21.0                 10.64
# 99128  38.0      126514.72                 21.0                 10.64
# 99129  38.0      126514.72                 26.0                 17.64
# 99130  38.0      126514.72                 21.0                 10.64
# 99131  38.0      126514.72                 21.0                 10.64
# 99132  38.0      126514.72                 21.0                 10.64
# 99133  38.0      126514.72                 21.0                 10.64
# 99134  39.0      126514.72                 16.0                 10.64
#
#        Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 99127            470.42                 39.388005               20.56
# 99128            470.42                 31.521136               29.30
# 99129            470.42                 38.404222               29.40
# 99130            470.42                 40.446888               29.50
# 99131            470.42                 24.720156               29.60
# 99132            470.42                 29.696182               29.70
# 99133            470.42                 35.433181               29.80
# 99134            470.42                 27.048564               17.24
#
#        Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance  \
# 99127           312.032853               267.774185       483.659737
# 99128           312.032853               232.074065       590.002908
# 99129           312.032853               105.667799       375.240289
# 99130           312.032853               314.042671       669.897470
# 99131           312.032853               804.418057       345.855278
# 99132         61447.000000               902.340388       554.658039
# 99133           312.032853               130.270479       533.981453
# 99134           312.032853               416.269711       356.580210
#
#       Customer_ID     Month Occupation Credit_Mix Payment_of_Min_Amount  \
# 99127  CUS_0x5d6d   January     Writer   Standard                    No
# 99128  CUS_0x5d6d  February     Writer   Standard                    No
# 99129  CUS_0x5d6d     March     Writer   Standard                    No
# 99130  CUS_0x5d6d     April     Writer   Standard                    No
# 99131  CUS_0x5d6d       May     Writer   Standard                    No
# 99132  CUS_0x5d6d      June     Writer   Standard                    No
# 99133  CUS_0x5d6d      July     Writer   Standard                    No
# 99134  CUS_0x5d6d    August     Writer   Standard                    No
#
#                       Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 99127    Low_spent_Small_value_payments     Standard                8.0
# 99128   High_spent_Small_value_payments     Standard                8.0
# 99129    Low_spent_Small_value_payments     Standard                8.0
# 99130  High_spent_Medium_value_payments         Good                8.0
# 99131    Low_spent_Small_value_payments         Good                8.0
# 99132    Low_spent_Small_value_payments         Good                8.0
# 99133  High_spent_Medium_value_payments     Standard                8.0
# 99134    Low_spent_Small_value_payments     Standard                8.0
#
#        Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 99127              7.0            5.0                    18.0
# 99128              7.0            5.0                    18.0
# 99129              7.0            5.0                    21.0
# 99130              7.0            5.0                    19.0
# 99131              7.0            5.0                    18.0
# 99132              7.0            5.0                    19.0
# 99133              7.0            5.0                    17.0
# 99134              7.0            5.0                    18.0
#
#        Num_Credit_Inquiries  Num_of_loan2
# 99127                   0.0           3.0
# 99128                   0.0           3.0
# 99129                   0.0           3.0
# 99130                   0.0           3.0
# 99131                   0.0           3.0
# 99132                   0.0           3.0
# 99133                   0.0           3.0
# 99134                   2.0           3.0

# %%
df1[df1.Total_EMI_per_month > 1000]
# Out:
#         Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 38     31.0       73928.46                 12.0                 10.14
# 43     31.0       73928.46                  7.0                 10.14
# 49     34.0      131313.40                  0.0                  8.34
# 50     34.0      131313.40                  0.0                  9.34
# 74     44.0       31370.80                  1.0                  5.76
# ...     ...            ...                  ...                   ...
# 99443  38.0      139664.96                 14.0                 12.39
# 99482  18.0       42903.79                 14.0                  4.10
# 99492  44.0       16680.35                  1.0                  5.69
# 99507  28.0       20002.88                 33.0                 23.31
# 99515  25.0       39628.99                 23.0                 11.50
#
#        Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 38               548.20                 39.962685              29.222
# 43               548.20                 35.275437              23.300
# 49               352.16                 42.645785              30.100
# 50               352.16                 40.902517              30.110
# 74               421.43                 25.189232              26.900
# ...                 ...                       ...                 ...
# 99443            365.66                 40.171095              29.800
# 99482           1079.48                 27.289440              28.100
# 99492            897.16                 30.472041              21.300
# 99507           3571.70                 39.772607               5.900
# 99515            502.38                 29.135447              31.400
#
#        Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance  \
# 38                 15015.0                98.674410       740.196090
# 43                 15515.0               235.790325       633.080175
# 49                 23834.0               337.434956       899.198772
# 50                 32662.0               263.378909       963.254819
# 74                 16415.0               184.700572       341.206633
# ...                    ...                      ...              ...
# 99443              20563.0               421.318866       679.120722
# 99482              50894.0                78.514945       539.282250
# 99492              75011.0                75.504972       488.165125
# 99507              12112.0               148.275233       247.198404
# 99515              58638.0               180.733095       390.525592
#
#       Customer_ID     Month     Occupation Credit_Mix Payment_of_Min_Amount  \
# 38     CUS_0x95ee   January         Lawyer       Good                    No
# 43     CUS_0x95ee      June         Lawyer       Good                    No
# 49     CUS_0x284a     April         Lawyer       Good                    No
# 50     CUS_0x284a       May         Lawyer       Good                    No
# 74     CUS_0xba08       May     Journalist       Good                    No
# ...           ...       ...            ...        ...                   ...
# 99443  CUS_0x2654  February  Media_Manager   Standard                   Yes
# 99482  CUS_0x372c   January         Lawyer       Good                    No
# 99492   CUS_0xf16     March  Media_Manager       Good                    No
# 99507  CUS_0x8600  February      Architect        Bad                   Yes
# 99515  CUS_0x942c  February       Mechanic       Good                    No
#
#                       Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 38      High_spent_Large_value_payments         Good                4.0
# 43       Low_spent_Large_value_payments         Good                4.0
# 49     High_spent_Medium_value_payments         Good                0.0
# 50      High_spent_Large_value_payments         Good                0.0
# 74       Low_spent_Small_value_payments         Good                1.0
# ...                                 ...          ...                ...
# 99443  High_spent_Medium_value_payments     Standard                3.0
# 99482   High_spent_Small_value_payments         Good                0.0
# 99492   Low_spent_Medium_value_payments         Good                1.0
# 99507    Low_spent_Small_value_payments         Poor               10.0
# 99515   Low_spent_Medium_value_payments     Standard                4.0
#
#        Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 38                 5.0            8.0                    10.0
# 43                 5.0            8.0                     7.0
# 49                 1.0            8.0                     2.0
# 50                 1.0            8.0                     4.0
# 74                 6.0           12.0                     0.0
# ...                ...            ...                     ...
# 99443              6.0           12.0                    12.0
# 99482              4.0            6.0                     0.0
# 99492              1.0            5.0                     0.0
# 99507              8.0           29.0                    25.0
# 99515              6.0            7.0                     6.0
#
#        Num_Credit_Inquiries  Num_of_loan2
# 38                      2.0           0.0
# 43                      2.0           0.0
# 49                      4.0           2.0
# 50                      4.0           2.0
# 74                      5.0           2.0
# ...                     ...           ...
# 99443                   8.0           4.0
# 99482                   1.0           1.0
# 99492                   8.0           4.0
# 99507                   9.0           5.0
# 99515                   3.0           2.0
#
# [3396 rows x 23 columns]

# %%
df1[df1.Customer_ID == 'CUS_0x95ee']
# Out:
#      Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 38  31.0       73928.46                 12.0                 10.14
# 39  31.0       73928.46                  8.0                 10.14
# 40  31.0       73928.46                  8.0                 10.14
# 41  31.0       73928.46                  8.0                 10.14
# 42  31.0       73928.46                 11.0                 10.14
# 43  31.0       73928.46                  7.0                 10.14
# 44  31.0       73928.46                  8.0                  9.14
# 45  31.0       73928.46                  8.0                 10.14
#
#     Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 38             548.2                 39.962685              29.222
# 39             548.2                 42.769864              32.000
# 40             548.2                 40.712187              24.220
# 41             548.2                 30.201658              32.200
# 42             548.2                 26.333310              32.300
# 43             548.2                 35.275437              23.300
# 44             548.2                 36.624791              32.500
# 45             548.2                 31.580990              32.600
#
#     Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance Customer_ID  \
# 38              15015.0                98.674410       740.196090  CUS_0x95ee
# 39                  0.0               172.939214       705.931286  CUS_0x95ee
# 40                  0.0               150.059734       698.810766  CUS_0x95ee
# 41                  0.0               618.202391       270.668109  CUS_0x95ee
# 42                  0.0               177.951836       690.918664  CUS_0x95ee
# 43              15515.0               235.790325       633.080175  CUS_0x95ee
# 44                  0.0               348.509400       510.361100  CUS_0x95ee
# 45                  0.0                42.635590       796.234910  CUS_0x95ee
#
#        Month Occupation Credit_Mix Payment_of_Min_Amount  \
# 38   January     Lawyer       Good                    No
# 39  February     Lawyer       Good                    NM
# 40     March     Lawyer       Good                    No
# 41     April     Lawyer       Good                    No
# 42       May     Lawyer       Good                    No
# 43      June     Lawyer       Good                    No
# 44      July     Lawyer       Good                    No
# 45    August     Lawyer       Good                    No
#
#                    Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 38   High_spent_Large_value_payments         Good                4.0
# 39   Low_spent_Medium_value_payments         Good                4.0
# 40  High_spent_Medium_value_payments         Good                4.0
# 41    Low_spent_Small_value_payments         Good                4.0
# 42    Low_spent_Large_value_payments         Good                4.0
# 43    Low_spent_Large_value_payments         Good                4.0
# 44   High_spent_Small_value_payments     Standard                4.0
# 45    Low_spent_Large_value_payments         Good                4.0
#
#     Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 38              5.0            8.0                    10.0
# 39              5.0            8.0                     7.0
# 40              5.0            8.0                     7.0
# 41              5.0            8.0                     7.0
# 42              5.0            8.0                     7.0
# 43              5.0            8.0                     7.0
# 44              5.0            8.0                     4.0
# 45              5.0            8.0                     7.0
#
#     Num_Credit_Inquiries  Num_of_loan2
# 38                   2.0           0.0
# 39                   2.0           0.0
# 40                   2.0           0.0
# 41                   2.0           0.0
# 42                   2.0           0.0
# 43                   2.0           0.0
# 44                   2.0           0.0
# 45                   2.0           0.0

# %%
df1[df1.Customer_ID == 'CUS_0x284a']

### do later
# Out:
#      Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 46  33.0       131313.4                  0.0                  9.34
# 47  34.0       131313.4                 -1.0                 15.34
# 48  34.0       131313.4                  0.0                  9.34
# 49  34.0       131313.4                  0.0                  8.34
# 50  34.0       131313.4                  0.0                  9.34
# 51  34.0       131313.4                  0.0                 11.34
# 52  34.0     10909427.0                  0.0                  9.34
# 53  34.0       131313.4                  0.0                  9.34
#
#     Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 46            352.16                 32.200509               30.70
# 47            352.16                 31.983710               30.80
# 48            352.16                 31.803134               30.90
# 49            352.16                 42.645785               30.10
# 50            352.16                 40.902517               30.11
# 51            352.16                 41.980170               31.00
# 52            352.16                 26.947565               31.10
# 53            352.16                 29.187913               31.20
#
#     Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance Customer_ID  \
# 46           137.644605               378.171254       858.462474  CUS_0x284a
# 47           137.644605               698.873271       547.760457  CUS_0x284a
# 48           911.220179               188.064321      1038.569407  CUS_0x284a
# 49         23834.000000               337.434956       899.198772  CUS_0x284a
# 50         32662.000000               263.378909       963.254819  CUS_0x284a
# 51           911.220179                86.566388      1140.067340  CUS_0x284a
# 52           911.220179               930.391898       326.241830  CUS_0x284a
# 53           911.220179               870.522382       396.111346  CUS_0x284a
#
#        Month Occupation Credit_Mix Payment_of_Min_Amount  \
# 46   January     Lawyer       Good                    NM
# 47  February     Lawyer       Good                    No
# 48     March     Lawyer       Good                    NM
# 49     April     Lawyer       Good                    No
# 50       May     Lawyer       Good                    No
# 51      June     Lawyer       Good                    No
# 52      July     Lawyer       Good                    No
# 53    August     Lawyer       Good                    No
#
#                    Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 46  High_spent_Medium_value_payments         Good                0.0
# 47   High_spent_Small_value_payments         Good                0.0
# 48   High_spent_Large_value_payments         Good                0.0
# 49  High_spent_Medium_value_payments         Good                0.0
# 50   High_spent_Large_value_payments         Good                0.0
# 51   High_spent_Large_value_payments     Standard                0.0
# 52   High_spent_Large_value_payments         Good                0.0
# 53   Low_spent_Medium_value_payments         Good                0.0
#
#     Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 46              1.0            8.0                     3.0
# 47              1.0            8.0                     2.0
# 48              1.0            8.0                     3.0
# 49              1.0            8.0                     2.0
# 50              1.0            8.0                     4.0
# 51              1.0            8.0                     3.0
# 52              1.0            8.0                     2.0
# 53              1.0            8.0                     2.0
#
#     Num_Credit_Inquiries  Num_of_loan2
# 46                   2.0           2.0
# 47                   4.0           2.0
# 48                   4.0           2.0
# 49                   4.0           2.0
# 50                   4.0           2.0
# 51                   4.0           2.0
# 52                   4.0           2.0
# 53                   4.0           2.0

# %%
#now we will fix amount inversted monthly
df1[df1.Amount_invested_monthly < 0]
# Out:
# Empty DataFrame
# Columns: [Age, Annual_Income, Delay_from_due_date, Changed_Credit_Limit, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Total_EMI_per_month, Amount_invested_monthly, Monthly_Balance, Customer_ID, Month, Occupation, Credit_Mix, Payment_of_Min_Amount, Payment_Behaviour, Credit_Score, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Delayed_Payment, Num_Credit_Inquiries, Num_of_loan2]
# Index: []

# %%
df1.Amount_invested_monthly.value_counts()
# Out:
# 10000.000000    4296
# 0.000000         169
# 108.839397         2
# 524.143716         1
# 121.048884         1
#                 ...
# 151.888158         1
# 464.859654         1
# 1159.589073        1
# 266.026937         1
# 167.163865         1
# Name: Amount_invested_monthly, Length: 95058, dtype: int64

# %%
df1.Amount_invested_monthly.max()
# Out:
# 10000.0

# %%
df1.Amount_invested_monthly.min()
# Out:
# 0.0

# %%
df1[df1.Amount_invested_monthly == 10000]
# Out:
#         Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 18     34.0      143162.64                  8.0                 11.10
# 23     34.0      143162.64                  8.0                  7.10
# 28     55.0       30689.89                  5.0                 -1.01
# 119    30.0       31993.78                 12.0                  6.28
# 140    46.0       32284.62                  7.0                  9.22
# ...     ...            ...                  ...                   ...
# 99401  27.0      118677.54                  3.0                  9.59
# 99404  31.0    16884797.00                  7.0                 12.57
# 99441  54.0       20059.98                 25.0                  2.97
# 99473  33.0       59146.36                  8.0                  6.68
# 99495  44.0       16680.35                  1.0                  0.69
#
#        Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 18              1303.01                 26.519815               17.11
# 23              1303.01                 38.374753               18.40
# 28               632.46                 41.154317               17.70
# 119              818.22                 37.958569               16.11
# 140             1283.37                 24.205533                6.11
# ...                 ...                       ...                 ...
# 99401            995.47                 39.747228               30.60
# 99404            330.60                 38.524095               23.00
# 99441            909.01                 32.473773               16.10
# 99473            418.03                 27.682186               20.80
# 99495            897.16                 24.972853               21.60
#
#        Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance  \
# 18              246.992319                  10000.0       715.741367
# 23              246.992319                  10000.0       895.494583
# 28               16.415452                  10000.0       359.374916
# 119              45.141298                  10000.0       157.869804
# 140             103.037560                  10000.0        85.902095
# ...                    ...                      ...              ...
# 99401           237.106366                  10000.0       753.849137
# 99404             0.000000                  10000.0       470.586703
# 99441            45.076827                  10000.0       582.082361
# 99473            26.778419                  10000.0       427.670851
# 99495            41.113561                  10000.0       310.895990
#
#       Customer_ID     Month     Occupation Credit_Mix Payment_of_Min_Amount  \
# 18     CUS_0x2dbc     March       Engineer       Good                    No
# 23     CUS_0x2dbc    August       Engineer       Good                    No
# 28     CUS_0xb891       May   Entrepreneur       Good                    No
# 119    CUS_0x33d2  February      Scientist   Standard                   Yes
# 140     CUS_0xfdb      July        Teacher   Standard                   Yes
# ...           ...       ...            ...        ...                   ...
# 99401  CUS_0x3855    August      Scientist       Good                    No
# 99404  CUS_0x47fa     March       Mechanic   Standard                   Yes
# 99441  CUS_0x1619    August  Media_Manager       Good                    No
# 99473  CUS_0x51b3    August  Media_Manager       Good                    No
# 99495   CUS_0xf16      June  Media_Manager       Good                    No
#
#                       Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 18      High_spent_Small_value_payments         Good                1.0
# 23      High_spent_Small_value_payments     Standard                1.0
# 28       Low_spent_Large_value_payments     Standard                2.0
# 119      Low_spent_Small_value_payments     Standard                6.0
# 140      Low_spent_Small_value_payments     Standard                6.0
# ...                                 ...          ...                ...
# 99401  High_spent_Medium_value_payments         Good                4.0
# 99404   High_spent_Small_value_payments     Standard                7.0
# 99441    Low_spent_Small_value_payments         Poor                8.0
# 99473    Low_spent_Large_value_payments     Standard                3.0
# 99495    Low_spent_Small_value_payments         Good                1.0
#
#        Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 18                 5.0            8.0                     7.0
# 23                 5.0            8.0                     6.0
# 28                 5.0            4.0                     6.0
# 119                6.0            7.0                    14.0
# 140                7.0           17.0                    12.0
# ...                ...            ...                     ...
# 99401              4.0            6.0                    11.0
# 99404              3.0           15.0                     8.0
# 99441              5.0           12.0                    11.0
# 99473              6.0            6.0                     6.0
# 99495              1.0            5.0                     0.0
#
#        Num_Credit_Inquiries  Num_of_loan2
# 18                      3.0           3.0
# 23                      3.0           3.0
# 28                      4.0           1.0
# 119                     0.0           2.0
# 140                    10.0           6.0
# ...                     ...           ...
# 99401                   5.0           4.0
# 99404                   2.0           0.0
# 99441                   8.0           4.0
# 99473                   5.0           1.0
# 99495                   8.0           4.0
#
# [4296 rows x 23 columns]

# %%
df1[df1.Customer_ID == 'CUS_0x33d2']
# Out:
#       Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 118  30.0       31993.78                  8.0                  6.28
# 119  30.0       31993.78                 12.0                  6.28
# 120  30.0       31993.78                  8.0                 10.28
# 121  30.0       31993.78                  8.0                  6.28
# 122  30.0       31993.78                  8.0                  6.28
# 123  30.0       31993.78                  8.0                  6.28
# 124  30.0       31993.78                  8.0                  6.28
# 125  30.0       31993.78                  8.0                  6.28
#
#      Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 118            818.22                 25.369597               16.10
# 119            818.22                 37.958569               16.11
# 120            818.22                 27.380109               17.00
# 121            818.22                 34.158262               17.10
# 122            818.22                 30.788039               17.20
# 123            818.22                 34.280969               17.30
# 124            818.22                 29.503454               17.40
# 125            818.22                 36.012794               17.50
#
#      Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance  \
# 118            45.141298                81.998835       447.074700
# 119            45.141298             10000.000000       157.869804
# 120            45.141298               264.257089       274.816447
# 121            45.141298               152.452326       376.621209
# 122            45.141298                43.470409       455.603126
# 123            45.141298               112.723887       396.349648
# 124            45.141298               104.557236       404.516299
# 125            45.141298                97.588203       421.485332
#
#     Customer_ID     Month Occupation Credit_Mix Payment_of_Min_Amount  \
# 118  CUS_0x33d2   January  Scientist   Standard                   Yes
# 119  CUS_0x33d2  February  Scientist   Standard                   Yes
# 120  CUS_0x33d2     March  Scientist   Standard                   Yes
# 121  CUS_0x33d2     April  Scientist   Standard                   Yes
# 122  CUS_0x33d2       May  Scientist   Standard                   Yes
# 123  CUS_0x33d2      June  Scientist   Standard                   Yes
# 124  CUS_0x33d2      July  Scientist   Standard                   Yes
# 125  CUS_0x33d2    August  Scientist   Standard                   Yes
#
#                     Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 118   Low_spent_Medium_value_payments     Standard                6.0
# 119    Low_spent_Small_value_payments     Standard                6.0
# 120    Low_spent_Small_value_payments     Standard                6.0
# 121   Low_spent_Medium_value_payments     Standard                6.0
# 122  High_spent_Medium_value_payments     Standard                6.0
# 123   High_spent_Small_value_payments     Standard                6.0
# 124   High_spent_Small_value_payments     Standard                6.0
# 125    Low_spent_Large_value_payments     Standard                6.0
#
#      Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 118              6.0            7.0                    14.0
# 119              6.0            7.0                    14.0
# 120              6.0            7.0                    14.0
# 121              6.0            7.0                    14.0
# 122              6.0            7.0                    14.0
# 123              6.0            7.0                    14.0
# 124              6.0            7.0                    16.0
# 125              6.0            7.0                    16.0
#
#      Num_Credit_Inquiries  Num_of_loan2
# 118                   0.0           2.0
# 119                   0.0           2.0
# 120                   1.0           2.0
# 121                   1.0           2.0
# 122                   1.0           2.0
# 123                   1.0           2.0
# 124                   1.0           2.0
# 125                   1.0           2.0

# %%
df1[df1.Customer_ID == 'CUS_0x1619']
#it look's and we will procceed further
# Out:
#         Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 99434  54.0       20059.98                 25.0                  2.97
# 99435  54.0       20059.98                 25.0                  2.97
# 99436  54.0       20059.98                 25.0                  2.97
# 99437  54.0       20059.98                 25.0                  2.97
# 99438  54.0       20059.98                 25.0                  2.97
# 99439  54.0       20059.98                 23.0                  2.97
# 99440  54.0       20059.98                 25.0                  2.97
# 99441  54.0       20059.98                 25.0                  2.97
#
#        Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 99434            909.01                 30.568185              16.300
# 99435            909.01                 25.982154              16.400
# 99436            909.01                 29.204711              16.500
# 99437            909.01                 27.341526              27.122
# 99438            909.01                 29.808796              19.740
# 99439            909.01                 34.413070              16.800
# 99440            909.01                 37.619516              16.900
# 99441            909.01                 32.473773              16.100
#
#        Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance  \
# 99434          6980.000000               151.214086       449.255341
# 99435            45.076827                74.713580       384.994750
# 99436            45.076827               111.567139       492.551069
# 99437            45.076827                83.694307       454.008675
# 99438            45.076827                49.712994       474.852462
# 99439            45.076827               118.116365       482.600497
# 99440            45.076827                72.166230       300.547929
# 99441            45.076827             10000.000000       582.082361
#
#       Customer_ID     Month     Occupation Credit_Mix Payment_of_Min_Amount  \
# 99434  CUS_0x1619   January  Media_Manager       Good                    No
# 99435  CUS_0x1619  February  Media_Manager       Good                    No
# 99436  CUS_0x1619     March  Media_Manager       Good                    No
# 99437  CUS_0x1619     April  Media_Manager       Good                    No
# 99438  CUS_0x1619       May  Media_Manager       Good                    NM
# 99439  CUS_0x1619      June  Media_Manager       Good                    No
# 99440  CUS_0x1619      July  Media_Manager       Good                    No
# 99441  CUS_0x1619    August  Media_Manager       Good                    No
#
#                      Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 99434  Low_spent_Medium_value_payments         Poor                8.0
# 99435  High_spent_Small_value_payments         Poor                8.0
# 99436   Low_spent_Large_value_payments         Poor                8.0
# 99437   Low_spent_Small_value_payments         Poor                8.0
# 99438  Low_spent_Medium_value_payments         Poor                8.0
# 99439   Low_spent_Small_value_payments         Poor                8.0
# 99440   Low_spent_Small_value_payments         Poor                8.0
# 99441   Low_spent_Small_value_payments         Poor                8.0
#
#        Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 99434              5.0           12.0                    11.0
# 99435              5.0           12.0                    11.0
# 99436              5.0           12.0                     9.0
# 99437              5.0           12.0                    11.0
# 99438              5.0           12.0                    11.0
# 99439              5.0           12.0                    11.0
# 99440              5.0           12.0                     8.0
# 99441              5.0           12.0                    11.0
#
#        Num_Credit_Inquiries  Num_of_loan2
# 99434                   3.0           4.0
# 99435                   3.0           4.0
# 99436                   3.0           4.0
# 99437                   3.0           4.0
# 99438                   3.0           4.0
# 99439                   8.0           4.0
# 99440                   8.0           4.0
# 99441                   8.0           4.0

# %%
##now we will work on Monthly_Balance

df1.Monthly_Balance[df1.Monthly_Balance < 0] = np.nan

# %%
df1.Monthly_Balance.value_counts()
# Out:
# 444.372118    2
# 422.696954    2
# 230.204225    2
# 247.389787    2
# 392.118254    2
#              ..
# 364.013997    1
# 264.554377    1
# 235.539689    1
# 337.725739    1
# 446.382819    1
# Name: Monthly_Balance, Length: 99507, dtype: int64

# %%
df1.Monthly_Balance.min()
# Out:
# 0.007759664775335295

# %%
df1.Monthly_Balance.max()
#this is fine and we will proceed further
# Out:
# 1602.040518962252

# %%
# now we will work on num of loan

# %%
df1[df1.Num_of_loan2 < 0]
# Out:
# Empty DataFrame
# Columns: [Age, Annual_Income, Delay_from_due_date, Changed_Credit_Limit, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Total_EMI_per_month, Amount_invested_monthly, Monthly_Balance, Customer_ID, Month, Occupation, Credit_Mix, Payment_of_Min_Amount, Payment_Behaviour, Credit_Score, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Delayed_Payment, Num_Credit_Inquiries, Num_of_loan2]
# Index: []

# %%
df1.Num_of_loan2.value_counts()
#this is fine and we will proceed futher
# Out:
# 3.0    15752
# 2.0    15712
# 4.0    15456
# 1.0    11128
# 0.0    10930
# 6.0     8144
# 7.0     7680
# 5.0     7528
# 9.0     3856
# 8.0     3336
# Name: Num_of_loan2, dtype: int64

# %%
df1.select_dtypes(object).columns
# Out:
# Index(['Customer_ID', 'Month', 'Occupation', 'Credit_Mix',
#        'Payment_of_Min_Amount', 'Payment_Behaviour', 'Credit_Score'],
#       dtype='object')

# %%
df1.select_dtypes(include='number').columns
# Out:
# Index(['Age', 'Annual_Income', 'Delay_from_due_date', 'Changed_Credit_Limit',
#        'Outstanding_Debt', 'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Total_EMI_per_month', 'Amount_invested_monthly', 'Monthly_Balance',
#        'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate',
#        'Num_of_Delayed_Payment', 'Num_Credit_Inquiries', 'Num_of_loan2'],
#       dtype='object')

# %%
df1.Annual_Income.value_counts().sort_index(ascending=False)
# Out:
# 2.419806e+07    1
# 2.418881e+07    1
# 2.417715e+07    1
# 2.416001e+07    1
# 2.410537e+07    1
#                ..
# 7.012310e+03    8
# 7.011685e+03    8
# 7.006520e+03    8
# 7.006035e+03    8
# 7.005930e+03    8
# Name: Annual_Income, Length: 13482, dtype: int64

# %%
df1.isnull().sum()
# Out:
# Age                         0
# Annual_Income               0
# Delay_from_due_date         0
# Changed_Credit_Limit        0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Monthly_Balance             0
# Customer_ID                 0
# Month                       0
# Occupation                  0
# Credit_Mix                  0
# Payment_of_Min_Amount       0
# Payment_Behaviour           0
# Credit_Score                0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Delayed_Payment      0
# Num_Credit_Inquiries        0
# Num_of_loan2                0
# dtype: int64

# %%
df1["Amount_invested_monthly"][df1["Amount_invested_monthly"]==10000] = np.nan

# %%
df1[df1["Amount_invested_monthly"].isnull()]
# Out:
#         Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 18     34.0      143162.64                  8.0                 11.10
# 23     34.0      143162.64                  8.0                  7.10
# 28     55.0       30689.89                  5.0                 -1.01
# 119    30.0       31993.78                 12.0                  6.28
# 140    46.0       32284.62                  7.0                  9.22
# ...     ...            ...                  ...                   ...
# 99401  27.0      118677.54                  3.0                  9.59
# 99404  31.0    16884797.00                  7.0                 12.57
# 99441  54.0       20059.98                 25.0                  2.97
# 99473  33.0       59146.36                  8.0                  6.68
# 99495  44.0       16680.35                  1.0                  0.69
#
#        Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 18              1303.01                 26.519815               17.11
# 23              1303.01                 38.374753               18.40
# 28               632.46                 41.154317               17.70
# 119              818.22                 37.958569               16.11
# 140             1283.37                 24.205533                6.11
# ...                 ...                       ...                 ...
# 99401            995.47                 39.747228               30.60
# 99404            330.60                 38.524095               23.00
# 99441            909.01                 32.473773               16.10
# 99473            418.03                 27.682186               20.80
# 99495            897.16                 24.972853               21.60
#
#        Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance  \
# 18              246.992319                      NaN       715.741367
# 23              246.992319                      NaN       895.494583
# 28               16.415452                      NaN       359.374916
# 119              45.141298                      NaN       157.869804
# 140             103.037560                      NaN        85.902095
# ...                    ...                      ...              ...
# 99401           237.106366                      NaN       753.849137
# 99404             0.000000                      NaN       470.586703
# 99441            45.076827                      NaN       582.082361
# 99473            26.778419                      NaN       427.670851
# 99495            41.113561                      NaN       310.895990
#
#       Customer_ID     Month     Occupation Credit_Mix Payment_of_Min_Amount  \
# 18     CUS_0x2dbc     March       Engineer       Good                    No
# 23     CUS_0x2dbc    August       Engineer       Good                    No
# 28     CUS_0xb891       May   Entrepreneur       Good                    No
# 119    CUS_0x33d2  February      Scientist   Standard                   Yes
# 140     CUS_0xfdb      July        Teacher   Standard                   Yes
# ...           ...       ...            ...        ...                   ...
# 99401  CUS_0x3855    August      Scientist       Good                    No
# 99404  CUS_0x47fa     March       Mechanic   Standard                   Yes
# 99441  CUS_0x1619    August  Media_Manager       Good                    No
# 99473  CUS_0x51b3    August  Media_Manager       Good                    No
# 99495   CUS_0xf16      June  Media_Manager       Good                    No
#
#                       Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 18      High_spent_Small_value_payments         Good                1.0
# 23      High_spent_Small_value_payments     Standard                1.0
# 28       Low_spent_Large_value_payments     Standard                2.0
# 119      Low_spent_Small_value_payments     Standard                6.0
# 140      Low_spent_Small_value_payments     Standard                6.0
# ...                                 ...          ...                ...
# 99401  High_spent_Medium_value_payments         Good                4.0
# 99404   High_spent_Small_value_payments     Standard                7.0
# 99441    Low_spent_Small_value_payments         Poor                8.0
# 99473    Low_spent_Large_value_payments     Standard                3.0
# 99495    Low_spent_Small_value_payments         Good                1.0
#
#        Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 18                 5.0            8.0                     7.0
# 23                 5.0            8.0                     6.0
# 28                 5.0            4.0                     6.0
# 119                6.0            7.0                    14.0
# 140                7.0           17.0                    12.0
# ...                ...            ...                     ...
# 99401              4.0            6.0                    11.0
# 99404              3.0           15.0                     8.0
# 99441              5.0           12.0                    11.0
# 99473              6.0            6.0                     6.0
# 99495              1.0            5.0                     0.0
#
#        Num_Credit_Inquiries  Num_of_loan2
# 18                      3.0           3.0
# 23                      3.0           3.0
# 28                      4.0           1.0
# 119                     0.0           2.0
# 140                    10.0           6.0
# ...                     ...           ...
# 99401                   5.0           4.0
# 99404                   2.0           0.0
# 99441                   8.0           4.0
# 99473                   5.0           1.0
# 99495                   8.0           4.0
#
# [4296 rows x 23 columns]

# %%
aim = ""
for i in df1.Customer_ID[df1.Amount_invested_monthly.isnull()]:
    aim = df1.Amount_invested_monthly[(df1.Customer_ID ==i) & (df1.Amount_invested_monthly.notnull())]
    df1.Amount_invested_monthly[(df1.Customer_ID == i) & (df1.Amount_invested_monthly.isnull())] = aim.mean()

# %%
df1[df1.Customer_ID == 'CUS_0x2dbc']
# Out:
#      Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 16  34.0      143162.64                  5.0                   7.1
# 17  34.0      143162.64                 13.0                   7.1
# 18  34.0      143162.64                  8.0                  11.1
# 19  34.0      143162.64                  8.0                   9.1
# 20  34.0      143162.64                 10.0                   7.1
# 21  34.0      143162.64                  8.0                   7.1
# 22  34.0      143162.64                  8.0                   7.1
# 23  34.0      143162.64                  8.0                   7.1
#
#     Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 16           1303.01                 28.616735               17.90
# 17           1303.01                 41.702573               17.10
# 18           1303.01                 26.519815               17.11
# 19           1303.01                 39.501648               16.36
# 20           1303.01                 31.376150               18.10
# 21           1303.01                 39.783993               18.20
# 22           1303.01                 38.068624               18.30
# 23           1303.01                 38.374753               18.40
#
#     Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance Customer_ID  \
# 16           246.992319               168.413703      1043.315978  CUS_0x2dbc
# 17           246.992319               232.860384       998.869297  CUS_0x2dbc
# 18           246.992319               363.070024       715.741367  CUS_0x2dbc
# 19           246.992319               825.216270       426.513411  CUS_0x2dbc
# 20           246.992319               430.947528       810.782153  CUS_0x2dbc
# 21           246.992319               257.808099       963.921581  CUS_0x2dbc
# 22           246.992319               263.174163       968.555517  CUS_0x2dbc
# 23           246.992319               363.070024       895.494583  CUS_0x2dbc
#
#        Month Occupation Credit_Mix Payment_of_Min_Amount  \
# 16   January   Engineer       Good                    No
# 17  February   Engineer       Good                    No
# 18     March   Engineer       Good                    No
# 19     April   Engineer       Good                    No
# 20       May   Engineer       Good                    No
# 21      June   Engineer       Good                    No
# 22      July   Engineer       Good                    No
# 23    August   Engineer       Good                    No
#
#                    Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 16   High_spent_Small_value_payments         Good                1.0
# 17   High_spent_Small_value_payments         Good                1.0
# 18   High_spent_Small_value_payments         Good                1.0
# 19   Low_spent_Medium_value_payments         Good                1.0
# 20    Low_spent_Large_value_payments         Good                1.0
# 21  High_spent_Medium_value_payments         Good                1.0
# 22   High_spent_Small_value_payments     Standard                1.0
# 23   High_spent_Small_value_payments     Standard                1.0
#
#     Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 16              5.0            8.0                     8.0
# 17              5.0            8.0                     6.0
# 18              5.0            8.0                     7.0
# 19              5.0            8.0                     5.0
# 20              5.0            8.0                     5.0
# 21              5.0            8.0                     6.0
# 22              5.0            8.0                     6.0
# 23              5.0            8.0                     6.0
#
#     Num_Credit_Inquiries  Num_of_loan2
# 16                   3.0           3.0
# 17                   3.0           3.0
# 18                   3.0           3.0
# 19                   3.0           3.0
# 20                   3.0           3.0
# 21                   3.0           3.0
# 22                   3.0           3.0
# 23                   3.0           3.0

# %%
df1["Amount_invested_monthly"].max()
# Out:
# 6303.636969241102

# %%
df1[df1["Customer_ID"]=="CUS_0xb891"]
# Out:
#      Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 24  54.0       30689.89                  0.0                  1.99
# 25  54.0       30689.89                  5.0                  1.99
# 26  55.0       30689.89                  3.0                  1.99
# 27  55.0       30689.89                  7.0                 -2.01
# 28  55.0       30689.89                  5.0                 -1.01
# 29  55.0       30689.89                  5.0                 -3.01
# 30  55.0       30689.89                  5.0                  1.99
# 31  55.0       30689.89                  4.0                  1.99
#
#     Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 24            632.46                 26.544229                17.3
# 25            632.46                 35.279982                17.4
# 26            632.46                 32.301163                17.5
# 27            632.46                 38.132348                17.6
# 28            632.46                 41.154317                17.7
# 29            632.46                 27.445422                17.8
# 30            632.46                 26.056395                17.9
# 31            632.46                 27.332515                17.1
#
#     Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance Customer_ID  \
# 24            16.415452                81.228859       433.604773  CUS_0xb891
# 25            16.415452               124.881820       409.951812  CUS_0xb891
# 26            16.415452                83.406509       411.427123  CUS_0xb891
# 27            16.415452               272.334037       262.499594  CUS_0xb891
# 28            16.415452               120.529285       359.374916  CUS_0xb891
# 29            16.415452                84.952848       419.880784  CUS_0xb891
# 30            16.415452                71.283675       443.549957  CUS_0xb891
# 31            16.415452               125.617251       379.216381  CUS_0xb891
#
#        Month    Occupation Credit_Mix Payment_of_Min_Amount  \
# 24   January  Entrepreneur       Good                    No
# 25  February  Entrepreneur       Good                    No
# 26     March  Entrepreneur       Good                    NM
# 27     April  Entrepreneur       Good                    No
# 28       May  Entrepreneur       Good                    No
# 29      June  Entrepreneur       Good                    No
# 30      July  Entrepreneur       Good                    No
# 31    August  Entrepreneur       Good                    No
#
#                    Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 24    Low_spent_Large_value_payments     Standard                2.0
# 25    Low_spent_Small_value_payments     Standard                2.0
# 26  High_spent_Medium_value_payments     Standard                2.0
# 27    Low_spent_Small_value_payments     Standard                2.0
# 28    Low_spent_Large_value_payments     Standard                2.0
# 29   High_spent_Small_value_payments     Standard                2.0
# 30    Low_spent_Large_value_payments     Standard                2.0
# 31   High_spent_Small_value_payments     Standard                2.0
#
#     Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 24              5.0            4.0                     6.0
# 25              5.0            4.0                     3.0
# 26              5.0            4.0                     9.0
# 27              5.0            4.0                     6.0
# 28              5.0            4.0                     6.0
# 29              5.0            4.0                     6.0
# 30              5.0            4.0                     6.0
# 31              5.0            4.0                     9.0
#
#     Num_Credit_Inquiries  Num_of_loan2
# 24                   4.0           1.0
# 25                   4.0           1.0
# 26                   4.0           1.0
# 27                   4.0           1.0
# 28                   4.0           1.0
# 29                   4.0           1.0
# 30                   4.0           1.0
# 31                   4.0           1.0

# %%
df1.Annual_Income[df1.Customer_ID =="CUS_0xb891"].mode()[0]
# Out:
# 30689.890000000014

# %%
df1[df1["Customer_ID"]=="CUS_0xbffe"] #CUS_0xd40 # CUS_0x942c #CUS_0x21b1
# Out:
#       Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 221  40.0       28572.39                 25.0                  4.89
# 222  40.0       28572.39                 25.0                  4.89
# 223  40.0       28572.39                 28.0                  4.89
# 224  40.0       28572.39                 25.0                  4.89
# 225  40.0       28572.39                 25.0                  4.89
# 226  40.0       28572.39                 25.0                  4.89
# 227  40.0       28572.39                 25.0                  4.89
# 228  40.0     6515990.00                 25.0                  4.89
#
#      Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 221            400.07                 24.422251               30.30
# 222            400.07                 36.437870               30.40
# 223            400.07                 29.323517               30.50
# 224            400.07                 34.714561               30.60
# 225            400.07                 37.504552               30.70
# 226            400.07                 35.693949               30.80
# 227            400.07                 35.025883               28.78
# 228            400.07                 23.177617               30.10
#
#      Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance  \
# 221             69.60292                42.850507       348.549822
# 222             69.60292                83.044209       358.356121
# 223             69.60292                53.484203       347.916126
# 224             69.60292                25.993462       375.406867
# 225             69.60292                61.628109       339.772220
# 226             69.60292               129.264835       312.135495
# 227             69.60292                76.607809       364.792521
# 228             69.60292                51.830859       339.569471
#
#     Customer_ID     Month Occupation Credit_Mix Payment_of_Min_Amount  \
# 221  CUS_0xbffe   January  Architect   Standard                   Yes
# 222  CUS_0xbffe  February  Architect   Standard                    NM
# 223  CUS_0xbffe     March  Architect   Standard                   Yes
# 224  CUS_0xbffe     April  Architect   Standard                   Yes
# 225  CUS_0xbffe       May  Architect   Standard                   Yes
# 226  CUS_0xbffe      June  Architect   Standard                   Yes
# 227  CUS_0xbffe      July  Architect   Standard                   Yes
# 228  CUS_0xbffe    August  Architect   Standard                   Yes
#
#                     Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 221   High_spent_Large_value_payments     Standard                6.0
# 222  High_spent_Medium_value_payments     Standard                6.0
# 223  High_spent_Medium_value_payments     Standard                6.0
# 224  High_spent_Medium_value_payments     Standard                6.0
# 225  High_spent_Medium_value_payments     Standard                6.0
# 226    Low_spent_Small_value_payments     Standard                6.0
# 227    Low_spent_Small_value_payments     Standard                6.0
# 228   High_spent_Large_value_payments     Standard                6.0
#
#      Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 221              3.0           15.0                    12.0
# 222              3.0           15.0                     9.0
# 223              3.0           15.0                    10.0
# 224              3.0           15.0                    14.0
# 225              3.0           15.0                    12.0
# 226              3.0           15.0                    11.0
# 227              3.0           15.0                    13.0
# 228              3.0           15.0                    12.0
#
#      Num_Credit_Inquiries  Num_of_loan2
# 221                   0.0           3.0
# 222                   0.0           3.0
# 223                   0.0           3.0
# 224                   0.0           3.0
# 225                   2.0           3.0
# 226                   2.0           3.0
# 227                   2.0           3.0
# 228                   2.0           3.0

# %%
df1[df1["Customer_ID"]=="CUS_0x51b3"]
# Out:
#         Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 99466  33.0       59146.36                  8.0                  6.68
# 99467  33.0    10152115.00                  8.0                  6.68
# 99468  33.0       59146.36                  8.0                  6.68
# 99469  33.0       59146.36                  8.0                  6.68
# 99470  33.0       59146.36                  8.0                  6.68
# 99471  33.0       59146.36                  6.0                  6.68
# 99472  33.0       59146.36                  8.0                  6.68
# 99473  33.0       59146.36                  8.0                  6.68
#
#        Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 99466            418.03                 34.720661               23.88
# 99467            418.03                 28.287481               20.20
# 99468            418.03                 35.750925               20.30
# 99469            418.03                 28.091458               20.40
# 99470            418.03                 36.813875               20.50
# 99471            418.03                 24.975531               20.60
# 99472            418.03                 38.199635               20.70
# 99473            418.03                 27.682186               20.80
#
#        Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance  \
# 99466            26.778419               606.436542       358.339106
# 99467            26.778419                77.794586       492.658175
# 99468            26.778419               188.544697       655.778476
# 99469            26.778419               183.584149       451.915049
# 99470            26.778419               463.834256       545.047675
# 99471            26.778419                91.321664       365.116427
# 99472            26.778419               502.376320       440.066754
# 99473            26.778419               301.984602       427.670851
#
#       Customer_ID     Month     Occupation Credit_Mix Payment_of_Min_Amount  \
# 99466  CUS_0x51b3   January  Media_Manager       Good                    No
# 99467  CUS_0x51b3  February  Media_Manager       Good                    No
# 99468  CUS_0x51b3     March  Media_Manager       Good                    No
# 99469  CUS_0x51b3     April  Media_Manager       Good                    No
# 99470  CUS_0x51b3       May  Media_Manager       Good                    No
# 99471  CUS_0x51b3      June  Media_Manager       Good                    NM
# 99472  CUS_0x51b3      July  Media_Manager       Good                    No
# 99473  CUS_0x51b3    August  Media_Manager       Good                    No
#
#                       Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 99466    Low_spent_Small_value_payments     Standard                2.0
# 99467   High_spent_Large_value_payments     Standard                2.0
# 99468  High_spent_Medium_value_payments     Standard                2.0
# 99469    Low_spent_Small_value_payments     Standard                2.0
# 99470    Low_spent_Small_value_payments     Standard                2.0
# 99471  High_spent_Medium_value_payments     Standard                3.0
# 99472    Low_spent_Small_value_payments     Standard                3.0
# 99473    Low_spent_Large_value_payments     Standard                3.0
#
#        Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 99466              5.0            6.0                     6.0
# 99467              5.0            6.0                     6.0
# 99468              5.0            6.0                     7.0
# 99469              5.0            6.0                     6.0
# 99470              5.0            6.0                     6.0
# 99471              6.0            6.0                     6.0
# 99472              6.0            6.0                     6.0
# 99473              6.0            6.0                     6.0
#
#        Num_Credit_Inquiries  Num_of_loan2
# 99466                   2.0           1.0
# 99467                   2.0           1.0
# 99468                   2.0           1.0
# 99469                   5.0           1.0
# 99470                   5.0           1.0
# 99471                   5.0           1.0
# 99472                   5.0           1.0
# 99473                   5.0           1.0

# %%
df1[df1["Customer_ID"]=="CUS_0x284a"]
# Out:
#      Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 46  33.0       131313.4                  0.0                  9.34
# 47  34.0       131313.4                 -1.0                 15.34
# 48  34.0       131313.4                  0.0                  9.34
# 49  34.0       131313.4                  0.0                  8.34
# 50  34.0       131313.4                  0.0                  9.34
# 51  34.0       131313.4                  0.0                 11.34
# 52  34.0     10909427.0                  0.0                  9.34
# 53  34.0       131313.4                  0.0                  9.34
#
#     Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 46            352.16                 32.200509               30.70
# 47            352.16                 31.983710               30.80
# 48            352.16                 31.803134               30.90
# 49            352.16                 42.645785               30.10
# 50            352.16                 40.902517               30.11
# 51            352.16                 41.980170               31.00
# 52            352.16                 26.947565               31.10
# 53            352.16                 29.187913               31.20
#
#     Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance Customer_ID  \
# 46           137.644605               378.171254       858.462474  CUS_0x284a
# 47           137.644605               698.873271       547.760457  CUS_0x284a
# 48           911.220179               188.064321      1038.569407  CUS_0x284a
# 49         23834.000000               337.434956       899.198772  CUS_0x284a
# 50         32662.000000               263.378909       963.254819  CUS_0x284a
# 51           911.220179                86.566388      1140.067340  CUS_0x284a
# 52           911.220179               930.391898       326.241830  CUS_0x284a
# 53           911.220179               870.522382       396.111346  CUS_0x284a
#
#        Month Occupation Credit_Mix Payment_of_Min_Amount  \
# 46   January     Lawyer       Good                    NM
# 47  February     Lawyer       Good                    No
# 48     March     Lawyer       Good                    NM
# 49     April     Lawyer       Good                    No
# 50       May     Lawyer       Good                    No
# 51      June     Lawyer       Good                    No
# 52      July     Lawyer       Good                    No
# 53    August     Lawyer       Good                    No
#
#                    Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 46  High_spent_Medium_value_payments         Good                0.0
# 47   High_spent_Small_value_payments         Good                0.0
# 48   High_spent_Large_value_payments         Good                0.0
# 49  High_spent_Medium_value_payments         Good                0.0
# 50   High_spent_Large_value_payments         Good                0.0
# 51   High_spent_Large_value_payments     Standard                0.0
# 52   High_spent_Large_value_payments         Good                0.0
# 53   Low_spent_Medium_value_payments         Good                0.0
#
#     Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 46              1.0            8.0                     3.0
# 47              1.0            8.0                     2.0
# 48              1.0            8.0                     3.0
# 49              1.0            8.0                     2.0
# 50              1.0            8.0                     4.0
# 51              1.0            8.0                     3.0
# 52              1.0            8.0                     2.0
# 53              1.0            8.0                     2.0
#
#     Num_Credit_Inquiries  Num_of_loan2
# 46                   2.0           2.0
# 47                   4.0           2.0
# 48                   4.0           2.0
# 49                   4.0           2.0
# 50                   4.0           2.0
# 51                   4.0           2.0
# 52                   4.0           2.0
# 53                   4.0           2.0

# %%
ai = ""
for i in df1.Customer_ID.unique():
    ai = df1.Annual_Income[df1.Customer_ID ==i]
    df1.Annual_Income[df1.Customer_ID == i] = ai.mode()[0]

# %%
df1[df1["Customer_ID"]=="CUS_0xbffe"]
# Out:
#       Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 221  40.0       28572.39                 25.0                  4.89
# 222  40.0       28572.39                 25.0                  4.89
# 223  40.0       28572.39                 28.0                  4.89
# 224  40.0       28572.39                 25.0                  4.89
# 225  40.0       28572.39                 25.0                  4.89
# 226  40.0       28572.39                 25.0                  4.89
# 227  40.0       28572.39                 25.0                  4.89
# 228  40.0       28572.39                 25.0                  4.89
#
#      Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 221            400.07                 24.422251               30.30
# 222            400.07                 36.437870               30.40
# 223            400.07                 29.323517               30.50
# 224            400.07                 34.714561               30.60
# 225            400.07                 37.504552               30.70
# 226            400.07                 35.693949               30.80
# 227            400.07                 35.025883               28.78
# 228            400.07                 23.177617               30.10
#
#      Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance  \
# 221             69.60292                42.850507       348.549822
# 222             69.60292                83.044209       358.356121
# 223             69.60292                53.484203       347.916126
# 224             69.60292                25.993462       375.406867
# 225             69.60292                61.628109       339.772220
# 226             69.60292               129.264835       312.135495
# 227             69.60292                76.607809       364.792521
# 228             69.60292                51.830859       339.569471
#
#     Customer_ID     Month Occupation Credit_Mix Payment_of_Min_Amount  \
# 221  CUS_0xbffe   January  Architect   Standard                   Yes
# 222  CUS_0xbffe  February  Architect   Standard                    NM
# 223  CUS_0xbffe     March  Architect   Standard                   Yes
# 224  CUS_0xbffe     April  Architect   Standard                   Yes
# 225  CUS_0xbffe       May  Architect   Standard                   Yes
# 226  CUS_0xbffe      June  Architect   Standard                   Yes
# 227  CUS_0xbffe      July  Architect   Standard                   Yes
# 228  CUS_0xbffe    August  Architect   Standard                   Yes
#
#                     Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 221   High_spent_Large_value_payments     Standard                6.0
# 222  High_spent_Medium_value_payments     Standard                6.0
# 223  High_spent_Medium_value_payments     Standard                6.0
# 224  High_spent_Medium_value_payments     Standard                6.0
# 225  High_spent_Medium_value_payments     Standard                6.0
# 226    Low_spent_Small_value_payments     Standard                6.0
# 227    Low_spent_Small_value_payments     Standard                6.0
# 228   High_spent_Large_value_payments     Standard                6.0
#
#      Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 221              3.0           15.0                    12.0
# 222              3.0           15.0                     9.0
# 223              3.0           15.0                    10.0
# 224              3.0           15.0                    14.0
# 225              3.0           15.0                    12.0
# 226              3.0           15.0                    11.0
# 227              3.0           15.0                    13.0
# 228              3.0           15.0                    12.0
#
#      Num_Credit_Inquiries  Num_of_loan2
# 221                   0.0           3.0
# 222                   0.0           3.0
# 223                   0.0           3.0
# 224                   0.0           3.0
# 225                   2.0           3.0
# 226                   2.0           3.0
# 227                   2.0           3.0
# 228                   2.0           3.0

# %%
df1[df1["Customer_ID"]=="CUS_0x51b3"]
# Out:
#         Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 99466  33.0       59146.36                  8.0                  6.68
# 99467  33.0       59146.36                  8.0                  6.68
# 99468  33.0       59146.36                  8.0                  6.68
# 99469  33.0       59146.36                  8.0                  6.68
# 99470  33.0       59146.36                  8.0                  6.68
# 99471  33.0       59146.36                  6.0                  6.68
# 99472  33.0       59146.36                  8.0                  6.68
# 99473  33.0       59146.36                  8.0                  6.68
#
#        Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 99466            418.03                 34.720661               23.88
# 99467            418.03                 28.287481               20.20
# 99468            418.03                 35.750925               20.30
# 99469            418.03                 28.091458               20.40
# 99470            418.03                 36.813875               20.50
# 99471            418.03                 24.975531               20.60
# 99472            418.03                 38.199635               20.70
# 99473            418.03                 27.682186               20.80
#
#        Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance  \
# 99466            26.778419               606.436542       358.339106
# 99467            26.778419                77.794586       492.658175
# 99468            26.778419               188.544697       655.778476
# 99469            26.778419               183.584149       451.915049
# 99470            26.778419               463.834256       545.047675
# 99471            26.778419                91.321664       365.116427
# 99472            26.778419               502.376320       440.066754
# 99473            26.778419               301.984602       427.670851
#
#       Customer_ID     Month     Occupation Credit_Mix Payment_of_Min_Amount  \
# 99466  CUS_0x51b3   January  Media_Manager       Good                    No
# 99467  CUS_0x51b3  February  Media_Manager       Good                    No
# 99468  CUS_0x51b3     March  Media_Manager       Good                    No
# 99469  CUS_0x51b3     April  Media_Manager       Good                    No
# 99470  CUS_0x51b3       May  Media_Manager       Good                    No
# 99471  CUS_0x51b3      June  Media_Manager       Good                    NM
# 99472  CUS_0x51b3      July  Media_Manager       Good                    No
# 99473  CUS_0x51b3    August  Media_Manager       Good                    No
#
#                       Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 99466    Low_spent_Small_value_payments     Standard                2.0
# 99467   High_spent_Large_value_payments     Standard                2.0
# 99468  High_spent_Medium_value_payments     Standard                2.0
# 99469    Low_spent_Small_value_payments     Standard                2.0
# 99470    Low_spent_Small_value_payments     Standard                2.0
# 99471  High_spent_Medium_value_payments     Standard                3.0
# 99472    Low_spent_Small_value_payments     Standard                3.0
# 99473    Low_spent_Large_value_payments     Standard                3.0
#
#        Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 99466              5.0            6.0                     6.0
# 99467              5.0            6.0                     6.0
# 99468              5.0            6.0                     7.0
# 99469              5.0            6.0                     6.0
# 99470              5.0            6.0                     6.0
# 99471              6.0            6.0                     6.0
# 99472              6.0            6.0                     6.0
# 99473              6.0            6.0                     6.0
#
#        Num_Credit_Inquiries  Num_of_loan2
# 99466                   2.0           1.0
# 99467                   2.0           1.0
# 99468                   2.0           1.0
# 99469                   5.0           1.0
# 99470                   5.0           1.0
# 99471                   5.0           1.0
# 99472                   5.0           1.0
# 99473                   5.0           1.0

# %%
df1[df1["Customer_ID"]=="CUS_0x284a"]
# Out:
#      Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 46  33.0       131313.4                  0.0                  9.34
# 47  34.0       131313.4                 -1.0                 15.34
# 48  34.0       131313.4                  0.0                  9.34
# 49  34.0       131313.4                  0.0                  8.34
# 50  34.0       131313.4                  0.0                  9.34
# 51  34.0       131313.4                  0.0                 11.34
# 52  34.0       131313.4                  0.0                  9.34
# 53  34.0       131313.4                  0.0                  9.34
#
#     Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 46            352.16                 32.200509               30.70
# 47            352.16                 31.983710               30.80
# 48            352.16                 31.803134               30.90
# 49            352.16                 42.645785               30.10
# 50            352.16                 40.902517               30.11
# 51            352.16                 41.980170               31.00
# 52            352.16                 26.947565               31.10
# 53            352.16                 29.187913               31.20
#
#     Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance Customer_ID  \
# 46           137.644605               378.171254       858.462474  CUS_0x284a
# 47           137.644605               698.873271       547.760457  CUS_0x284a
# 48           911.220179               188.064321      1038.569407  CUS_0x284a
# 49         23834.000000               337.434956       899.198772  CUS_0x284a
# 50         32662.000000               263.378909       963.254819  CUS_0x284a
# 51           911.220179                86.566388      1140.067340  CUS_0x284a
# 52           911.220179               930.391898       326.241830  CUS_0x284a
# 53           911.220179               870.522382       396.111346  CUS_0x284a
#
#        Month Occupation Credit_Mix Payment_of_Min_Amount  \
# 46   January     Lawyer       Good                    NM
# 47  February     Lawyer       Good                    No
# 48     March     Lawyer       Good                    NM
# 49     April     Lawyer       Good                    No
# 50       May     Lawyer       Good                    No
# 51      June     Lawyer       Good                    No
# 52      July     Lawyer       Good                    No
# 53    August     Lawyer       Good                    No
#
#                    Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 46  High_spent_Medium_value_payments         Good                0.0
# 47   High_spent_Small_value_payments         Good                0.0
# 48   High_spent_Large_value_payments         Good                0.0
# 49  High_spent_Medium_value_payments         Good                0.0
# 50   High_spent_Large_value_payments         Good                0.0
# 51   High_spent_Large_value_payments     Standard                0.0
# 52   High_spent_Large_value_payments         Good                0.0
# 53   Low_spent_Medium_value_payments         Good                0.0
#
#     Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 46              1.0            8.0                     3.0
# 47              1.0            8.0                     2.0
# 48              1.0            8.0                     3.0
# 49              1.0            8.0                     2.0
# 50              1.0            8.0                     4.0
# 51              1.0            8.0                     3.0
# 52              1.0            8.0                     2.0
# 53              1.0            8.0                     2.0
#
#     Num_Credit_Inquiries  Num_of_loan2
# 46                   2.0           2.0
# 47                   4.0           2.0
# 48                   4.0           2.0
# 49                   4.0           2.0
# 50                   4.0           2.0
# 51                   4.0           2.0
# 52                   4.0           2.0
# 53                   4.0           2.0

# %%
sns.boxplot(df1["Annual_Income"], orient='h')
# Out:
# <Axes: >

# %%
df1["Total_EMI_per_month"].max()
# Out:
# 82331.0

# %%
df1["Total_EMI_per_month"].value_counts()
# Out:
# 0.000000        10169
# 49.574949           8
# 64.008959           8
# 69.020960           8
# 250.408881          8
#                 ...
# 22898.000000        1
# 65311.000000        1
# 79218.000000        1
# 18859.000000        1
# 58638.000000        1
# Name: Total_EMI_per_month, Length: 14938, dtype: int64

# %%
df1[df1["Total_EMI_per_month"]>1000]
# Out:
#         Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 38     31.0       73928.46                 12.0                 10.14
# 43     31.0       73928.46                  7.0                 10.14
# 49     34.0      131313.40                  0.0                  8.34
# 50     34.0      131313.40                  0.0                  9.34
# 74     44.0       31370.80                  1.0                  5.76
# ...     ...            ...                  ...                   ...
# 99443  38.0      139664.96                 14.0                 12.39
# 99482  18.0       42903.79                 14.0                  4.10
# 99492  44.0       16680.35                  1.0                  5.69
# 99507  28.0       20002.88                 33.0                 23.31
# 99515  25.0       39628.99                 23.0                 11.50
#
#        Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 38               548.20                 39.962685              29.222
# 43               548.20                 35.275437              23.300
# 49               352.16                 42.645785              30.100
# 50               352.16                 40.902517              30.110
# 74               421.43                 25.189232              26.900
# ...                 ...                       ...                 ...
# 99443            365.66                 40.171095              29.800
# 99482           1079.48                 27.289440              28.100
# 99492            897.16                 30.472041              21.300
# 99507           3571.70                 39.772607               5.900
# 99515            502.38                 29.135447              31.400
#
#        Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance  \
# 38                 15015.0                98.674410       740.196090
# 43                 15515.0               235.790325       633.080175
# 49                 23834.0               337.434956       899.198772
# 50                 32662.0               263.378909       963.254819
# 74                 16415.0               184.700572       341.206633
# ...                    ...                      ...              ...
# 99443              20563.0               421.318866       679.120722
# 99482              50894.0                78.514945       539.282250
# 99492              75011.0                75.504972       488.165125
# 99507              12112.0               148.275233       247.198404
# 99515              58638.0               180.733095       390.525592
#
#       Customer_ID     Month     Occupation Credit_Mix Payment_of_Min_Amount  \
# 38     CUS_0x95ee   January         Lawyer       Good                    No
# 43     CUS_0x95ee      June         Lawyer       Good                    No
# 49     CUS_0x284a     April         Lawyer       Good                    No
# 50     CUS_0x284a       May         Lawyer       Good                    No
# 74     CUS_0xba08       May     Journalist       Good                    No
# ...           ...       ...            ...        ...                   ...
# 99443  CUS_0x2654  February  Media_Manager   Standard                   Yes
# 99482  CUS_0x372c   January         Lawyer       Good                    No
# 99492   CUS_0xf16     March  Media_Manager       Good                    No
# 99507  CUS_0x8600  February      Architect        Bad                   Yes
# 99515  CUS_0x942c  February       Mechanic       Good                    No
#
#                       Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 38      High_spent_Large_value_payments         Good                4.0
# 43       Low_spent_Large_value_payments         Good                4.0
# 49     High_spent_Medium_value_payments         Good                0.0
# 50      High_spent_Large_value_payments         Good                0.0
# 74       Low_spent_Small_value_payments         Good                1.0
# ...                                 ...          ...                ...
# 99443  High_spent_Medium_value_payments     Standard                3.0
# 99482   High_spent_Small_value_payments         Good                0.0
# 99492   Low_spent_Medium_value_payments         Good                1.0
# 99507    Low_spent_Small_value_payments         Poor               10.0
# 99515   Low_spent_Medium_value_payments     Standard                4.0
#
#        Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 38                 5.0            8.0                    10.0
# 43                 5.0            8.0                     7.0
# 49                 1.0            8.0                     2.0
# 50                 1.0            8.0                     4.0
# 74                 6.0           12.0                     0.0
# ...                ...            ...                     ...
# 99443              6.0           12.0                    12.0
# 99482              4.0            6.0                     0.0
# 99492              1.0            5.0                     0.0
# 99507              8.0           29.0                    25.0
# 99515              6.0            7.0                     6.0
#
#        Num_Credit_Inquiries  Num_of_loan2
# 38                      2.0           0.0
# 43                      2.0           0.0
# 49                      4.0           2.0
# 50                      4.0           2.0
# 74                      5.0           2.0
# ...                     ...           ...
# 99443                   8.0           4.0
# 99482                   1.0           1.0
# 99492                   8.0           4.0
# 99507                   9.0           5.0
# 99515                   3.0           2.0
#
# [3396 rows x 23 columns]

# %%
df1[df1["Customer_ID"]=="CUS_0x95ee"]
# Out:
#      Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 38  31.0       73928.46                 12.0                 10.14
# 39  31.0       73928.46                  8.0                 10.14
# 40  31.0       73928.46                  8.0                 10.14
# 41  31.0       73928.46                  8.0                 10.14
# 42  31.0       73928.46                 11.0                 10.14
# 43  31.0       73928.46                  7.0                 10.14
# 44  31.0       73928.46                  8.0                  9.14
# 45  31.0       73928.46                  8.0                 10.14
#
#     Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 38             548.2                 39.962685              29.222
# 39             548.2                 42.769864              32.000
# 40             548.2                 40.712187              24.220
# 41             548.2                 30.201658              32.200
# 42             548.2                 26.333310              32.300
# 43             548.2                 35.275437              23.300
# 44             548.2                 36.624791              32.500
# 45             548.2                 31.580990              32.600
#
#     Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance Customer_ID  \
# 38              15015.0                98.674410       740.196090  CUS_0x95ee
# 39                  0.0               172.939214       705.931286  CUS_0x95ee
# 40                  0.0               150.059734       698.810766  CUS_0x95ee
# 41                  0.0               618.202391       270.668109  CUS_0x95ee
# 42                  0.0               177.951836       690.918664  CUS_0x95ee
# 43              15515.0               235.790325       633.080175  CUS_0x95ee
# 44                  0.0               348.509400       510.361100  CUS_0x95ee
# 45                  0.0                42.635590       796.234910  CUS_0x95ee
#
#        Month Occupation Credit_Mix Payment_of_Min_Amount  \
# 38   January     Lawyer       Good                    No
# 39  February     Lawyer       Good                    NM
# 40     March     Lawyer       Good                    No
# 41     April     Lawyer       Good                    No
# 42       May     Lawyer       Good                    No
# 43      June     Lawyer       Good                    No
# 44      July     Lawyer       Good                    No
# 45    August     Lawyer       Good                    No
#
#                    Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 38   High_spent_Large_value_payments         Good                4.0
# 39   Low_spent_Medium_value_payments         Good                4.0
# 40  High_spent_Medium_value_payments         Good                4.0
# 41    Low_spent_Small_value_payments         Good                4.0
# 42    Low_spent_Large_value_payments         Good                4.0
# 43    Low_spent_Large_value_payments         Good                4.0
# 44   High_spent_Small_value_payments     Standard                4.0
# 45    Low_spent_Large_value_payments         Good                4.0
#
#     Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 38              5.0            8.0                    10.0
# 39              5.0            8.0                     7.0
# 40              5.0            8.0                     7.0
# 41              5.0            8.0                     7.0
# 42              5.0            8.0                     7.0
# 43              5.0            8.0                     7.0
# 44              5.0            8.0                     4.0
# 45              5.0            8.0                     7.0
#
#     Num_Credit_Inquiries  Num_of_loan2
# 38                   2.0           0.0
# 39                   2.0           0.0
# 40                   2.0           0.0
# 41                   2.0           0.0
# 42                   2.0           0.0
# 43                   2.0           0.0
# 44                   2.0           0.0
# 45                   2.0           0.0

# %%
df1[df1["Customer_ID"]=="CUS_0x284a"]
# Out:
#      Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 46  33.0       131313.4                  0.0                  9.34
# 47  34.0       131313.4                 -1.0                 15.34
# 48  34.0       131313.4                  0.0                  9.34
# 49  34.0       131313.4                  0.0                  8.34
# 50  34.0       131313.4                  0.0                  9.34
# 51  34.0       131313.4                  0.0                 11.34
# 52  34.0       131313.4                  0.0                  9.34
# 53  34.0       131313.4                  0.0                  9.34
#
#     Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 46            352.16                 32.200509               30.70
# 47            352.16                 31.983710               30.80
# 48            352.16                 31.803134               30.90
# 49            352.16                 42.645785               30.10
# 50            352.16                 40.902517               30.11
# 51            352.16                 41.980170               31.00
# 52            352.16                 26.947565               31.10
# 53            352.16                 29.187913               31.20
#
#     Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance Customer_ID  \
# 46           137.644605               378.171254       858.462474  CUS_0x284a
# 47           137.644605               698.873271       547.760457  CUS_0x284a
# 48           911.220179               188.064321      1038.569407  CUS_0x284a
# 49         23834.000000               337.434956       899.198772  CUS_0x284a
# 50         32662.000000               263.378909       963.254819  CUS_0x284a
# 51           911.220179                86.566388      1140.067340  CUS_0x284a
# 52           911.220179               930.391898       326.241830  CUS_0x284a
# 53           911.220179               870.522382       396.111346  CUS_0x284a
#
#        Month Occupation Credit_Mix Payment_of_Min_Amount  \
# 46   January     Lawyer       Good                    NM
# 47  February     Lawyer       Good                    No
# 48     March     Lawyer       Good                    NM
# 49     April     Lawyer       Good                    No
# 50       May     Lawyer       Good                    No
# 51      June     Lawyer       Good                    No
# 52      July     Lawyer       Good                    No
# 53    August     Lawyer       Good                    No
#
#                    Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 46  High_spent_Medium_value_payments         Good                0.0
# 47   High_spent_Small_value_payments         Good                0.0
# 48   High_spent_Large_value_payments         Good                0.0
# 49  High_spent_Medium_value_payments         Good                0.0
# 50   High_spent_Large_value_payments         Good                0.0
# 51   High_spent_Large_value_payments     Standard                0.0
# 52   High_spent_Large_value_payments         Good                0.0
# 53   Low_spent_Medium_value_payments         Good                0.0
#
#     Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 46              1.0            8.0                     3.0
# 47              1.0            8.0                     2.0
# 48              1.0            8.0                     3.0
# 49              1.0            8.0                     2.0
# 50              1.0            8.0                     4.0
# 51              1.0            8.0                     3.0
# 52              1.0            8.0                     2.0
# 53              1.0            8.0                     2.0
#
#     Num_Credit_Inquiries  Num_of_loan2
# 46                   2.0           2.0
# 47                   4.0           2.0
# 48                   4.0           2.0
# 49                   4.0           2.0
# 50                   4.0           2.0
# 51                   4.0           2.0
# 52                   4.0           2.0
# 53                   4.0           2.0

# %%
df1.Total_EMI_per_month.describe().T
# Out:
# count    99522.000000
# mean      1405.185237
# std       8310.992210
# min          0.000000
# 25%         30.759834
# 50%         69.602920
# 75%        161.978219
# max      82331.000000
# Name: Total_EMI_per_month, dtype: float64

# %%
q1 = df1.Total_EMI_per_month.quantile(0.25)
q3 = df1.Total_EMI_per_month.quantile(0.75)

iqr =q3-q1

ul = iqr+5.0*q3
#ll = iqr+1.5*q3
ul
# Out:
# 941.1094814848652

# %%
df1.Total_EMI_per_month[df1.Total_EMI_per_month > ul]=np.nan

# %%
tpm = ""
for i in df1.Customer_ID[df1.Total_EMI_per_month.isnull()]:
    tpm = df1.Total_EMI_per_month[(df1.Customer_ID ==i) & (df1.Total_EMI_per_month.notnull())]
    df1.Total_EMI_per_month[(df1.Customer_ID == i) & (df1.Total_EMI_per_month.isnull())] = tpm.mean()

# %%
df1.Total_EMI_per_month.isnull().sum()
# Out:
# 8

# %%
df1[df1.Total_EMI_per_month.isnull()]
# Out:
#         Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 39800  16.0      116522.68                 26.0                 16.74
# 39801  16.0      116522.68                 26.0                 16.74
# 39802  16.0      116522.68                 26.0                 16.74
# 39803  16.0      116522.68                 26.0                 16.74
# 39804  16.0      116522.68                 31.0                 16.74
# 39805  16.0      116522.68                 26.0                 17.74
# 39806  16.0      116522.68                 29.0                 16.74
# 39807  16.0      116522.68                 26.0                 16.74
#
#        Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 39800             272.6                 39.529611                5.40
# 39801             272.6                 39.811663                5.50
# 39802             272.6                 28.952960                5.60
# 39803             272.6                 27.560149                5.70
# 39804             272.6                 37.759572                5.80
# 39805             272.6                 25.035876                5.90
# 39806             272.6                 25.712128                5.10
# 39807             272.6                 26.254382                5.11
#
#        Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance  \
# 39800                  NaN               178.255077       646.900427
# 39801                  NaN               575.146069       290.009435
# 39802                  NaN               280.355450       343.622426
# 39803                  NaN               225.284670       609.870834
# 39804                  NaN               319.891283       515.264221
# 39805                  NaN               718.439984       136.715520
# 39806                  NaN               177.362071       667.793433
# 39807                  NaN               571.699736       293.455767
#
#       Customer_ID     Month Occupation Credit_Mix Payment_of_Min_Amount  \
# 39800  CUS_0x72c0   January    Teacher   Standard                    NM
# 39801  CUS_0x72c0  February    Teacher   Standard                   Yes
# 39802  CUS_0x72c0     March    Teacher   Standard                   Yes
# 39803  CUS_0x72c0     April    Teacher   Standard                    NM
# 39804  CUS_0x72c0       May    Teacher   Standard                   Yes
# 39805  CUS_0x72c0      June    Teacher   Standard                   Yes
# 39806  CUS_0x72c0      July    Teacher   Standard                   Yes
# 39807  CUS_0x72c0    August    Teacher   Standard                   Yes
#
#                       Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 39800   High_spent_Large_value_payments     Standard                3.0
# 39801   Low_spent_Medium_value_payments     Standard                3.0
# 39802    Low_spent_Large_value_payments     Standard                3.0
# 39803  High_spent_Medium_value_payments     Standard                3.0
# 39804  High_spent_Medium_value_payments         Good                3.0
# 39805    Low_spent_Large_value_payments     Standard                3.0
# 39806   High_spent_Small_value_payments     Standard                3.0
# 39807   Low_spent_Medium_value_payments     Standard                3.0
#
#        Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 39800              4.0           16.0                     8.0
# 39801              4.0           16.0                     8.0
# 39802              4.0           16.0                     8.0
# 39803              4.0           16.0                     8.0
# 39804              4.0           16.0                     6.0
# 39805              4.0           16.0                    10.0
# 39806              4.0           16.0                    11.0
# 39807              4.0           16.0                     7.0
#
#        Num_Credit_Inquiries  Num_of_loan2
# 39800                   7.0           6.0
# 39801                   7.0           6.0
# 39802                   7.0           6.0
# 39803                   7.0           6.0
# 39804                  11.0           6.0
# 39805                  11.0           6.0
# 39806                  11.0           6.0
# 39807                  11.0           6.0

# %%
df1.shape
# Out:
# (99522, 23)

# %%
df1.dropna(subset= ['Total_EMI_per_month'],inplace= True)

# %%
df1.Monthly_Balance.describe()
# Out:
# count    99514.000000
# mean       400.789017
# std        211.238475
# min          0.007760
# 25%        270.159025
# 50%        336.442215
# 75%        468.137700
# max       1602.040519
# Name: Monthly_Balance, dtype: float64

# %%
df1.shape
df1.drop('Customer_ID',axis = 1,inplace= True)
cat_cols.remove('Customer_ID')

# %%
t=1
plt.figure(figsize=(12,10))
for i in num_cols:
    plt.subplot(4,3,t)
    sns.boxplot(df1[i], orient='h')
    plt.title(i)
    t+=1
    
plt.tight_layout()
plt.show()

# %%
df1.isnull().sum()
# Out:
# Age                         0
# Annual_Income               0
# Delay_from_due_date         0
# Changed_Credit_Limit        0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Monthly_Balance             0
# Month                       0
# Occupation                  0
# Credit_Mix                  0
# Payment_of_Min_Amount       0
# Payment_Behaviour           0
# Credit_Score                0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Delayed_Payment      0
# Num_Credit_Inquiries        0
# Num_of_loan2                0
# dtype: int64

# %%
#now we have fixed aLL THE VALUES and we will proceed with bivariate and univariate analysis

# %% [markdown]
# ## Numerical with Categorical(Target) columns

# %%
j=1
plt.figure(figsize=(20,30))
for i in num_cols:
    plt.subplot(5,2,j)
    sns.boxplot(x=df1[i], y=df1["Credit_Score"])
    plt.title(i)
    j+=1
    
plt.tight_layout()
plt.show()

# %%
df1.Num_Bank_Accounts.value_counts()
# Out:
# 6.0     13122
# 7.0     12938
# 8.0     12906
# 4.0     12283
# 5.0     12245
# 3.0     11991
# 9.0      5485
# 10.0     5338
# 1.0      4514
# 0.0      4375
# 2.0      4317
# Name: Num_Bank_Accounts, dtype: int64

# %% [markdown]
# ## Categorical with Categorical(Target) column

# %%
plt.figure(figsize=(20,40))
t = 1
for i in cat_cols:
    plt.subplot(6,2,t)
    sns.countplot(data=df1, x=i, hue='Credit_Score')
    t+=1
    plt.title(i)
    plt.xticks(rotation=60)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Encoding

# %%
df1.select_dtypes(include=np.number)
# Out:
#         Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 0      23.0       19114.12                  3.0                 11.27
# 1      23.0       19114.12                 -1.0                 11.27
# 2      23.0       19114.12                  3.0                  7.50
# 3      23.0       19114.12                  5.0                  6.27
# 4      23.0       19114.12                  6.0                 11.27
# ...     ...            ...                  ...                   ...
# 99517  25.0       39628.99                 23.0                 11.50
# 99518  25.0       39628.99                 18.0                 11.50
# 99519  25.0       39628.99                 27.0                 11.50
# 99520  25.0       39628.99                 20.0                 11.50
# 99521  25.0       39628.99                 18.0                 11.50
#
#        Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 0                809.98                 26.822620               22.10
# 1                809.98                 31.944960               25.78
# 2                809.98                 28.609352               22.30
# 3                809.98                 31.377862               22.40
# 4                809.98                 24.797347               22.50
# ...                 ...                       ...                 ...
# 99517            502.38                 34.663572               31.60
# 99518            502.38                 40.565631               31.70
# 99519            502.38                 41.255522               31.80
# 99520            502.38                 33.638208               31.90
# 99521            502.38                 34.192463               31.10
#
#        Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance  \
# 0                49.574949                80.415295       312.494089
# 1                49.574949               118.280222       284.629162
# 2                49.574949                81.699521       331.209863
# 3                49.574949               199.458074       223.451310
# 4                49.574949                41.420153       341.489231
# ...                    ...                      ...              ...
# 99517            35.104023                60.971333       414.546031
# 99518            35.104023                54.185950       654.233454
# 99519            35.104023                24.028477       684.255728
# 99520            35.104023               251.672582       426.509782
# 99521            35.104023               167.163865       446.382819
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  \
# 0                    3.0              4.0            3.0
# 1                    3.0              4.0            3.0
# 2                    3.0              4.0            3.0
# 3                    3.0              4.0            3.0
# 4                    3.0              4.0            3.0
# ...                  ...              ...            ...
# 99517                4.0              6.0            7.0
# 99518                4.0              6.0            7.0
# 99519                4.0              6.0            7.0
# 99520                4.0              6.0            7.0
# 99521                4.0              6.0            7.0
#
#        Num_of_Delayed_Payment  Num_Credit_Inquiries  Num_of_loan2
# 0                         7.0                   4.0           4.0
# 1                         4.0                   4.0           4.0
# 2                         7.0                   4.0           4.0
# 3                         4.0                   4.0           4.0
# 4                         4.0                   4.0           4.0
# ...                       ...                   ...           ...
# 99517                     7.0                   3.0           2.0
# 99518                     7.0                   3.0           2.0
# 99519                     6.0                   3.0           2.0
# 99520                     6.0                   3.0           2.0
# 99521                     6.0                   3.0           2.0
#
# [99514 rows x 16 columns]

# %%
df1.select_dtypes(include=object)
# Out:
#           Month Occupation Credit_Mix Payment_of_Min_Amount  \
# 0       January  Scientist       Good                    No
# 1      February  Scientist       Good                    No
# 2         March  Scientist       Good                    No
# 3         April  Scientist       Good                    No
# 4           May  Scientist       Good                    No
# ...         ...        ...        ...                   ...
# 99517     April   Mechanic       Good                    No
# 99518       May   Mechanic       Good                    No
# 99519      June   Mechanic       Good                    No
# 99520      July   Mechanic       Good                    No
# 99521    August   Mechanic       Good                    No
#
#                       Payment_Behaviour Credit_Score
# 0       High_spent_Small_value_payments         Good
# 1        Low_spent_Large_value_payments         Good
# 2       Low_spent_Medium_value_payments         Good
# 3        Low_spent_Small_value_payments         Good
# 4      High_spent_Medium_value_payments         Good
# ...                                 ...          ...
# 99517   High_spent_Large_value_payments         Poor
# 99518  High_spent_Medium_value_payments         Poor
# 99519   High_spent_Large_value_payments         Poor
# 99520    Low_spent_Large_value_payments     Standard
# 99521   High_spent_Large_value_payments         Poor
#
# [99514 rows x 6 columns]

# %%
df1["Credit_Score"].value_counts()
# Out:
# Standard    52884
# Poor        28953
# Good        17677
# Name: Credit_Score, dtype: int64

# %%
cat_cols.remove("Credit_Score")

# %%
df1['Credit_Score'] = df1['Credit_Score'].map({'Standard':1,'Poor':0,'Good':2})

# %%
df1.Credit_Score
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 99517    0
# 99518    0
# 99519    0
# 99520    1
# 99521    0
# Name: Credit_Score, Length: 99514, dtype: int64

# %%
df1["Credit_Score"].value_counts()
# Out:
# 1    52884
# 0    28953
# 2    17677
# Name: Credit_Score, dtype: int64

# %%
df1.select_dtypes(include=object)
# Out:
#           Month Occupation Credit_Mix Payment_of_Min_Amount  \
# 0       January  Scientist       Good                    No
# 1      February  Scientist       Good                    No
# 2         March  Scientist       Good                    No
# 3         April  Scientist       Good                    No
# 4           May  Scientist       Good                    No
# ...         ...        ...        ...                   ...
# 99517     April   Mechanic       Good                    No
# 99518       May   Mechanic       Good                    No
# 99519      June   Mechanic       Good                    No
# 99520      July   Mechanic       Good                    No
# 99521    August   Mechanic       Good                    No
#
#                       Payment_Behaviour
# 0       High_spent_Small_value_payments
# 1        Low_spent_Large_value_payments
# 2       Low_spent_Medium_value_payments
# 3        Low_spent_Small_value_payments
# 4      High_spent_Medium_value_payments
# ...                                 ...
# 99517   High_spent_Large_value_payments
# 99518  High_spent_Medium_value_payments
# 99519   High_spent_Large_value_payments
# 99520    Low_spent_Large_value_payments
# 99521   High_spent_Large_value_payments
#
# [99514 rows x 5 columns]

# %%
cat_cols1 = ['Month','Occupation','Credit_Mix','Payment_of_Min_Amount','Payment_Behaviour']

# %%
df1[cat_cols1]
# Out:
#           Month Occupation Credit_Mix Payment_of_Min_Amount  \
# 0       January  Scientist       Good                    No
# 1      February  Scientist       Good                    No
# 2         March  Scientist       Good                    No
# 3         April  Scientist       Good                    No
# 4           May  Scientist       Good                    No
# ...         ...        ...        ...                   ...
# 99517     April   Mechanic       Good                    No
# 99518       May   Mechanic       Good                    No
# 99519      June   Mechanic       Good                    No
# 99520      July   Mechanic       Good                    No
# 99521    August   Mechanic       Good                    No
#
#                       Payment_Behaviour
# 0       High_spent_Small_value_payments
# 1        Low_spent_Large_value_payments
# 2       Low_spent_Medium_value_payments
# 3        Low_spent_Small_value_payments
# 4      High_spent_Medium_value_payments
# ...                                 ...
# 99517   High_spent_Large_value_payments
# 99518  High_spent_Medium_value_payments
# 99519   High_spent_Large_value_payments
# 99520    Low_spent_Large_value_payments
# 99521   High_spent_Large_value_payments
#
# [99514 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
for i in cat_cols1:
    df1[i] = le.fit_transform(df1[i])
df1.head()
# Out:
#     Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 0  23.0       19114.12                  3.0                 11.27
# 1  23.0       19114.12                 -1.0                 11.27
# 2  23.0       19114.12                  3.0                  7.50
# 3  23.0       19114.12                  5.0                  6.27
# 4  23.0       19114.12                  6.0                 11.27
#
#    Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 0            809.98                 26.822620               22.10
# 1            809.98                 31.944960               25.78
# 2            809.98                 28.609352               22.30
# 3            809.98                 31.377862               22.40
# 4            809.98                 24.797347               22.50
#
#    Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance  Month  \
# 0            49.574949                80.415295       312.494089      3
# 1            49.574949               118.280222       284.629162      2
# 2            49.574949                81.699521       331.209863      6
# 3            49.574949               199.458074       223.451310      0
# 4            49.574949                41.420153       341.489231      7
#
#    Occupation  Credit_Mix  Payment_of_Min_Amount  Payment_Behaviour  \
# 0          12           1                      1                  2
# 1          12           1                      1                  3
# 2          12           1                      1                  4
# 3          12           1                      1                  5
# 4          12           1                      1                  1
#
#    Credit_Score  Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  \
# 0             2                3.0              4.0            3.0
# 1             2                3.0              4.0            3.0
# 2             2                3.0              4.0            3.0
# 3             2                3.0              4.0            3.0
# 4             2                3.0              4.0            3.0
#
#    Num_of_Delayed_Payment  Num_Credit_Inquiries  Num_of_loan2
# 0                     7.0                   4.0           4.0
# 1                     4.0                   4.0           4.0
# 2                     7.0                   4.0           4.0
# 3                     4.0                   4.0           4.0
# 4                     4.0                   4.0           4.0

# %% [markdown]
# ## Modelling

# %%
from sklearn.model_selection import train_test_split

# %%
x = df1.drop(['Credit_Score'],axis = 1)
y = df1.Credit_Score

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y,
                                                test_size=0.20,
                                                random_state = 2,stratify=y)

# %%
xtrain.shape, xtest.shape, ytrain.shape, ytest.shape
# Out:
# ((79611, 21), (19903, 21), (79611,), (19903,))

# %%
ytrain.value_counts(normalize = True)
# Out:
# 1    0.531422
# 0    0.290940
# 2    0.177639
# Name: Credit_Score, dtype: float64

# %%
ytest.value_counts(normalize= True)
# Out:
# 1    0.531427
# 0    0.290961
# 2    0.177611
# Name: Credit_Score, dtype: float64

# %%
y.value_counts(normalize = True)
# Out:
# 1    0.531423
# 0    0.290944
# 2    0.177633
# Name: Credit_Score, dtype: float64

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve,roc_auc_score, cohen_kappa_score

# %%
def validation(test,pred):
    print('Accuracy Score:',accuracy_score(test,pred))
    print('Confusion Matrix:\n',confusion_matrix(test,pred))
    print('Classification report:\n',classification_report(test,pred))

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_dt = dt.predict(xtest)

# %%
validation(ytest,y_pred_dt)
# Out:
# Accuracy Score: 0.7096417625483595
# Confusion Matrix:
#  [[4034 1629  128]
#  [1583 7825 1169]
#  [ 136 1134 2265]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.70      0.70      0.70      5791
#            1       0.74      0.74      0.74     10577
#            2       0.64      0.64      0.64      3535
#
#     accuracy                           0.71     19903
#    macro avg       0.69      0.69      0.69     19903
# weighted avg       0.71      0.71      0.71     19903

# %%
cohen_kappa_score(ytest,y_pred_dt)
# Out:
# 0.5171973897469382

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
y_pred_rf = rf.predict(xtest)

# %%
validation(ytest,y_pred_rf)
# Out:
# Accuracy Score: 0.8056071948952419
# Confusion Matrix:
#  [[4817  902   72]
#  [1262 8549  766]
#  [  13  854 2668]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.83      0.81      5791
#            1       0.83      0.81      0.82     10577
#            2       0.76      0.75      0.76      3535
#
#     accuracy                           0.81     19903
#    macro avg       0.79      0.80      0.80     19903
# weighted avg       0.81      0.81      0.81     19903

# %%
###use gridserchCV with rf for better results AND Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {'criterion' : ['gini','entropy'],
         'max_depth' : [3,4,5,6,7],
         'n_estimators' : [100,300,500]}

# %%
gscv = GridSearchCV(estimator= RandomForestClassifier(),param_grid= params,scoring = 'f1',cv=3,verbose= 4)

# %%
gscv.fit(xtrain,ytrain)
# Out:
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# [CV 1/3] END criterion=gini, max_depth=3, n_estimators=100;, score=nan total time=   7.9s
# [CV 2/3] END criterion=gini, max_depth=3, n_estimators=100;, score=nan total time=   6.2s
# [CV 3/3] END criterion=gini, max_depth=3, n_estimators=100;, score=nan total time=   8.3s
# [CV 1/3] END criterion=gini, max_depth=3, n_estimators=300;, score=nan total time=  26.7s
# [CV 2/3] END criterion=gini, max_depth=3, n_estimators=300;, score=nan total time=  24.5s
# [CV 3/3] END criterion=gini, max_depth=3, n_estimators=300;, score=nan total time=  22.9s
# [CV 1/3] END criterion=gini, max_depth=3, n_estimators=500;, score=nan total time=  45.2s
# [CV 2/3] END criterion=gini, max_depth=3, n_estimators=500;, score=nan total time=  40.3s
# [CV 3/3] END criterion=gini, max_depth=3, n_estimators=500;, score=nan total time=  39.0s
# [CV 1/3] END criterion=gini, max_depth=4, n_estimators=100;, score=nan total time=   9.7s
# [CV 2/3] END criterion=gini, max_depth=4, n_estimators=100;, score=nan total time=  10.3s
# [CV 3/3] END criterion=gini, max_depth=4, n_estimators=100;, score=nan total time=   9.7s
# [CV 1/3] END criterion=gini, max_depth=4, n_estimators=300;, score=nan total time=  30.4s
# [CV 2/3] END criterion=gini, max_depth=4, n_estimators=300;, score=nan total time=  29.6s
# [CV 3/3] END criterion=gini, max_depth=4, n_estimators=300;, score=nan total time=  30.6s
# [CV 1/3] END criterion=gini, max_depth=4, n_estimators=500;, score=nan total time=  50.1s
# [CV 2/3] END criterion=gini, max_depth=4, n_estimators=500;, score=nan total time=  54.8s
# [CV 3/3] END criterion=gini, max_depth=4, n_estimators=500;, score=nan total time=  58.2s
# [CV 1/3] END criterion=gini, max_depth=5, n_estimators=100;, score=nan total time=  13.5s
# [CV 2/3] END criterion=gini, max_depth=5, n_estimators=100;, score=nan total time=  13.8s
# [CV 3/3] END criterion=gini, max_depth=5, n_estimators=100;, score=nan total time=  12.3s
# [CV 1/3] END criterion=gini, max_depth=5, n_estimators=300;, score=nan total time=  35.6s
# [CV 2/3] END criterion=gini, max_depth=5, n_estimators=300;, score=nan total time=  33.7s
# [CV 3/3] END criterion=gini, max_depth=5, n_estimators=300;, score=nan total time=  38.4s
# [CV 1/3] END criterion=gini, max_depth=5, n_estimators=500;, score=nan total time= 1.1min
# [CV 2/3] END criterion=gini, max_depth=5, n_estimators=500;, score=nan total time= 1.3min
# [CV 3/3] END criterion=gini, max_depth=5, n_estimators=500;, score=nan total time= 1.3min
# [CV 1/3] END criterion=gini, max_depth=6, n_estimators=100;, score=nan total time=  18.4s
# [CV 2/3] END criterion=gini, max_depth=6, n_estimators=100;, score=nan total time=  16.8s
# [CV 3/3] END criterion=gini, max_depth=6, n_estimators=100;, score=nan total time=  16.9s
# [CV 1/3] END criterion=gini, max_depth=6, n_estimators=300;, score=nan total time=  54.8s
# [CV 2/3] END criterion=gini, max_depth=6, n_estimators=300;, score=nan total time=  48.1s
# [CV 3/3] END criterion=gini, max_depth=6, n_estimators=300;, score=nan total time=  40.3s
# [CV 1/3] END criterion=gini, max_depth=6, n_estimators=500;, score=nan total time= 1.2min
# [CV 2/3] END criterion=gini, max_depth=6, n_estimators=500;, score=nan total time= 1.3min
# [CV 3/3] END criterion=gini, max_depth=6, n_estimators=500;, score=nan total time= 1.3min
# [CV 1/3] END criterion=gini, max_depth=7, n_estimators=100;, score=nan total time=  16.6s
# [CV 2/3] END criterion=gini, max_depth=7, n_estimators=100;, score=nan total time=  17.7s
# [CV 3/3] END criterion=gini, max_depth=7, n_estimators=100;, score=nan total time=  17.7s
# [CV 1/3] END criterion=gini, max_depth=7, n_estimators=300;, score=nan total time=  52.9s
# [CV 2/3] END criterion=gini, max_depth=7, n_estimators=300;, score=nan total time=  52.8s
# [CV 3/3] END criterion=gini, max_depth=7, n_estimators=300;, score=nan total time=  52.0s
# [CV 1/3] END criterion=gini, max_depth=7, n_estimators=500;, score=nan total time= 1.7min
# [CV 2/3] END criterion=gini, max_depth=7, n_estimators=500;, score=nan total time= 1.5min
# [CV 3/3] END criterion=gini, max_depth=7, n_estimators=500;, score=nan total time= 1.5min
# [CV 1/3] END criterion=entropy, max_depth=3, n_estimators=100;, score=nan total time=  10.1s
# [CV 2/3] END criterion=entropy, max_depth=3, n_estimators=100;, score=nan total time=  10.2s
# [CV 3/3] END criterion=entropy, max_depth=3, n_estimators=100;, score=nan total time=  11.9s
# [CV 1/3] END criterion=entropy, max_depth=3, n_estimators=300;, score=nan total time=  33.7s
# [CV 2/3] END criterion=entropy, max_depth=3, n_estimators=300;, score=nan total time=  31.1s
# [CV 3/3] END criterion=entropy, max_depth=3, n_estimators=300;, score=nan total time=  31.6s
# [CV 1/3] END criterion=entropy, max_depth=3, n_estimators=500;, score=nan total time=  51.2s
# [CV 2/3] END criterion=entropy, max_depth=3, n_estimators=500;, score=nan total time=  47.0s
# [CV 3/3] END criterion=entropy, max_depth=3, n_estimators=500;, score=nan total time=  49.2s
# [CV 1/3] END criterion=entropy, max_depth=4, n_estimators=100;, score=nan total time=  12.4s
# [CV 2/3] END criterion=entropy, max_depth=4, n_estimators=100;, score=nan total time=  12.2s
# [CV 3/3] END criterion=entropy, max_depth=4, n_estimators=100;, score=nan total time=  12.6s
# [CV 1/3] END criterion=entropy, max_depth=4, n_estimators=300;, score=nan total time=  21.9s
# [CV 2/3] END criterion=entropy, max_depth=4, n_estimators=300;, score=nan total time=  20.3s
# [CV 3/3] END criterion=entropy, max_depth=4, n_estimators=300;, score=nan total time=  20.1s
# [CV 1/3] END criterion=entropy, max_depth=4, n_estimators=500;, score=nan total time=  35.2s
# [CV 2/3] END criterion=entropy, max_depth=4, n_estimators=500;, score=nan total time=  37.7s
# [CV 3/3] END criterion=entropy, max_depth=4, n_estimators=500;, score=nan total time=  37.1s
# [CV 1/3] END criterion=entropy, max_depth=5, n_estimators=100;, score=nan total time=   9.4s
# [CV 2/3] END criterion=entropy, max_depth=5, n_estimators=100;, score=nan total time=   8.8s
# [CV 3/3] END criterion=entropy, max_depth=5, n_estimators=100;, score=nan total time=   8.4s
# [CV 1/3] END criterion=entropy, max_depth=5, n_estimators=300;, score=nan total time=  27.9s
# [CV 2/3] END criterion=entropy, max_depth=5, n_estimators=300;, score=nan total time=  27.0s
# [CV 3/3] END criterion=entropy, max_depth=5, n_estimators=300;, score=nan total time=  26.5s
# [CV 1/3] END criterion=entropy, max_depth=5, n_estimators=500;, score=nan total time=  57.2s
# [CV 2/3] END criterion=entropy, max_depth=5, n_estimators=500;, score=nan total time=  42.3s
# [CV 3/3] END criterion=entropy, max_depth=5, n_estimators=500;, score=nan total time=  41.4s
# [CV 1/3] END criterion=entropy, max_depth=6, n_estimators=100;, score=nan total time=   9.6s
# [CV 2/3] END criterion=entropy, max_depth=6, n_estimators=100;, score=nan total time=   9.4s
# [CV 3/3] END criterion=entropy, max_depth=6, n_estimators=100;, score=nan total time=   9.9s
# [CV 1/3] END criterion=entropy, max_depth=6, n_estimators=300;, score=nan total time=  28.8s
# [CV 2/3] END criterion=entropy, max_depth=6, n_estimators=300;, score=nan total time=  28.7s
# [CV 3/3] END criterion=entropy, max_depth=6, n_estimators=300;, score=nan total time=  29.1s
# [CV 1/3] END criterion=entropy, max_depth=6, n_estimators=500;, score=nan total time=  49.1s
# [CV 2/3] END criterion=entropy, max_depth=6, n_estimators=500;, score=nan total time=  49.2s
# [CV 3/3] END criterion=entropy, max_depth=6, n_estimators=500;, score=nan total time=44.1min
# [CV 1/3] END criterion=entropy, max_depth=7, n_estimators=100;, score=nan total time=  16.2s
# [CV 2/3] END criterion=entropy, max_depth=7, n_estimators=100;, score=nan total time=  15.4s
# [CV 3/3] END criterion=entropy, max_depth=7, n_estimators=100;, score=nan total time=  14.9s
# [CV 1/3] END criterion=entropy, max_depth=7, n_estimators=300;, score=nan total time=  45.1s
# [CV 2/3] END criterion=entropy, max_depth=7, n_estimators=300;, score=nan total time=  45.3s
# [CV 3/3] END criterion=entropy, max_depth=7, n_estimators=300;, score=nan total time=  45.5s
# [CV 1/3] END criterion=entropy, max_depth=7, n_estimators=500;, score=nan total time= 1.2min
# [CV 2/3] END criterion=entropy, max_depth=7, n_estimators=500;, score=nan total time=54.0min
# [CV 3/3] END criterion=entropy, max_depth=7, n_estimators=500;, score=nan total time= 1.4min
# GridSearchCV(cv=3, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 4, 5, 6, 7],
#                          'n_estimators': [100, 300, 500]},
#              scoring='f1', verbose=4)

# %%
gscv.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 3, 'n_estimators': 100}

# %%
rf = RandomForestClassifier(**gscv.best_params_)

# %%
rf.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier(max_depth=3)

# %%
y_pred_rf = rf.predict(xtest)

# %%
validation(ytest,y_pred_rf)
# Out:
# Accuracy Score: 0.642867909360398
# Confusion Matrix:
#  [[3865 1926    0]
#  [2060 8319  198]
#  [  75 2849  611]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.64      0.67      0.66      5791
#            1       0.64      0.79      0.70     10577
#            2       0.76      0.17      0.28      3535
#
#     accuracy                           0.64     19903
#    macro avg       0.68      0.54      0.55     19903
# weighted avg       0.66      0.64      0.61     19903

# %%
cohen_kappa_score(ytest,y_pred_rf)
# Out:
# 0.35703503597509034

# %%
from xgboost import XGBClassifier

# %%
xg = XGBClassifier()

# %%
xg.fit(xtrain,ytrain)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
y_prd_xg = xg.predict(xtest)

# %%
validation(ytest,y_prd_xg)
# Out:
# Accuracy Score: 0.7705371049590514
# Confusion Matrix:
#  [[4401 1166  224]
#  [1277 8345  955]
#  [  48  897 2590]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.76      0.76      5791
#            1       0.80      0.79      0.80     10577
#            2       0.69      0.73      0.71      3535
#
#     accuracy                           0.77     19903
#    macro avg       0.75      0.76      0.76     19903
# weighted avg       0.77      0.77      0.77     19903

# %%
cohen_kappa_score(ytest,y_prd_xg)
# Out:
# 0.6205689464582662

# %%
pd.DataFrame({'features' : xg.feature_importances_},index = xtrain.columns).sort_values(by = 'features',ascending= False)
# Out:
#                           features
# Credit_Mix                0.527100
# Interest_Rate             0.097345
# Outstanding_Debt          0.078394
# Num_Credit_Card           0.036214
# Month                     0.033224
# Delay_from_due_date       0.022552
# Changed_Credit_Limit      0.021519
# Payment_of_Min_Amount     0.020344
# Num_Bank_Accounts         0.018950
# Total_EMI_per_month       0.015208
# Num_of_Delayed_Payment    0.014598
# Num_Credit_Inquiries      0.014252
# Annual_Income             0.014063
# Payment_Behaviour         0.013903
# Num_of_loan2              0.013771
# Occupation                0.012163
# Age                       0.011806
# Credit_History_Age        0.011086
# Amount_invested_monthly   0.009080
# Monthly_Balance           0.008223
# Credit_Utilization_Ratio  0.006204

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ad = AdaBoostClassifier()

# %%
ad.fit(xtrain,ytrain)
# Out:
# AdaBoostClassifier()

# %%
y_prd_ada = ad.predict(xtest)

# %%
validation(ytest,y_prd_ada)
# Out:
# Accuracy Score: 0.6565844345073607
# Confusion Matrix:
#  [[3226 2115  450]
#  [1475 7805 1297]
#  [  80 1418 2037]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.56      0.61      5791
#            1       0.69      0.74      0.71     10577
#            2       0.54      0.58      0.56      3535
#
#     accuracy                           0.66     19903
#    macro avg       0.63      0.62      0.63     19903
# weighted avg       0.66      0.66      0.65     19903

# %%
cohen_kappa_score(ytest,y_prd_ada)
# Out:
# 0.4214740520977063

# %%
#Xg boost is giving the best results
