# %% [markdown]
# # Credit Score Classification

# %% [markdown]
# # Problem Statement:

# %% [markdown]
# To develop a predictive model for classifying individuals into credit score categories based on their financial data and other relevant factors. Accurate credit scoring is crucial for the financial institutions to assess the reliability of applicants and manage risk effectively as it leads to less default.

# %%
# Importing Related Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# Libraries for KNN IMPUTER 
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler

# %%
# Reading the file
df = pd.read_csv('train.csv')

# %%
print('Rows:',df.shape[0])
print('Columns:',df.shape[1])
# Out:
# Rows: 100000
# Columns: 28

# %%
# Displaying First 5 Rows of the data
df.head()
# Out:
#        ID Customer_ID     Month           Name   Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265  Scientist
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0      19114.12            1824.843333                  3  ...           _
# 1      19114.12                    NaN                  3  ...        Good
# 2      19114.12                    NaN                  3  ...        Good
# 3      19114.12                    NaN                  3  ...        Good
# 4      19114.12            1824.843333                  3  ...        Good
#
#    Outstanding_Debt Credit_Utilization_Ratio     Credit_History_Age  \
# 0            809.98                26.822620  22 Years and 1 Months
# 1            809.98                31.944960                    NaN
# 2            809.98                28.609352  22 Years and 3 Months
# 3            809.98                31.377862  22 Years and 4 Months
# 4            809.98                24.797347  22 Years and 5 Months
#
#    Payment_of_Min_Amount Total_EMI_per_month Amount_invested_monthly  \
# 0                     No           49.574949       80.41529543900253
# 1                     No           49.574949      118.28022162236736
# 2                     No           49.574949         81.699521264648
# 3                     No           49.574949       199.4580743910713
# 4                     No           49.574949      41.420153086217326
#
#                   Payment_Behaviour     Monthly_Balance Credit_Score
# 0   High_spent_Small_value_payments  312.49408867943663         Good
# 1    Low_spent_Large_value_payments  284.62916249607184         Good
# 2   Low_spent_Medium_value_payments   331.2098628537912         Good
# 3    Low_spent_Small_value_payments  223.45130972736786         Good
# 4  High_spent_Medium_value_payments  341.48923103222177         Good
#
# [5 rows x 28 columns]

# %%
# Checking for the null columns
df.isnull().sum()
# Out:
# ID                              0
# Customer_ID                     0
# Month                           0
# Name                         9985
# Age                             0
# SSN                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary       15002
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                11408
# Delay_from_due_date             0
# Num_of_Delayed_Payment       7002
# Changed_Credit_Limit            0
# Num_Credit_Inquiries         1965
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age           9030
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly      4479
# Payment_Behaviour               0
# Monthly_Balance              1200
# Credit_Score                    0
# dtype: int64

# %%
# Five point summary of the Numerical columns
df.describe().T
# Out:
#                              count         mean          std         min  \
# Monthly_Inhand_Salary      84998.0  4194.170850  3183.686167  303.645417
# Num_Bank_Accounts         100000.0    17.091280   117.404834   -1.000000
# Num_Credit_Card           100000.0    22.474430   129.057410    0.000000
# Interest_Rate             100000.0    72.466040   466.422621    1.000000
# Delay_from_due_date       100000.0    21.068780    14.860104   -5.000000
# Num_Credit_Inquiries       98035.0    27.754251   193.177339    0.000000
# Credit_Utilization_Ratio  100000.0    32.285173     5.116875   20.000000
# Total_EMI_per_month       100000.0  1403.118217  8306.041270    0.000000
#
#                                   25%          50%          75%           max
# Monthly_Inhand_Salary     1625.568229  3093.745000  5957.448333  15204.633333
# Num_Bank_Accounts            3.000000     6.000000     7.000000   1798.000000
# Num_Credit_Card              4.000000     5.000000     7.000000   1499.000000
# Interest_Rate                8.000000    13.000000    20.000000   5797.000000
# Delay_from_due_date         10.000000    18.000000    28.000000     67.000000
# Num_Credit_Inquiries         3.000000     6.000000     9.000000   2597.000000
# Credit_Utilization_Ratio    28.052567    32.305784    36.496663     50.000000
# Total_EMI_per_month         30.306660    69.249473   161.224249  82331.000000

# %%
# Summary of Categorical Columns
df.describe(include = object).T
# Out:
#                           count  unique                               top  \
# ID                       100000  100000                            0x1602
# Customer_ID              100000   12500                         CUS_0xd40
# Month                    100000       8                           January
# Name                      90015   10139                            Langep
# Age                      100000    1788                                38
# SSN                      100000   12501                         #F%$D@*&8
# Occupation               100000      16                           _______
# Annual_Income            100000   18940                          36585.12
# Num_of_Loan              100000     434                                 3
# Type_of_Loan              88592    6260                     Not Specified
# Num_of_Delayed_Payment    92998     749                                19
# Changed_Credit_Limit     100000    4384                                 _
# Credit_Mix               100000       4                          Standard
# Outstanding_Debt         100000   13178                           1360.45
# Credit_History_Age        90970     404            15 Years and 11 Months
# Payment_of_Min_Amount    100000       3                               Yes
# Amount_invested_monthly   95521   91049                         __10000__
# Payment_Behaviour        100000       7    Low_spent_Small_value_payments
# Monthly_Balance           98800   98792  __-333333333333333333333333333__
# Credit_Score             100000       3                          Standard
#
#                           freq
# ID                           1
# Customer_ID                  8
# Month                    12500
# Name                        44
# Age                       2833
# SSN                       5572
# Occupation                7062
# Annual_Income               16
# Num_of_Loan              14386
# Type_of_Loan              1408
# Num_of_Delayed_Payment    5327
# Changed_Credit_Limit      2091
# Credit_Mix               36479
# Outstanding_Debt            24
# Credit_History_Age         446
# Payment_of_Min_Amount    52326
# Amount_invested_monthly   4305
# Payment_Behaviour        25513
# Monthly_Balance              9
# Credit_Score             53174

# %% [markdown]
# ## Data cleaning

# %%
# Checking for the unique value count in Customer_ID
df.Customer_ID.nunique()
# Out:
# 12500

# %%
# Splitting the sub category and getting the count of Type_of_Loan 

len(df.Type_of_Loan[0].split(','))
# Out:
# 4

# %%
# Treating the noise in the Num_of_Loan

df.Num_of_Loan =df.Num_of_Loan.str.replace('_','')
df.Num_of_Loan = df.Num_of_Loan.replace('-','')

# %%
df.Num_of_Loan.isnull().sum()
# Out:
# 0

# %%
df.Num_of_Loan.dtype
# Out:
# dtype('O')

# %%
# Exploring Num_of_Loan column for more possible noise

df.Num_of_Loan.unique()

# Num of loan has many absurd values so we will not use it and remove it
# Out:
# array(['4', '1', '3', '967', '-100', '0', '2', '7', '5', '6', '8', '9',
#        '1464', '622', '352', '472', '1017', '945', '146', '563', '341',
#        '444', '720', '1485', '49', '737', '1106', '466', '728', '313',
#        '843', '597', '617', '119', '663', '640', '92', '1019', '501',
#        '1302', '39', '716', '848', '931', '1214', '186', '424', '1001',
#        '1110', '1152', '457', '1433', '1187', '52', '1480', '1047',
#        '1035', '1347', '33', '193', '699', '329', '1451', '484', '132',
#        '649', '995', '545', '684', '1135', '1094', '1204', '654', '58',
#        '348', '614', '1363', '323', '1406', '1348', '430', '153', '1461',
#        '905', '1312', '1424', '1154', '95', '1353', '1228', '819', '1006',
#        '795', '359', '1209', '590', '696', '1185', '1465', '911', '1181',
#        '70', '816', '1369', '143', '1416', '455', '55', '1096', '1474',
#        '420', '1131', '904', '89', '1259', '527', '1241', '449', '983',
#        '418', '319', '23', '238', '638', '138', '235', '280', '1070',
#        '1484', '274', '494', '1459', '404', '1354', '1495', '1391', '601',
#        '1313', '1319', '898', '231', '752', '174', '961', '1046', '834',
#        '284', '438', '288', '1463', '1151', '719', '198', '1015', '855',
#        '841', '392', '1444', '103', '1320', '745', '172', '252', '630',
#        '241', '31', '405', '1217', '1030', '1257', '137', '157', '164',
#        '1088', '1236', '777', '1048', '613', '330', '1439', '321', '661',
#        '952', '939', '562', '1202', '302', '943', '394', '955', '1318',
#        '936', '781', '100', '1329', '1365', '860', '217', '191', '32',
#        '282', '351', '1387', '757', '416', '833', '292', '1225', '1227',
#        '639', '859', '243', '267', '510', '332', '996', '311', '492',
#        '820', '336', '123', '540', '131', '1311', '1441', '895', '891',
#        '50', '940', '935', '596', '29', '1182', '1129', '1014', '251',
#        '365', '291', '1447', '742', '1085', '148', '462', '832', '881',
#        '1412', '785', '1127', '910', '538', '999', '733', '101', '237',
#        '87', '659', '633', '387', '447', '629', '831', '1384', '773',
#        '621', '1419', '289', '285', '1393', '27', '1359', '1482', '1189',
#        '1294', '201', '579', '814', '141', '581', '1171', '295', '290',
#        '433', '679', '1040', '1054', '1430', '1023', '1077', '1457',
#        '1150', '701', '1382', '889', '437', '372', '1222', '126', '1159',
#        '868', '19', '1297', '227', '190', '809', '1216', '1074', '571',
#        '520', '1274', '1340', '991', '316', '697', '926', '873', '1002',
#        '378', '65', '875', '867', '548', '652', '1372', '606', '1036',
#        '1300', '17', '1178', '802', '1219', '1271', '1137', '1496', '439',
#        '196', '636', '192', '228', '1053', '229', '753', '1296', '1371',
#        '254', '863', '464', '515', '838', '1160', '1289', '1298', '799',
#        '182', '574', '242', '415', '869', '958', '54', '1265', '656',
#        '275', '778', '208', '147', '350', '507', '463', '497', '927',
#        '653', '662', '529', '635', '1027', '897', '1039', '1345', '924',
#        '1279', '546', '1112', '1210', '526', '300', '1103', '504', '136',
#        '1400', '78', '686', '1091', '344', '215', '84', '628', '1470',
#        '968', '1478', '83', '1196', '1307', '1132', '1008', '917', '657',
#        '56', '18', '41', '801', '978', '216', '349', '966'], dtype=object)

# %%
# Now we will try to find out the possible pattern through Type_of_Loan.

df[df.Type_of_Loan.notnull()]
# Out:
#             ID Customer_ID     Month           Name   Age          SSN  \
# 0       0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265
# 1       0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265
# 2       0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265
# 3       0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265
# 4       0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265
# ...        ...         ...       ...            ...   ...          ...
# 99995  0x25fe9  CUS_0x942c     April          Nicks    25  078-73-5990
# 99996  0x25fea  CUS_0x942c       May          Nicks    25  078-73-5990
# 99997  0x25feb  CUS_0x942c      June          Nicks    25  078-73-5990
# 99998  0x25fec  CUS_0x942c      July          Nicks    25  078-73-5990
# 99999  0x25fed  CUS_0x942c    August          Nicks    25  078-73-5990
#
#       Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0      Scientist      19114.12            1824.843333                  3  ...
# 1      Scientist      19114.12                    NaN                  3  ...
# 2      Scientist      19114.12                    NaN                  3  ...
# 3      Scientist      19114.12                    NaN                  3  ...
# 4      Scientist      19114.12            1824.843333                  3  ...
# ...          ...           ...                    ...                ...  ...
# 99995   Mechanic      39628.99            3359.415833                  4  ...
# 99996   Mechanic      39628.99            3359.415833                  4  ...
# 99997   Mechanic      39628.99            3359.415833                  4  ...
# 99998   Mechanic      39628.99            3359.415833                  4  ...
# 99999   Mechanic     39628.99_            3359.415833                  4  ...
#
#        Credit_Mix  Outstanding_Debt Credit_Utilization_Ratio  \
# 0               _            809.98                26.822620
# 1            Good            809.98                31.944960
# 2            Good            809.98                28.609352
# 3            Good            809.98                31.377862
# 4            Good            809.98                24.797347
# ...           ...               ...                      ...
# 99995           _            502.38                34.663572
# 99996           _            502.38                40.565631
# 99997        Good            502.38                41.255522
# 99998        Good            502.38                33.638208
# 99999        Good            502.38                34.192463
#
#            Credit_History_Age  Payment_of_Min_Amount Total_EMI_per_month  \
# 0       22 Years and 1 Months                     No           49.574949
# 1                         NaN                     No           49.574949
# 2       22 Years and 3 Months                     No           49.574949
# 3       22 Years and 4 Months                     No           49.574949
# 4       22 Years and 5 Months                     No           49.574949
# ...                       ...                    ...                 ...
# 99995   31 Years and 6 Months                     No           35.104023
# 99996   31 Years and 7 Months                     No           35.104023
# 99997   31 Years and 8 Months                     No           35.104023
# 99998   31 Years and 9 Months                     No           35.104023
# 99999  31 Years and 10 Months                     No           35.104023
#
#       Amount_invested_monthly                 Payment_Behaviour  \
# 0           80.41529543900253   High_spent_Small_value_payments
# 1          118.28022162236736    Low_spent_Large_value_payments
# 2             81.699521264648   Low_spent_Medium_value_payments
# 3           199.4580743910713    Low_spent_Small_value_payments
# 4          41.420153086217326  High_spent_Medium_value_payments
# ...                       ...                               ...
# 99995       60.97133255718485   High_spent_Large_value_payments
# 99996       54.18595028760385  High_spent_Medium_value_payments
# 99997       24.02847744864441   High_spent_Large_value_payments
# 99998      251.67258219721603    Low_spent_Large_value_payments
# 99999       167.1638651610451                            !@9#%8
#
#           Monthly_Balance Credit_Score
# 0      312.49408867943663         Good
# 1      284.62916249607184         Good
# 2       331.2098628537912         Good
# 3      223.45130972736786         Good
# 4      341.48923103222177         Good
# ...                   ...          ...
# 99995          479.866228         Poor
# 99996           496.65161         Poor
# 99997          516.809083         Poor
# 99998          319.164979     Standard
# 99999          393.673696         Poor
#
# [88592 rows x 28 columns]

# %%
# Generating a new column by deriving values through the segmentation of data in Type_of_Loan

list = []
for i in range(df.shape[0]):
    if pd.isna(df.iloc[i,13]) == True:
        list.append(np.nan)
    else:
        list.append(len(df.Type_of_Loan[i].split(',')))

# %%
list = pd.Series(list)
df['Num_of_loan2'] = list

# %% [markdown]
# ## Missing value treatment

# %% [markdown]
# ### Num_of_loan2

# %%
df["Num_of_loan2"].isnull().sum()
# Out:
# 11408

# %%
df.Num_of_loan2.value_counts()
# Out:
# 3.0    15752
# 2.0    15712
# 4.0    15456
# 1.0    11128
# 6.0     8144
# 7.0     7680
# 5.0     7528
# 9.0     3856
# 8.0     3336
# Name: Num_of_loan2, dtype: int64

# %%
# Filling null values in the Num_of_loan2 column by replacing them with zeros obtained from the old loan column(Num_of_Loan).

df.loc[(df.Num_of_loan2.isnull()) & (df.Num_of_Loan == '0'), 'Num_of_loan2'] = 0

# %%
#df['Num_of_loan2'] = df['Num_of_loan2'].astype(int)
# after fixing null values we will covert to int

# %%
df.loc[(df.Num_of_loan2.isnull())]

#we can remove these 478 remaining values as they have no pattern or nothong
# Out:
#             ID Customer_ID   Month                  Name Age          SSN  \
# 34      0x1634  CUS_0x1cdb   March                Deepaa  21  615-06-7821
# 39      0x1639  CUS_0x1cdb  August                Deepaa  21  615-06-7821
# 180     0x170e  CUS_0xac86     May                 Nickb  20  028-16-4402
# 327     0x17e9  CUS_0xb5ff  August                 Nateg  33  060-81-1328
# 355     0x1815  CUS_0xaedb   April          Olivia Oranr  19  272-47-1135
# ...        ...         ...     ...                   ...  ..          ...
# 99611  0x25da9  CUS_0x2829   April        Alistair Barre  31  172-85-1573
# 99612  0x25daa  CUS_0x2829     May        Alistair Barre  32  172-85-1573
# 99630  0x25dc4  CUS_0x738b    July                 Leahh  25  769-44-1950
# 99663  0x25df5  CUS_0x30fc  August  Zoran Radosavljevicl  28  209-55-1275
# 99859  0x25f1d  CUS_0x1285   April               Lauriay  43  540-18-1115
#
#           Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 34         Developer      35547.71            2853.309167                  7
# 39         Developer      35547.71            2853.309167                  7
# 180     Entrepreneur    106733.13_            8873.427500                  4
# 327    Media_Manager     12909.895             853.824583                  5
# 355         Musician      85554.03            7185.502500                  4
# ...              ...           ...                    ...                ...
# 99611     Journalist      64901.37            5298.447500                  3
# 99612     Journalist      64901.37            5298.447500                  3
# 99630     Accountant     123828.52            9317.324054                  4
# 99663        Manager      90781.53            7505.127500                  7
# 99859      Architect     10692.16_             817.013333                  8
#
#        ...  Outstanding_Debt  Credit_Utilization_Ratio  \
# 34     ...            943.86                 23.462303
# 39     ...            943.86                 25.862922
# 180    ...             76.23                 28.820554
# 327    ...             602.5                 23.579851
# 355    ...           1095.73                 31.360245
# ...    ...               ...                       ...
# 99611  ...            442.06                 29.639741
# 99612  ...            442.06                 37.699808
# 99630  ...           1288.43                 39.099750
# 99663  ...            494.51                 36.809951
# 99859  ...           1350.85                 31.460700
#
#            Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 34     30 Years and 10 Months                   Yes             0.000000
# 39      31 Years and 3 Months                   Yes             0.000000
# 180     33 Years and 1 Months                    No             0.000000
# 327     17 Years and 8 Months                    No             0.000000
# 355    19 Years and 10 Months                    No             0.000000
# ...                       ...                   ...                  ...
# 99611   31 Years and 1 Months                   Yes             0.000000
# 99612                     NaN                   Yes             0.000000
# 99630   32 Years and 7 Months                    NM           999.719279
# 99663                     NaN                   Yes             0.000000
# 99859   31 Years and 8 Months                   Yes             0.000000
#
#       Amount_invested_monthly                 Payment_Behaviour  \
# 34         173.13865100158367   Low_spent_Medium_value_payments
# 39         181.33090096186916   High_spent_Small_value_payments
# 180        345.60913541068396  High_spent_Medium_value_payments
# 327        60.052634766462795   Low_spent_Medium_value_payments
# 355         303.6646866498075    Low_spent_Large_value_payments
# ...                       ...                               ...
# 99611      162.17115972608323  High_spent_Medium_value_payments
# 99612       97.41318994087194   High_spent_Large_value_payments
# 99630                     NaN   Low_spent_Medium_value_payments
# 99663       688.2568750926885   Low_spent_Medium_value_payments
# 99859       49.03380771131993    Low_spent_Large_value_payments
#
#           Monthly_Balance Credit_Score Num_of_loan2
# 34      392.1922656650829     Standard          NaN
# 39     364.00001570479753     Standard          NaN
# 180      791.733614589316         Good          NaN
# 327    305.32982356687063     Standard          NaN
# 355     684.8855633501927         Good          NaN
# ...                   ...          ...          ...
# 99611           617.67359     Standard          NaN
# 99612           672.43156     Standard          NaN
# 99630          530.878992         Good          NaN
# 99663          342.255875     Standard          NaN
# 99859          302.667526     Standard          NaN
#
# [478 rows x 29 columns]

# %%
#df.drop(df.loc[(df.Num_of_loan2.isnull())],axis = 0)
#df.shape
#df.Num_of_loan2.dropna()
#df['Num_of_loan2'].dropna(inplace=True,)
#df.drop(df.Num_of_loan2.isnull(), axis = 0).reset_index(drop = True)
df.dropna(subset = 'Num_of_loan2',inplace= True)

# %%
df.Num_of_loan2.isnull().sum()
# Out:
# 0

# %%
df.Num_of_loan2.value_counts()
# Out:
# 3.0    15752
# 2.0    15712
# 4.0    15456
# 1.0    11128
# 0.0    10930
# 6.0     8144
# 7.0     7680
# 5.0     7528
# 9.0     3856
# 8.0     3336
# Name: Num_of_loan2, dtype: int64

# %%
df.isnull().sum()
# we will remove name so no need for imputing null value for name
# type of loan also remove so no need to imoute
# Out:
# ID                              0
# Customer_ID                     0
# Month                           0
# Name                         9944
# Age                             0
# SSN                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary       14932
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                10930
# Delay_from_due_date             0
# Num_of_Delayed_Payment       6968
# Changed_Credit_Limit            0
# Num_Credit_Inquiries         1954
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age           8993
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly      4451
# Payment_Behaviour               0
# Monthly_Balance              1199
# Credit_Score                    0
# Num_of_loan2                    0
# dtype: int64

# %%
extracted_Data = df['Credit_History_Age'].str.extract(r'(\d+) Years and (\d+) Months')

# %%
df['Credit_History_Age'] = extracted_Data[0]+'.'+extracted_Data[1]
#converted extracted date to year.months
#now we can either round off or remove month

# %%
#df[df.Name == 'Aaron Maashoh']

# %%
df['Age'] = df.Age.str.replace('-','')
#cleaning age

# %%
df['Age'] = df.Age.str.replace('_','')
#now we have cleaned age

# %%
#as age has no null value we will try to change it to int
df['Age'] = df.Age.astype(int)

# %%
# as age has anomalous data we will try to check for age as value are absurd with ranging uptio 1000
#-----------for every name check other entries with same name-----------
df.Age
# Out:
# 0         23
# 1         23
# 2        500
# 3         23
# 4         23
#         ...
# 99995     25
# 99996     25
# 99997     25
# 99998     25
# 99999     25
# Name: Age, Length: 99522, dtype: int32

# %%
df[df.Name == 'Aaron Maashoh']
# Out:
#        ID Customer_ID     Month           Name  Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh   23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh   23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh  500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April  Aaron Maashoh   23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May  Aaron Maashoh   23  821-00-0265  Scientist
# 5  0x1607   CUS_0xd40      June  Aaron Maashoh   23  821-00-0265  Scientist
# 6  0x1608   CUS_0xd40      July  Aaron Maashoh   23  821-00-0265  Scientist
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0      19114.12            1824.843333                  3  ...
# 1      19114.12                    NaN                  3  ...
# 2      19114.12                    NaN                  3  ...
# 3      19114.12                    NaN                  3  ...
# 4      19114.12            1824.843333                  3  ...
# 5      19114.12                    NaN                  3  ...
# 6      19114.12            1824.843333                  3  ...
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# 0            809.98                 26.822620               22.1
# 1            809.98                 31.944960                NaN
# 2            809.98                 28.609352               22.3
# 3            809.98                 31.377862               22.4
# 4            809.98                 24.797347               22.5
# 5            809.98                 27.262259               22.6
# 6            809.98                 22.537593               22.7
#
#   Payment_of_Min_Amount  Total_EMI_per_month Amount_invested_monthly  \
# 0                    No            49.574949       80.41529543900253
# 1                    No            49.574949      118.28022162236736
# 2                    No            49.574949         81.699521264648
# 3                    No            49.574949       199.4580743910713
# 4                    No            49.574949      41.420153086217326
# 5                    No            49.574949      62.430172331195294
# 6                    No            49.574949       178.3440674122349
#
#                   Payment_Behaviour     Monthly_Balance Credit_Score  \
# 0   High_spent_Small_value_payments  312.49408867943663         Good
# 1    Low_spent_Large_value_payments  284.62916249607184         Good
# 2   Low_spent_Medium_value_payments   331.2098628537912         Good
# 3    Low_spent_Small_value_payments  223.45130972736786         Good
# 4  High_spent_Medium_value_payments  341.48923103222177         Good
# 5                            !@9#%8   340.4792117872438         Good
# 6    Low_spent_Small_value_payments   244.5653167062043         Good
#
#   Num_of_loan2
# 0          4.0
# 1          4.0
# 2          4.0
# 3          4.0
# 4          4.0
# 5          4.0
# 6          4.0
#
# [7 rows x 29 columns]

# %%
df.Age[df.Age < 100].unique()

#now we will make these values null and try to impute them
# Out:
# array([23, 28, 34, 54, 55, 21, 31, 33, 30, 24, 44, 45, 40, 41, 32, 35, 36,
#        39, 37, 20, 46, 26, 42, 19, 48, 38, 43, 22, 16, 18, 15, 27, 25, 14,
#        17, 47, 53, 56, 29, 49, 51, 50, 52, 99, 95])

# %%
###do in classssssss-----------------------------------
df[df.Name == 'Costas Pitasw']
# Out:
#            ID Customer_ID     Month           Name  Age          SSN  \
# 38248  0xf61e  CUS_0x7e94   January  Costas Pitasw   95  446-63-0451
# 38249  0xf61f  CUS_0x7e94  February  Costas Pitasw   32  446-63-0451
# 38250  0xf620  CUS_0x7e94     March  Costas Pitasw   32  446-63-0451
# 38251  0xf621  CUS_0x7e94     April  Costas Pitasw   32  446-63-0451
# 38252  0xf622  CUS_0x7e94       May  Costas Pitasw   32  446-63-0451
# 38253  0xf623  CUS_0x7e94      June  Costas Pitasw   32    #F%$D@*&8
# 38254  0xf624  CUS_0x7e94      July  Costas Pitasw   32  446-63-0451
#
#       Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 38248   Engineer      46162.62               3548.885                 10  ...
# 38249   Engineer      46162.62               3548.885                 10  ...
# 38250    _______      46162.62               3548.885                 10  ...
# 38251   Engineer      46162.62               3548.885                 10  ...
# 38252   Engineer      46162.62               3548.885                 10  ...
# 38253   Engineer      46162.62               3548.885                 10  ...
# 38254   Engineer      46162.62               3548.885                 10  ...
#
#        Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# 38248           1788.63                 35.386419               15.5
# 38249           1788.63                 35.093605               15.6
# 38250           1788.63                 24.654948               15.7
# 38251           1788.63                 26.129869               15.8
# 38252           1788.63                 39.664228               15.9
# 38253           1788.63                 26.397466                NaN
# 38254           1788.63                 27.376443              15.11
#
#       Payment_of_Min_Amount  Total_EMI_per_month Amount_invested_monthly  \
# 38248                   Yes            65.956819      288.64584382244783
# 38249                   Yes            65.956819      51.315112747532005
# 38250                   Yes            65.956819      163.21228343517177
# 38251                   Yes            65.956819      51.978908120914326
# 38252                   Yes            65.956819       66.77935462510587
# 38253                   Yes            65.956819      106.60843476122956
# 38254                   Yes            65.956819       82.31997818867063
#
#                       Payment_Behaviour     Monthly_Balance Credit_Score  \
# 38248    Low_spent_Small_value_payments  290.28583676908613     Standard
# 38249  High_spent_Medium_value_payments  487.61656784400185         Poor
# 38250   High_spent_Small_value_payments  385.71939715636216         Poor
# 38251  High_spent_Medium_value_payments  486.95277247061966         Poor
# 38252  High_spent_Medium_value_payments  472.15232596642807         Poor
# 38253    Low_spent_Large_value_payments   452.3232458303044         Poor
# 38254  High_spent_Medium_value_payments  456.61170240286333         Poor
#
#       Num_of_loan2
# 38248          2.0
# 38249          2.0
# 38250          2.0
# 38251          2.0
# 38252          2.0
# 38253          2.0
# 38254          2.0
#
# [7 rows x 29 columns]

# %%
#column_name = 'Age' group_by = 'Customer_ID' user_friendly_name = 'Age' 
#Get Details
#get_column_details(df,'Age')
#Cleaning clean_numerical_field(df_train,group_by,column_name,strip='_',datatype='int')
#Plot Graph plot_displot(df_train,column_name,user_friendly_name,bins=40)

# %%
#df['Age'][df['Age'] > 60] = np.nan

# %%
##cleaning occupation

# %%
df['Occupation'].value_counts()
# Out:
# _______          7024
# Lawyer           6553
# Architect        6326
# Engineer         6315
# Mechanic         6273
# Scientist        6271
# Accountant       6239
# Media_Manager    6202
# Developer        6197
# Teacher          6186
# Entrepreneur     6146
# Doctor           6069
# Journalist       6054
# Manager          5941
# Musician         5872
# Writer           5854
# Name: Occupation, dtype: int64

# %%
df[df.Occupation == '_______']
# Out:
#             ID Customer_ID     Month              Name  Age          SSN  \
# 8       0x160e  CUS_0x21b1   January   Rick Rothackerj   28  004-07-5839
# 16      0x161a  CUS_0x2dbc   January            Langep   34  486-85-3974
# 18      0x161c  CUS_0x2dbc     March            Langep   34  486-85-3974
# 20      0x161e  CUS_0x2dbc       May            Langep   34  486-85-3974
# 29      0x162b  CUS_0xb891      June            Jasond   55    #F%$D@*&8
# ...        ...         ...       ...               ...  ...          ...
# 99920  0x25f7a  CUS_0x2654   January               enj   37  647-67-8889
# 99935  0x25f8d  CUS_0xb11c    August    Yinka Adegokej   38  546-94-4789
# 99937  0x25f93  CUS_0xad4f  February  Sabina Zawadzkig  500  226-45-0652
# 99943  0x25f99  CUS_0xad4f    August  Sabina Zawadzkig   48  226-45-0652
# 99989  0x25fdf  CUS_0x8600      June    Sarah McBridec   28  031-35-0942
#
#       Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 8        _______      34847.84            3037.986667                  2  ...
# 16       _______     143162.64           12187.220000                  1  ...
# 18       _______     143162.64                    NaN                  1  ...
# 20       _______     143162.64           12187.220000                  1  ...
# 29       _______      30689.89            2612.490833                  2  ...
# ...          ...           ...                    ...                ...  ...
# 99920    _______     139664.96           11777.746667                  3  ...
# 99935    _______      15319.65            1460.637500                  6  ...
# 99937    _______      22620.79            1722.065833                  7  ...
# 99943    _______      22620.79                    NaN                  6  ...
# 99989    _______      20002.88            1929.906667                 10  ...
#
#        Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# 8                605.03                 24.464031               26.7
# 16              1303.01                 28.616735               17.9
# 18              1303.01                 26.519815              17.11
# 20              1303.01                 31.376150               18.1
# 29               632.46                 27.445422               17.8
# ...                 ...                       ...                ...
# 99920            365.66                 31.043048               29.7
# 99935           1453.61                 34.557510               11.4
# 99937            642.46                 31.841872                NaN
# 99943            642.46                 34.026427              29.10
# 99989            3571.7                 33.359987                6.1
#
#       Payment_of_Min_Amount  Total_EMI_per_month Amount_invested_monthly  \
# 8                        No            18.816215        104.291825168246
# 16                       No           246.992319        168.413702679309
# 18                       No           246.992319               __10000__
# 20                       No           246.992319       430.9475278803298
# 29                       No            16.415452       84.95284817115969
# ...                     ...                  ...                     ...
# 99920                   Yes           423.731016      282.78234595777644
# 99935                   Yes            28.182033      191.87777851803025
# 99937                    No             0.000000      105.07629339039072
# 99943                    No             0.000000      205.21728040016708
# 99989                   Yes            60.964772       74.36660309585342
#
#                      Payment_Behaviour     Monthly_Balance Credit_Score  \
# 8       Low_spent_Small_value_payments  470.69062692529184     Standard
# 16                              !@9#%8  1043.3159778669492         Good
# 18     High_spent_Small_value_payments    715.741367403555         Good
# 20      Low_spent_Large_value_payments   810.7821526659284         Good
# 29     High_spent_Small_value_payments   419.8807835023488     Standard
# ...                                ...                 ...          ...
# 99920  High_spent_Large_value_payments          711.261305     Standard
# 99935   Low_spent_Small_value_payments          216.003938         Poor
# 99937   Low_spent_Large_value_payments           337.13029     Standard
# 99943   Low_spent_Small_value_payments          256.989303         Poor
# 99989                           !@9#%8          307.659291     Standard
#
#       Num_of_loan2
# 8              1.0
# 16             3.0
# 18             3.0
# 20             3.0
# 29             1.0
# ...            ...
# 99920          4.0
# 99935          4.0
# 99937          0.0
# 99943          0.0
# 99989          5.0
#
# [7024 rows x 29 columns]

# %%
df[df.Name == 'Langep']
# Out:
#             ID Customer_ID     Month    Name  Age          SSN  Occupation  \
# 16      0x161a  CUS_0x2dbc   January  Langep   34  486-85-3974     _______
# 18      0x161c  CUS_0x2dbc     March  Langep   34  486-85-3974     _______
# 19      0x161d  CUS_0x2dbc     April  Langep   34  486-85-3974    Engineer
# 20      0x161e  CUS_0x2dbc       May  Langep   34  486-85-3974     _______
# 21      0x161f  CUS_0x2dbc      June  Langep   34  486-85-3974    Engineer
# 23      0x1621  CUS_0x2dbc    August  Langep   34  486-85-3974    Engineer
# 11872   0x5b92  CUS_0xaf95   January  Langep   38  917-87-3520  Accountant
# 11873   0x5b93  CUS_0xaf95  February  Langep   38  917-87-3520     _______
# 11874   0x5b94  CUS_0xaf95     March  Langep   38  917-87-3520  Accountant
# 11875   0x5b95  CUS_0xaf95     April  Langep   38  917-87-3520  Accountant
# 11876   0x5b96  CUS_0xaf95       May  Langep   38  917-87-3520  Accountant
# 11877   0x5b97  CUS_0xaf95      June  Langep   38  917-87-3520  Accountant
# 11878   0x5b98  CUS_0xaf95      July  Langep   39    #F%$D@*&8  Accountant
# 11879   0x5b99  CUS_0xaf95    August  Langep   39  917-87-3520  Accountant
# 44856  0x11cd6  CUS_0x109d   January  Langep  500  260-21-1290      Writer
# 44857  0x11cd7  CUS_0x109d  February  Langep   44  260-21-1290      Writer
# 44858  0x11cd8  CUS_0x109d     March  Langep   45    #F%$D@*&8      Writer
# 44859  0x11cd9  CUS_0x109d     April  Langep   45  260-21-1290      Writer
# 44860  0x11cda  CUS_0x109d       May  Langep   45  260-21-1290      Writer
# 44861  0x11cdb  CUS_0x109d      June  Langep   45  260-21-1290      Writer
# 44862  0x11cdc  CUS_0x109d      July  Langep   45  260-21-1290      Writer
# 44863  0x11cdd  CUS_0x109d    August  Langep   45  260-21-1290      Writer
# 53272  0x14e26  CUS_0x4854   January  Langep   44  564-50-3217  Accountant
# 53273  0x14e27  CUS_0x4854  February  Langep   44  564-50-3217  Accountant
# 53274  0x14e28  CUS_0x4854     March  Langep   44  564-50-3217  Accountant
# 53275  0x14e29  CUS_0x4854     April  Langep   44  564-50-3217  Accountant
# 53276  0x14e2a  CUS_0x4854       May  Langep   44  564-50-3217  Accountant
# 53277  0x14e2b  CUS_0x4854      June  Langep   44    #F%$D@*&8  Accountant
# 53278  0x14e2c  CUS_0x4854      July  Langep   44  564-50-3217  Accountant
# 53279  0x14e2d  CUS_0x4854    August  Langep   44  564-50-3217  Accountant
# 61376  0x17da2  CUS_0xba1c   January  Langep   32  419-82-4747      Lawyer
# 61377  0x17da3  CUS_0xba1c  February  Langep   32  419-82-4747      Lawyer
# 61378  0x17da4  CUS_0xba1c     March  Langep   32  419-82-4747      Lawyer
# 61379  0x17da5  CUS_0xba1c     April  Langep   32  419-82-4747      Lawyer
# 61381  0x17da7  CUS_0xba1c      June  Langep   32  419-82-4747      Lawyer
# 61382  0x17da8  CUS_0xba1c      July  Langep   32  419-82-4747      Lawyer
# 61383  0x17da9  CUS_0xba1c    August  Langep   33  419-82-4747      Lawyer
# 76872  0x1d86e  CUS_0x7a96   January  Langep   29  255-67-1198     Manager
# 76873  0x1d86f  CUS_0x7a96  February  Langep   29  255-67-1198     Manager
# 76874  0x1d870  CUS_0x7a96     March  Langep   29  255-67-1198     Manager
# 76875  0x1d871  CUS_0x7a96     April  Langep   29  255-67-1198     Manager
# 76876  0x1d872  CUS_0x7a96       May  Langep   30  255-67-1198     Manager
# 76878  0x1d874  CUS_0x7a96      July  Langep   30  255-67-1198     Manager
# 76879  0x1d875  CUS_0x7a96    August  Langep   30  255-67-1198     Manager
#
#       Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 16        143162.64           12187.220000                  1  ...
# 18        143162.64                    NaN                  1  ...
# 19        143162.64           12187.220000                  1  ...
# 20        143162.64           12187.220000                  1  ...
# 21        143162.64           12187.220000                  1  ...
# 23        143162.64           12187.220000                  1  ...
# 11872     10418.045             994.170417                  9  ...
# 11873     10418.045             994.170417                  9  ...
# 11874     10418.045             994.170417                  9  ...
# 11875     10418.045             994.170417                  9  ...
# 11876     10418.045             994.170417                  9  ...
# 11877     10418.045             994.170417                  9  ...
# 11878     10418.045                    NaN                  9  ...
# 11879     10418.045             994.170417                  9  ...
# 44856      49140.87            4377.072500                 10  ...
# 44857      49140.87            4377.072500                 10  ...
# 44858      49140.87            4377.072500                232  ...
# 44859      49140.87            4377.072500                 10  ...
# 44860      49140.87            4377.072500                 10  ...
# 44861      49140.87            4377.072500                 10  ...
# 44862      49140.87            4377.072500                 10  ...
# 44863      49140.87            4377.072500                 10  ...
# 53272      66012.28            5400.023333                 10  ...
# 53273      66012.28            5400.023333                 10  ...
# 53274      66012.28                    NaN                 10  ...
# 53275      66012.28            5400.023333                 10  ...
# 53276      66012.28                    NaN                 10  ...
# 53277      66012.28            5400.023333                 10  ...
# 53278      66012.28            5400.023333                 10  ...
# 53279      66012.28            5400.023333                 10  ...
# 61376      41757.44            3317.786667                  6  ...
# 61377      41757.44            3317.786667                  6  ...
# 61378      41757.44                    NaN                  6  ...
# 61379      41757.44            3317.786667                  6  ...
# 61381     41757.44_            3317.786667                  6  ...
# 61382      41757.44            3317.786667                  6  ...
# 61383     41757.44_                    NaN                  6  ...
# 76872       24424.7            2051.391667                  8  ...
# 76873       24424.7            2051.391667                  8  ...
# 76874       24424.7            2051.391667                  8  ...
# 76875       24424.7            2051.391667                  8  ...
# 76876       24424.7            2051.391667                  8  ...
# 76878       24424.7                    NaN                  8  ...
# 76879       24424.7            2051.391667                  8  ...
#
#        Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# 16              1303.01                 28.616735               17.9
# 18              1303.01                 26.519815              17.11
# 19              1303.01                 39.501648                NaN
# 20              1303.01                 31.376150               18.1
# 21              1303.01                 39.783993               18.2
# 23              1303.01                 38.374753               18.4
# 11872           3599.97                 25.100129                8.7
# 11873           3599.97                 39.090271                8.8
# 11874           3599.97                 34.731204                NaN
# 11875           3599.97                 23.725047               8.10
# 11876           3599.97                 29.596306               8.11
# 11877           3599.97                 25.640773                9.0
# 11878           3599.97                 24.789920                9.1
# 11879           3599.97                 26.751006                9.2
# 44856            2950.8                 28.875662                NaN
# 44857            2950.8                 25.294527                6.0
# 44858            2950.8                 34.142258                6.1
# 44859            2950.8                 26.586091                6.2
# 44860            2950.8                 40.657363                6.3
# 44861            2950.8                 28.706417                6.4
# 44862            2950.8                 28.446317                6.5
# 44863            2950.8                 31.163786                6.6
# 53272           3696.36                 38.731936               13.7
# 53273           3696.36                 38.395068               13.8
# 53274           3696.36                 33.302369               13.9
# 53275           3696.36                 39.774138              13.10
# 53276           3696.36                 26.076722              13.11
# 53277           3696.36                 23.408542               14.0
# 53278           3696.36                 27.893745               14.1
# 53279           3696.36                 29.570505               14.2
# 61376           1360.45                 33.287966               17.4
# 61377           1360.45                 34.432490               17.5
# 61378           1360.45                 34.007853               17.6
# 61379           1360.45                 25.616749               17.7
# 61381           1360.45                 38.816413               17.9
# 61382           1360.45                 28.265031              17.10
# 61383           1360.45                 37.542362              17.11
# 76872            626.57                 26.238410               22.2
# 76873            626.57                 27.436075               22.3
# 76874            626.57                 35.133788               22.4
# 76875            626.57                 38.554934               22.5
# 76876            626.57                 26.159936               22.6
# 76878            626.57                 29.053649               22.8
# 76879            626.57                 41.621925               22.9
#
#       Payment_of_Min_Amount  Total_EMI_per_month Amount_invested_monthly  \
# 16                       No           246.992319        168.413702679309
# 18                       No           246.992319               __10000__
# 19                       No           246.992319       825.2162699393922
# 20                       No           246.992319       430.9475278803298
# 21                       No           246.992319      257.80809942568976
# 23                       No           246.992319               __10000__
# 11872                   Yes            27.594591       38.34652425964861
# 11873                   Yes            27.594591       91.72067560958176
# 11874                    NM            27.594591      107.00551841605062
# 11875                   Yes            27.594591       49.79141297051545
# 11876                   Yes            27.594591       39.66109770522233
# 11877                   Yes         54106.000000       88.84988827246971
# 11878                   Yes            27.594591       83.30824766455746
# 11879                   Yes            27.594591      30.093083131381434
# 44856                    NM           154.172426       113.5947068431238
# 44857                   Yes           154.172426                     NaN
# 44858                   Yes           154.172426      177.29830882315827
# 44859                    NM           154.172426      102.23121930882247
# 44860                   Yes           154.172426      112.35604289157084
# 44861                   Yes           154.172426      226.73129611902863
# 44862                   Yes           154.172426        269.190939082866
# 44863                    NM           154.172426       301.5937949187359
# 53272                   Yes           227.301860               __10000__
# 53273                   Yes           227.301860       302.3287876193388
# 53274                   Yes           227.301860      285.72821678996695
# 53275                   Yes           227.301860      226.80456491264718
# 53276                   Yes           227.301860                     NaN
# 53277                   Yes           227.301860       353.2630280303908
# 53278                   Yes           227.301860       219.8688674374263
# 53279                   Yes           227.301860      118.05301559401012
# 61376                   Yes           100.069628        35.2267644265974
# 61377                   Yes           100.069628       116.2639798801188
# 61378                   Yes           100.069628       66.57068250129537
# 61379                   Yes           100.069628      31.565207152562877
# 61381                    NM           100.069628       79.96773477564284
# 61382                   Yes           100.069628       248.3894489673249
# 61383                   Yes           100.069628      117.10900181158121
# 76872                   Yes             0.000000                     NaN
# 76873                    NM             0.000000      34.482412228308924
# 76874                   Yes             0.000000       33.29935237549108
# 76875                   Yes             0.000000       67.21400110609777
# 76876                   Yes             0.000000       48.40457063771542
# 76878                   Yes             0.000000      198.73751227870858
# 76879                   Yes             0.000000                     NaN
#
#                       Payment_Behaviour     Monthly_Balance Credit_Score  \
# 16                               !@9#%8  1043.3159778669492         Good
# 18      High_spent_Small_value_payments    715.741367403555         Good
# 19      Low_spent_Medium_value_payments   426.5134106068658         Good
# 20       Low_spent_Large_value_payments   810.7821526659284         Good
# 21     High_spent_Medium_value_payments   963.9215811205684         Good
# 23      High_spent_Small_value_payments    895.494583180492     Standard
# 11872    Low_spent_Small_value_payments   323.4759264390949     Standard
# 11873    Low_spent_Large_value_payments  250.10177508916172     Standard
# 11874    Low_spent_Small_value_payments   254.8169322826929     Standard
# 11875    Low_spent_Small_value_payments  312.03103772822806     Standard
# 11876                            !@9#%8   322.1613529935212     Standard
# 11877    Low_spent_Small_value_payments   272.9725624262738     Standard
# 11878    Low_spent_Small_value_payments  278.51420303418604     Standard
# 11879   Low_spent_Medium_value_payments  321.72936756736215     Standard
# 44856   High_spent_Large_value_payments  409.94011683170373     Standard
# 44857                            !@9#%8   361.5368983485935     Standard
# 44858   High_spent_Small_value_payments   366.2365148516693     Standard
# 44859   High_spent_Large_value_payments   421.3036043660051     Standard
# 44860   High_spent_Small_value_payments   431.1787807832567     Standard
# 44861   High_spent_Small_value_payments   316.8035275557988     Standard
# 44862   High_spent_Small_value_payments   274.3438845919615     Standard
# 44863    Low_spent_Small_value_payments  271.94102875609155     Standard
# 53272  High_spent_Medium_value_payments   441.2311967238395     Standard
# 53273   High_spent_Small_value_payments  270.37168569669905     Standard
# 53274    Low_spent_Small_value_payments  316.97225652607085     Standard
# 53275    Low_spent_Small_value_payments  375.89590840339065     Standard
# 53276    Low_spent_Small_value_payments                 NaN     Standard
# 53277   High_spent_Small_value_payments  219.43744528564704     Standard
# 53278    Low_spent_Large_value_payments   362.8316058786116     Standard
# 53279  High_spent_Medium_value_payments  444.64745772202775     Standard
# 61376                            !@9#%8    436.482273999598         Poor
# 61377  High_spent_Medium_value_payments  365.44505854607667         Poor
# 61378                            !@9#%8  425.13835592490005         Poor
# 61379   High_spent_Large_value_payments   440.1438312736325     Standard
# 61381   High_spent_Large_value_payments   391.7413036505526         Poor
# 61382    Low_spent_Small_value_payments   273.3195894588705         Poor
# 61383   High_spent_Small_value_payments  374.60003661461417         Poor
# 76872    Low_spent_Small_value_payments   336.3243815880911     Standard
# 76873   High_spent_Large_value_payments   410.6567544383577     Standard
# 76874  High_spent_Medium_value_payments   421.8398142911756     Standard
# 76875    Low_spent_Large_value_payments  407.92516556056887     Standard
# 76876   High_spent_Small_value_payments  416.73459602895133     Standard
# 76878    Low_spent_Small_value_payments  296.40165438795805     Standard
# 76879                            !@9#%8  364.51833712960763     Standard
#
#       Num_of_loan2
# 16             3.0
# 18             3.0
# 19             3.0
# 20             3.0
# 21             3.0
# 23             3.0
# 11872          6.0
# 11873          6.0
# 11874          6.0
# 11875          6.0
# 11876          6.0
# 11877          6.0
# 11878          6.0
# 11879          6.0
# 44856          6.0
# 44857          6.0
# 44858          6.0
# 44859          6.0
# 44860          6.0
# 44861          6.0
# 44862          6.0
# 44863          6.0
# 53272          6.0
# 53273          6.0
# 53274          6.0
# 53275          6.0
# 53276          6.0
# 53277          6.0
# 53278          6.0
# 53279          6.0
# 61376          3.0
# 61377          3.0
# 61378          3.0
# 61379          3.0
# 61381          3.0
# 61382          3.0
# 61383          3.0
# 76872          0.0
# 76873          0.0
# 76874          0.0
# 76875          0.0
# 76876          0.0
# 76878          0.0
# 76879          0.0
#
# [44 rows x 29 columns]

# %%
df[df.Customer_ID == 'CUS_0xb11c']
# Out:
#             ID Customer_ID     Month            Name  Age          SSN  \
# 99928  0x25f86  CUS_0xb11c   January  Yinka Adegokej   38  546-94-4789
# 99929  0x25f87  CUS_0xb11c  February  Yinka Adegokej   38  546-94-4789
# 99930  0x25f88  CUS_0xb11c     March  Yinka Adegokej   38  546-94-4789
# 99931  0x25f89  CUS_0xb11c     April  Yinka Adegokej   38  546-94-4789
# 99932  0x25f8a  CUS_0xb11c       May  Yinka Adegokej   38  546-94-4789
# 99933  0x25f8b  CUS_0xb11c      June  Yinka Adegokej   38  546-94-4789
# 99934  0x25f8c  CUS_0xb11c      July  Yinka Adegokej   38  546-94-4789
# 99935  0x25f8d  CUS_0xb11c    August  Yinka Adegokej   38  546-94-4789
#
#       Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 99928    Manager      15319.65                    NaN                  6  ...
# 99929    Manager      15319.65              1460.6375                  6  ...
# 99930    Manager      15319.65              1460.6375                  6  ...
# 99931    Manager      15319.65              1460.6375                  6  ...
# 99932    Manager      15319.65              1460.6375                  6  ...
# 99933    Manager      15319.65              1460.6375                  6  ...
# 99934    Manager      15319.65              1460.6375                  6  ...
# 99935    _______      15319.65              1460.6375                  6  ...
#
#        Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# 99928           1453.61                 36.518222               10.9
# 99929           1453.61                 39.705561              10.10
# 99930          1453.61_                 37.266724              10.11
# 99931           1453.61                 34.243058               11.0
# 99932           1453.61                 25.539990               11.1
# 99933           1453.61                 24.846424               11.2
# 99934           1453.61                 38.987835                NaN
# 99935           1453.61                 34.557510               11.4
#
#       Payment_of_Min_Amount  Total_EMI_per_month Amount_invested_monthly  \
# 99928                   Yes            28.182033      167.88843516537085
# 99929                   Yes            28.182033      162.66249736888412
# 99930                   Yes            28.182033       91.56581797275696
# 99931                   Yes            28.182033                     0.0
# 99932                   Yes            28.182033       89.75730477101116
# 99933                   Yes            28.182033       45.61171819143637
# 99934                   Yes            28.182033        70.2417852372894
# 99935                   Yes            28.182033      191.87777851803025
#
#                      Payment_Behaviour  Monthly_Balance Credit_Score  \
# 99928   Low_spent_Small_value_payments       239.993281         Poor
# 99929   Low_spent_Small_value_payments       245.219219         Poor
# 99930  Low_spent_Medium_value_payments       306.315899         Poor
# 99931  High_spent_Large_value_payments       348.088383     Standard
# 99932   Low_spent_Small_value_payments       318.124412     Standard
# 99933  High_spent_Small_value_payments       332.269998     Standard
# 99934   Low_spent_Large_value_payments       317.639931         Poor
# 99935   Low_spent_Small_value_payments       216.003938         Poor
#
#       Num_of_loan2
# 99928          4.0
# 99929          4.0
# 99930          4.0
# 99931          4.0
# 99932          4.0
# 99933          4.0
# 99934          4.0
# 99935          4.0
#
# [8 rows x 29 columns]

# %%
##create function
#customner ID of person who has ---- in occupation
#   check for other occupation of that same person
#   if not ---- then replace occupation else impute null

# customner ID of person who has --- or null or abnormal value
# them check for same id where not null or not ---- and fill value form there
import warnings
warnings.filterwarnings('ignore')

# %%
df[df.Occupation == '_______'].shape
# Out:
# (7024, 29)

# %% [raw]
# #for i in df.Customer_ID[df.Occupation == '_______']:
# #    for j in df.Occupation[(df.Customer_ID ==i) & (df.Occupation != '_______')]:
# #        df.Occupation[(df.Customer_ID == i) & (df.Occupation == '_______')] = j
#     #rint(i)

# %%
job=""
for i in df.Customer_ID[df.Occupation == '_______']:
    job = df.Occupation[(df.Customer_ID ==i) & (df.Occupation != '_______')].unique()
    df.Occupation[df.Customer_ID == i] = job 
    #rint(i)

# %%
#df.Occupation[df.Customer_ID == 'CUS_0x6649']
df.Occupation[(df.Customer_ID == 'CUS_0xbffe') & (df.Occupation != '_______')]
# Out:
# 224    Architect
# 225    Architect
# 226    Architect
# 227    Architect
# 228    Architect
# 229    Architect
# 230    Architect
# 231    Architect
# Name: Occupation, dtype: object

# %%
#job = df.Occupation[(df.Customer_ID == 'CUS_0x6649') & (df.Occupation != '_______')]
#job
df.Occupation[df.Customer_ID == 'CUS_0x6649']
# Out:
# 608    Mechanic
# 609    Mechanic
# 610    Mechanic
# 611    Mechanic
# 612    Mechanic
# 613    Mechanic
# 614    Mechanic
# 615    Mechanic
# Name: Occupation, dtype: object

# %%
# Doing Treatment for the age Column

# %%
df.Age[df['Age']>90] = np.nan

# %%
df['Age'].isnull().sum()
# Out:
# 2765

# %%
df.Age[df.Age.isnull()]
# Out:
# 2       NaN
# 56      NaN
# 113     NaN
# 122     NaN
# 219     NaN
#          ..
# 99913   NaN
# 99937   NaN
# 99950   NaN
# 99963   NaN
# 99972   NaN
# Name: Age, Length: 2765, dtype: float64

# %%
age=""
Age1=""
for i in df.Customer_ID[df.Age.isnull()]:
    age = df.Age[(df.Customer_ID ==i) & (df.Age.notnull())]
    Age1 = age.to_list()
    df.Age[df.Customer_ID == i] = Age1[0]

# %%
df.loc[99972]
# Out:
# ID                                                                    0x25fc6
# Customer_ID                                                         CUS_0xf16
# Month                                                                     May
# Name                                                           Maria Sheahanb
# Age                                                                      44.0
# SSN                                                               868-70-2218
# Occupation                                                      Media_Manager
# Annual_Income                                                        16680.35
# Monthly_Inhand_Salary                                             1528.029167
# Num_Bank_Accounts                                                           1
# Num_Credit_Card                                                             1
# Interest_Rate                                                               5
# Num_of_Loan                                                                 4
# Type_of_Loan                Payday Loan, Student Loan, Mortgage Loan, and ...
# Delay_from_due_date                                                         1
# Num_of_Delayed_Payment                                                      0
# Changed_Credit_Limit                                                     5.69
# Num_Credit_Inquiries                                                      8.0
# Credit_Mix                                                               Good
# Outstanding_Debt                                                       897.16
# Credit_Utilization_Ratio                                            37.788217
# Credit_History_Age                                                       21.5
# Payment_of_Min_Amount                                                      No
# Total_EMI_per_month                                                 41.113561
# Amount_invested_monthly                                     64.54974829039807
# Payment_Behaviour                              Low_spent_Large_value_payments
# Monthly_Balance                                                    317.139608
# Credit_Score                                                         Standard
# Num_of_loan2                                                              4.0
# Name: 99972, dtype: object

# %%
# successfully Treated the Null Valuedf.Age.isnull()]
df.Age.isnull().sum()
# Out:
# 0

# %%
Credit_Age = df[df.Credit_History_Age.isnull()]

# %%
df.loc[df.Name == 'Langep', ['Customer_ID','Month', 'Credit_History_Age']]
# Out:
#       Customer_ID     Month Credit_History_Age
# 16     CUS_0x2dbc   January               17.9
# 18     CUS_0x2dbc     March              17.11
# 19     CUS_0x2dbc     April                NaN
# 20     CUS_0x2dbc       May               18.1
# 21     CUS_0x2dbc      June               18.2
# 23     CUS_0x2dbc    August               18.4
# 11872  CUS_0xaf95   January                8.7
# 11873  CUS_0xaf95  February                8.8
# 11874  CUS_0xaf95     March                NaN
# 11875  CUS_0xaf95     April               8.10
# 11876  CUS_0xaf95       May               8.11
# 11877  CUS_0xaf95      June                9.0
# 11878  CUS_0xaf95      July                9.1
# 11879  CUS_0xaf95    August                9.2
# 44856  CUS_0x109d   January                NaN
# 44857  CUS_0x109d  February                6.0
# 44858  CUS_0x109d     March                6.1
# 44859  CUS_0x109d     April                6.2
# 44860  CUS_0x109d       May                6.3
# 44861  CUS_0x109d      June                6.4
# 44862  CUS_0x109d      July                6.5
# 44863  CUS_0x109d    August                6.6
# 53272  CUS_0x4854   January               13.7
# 53273  CUS_0x4854  February               13.8
# 53274  CUS_0x4854     March               13.9
# 53275  CUS_0x4854     April              13.10
# 53276  CUS_0x4854       May              13.11
# 53277  CUS_0x4854      June               14.0
# 53278  CUS_0x4854      July               14.1
# 53279  CUS_0x4854    August               14.2
# 61376  CUS_0xba1c   January               17.4
# 61377  CUS_0xba1c  February               17.5
# 61378  CUS_0xba1c     March               17.6
# 61379  CUS_0xba1c     April               17.7
# 61381  CUS_0xba1c      June               17.9
# 61382  CUS_0xba1c      July              17.10
# 61383  CUS_0xba1c    August              17.11
# 76872  CUS_0x7a96   January               22.2
# 76873  CUS_0x7a96  February               22.3
# 76874  CUS_0x7a96     March               22.4
# 76875  CUS_0x7a96     April               22.5
# 76876  CUS_0x7a96       May               22.6
# 76878  CUS_0x7a96      July               22.8
# 76879  CUS_0x7a96    August               22.9

# %%
df.loc[df.Name == 'Aaron Maashoh', ['Customer_ID','Month', 'Credit_History_Age']]
# Out:
#   Customer_ID     Month Credit_History_Age
# 0   CUS_0xd40   January               22.1
# 1   CUS_0xd40  February                NaN
# 2   CUS_0xd40     March               22.3
# 3   CUS_0xd40     April               22.4
# 4   CUS_0xd40       May               22.5
# 5   CUS_0xd40      June               22.6
# 6   CUS_0xd40      July               22.7

# %%
## Treating Annual Income
df.Annual_Income.value_counts()
# Out:
# 17273.83      16
# 20867.67      16
# 36585.12      16
# 95596.35      15
# 33029.66      15
#               ..
# 19271.95_      1
# 14120005.0     1
# 33199.13_      1
# 18792543.0     1
# 21755.79_      1
# Name: Annual_Income, Length: 18911, dtype: int64

# %%
df.Annual_Income = df.Annual_Income.str.replace('_','')

# %%
df.Annual_Income = df.Annual_Income.str.replace('-','')

# %%
df.Annual_Income = df.Annual_Income.astype(float)

# %%
df.Annual_Income.dtype
# Out:
# dtype('float64')

# %%
df.isnull().sum()
# Out:
# ID                              0
# Customer_ID                     0
# Month                           0
# Name                         9944
# Age                             0
# SSN                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary       14932
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                10930
# Delay_from_due_date             0
# Num_of_Delayed_Payment       6968
# Changed_Credit_Limit            0
# Num_Credit_Inquiries         1954
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age           8993
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly      4451
# Payment_Behaviour               0
# Monthly_Balance              1199
# Credit_Score                    0
# Num_of_loan2                    0
# dtype: int64

# %%
df.Num_of_Delayed_Payment
# Out:
# 0          7
# 1        NaN
# 2          7
# 3          4
# 4        NaN
#         ...
# 99995      7
# 99996      7
# 99997      6
# 99998    NaN
# 99999      6
# Name: Num_of_Delayed_Payment, Length: 99522, dtype: object

# %%
df.isnull().sum()
# Out:
# ID                              0
# Customer_ID                     0
# Month                           0
# Name                         9944
# Age                             0
# SSN                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary       14932
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                10930
# Delay_from_due_date             0
# Num_of_Delayed_Payment       6968
# Changed_Credit_Limit            0
# Num_Credit_Inquiries         1954
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age           8993
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly      4451
# Payment_Behaviour               0
# Monthly_Balance              1199
# Credit_Score                    0
# Num_of_loan2                    0
# dtype: int64

# %%
# Credit_History_Age - Knn
# Num_of_Delayed_Payment, Num_Credit_Inquiry, Amount_Invested_Monthly, Monthly_Balance

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# ID                           0.000000
# Customer_ID                  0.000000
# Month                        0.000000
# Name                         9.991761
# Age                          0.000000
# SSN                          0.000000
# Occupation                   0.000000
# Annual_Income                0.000000
# Monthly_Inhand_Salary       15.003718
# Num_Bank_Accounts            0.000000
# Num_Credit_Card              0.000000
# Interest_Rate                0.000000
# Num_of_Loan                  0.000000
# Type_of_Loan                10.982496
# Delay_from_due_date          0.000000
# Num_of_Delayed_Payment       7.001467
# Changed_Credit_Limit         0.000000
# Num_Credit_Inquiries         1.963385
# Credit_Mix                   0.000000
# Outstanding_Debt             0.000000
# Credit_Utilization_Ratio     0.000000
# Credit_History_Age           9.036193
# Payment_of_Min_Amount        0.000000
# Total_EMI_per_month          0.000000
# Amount_invested_monthly      4.472378
# Payment_Behaviour            0.000000
# Monthly_Balance              1.204759
# Credit_Score                 0.000000
# Num_of_loan2                 0.000000
# dtype: float64

# %%
df.Credit_Utilization_Ratio.describe()
# Out:
# count    99522.000000
# mean        32.280320
# std          5.114569
# min         20.000000
# 25%         28.047791
# 50%         32.301553
# 75%         36.491825
# max         50.000000
# Name: Credit_Utilization_Ratio, dtype: float64

# %%
df.Credit_Mix.value_counts()
# Out:
# Standard    36285
# Good        24130
# _           20118
# Bad         18989
# Name: Credit_Mix, dtype: int64

# %%
# Checking for the garbage values and taking necessary steps to clean it

df.Payment_Behaviour.value_counts()
# Out:
# Low_spent_Small_value_payments      25439
# High_spent_Medium_value_payments    17457
# Low_spent_Medium_value_payments     13793
# High_spent_Large_value_payments     13626
# High_spent_Small_value_payments     11280
# Low_spent_Large_value_payments      10376
# !@9#%8                               7551
# Name: Payment_Behaviour, dtype: int64

# %%
df[df["Payment_Behaviour"]=="!@9#%8"]
# Out:
#             ID Customer_ID    Month            Name   Age          SSN  \
# 5       0x1607   CUS_0xd40     June   Aaron Maashoh  23.0  821-00-0265
# 16      0x161a  CUS_0x2dbc  January          Langep  34.0  486-85-3974
# 32      0x1632  CUS_0x1cdb  January          Deepaa  21.0  615-06-7821
# 47      0x1645  CUS_0x95ee   August              Np  31.0  612-70-8987
# 54      0x1650  CUS_0x284a     July          Nadiaq  34.0    #F%$D@*&8
# ...        ...         ...      ...             ...   ...          ...
# 99947  0x25fa1  CUS_0x51b3    April             NaN  33.0  837-85-9800
# 99980  0x25fd2  CUS_0xaf61      May  Chris Wickhamm  49.0  133-16-7738
# 99982  0x25fd4  CUS_0xaf61     July  Chris Wickhamm  50.0  133-16-7738
# 99989  0x25fdf  CUS_0x8600     June  Sarah McBridec  28.0  031-35-0942
# 99999  0x25fed  CUS_0x942c   August           Nicks  25.0  078-73-5990
#
#           Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 5          Scientist       19114.12                    NaN                  3
# 16          Engineer      143162.64           12187.220000                  1
# 32         Developer       35547.71            2853.309167                  7
# 47            Lawyer       73928.46            5988.705000                  4
# 54            Lawyer    10909427.00                    NaN                  0
# ...              ...            ...                    ...                ...
# 99947  Media_Manager       59146.36            4908.863333                  2
# 99980         Writer       37188.10            3097.008333                  1
# 99982         Writer       37188.10            3097.008333                  1
# 99989      Architect       20002.88            1929.906667                 10
# 99999       Mechanic       39628.99            3359.415833                  4
#
#        ...  Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# 5      ...            809.98                 27.262259               22.6
# 16     ...           1303.01                 28.616735               17.9
# 32     ...            943.86                 39.797764               30.8
# 47     ...             548.2                 31.580990               32.6
# 54     ...            352.16                 26.947565               31.1
# ...    ...               ...                       ...                ...
# 99947  ...            418.03                 28.091458               20.4
# 99980  ...            620.64                 27.495263               30.1
# 99982  ...            620.64                 38.850680               30.3
# 99989  ...            3571.7                 33.359987                6.1
# 99999  ...            502.38                 34.192463              31.10
#
#       Payment_of_Min_Amount  Total_EMI_per_month Amount_invested_monthly  \
# 5                        No            49.574949      62.430172331195294
# 16                       No           246.992319        168.413702679309
# 32                      Yes             0.000000      276.72539431736266
# 47                       No             0.000000       42.63559025189578
# 54                       No           911.220179       930.3918977796665
# ...                     ...                  ...                     ...
# 99947                    No            26.778419       183.5841488690948
# 99980                    No            84.205949       78.49772657092517
# 99982                    No            84.205949       82.82557214415213
# 99989                   Yes            60.964772       74.36660309585342
# 99999                    No            35.104023       167.1638651610451
#
#       Payment_Behaviour     Monthly_Balance Credit_Score Num_of_loan2
# 5                !@9#%8   340.4792117872438         Good          4.0
# 16               !@9#%8  1043.3159778669492         Good          3.0
# 32               !@9#%8  288.60552234930395     Standard          0.0
# 47               !@9#%8   796.2349097481042         Good          0.0
# 54               !@9#%8  326.24183015224526         Good          2.0
# ...                 ...                 ...          ...          ...
# 99947            !@9#%8          530.523765     Standard          1.0
# 99980            !@9#%8          396.997157     Standard          3.0
# 99982            !@9#%8          412.669312         Good          3.0
# 99989            !@9#%8          307.659291     Standard          5.0
# 99999            !@9#%8          393.673696         Poor          2.0
#
# [7551 rows x 29 columns]

# %%
df[df["Customer_ID"]=="CUS_0x2dbc"]
# Out:
#         ID Customer_ID     Month    Name   Age          SSN Occupation  \
# 16  0x161a  CUS_0x2dbc   January  Langep  34.0  486-85-3974   Engineer
# 17  0x161b  CUS_0x2dbc  February     NaN  34.0  486-85-3974   Engineer
# 18  0x161c  CUS_0x2dbc     March  Langep  34.0  486-85-3974   Engineer
# 19  0x161d  CUS_0x2dbc     April  Langep  34.0  486-85-3974   Engineer
# 20  0x161e  CUS_0x2dbc       May  Langep  34.0  486-85-3974   Engineer
# 21  0x161f  CUS_0x2dbc      June  Langep  34.0  486-85-3974   Engineer
# 22  0x1620  CUS_0x2dbc      July     NaN  34.0  486-85-3974   Engineer
# 23  0x1621  CUS_0x2dbc    August  Langep  34.0  486-85-3974   Engineer
#
#     Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 16      143162.64               12187.22                  1  ...
# 17      143162.64               12187.22                  1  ...
# 18      143162.64                    NaN                  1  ...
# 19      143162.64               12187.22                  1  ...
# 20      143162.64               12187.22                  1  ...
# 21      143162.64               12187.22                  1  ...
# 22      143162.64               12187.22                  1  ...
# 23      143162.64               12187.22                  1  ...
#
#     Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# 16           1303.01                 28.616735               17.9
# 17           1303.01                 41.702573              17.10
# 18           1303.01                 26.519815              17.11
# 19           1303.01                 39.501648                NaN
# 20           1303.01                 31.376150               18.1
# 21           1303.01                 39.783993               18.2
# 22           1303.01                 38.068624               18.3
# 23           1303.01                 38.374753               18.4
#
#    Payment_of_Min_Amount  Total_EMI_per_month Amount_invested_monthly  \
# 16                    No           246.992319        168.413702679309
# 17                    No           246.992319      232.86038375993544
# 18                    No           246.992319               __10000__
# 19                    No           246.992319       825.2162699393922
# 20                    No           246.992319       430.9475278803298
# 21                    No           246.992319      257.80809942568976
# 22                    No           246.992319      263.17416316163934
# 23                    No           246.992319               __10000__
#
#                    Payment_Behaviour     Monthly_Balance Credit_Score  \
# 16                            !@9#%8  1043.3159778669492         Good
# 17   High_spent_Small_value_payments   998.8692967863226         Good
# 18   High_spent_Small_value_payments    715.741367403555         Good
# 19   Low_spent_Medium_value_payments   426.5134106068658         Good
# 20    Low_spent_Large_value_payments   810.7821526659284         Good
# 21  High_spent_Medium_value_payments   963.9215811205684         Good
# 22   High_spent_Small_value_payments   968.5555173846187     Standard
# 23   High_spent_Small_value_payments    895.494583180492     Standard
#
#    Num_of_loan2
# 16          3.0
# 17          3.0
# 18          3.0
# 19          3.0
# 20          3.0
# 21          3.0
# 22          3.0
# 23          3.0
#
# [8 rows x 29 columns]

# %%
#df[df["Customer_ID"]=="CUS_0x1cdb"]
df.loc[df.Customer_ID == 'CUS_0x1cdb', ['Customer_ID','Credit_Utilization_Ratio', 'Credit_Mix',"Payment_Behaviour"]]

# Trying to find pattern in order to fill the garbage value in Payment_Behaviour columns "!@9#%8"
# Out:
#    Customer_ID  Credit_Utilization_Ratio Credit_Mix  \
# 32  CUS_0x1cdb                 39.797764   Standard
# 33  CUS_0x1cdb                 27.020360   Standard
# 35  CUS_0x1cdb                 28.924954          _
# 36  CUS_0x1cdb                 41.776187          _
# 37  CUS_0x1cdb                 29.217556   Standard
# 38  CUS_0x1cdb                 26.263823   Standard
#
#                    Payment_Behaviour
# 32                            !@9#%8
# 33  High_spent_Medium_value_payments
# 35  High_spent_Medium_value_payments
# 36   High_spent_Small_value_payments
# 37  High_spent_Medium_value_payments
# 38    Low_spent_Small_value_payments

# %%
#df[df["Customer_ID"]=="CUS_0x95ee"]
df.loc[df.Customer_ID == 'CUS_0x95ee', ['Customer_ID','Credit_Utilization_Ratio', 'Credit_Mix',"Payment_Behaviour"]]
# Out:
#    Customer_ID  Credit_Utilization_Ratio Credit_Mix  \
# 40  CUS_0x95ee                 39.962685       Good
# 41  CUS_0x95ee                 42.769864       Good
# 42  CUS_0x95ee                 40.712187       Good
# 43  CUS_0x95ee                 30.201658       Good
# 44  CUS_0x95ee                 26.333310          _
# 45  CUS_0x95ee                 35.275437       Good
# 46  CUS_0x95ee                 36.624791          _
# 47  CUS_0x95ee                 31.580990       Good
#
#                    Payment_Behaviour
# 40   High_spent_Large_value_payments
# 41   Low_spent_Medium_value_payments
# 42  High_spent_Medium_value_payments
# 43    Low_spent_Small_value_payments
# 44    Low_spent_Large_value_payments
# 45    Low_spent_Large_value_payments
# 46   High_spent_Small_value_payments
# 47                            !@9#%8

# %%
df.Payment_Behaviour.value_counts(normalize=True)
# Out:
# Low_spent_Small_value_payments      0.255612
# High_spent_Medium_value_payments    0.175408
# Low_spent_Medium_value_payments     0.138592
# High_spent_Large_value_payments     0.136914
# High_spent_Small_value_payments     0.113342
# Low_spent_Large_value_payments      0.104258
# !@9#%8                              0.075873
# Name: Payment_Behaviour, dtype: float64

# %%
pb = ""
for i in df.Customer_ID[df["Payment_Behaviour"]=="!@9#%8"]:
    pb = df.Payment_Behaviour[df["Customer_ID"] ==i].mode()[0]
    df.Payment_Behaviour[(df["Customer_ID"] == i) & (df["Payment_Behaviour"]=="!@9#%8")] = pb

# %%
# Successfully imputed the garbage values inside the Payment_Behaviour column

df.Payment_Behaviour.value_counts(normalize= True)
# Out:
# Low_spent_Small_value_payments      0.275437
# High_spent_Medium_value_payments    0.189074
# High_spent_Large_value_payments     0.148791
# Low_spent_Medium_value_payments     0.144149
# High_spent_Small_value_payments     0.117612
# Low_spent_Large_value_payments      0.107695
# !@9#%8                              0.017242
# Name: Payment_Behaviour, dtype: float64

# %%
#now the left value will be filled with mode of all the given value( As the garbage value is just 1.7%)

# %%
df.Payment_Behaviour[df["Payment_Behaviour"]=="!@9#%8"] = df.Payment_Behaviour.mode()[0]

# %%
pd.set_option('display.max_columns', None)

# %%
df.Payment_Behaviour.value_counts(normalize= True)
# Out:
# Low_spent_Small_value_payments      0.292679
# High_spent_Medium_value_payments    0.189074
# High_spent_Large_value_payments     0.148791
# Low_spent_Medium_value_payments     0.144149
# High_spent_Small_value_payments     0.117612
# Low_spent_Large_value_payments      0.107695
# Name: Payment_Behaviour, dtype: float64

# %%
df.Credit_Mix.value_counts()
# Out:
# Standard    36285
# Good        24130
# _           20118
# Bad         18989
# Name: Credit_Mix, dtype: int64

# %%
df.tail()
# Out:
#             ID Customer_ID   Month   Name   Age          SSN Occupation  \
# 99995  0x25fe9  CUS_0x942c   April  Nicks  25.0  078-73-5990   Mechanic
# 99996  0x25fea  CUS_0x942c     May  Nicks  25.0  078-73-5990   Mechanic
# 99997  0x25feb  CUS_0x942c    June  Nicks  25.0  078-73-5990   Mechanic
# 99998  0x25fec  CUS_0x942c    July  Nicks  25.0  078-73-5990   Mechanic
# 99999  0x25fed  CUS_0x942c  August  Nicks  25.0  078-73-5990   Mechanic
#
#        Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 99995       39628.99            3359.415833                  4
# 99996       39628.99            3359.415833                  4
# 99997       39628.99            3359.415833                  4
# 99998       39628.99            3359.415833                  4
# 99999       39628.99            3359.415833                  4
#
#        Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 99995                6              7           2
# 99996                6              7           2
# 99997                6           5729           2
# 99998                6              7           2
# 99999                6              7           2
#
#                       Type_of_Loan  Delay_from_due_date  \
# 99995  Auto Loan, and Student Loan                   23
# 99996  Auto Loan, and Student Loan                   18
# 99997  Auto Loan, and Student Loan                   27
# 99998  Auto Loan, and Student Loan                   20
# 99999  Auto Loan, and Student Loan                   18
#
#       Num_of_Delayed_Payment Changed_Credit_Limit  Num_Credit_Inquiries  \
# 99995                      7                 11.5                   3.0
# 99996                      7                 11.5                   3.0
# 99997                      6                 11.5                   3.0
# 99998                    NaN                 11.5                   3.0
# 99999                      6                 11.5                   3.0
#
#       Credit_Mix Outstanding_Debt  Credit_Utilization_Ratio  \
# 99995          _           502.38                 34.663572
# 99996          _           502.38                 40.565631
# 99997       Good           502.38                 41.255522
# 99998       Good           502.38                 33.638208
# 99999       Good           502.38                 34.192463
#
#       Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 99995               31.6                    No            35.104023
# 99996               31.7                    No            35.104023
# 99997               31.8                    No            35.104023
# 99998               31.9                    No            35.104023
# 99999              31.10                    No            35.104023
#
#       Amount_invested_monthly                 Payment_Behaviour  \
# 99995       60.97133255718485   High_spent_Large_value_payments
# 99996       54.18595028760385  High_spent_Medium_value_payments
# 99997       24.02847744864441   High_spent_Large_value_payments
# 99998      251.67258219721603    Low_spent_Large_value_payments
# 99999       167.1638651610451   High_spent_Large_value_payments
#
#       Monthly_Balance Credit_Score  Num_of_loan2
# 99995      479.866228         Poor           2.0
# 99996       496.65161         Poor           2.0
# 99997      516.809083         Poor           2.0
# 99998      319.164979     Standard           2.0
# 99999      393.673696         Poor           2.0

# %%
df.Credit_Mix.value_counts()
# Out:
# Standard    36285
# Good        24130
# _           20118
# Bad         18989
# Name: Credit_Mix, dtype: int64

# %%
df.Credit_Mix.value_counts(normalize=True)
# Out:
# Standard    0.364593
# Good        0.242459
# _           0.202146
# Bad         0.190802
# Name: Credit_Mix, dtype: float64

# %%
# Treating the garbage value in Credit_Mix columnn ("_")

cm = ""
for i in df.Customer_ID[df["Credit_Mix"]=="_"]:
    cm = df.Credit_Mix[df.Customer_ID == i].mode()[0]
    df.Credit_Mix[(df["Customer_ID"] == i) & (df["Credit_Mix"]=="_")] = cm

# %%
df.Credit_Mix.value_counts(normalize= True)
# Out:
# Standard    0.454633
# Good        0.301039
# Bad         0.237184
# _           0.007144
# Name: Credit_Mix, dtype: float64

# %%
 df.Credit_Mix[df["Credit_Mix"]=="_"] =  df.Credit_Mix.mode()[0]

# %%
df.Credit_Mix.value_counts(normalize= True)
# Out:
# Standard    0.461777
# Good        0.301039
# Bad         0.237184
# Name: Credit_Mix, dtype: float64

# %%
df.isnull().sum()
# Out:
# ID                              0
# Customer_ID                     0
# Month                           0
# Name                         9944
# Age                             0
# SSN                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary       14932
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                10930
# Delay_from_due_date             0
# Num_of_Delayed_Payment       6968
# Changed_Credit_Limit            0
# Num_Credit_Inquiries         1954
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age           8993
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly      4451
# Payment_Behaviour               0
# Monthly_Balance              1199
# Credit_Score                    0
# Num_of_loan2                    0
# dtype: int64

# %%
#now we take up amount invested monthly
df.Amount_invested_monthly.value_counts()
#first we will clean it
# Out:
# __10000__            4296
# 0.0                   169
# 80.41529543900253       1
# 81.77340833765794       1
# 195.5938316873959       1
#                      ...
# 33.6098814431885        1
# 76.87001005130772       1
# 908.6939096189257       1
# 458.552411389832        1
# 167.1638651610451       1
# Name: Amount_invested_monthly, Length: 90608, dtype: int64

# %%
df.Amount_invested_monthly = df.Amount_invested_monthly.str.replace('_','').replace('-','')

# %%
#now we fix missing values
df.Amount_invested_monthly
# Out:
# 0         80.41529543900253
# 1        118.28022162236736
# 2           81.699521264648
# 3         199.4580743910713
# 4        41.420153086217326
#                 ...
# 99995     60.97133255718485
# 99996     54.18595028760385
# 99997     24.02847744864441
# 99998    251.67258219721603
# 99999     167.1638651610451
# Name: Amount_invested_monthly, Length: 99522, dtype: object

# %%
df.Amount_invested_monthly = df.Amount_invested_monthly.astype(float)
#after cleaning we convert it to float

# %%
#we will fill it by knnimputer or deleting

# %%
df.Monthly_Balance.value_counts()
# Out:
# __-333333333333333333333333333__    9
# 312.49408867943663                  1
# 669.8565027612123                   1
# 299.5453745546086                   1
# 559.5405544823427                   1
#                                    ..
# 321.2336043357731                   1
# 373.29270287694055                  1
# 302.79976223961546                  1
# 348.4455267743164                   1
# 393.6736955618808                   1
# Name: Monthly_Balance, Length: 98315, dtype: int64

# %%
df.Monthly_Balance = df.Monthly_Balance.str.replace('_','').replace('-','')

# %%
df.Monthly_Balance = df.Monthly_Balance.astype(float)

# %%
#df[(df.Monthly_Balance.isnull()) & (df.Customer_ID == 'CUS_0x942c')]
# we will fill this with KNNimputer

# %%
df[df.Num_Credit_Inquiries.isnull()].head()
df.Num_Credit_Inquiries = df.Num_Credit_Inquiries.astype(float)
#KNN imputer and no has no garbeage

# %%
df.isnull().sum()
# Out:
# ID                              0
# Customer_ID                     0
# Month                           0
# Name                         9944
# Age                             0
# SSN                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary       14932
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                10930
# Delay_from_due_date             0
# Num_of_Delayed_Payment       6968
# Changed_Credit_Limit            0
# Num_Credit_Inquiries         1954
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age           8993
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly      4451
# Payment_Behaviour               0
# Monthly_Balance              2856
# Credit_Score                    0
# Num_of_loan2                    0
# dtype: int64

# %%
df.Num_of_Delayed_Payment = df.Num_of_Delayed_Payment.str.replace('_','').replace('-','')

# %%
df[df.Num_of_Delayed_Payment.isnull()]
# Out:
#             ID Customer_ID     Month            Name   Age          SSN  \
# 1       0x1603   CUS_0xd40  February   Aaron Maashoh  23.0  821-00-0265
# 4       0x1606   CUS_0xd40       May   Aaron Maashoh  23.0  821-00-0265
# 30      0x162c  CUS_0xb891      July          Jasond  55.0  072-31-6145
# 32      0x1632  CUS_0x1cdb   January          Deepaa  21.0  615-06-7821
# 33      0x1633  CUS_0x1cdb  February          Deepaa  21.0  615-06-7821
# ...        ...         ...       ...             ...   ...          ...
# 99973  0x25fc7   CUS_0xf16      June             NaN  44.0  868-70-2218
# 99974  0x25fc8   CUS_0xf16      July  Maria Sheahanb  44.0  868-70-2218
# 99992  0x25fe6  CUS_0x942c   January           Nicks  24.0  078-73-5990
# 99993  0x25fe7  CUS_0x942c  February           Nicks  25.0  078-73-5990
# 99998  0x25fec  CUS_0x942c      July           Nicks  25.0  078-73-5990
#
#           Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 1          Scientist       19114.12                    NaN                  3
# 4          Scientist       19114.12            1824.843333                  3
# 30      Entrepreneur       30689.89            2612.490833                  2
# 32         Developer       35547.71            2853.309167                  7
# 33         Developer       35547.71                    NaN                  7
# ...              ...            ...                    ...                ...
# 99973  Media_Manager       16680.35            1528.029167                  1
# 99974  Media_Manager       16680.35            1528.029167                  1
# 99992       Mechanic       39628.99            3359.415833                  4
# 99993       Mechanic       39628.99            3359.415833                  4
# 99998       Mechanic       39628.99            3359.415833                  4
#
#        Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 1                    4              3           4
# 4                    4              3           4
# 30                   5              4           1
# 32                   5              5           0
# 33                   5              5           0
# ...                ...            ...         ...
# 99973                1              5           4
# 99974                1              5           4
# 99992                6              7           2
# 99993                6              7           2
# 99998                6              7           2
#
#                                             Type_of_Loan  Delay_from_due_date  \
# 1      Auto Loan, Credit-Builder Loan, Personal Loan,...                   -1
# 4      Auto Loan, Credit-Builder Loan, Personal Loan,...                    6
# 30                                         Not Specified                    5
# 32                                                   NaN                    5
# 33                                                   NaN                    9
# ...                                                  ...                  ...
# 99973  Payday Loan, Student Loan, Mortgage Loan, and ...                    1
# 99974  Payday Loan, Student Loan, Mortgage Loan, and ...                    1
# 99992                        Auto Loan, and Student Loan                   23
# 99993                        Auto Loan, and Student Loan                   23
# 99998                        Auto Loan, and Student Loan                   20
#
#       Num_of_Delayed_Payment Changed_Credit_Limit  Num_Credit_Inquiries  \
# 1                        NaN                11.27                   4.0
# 4                        NaN                11.27                   4.0
# 30                       NaN                 1.99                   4.0
# 32                       NaN                 2.58                   4.0
# 33                       NaN                 2.58                   4.0
# ...                      ...                  ...                   ...
# 99973                    NaN   0.6900000000000004                   8.0
# 99974                    NaN                11.69                   8.0
# 99992                    NaN                  9.5                   3.0
# 99993                    NaN                 11.5                   3.0
# 99998                    NaN                 11.5                   3.0
#
#       Credit_Mix Outstanding_Debt  Credit_Utilization_Ratio  \
# 1           Good           809.98                 31.944960
# 4           Good           809.98                 24.797347
# 30          Good           632.46                 26.056395
# 32      Standard           943.86                 39.797764
# 33      Standard           943.86                 27.020360
# ...          ...              ...                       ...
# 99973       Good           897.16                 24.972853
# 99974       Good           897.16                 36.166925
# 99992       Good           502.38                 32.991333
# 99993       Good           502.38                 29.135447
# 99998       Good           502.38                 33.638208
#
#       Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 1                    NaN                    No            49.574949
# 4                   22.5                    No            49.574949
# 30                  17.9                    No            16.415452
# 32                  30.8                   Yes             0.000000
# 33                  30.9                    NM             0.000000
# ...                  ...                   ...                  ...
# 99973               21.6                    No            41.113561
# 99974               21.7                    No            41.113561
# 99992               31.3                    No            35.104023
# 99993               31.4                    No         58638.000000
# 99998               31.9                    No            35.104023
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 1                   118.280222    Low_spent_Large_value_payments
# 4                    41.420153  High_spent_Medium_value_payments
# 30                   71.283675    Low_spent_Large_value_payments
# 32                  276.725394  High_spent_Medium_value_payments
# 33                   74.443641  High_spent_Medium_value_payments
# ...                        ...                               ...
# 99973             10000.000000    Low_spent_Small_value_payments
# 99974                      NaN    Low_spent_Small_value_payments
# 99992               401.196481    Low_spent_Small_value_payments
# 99993               180.733095   Low_spent_Medium_value_payments
# 99998               251.672582    Low_spent_Large_value_payments
#
#        Monthly_Balance Credit_Score  Num_of_loan2
# 1           284.629162         Good           4.0
# 4           341.489231         Good           4.0
# 30          443.549957     Standard           1.0
# 32          288.605522     Standard           0.0
# 33          460.887276     Standard           0.0
# ...                ...          ...           ...
# 99973              NaN         Good           4.0
# 99974              NaN         Good           4.0
# 99992              NaN         Poor           2.0
# 99993              NaN     Standard           2.0
# 99998              NaN     Standard           2.0
#
# [6968 rows x 29 columns]

# %%
#df[(df.Customer_ID == 'CUS_0xd40')]
##it has no garbage values so we will do KNN imputer
df.Num_of_Delayed_Payment = df.Num_of_Delayed_Payment.astype(float)

# %%
df[df.Credit_History_Age.isnull()]
#it has no garbage value only missing so do knn imputer
# Out:
#             ID Customer_ID     Month             Name   Age          SSN  \
# 1       0x1603   CUS_0xd40  February    Aaron Maashoh  23.0  821-00-0265
# 7       0x1609   CUS_0xd40    August              NaN  23.0    #F%$D@*&8
# 19      0x161d  CUS_0x2dbc     April           Langep  34.0  486-85-3974
# 40      0x163e  CUS_0x95ee   January               Np  31.0  612-70-8987
# 42      0x1640  CUS_0x95ee     March               Np  31.0  612-70-8987
# ...        ...         ...       ...              ...   ...          ...
# 99944  0x25f9e  CUS_0x51b3   January            Ryana  33.0  837-85-9800
# 99963  0x25fb9  CUS_0x372c     April  Lucia Mutikanik  18.0  340-85-7301
# 99968  0x25fc2   CUS_0xf16   January   Maria Sheahanb  44.0    #F%$D@*&8
# 99975  0x25fc9   CUS_0xf16    August   Maria Sheahanb  44.0  868-70-2218
# 99990  0x25fe0  CUS_0x8600      July   Sarah McBridec  28.0  031-35-0942
#
#           Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 1          Scientist       19114.12                    NaN                  3
# 7          Scientist       19114.12            1824.843333                  3
# 19          Engineer      143162.64           12187.220000                  1
# 40            Lawyer       73928.46                    NaN                  4
# 42            Lawyer       73928.46            5988.705000                  4
# ...              ...            ...                    ...                ...
# 99944  Media_Manager       59146.36                    NaN                  2
# 99963         Lawyer       42903.79                    NaN                  0
# 99968  Media_Manager       16680.35            1528.029167                  1
# 99975  Media_Manager       16680.35                    NaN                  1
# 99990      Architect       20002.88            1929.906667                 10
#
#        Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 1                    4              3           4
# 7                    4              3           4
# 19                   5              8           3
# 40                1288              8           0
# 42                   5              8           0
# ...                ...            ...         ...
# 99944                5              6           1
# 99963                4              6           1
# 99968                1              5           4
# 99975                1              5           4
# 99990                8             29           5
#
#                                             Type_of_Loan  Delay_from_due_date  \
# 1      Auto Loan, Credit-Builder Loan, Personal Loan,...                   -1
# 7      Auto Loan, Credit-Builder Loan, Personal Loan,...                    3
# 19               Auto Loan, Auto Loan, and Not Specified                    8
# 40                                                   NaN                   12
# 42                                                   NaN                    8
# ...                                                  ...                  ...
# 99944                                      Personal Loan                    8
# 99963                                      Not Specified                   14
# 99968  Payday Loan, Student Loan, Mortgage Loan, and ...                    4
# 99975  Payday Loan, Student Loan, Mortgage Loan, and ...                    1
# 99990  Personal Loan, Auto Loan, Mortgage Loan, Stude...                   33
#
#        Num_of_Delayed_Payment Changed_Credit_Limit  Num_Credit_Inquiries  \
# 1                         NaN                11.27                   4.0
# 7                         6.0                11.27                   4.0
# 19                        5.0                  9.1                   3.0
# 40                       10.0                10.14                   2.0
# 42                        7.0                10.14                   2.0
# ...                       ...                  ...                   ...
# 99944                     6.0                 6.68                   2.0
# 99963                     0.0                  5.1                   1.0
# 99968                     0.0                 5.69                   4.0
# 99975                     0.0                 5.69                   8.0
# 99990                    26.0                18.31                   9.0
#
#       Credit_Mix Outstanding_Debt  Credit_Utilization_Ratio  \
# 1           Good           809.98                 31.944960
# 7           Good           809.98                 23.933795
# 19          Good          1303.01                 39.501648
# 40          Good            548.2                 39.962685
# 42          Good            548.2                 40.712187
# ...          ...              ...                       ...
# 99944       Good           418.03                 34.720661
# 99963       Good          1079.48                 30.625298
# 99968       Good           897.16                 39.868572
# 99975       Good           897.16                 41.212367
# 99990        Bad           3571.7                 25.123535
#
#       Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 1                    NaN                    No            49.574949
# 7                    NaN                    No            49.574949
# 19                   NaN                    No           246.992319
# 40                   NaN                    No         15015.000000
# 42                   NaN                    No             0.000000
# ...                  ...                   ...                  ...
# 99944                NaN                    No            26.778419
# 99963                NaN                    No            34.975457
# 99968                NaN                    NM            41.113561
# 99975                NaN                    No            41.113561
# 99990                NaN                   Yes            60.964772
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 1                   118.280222    Low_spent_Large_value_payments
# 7                    24.785217  High_spent_Medium_value_payments
# 19                  825.216270   Low_spent_Medium_value_payments
# 40                   98.674410   High_spent_Large_value_payments
# 42                  150.059734  High_spent_Medium_value_payments
# ...                        ...                               ...
# 99944               606.436542    Low_spent_Small_value_payments
# 99963                31.193919   High_spent_Large_value_payments
# 99968                52.951978   High_spent_Small_value_payments
# 99975                70.805550    Low_spent_Large_value_payments
# 99990               173.275503    Low_spent_Large_value_payments
#
#        Monthly_Balance Credit_Score  Num_of_loan2
# 1           284.629162         Good           4.0
# 7           358.124168     Standard           4.0
# 19          426.513411         Good           3.0
# 40          740.196090         Good           0.0
# 42          698.810766         Good           0.0
# ...                ...          ...           ...
# 99944              NaN     Standard           1.0
# 99963              NaN     Standard           1.0
# 99968              NaN         Good           4.0
# 99975              NaN         Good           4.0
# 99990              NaN     Standard           5.0
#
# [8993 rows x 29 columns]

# %%
df.Customer_ID.nunique()
# Out:
# 12500

# %%
df.ID.nunique()
# Out:
# 99522

# %%
df.Credit_History_Age = df.Credit_History_Age.astype(float)

# %%
#now we will work on Outstanding debt

# %%
df.Outstanding_Debt.value_counts()
# Out:
# 1360.45     24
# 1151.7      23
# 1109.03     23
# 460.46      23
# 55.46       16
#             ..
# 4319.35_     1
# 1078.95_     1
# 731.05_      1
# 369.7_       1
# 4572.01_     1
# Name: Outstanding_Debt, Length: 13172, dtype: int64

# %%
#now we will clean it
df.Outstanding_Debt = df.Outstanding_Debt.str.replace('_','').replace('-','')

# %%
df.Outstanding_Debt.value_counts()
# Out:
# 1151.7     24
# 1109.03    24
# 460.46     24
# 1360.45    24
# 217.92     16
#            ..
# 39.68       6
# 80.09       6
# 936.59      5
# 581.67      5
# 1041.07     5
# Name: Outstanding_Debt, Length: 12203, dtype: int64

# %%
df.Outstanding_Debt = df.Outstanding_Debt.astype(float)

# %%
#now we will take up changed credit limit
df.Changed_Credit_Limit.value_counts()
# Out:
# _                      2083
# 8.22                    133
# 11.5                    126
# 11.32                   126
# 10.06                   121
#                        ...
# -0.6500000000000004       1
# -5.5                      1
# -4.98                     1
# -0.11                     1
# 21.17                     1
# Name: Changed_Credit_Limit, Length: 4381, dtype: int64

# %%
df.Changed_Credit_Limit = df.Changed_Credit_Limit.str.replace('_','')

# %%
df.Changed_Credit_Limit.value_counts()
# Out:
#                        2083
# 8.22                    133
# 11.5                    126
# 11.32                   126
# 10.06                   121
#                        ...
# -0.6500000000000004       1
# -5.5                      1
# -4.98                     1
# -0.11                     1
# 21.17                     1
# Name: Changed_Credit_Limit, Length: 4381, dtype: int64

# %%
df.Changed_Credit_Limit = df.Changed_Credit_Limit.str.replace('_','')

# %%
df.Changed_Credit_Limit.value_counts()
# Out:
#                        2083
# 8.22                    133
# 11.5                    126
# 11.32                   126
# 10.06                   121
#                        ...
# -0.6500000000000004       1
# -5.5                      1
# -4.98                     1
# -0.11                     1
# 21.17                     1
# Name: Changed_Credit_Limit, Length: 4381, dtype: int64

# %%
df.Changed_Credit_Limit[df.Changed_Credit_Limit == ''] = np.nan

# %%
df.Changed_Credit_Limit = df.Changed_Credit_Limit.astype('float')

# %%
df.Changed_Credit_Limit = np.round(df.Changed_Credit_Limit,2)

# %%
df.Changed_Credit_Limit.isnull().sum()
#we will impute this using KNN imputer
# Out:
# 2083

# %%
#now we will drop the unnecessary and redundant columns

# %%
df.isnull().sum()
df.drop(['Name','Monthly_Inhand_Salary','Num_of_Loan','Type_of_Loan','ID','SSN'],axis = 1,inplace= True)

# %%
df.Num_of_loan2.isnull().sum()
# Out:
# 0

# %%
df.select_dtypes(include= np.number)
# Out:
#         Age  Annual_Income  Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  \
# 0      23.0       19114.12                  3                4              3
# 1      23.0       19114.12                  3                4              3
# 2      23.0       19114.12                  3                4              3
# 3      23.0       19114.12                  3                4              3
# 4      23.0       19114.12                  3                4              3
# ...     ...            ...                ...              ...            ...
# 99995  25.0       39628.99                  4                6              7
# 99996  25.0       39628.99                  4                6              7
# 99997  25.0       39628.99                  4                6           5729
# 99998  25.0       39628.99                  4                6              7
# 99999  25.0       39628.99                  4                6              7
#
#        Delay_from_due_date  Num_of_Delayed_Payment  Changed_Credit_Limit  \
# 0                        3                     7.0                 11.27
# 1                       -1                     NaN                 11.27
# 2                        3                     7.0                   NaN
# 3                        5                     4.0                  6.27
# 4                        6                     NaN                 11.27
# ...                    ...                     ...                   ...
# 99995                   23                     7.0                 11.50
# 99996                   18                     7.0                 11.50
# 99997                   27                     6.0                 11.50
# 99998                   20                     NaN                 11.50
# 99999                   18                     6.0                 11.50
#
#        Num_Credit_Inquiries  Outstanding_Debt  Credit_Utilization_Ratio  \
# 0                       4.0            809.98                 26.822620
# 1                       4.0            809.98                 31.944960
# 2                       4.0            809.98                 28.609352
# 3                       4.0            809.98                 31.377862
# 4                       4.0            809.98                 24.797347
# ...                     ...               ...                       ...
# 99995                   3.0            502.38                 34.663572
# 99996                   3.0            502.38                 40.565631
# 99997                   3.0            502.38                 41.255522
# 99998                   3.0            502.38                 33.638208
# 99999                   3.0            502.38                 34.192463
#
#        Credit_History_Age  Total_EMI_per_month  Amount_invested_monthly  \
# 0                    22.1            49.574949                80.415295
# 1                     NaN            49.574949               118.280222
# 2                    22.3            49.574949                81.699521
# 3                    22.4            49.574949               199.458074
# 4                    22.5            49.574949                41.420153
# ...                   ...                  ...                      ...
# 99995                31.6            35.104023                60.971333
# 99996                31.7            35.104023                54.185950
# 99997                31.8            35.104023                24.028477
# 99998                31.9            35.104023               251.672582
# 99999                31.1            35.104023               167.163865
#
#        Monthly_Balance  Num_of_loan2
# 0           312.494089           4.0
# 1           284.629162           4.0
# 2           331.209863           4.0
# 3           223.451310           4.0
# 4           341.489231           4.0
# ...                ...           ...
# 99995              NaN           2.0
# 99996              NaN           2.0
# 99997              NaN           2.0
# 99998              NaN           2.0
# 99999              NaN           2.0
#
# [99522 rows x 16 columns]

# %%
df.select_dtypes(include= object)
# Out:
#       Customer_ID     Month Occupation Credit_Mix Payment_of_Min_Amount  \
# 0       CUS_0xd40   January  Scientist       Good                    No
# 1       CUS_0xd40  February  Scientist       Good                    No
# 2       CUS_0xd40     March  Scientist       Good                    No
# 3       CUS_0xd40     April  Scientist       Good                    No
# 4       CUS_0xd40       May  Scientist       Good                    No
# ...           ...       ...        ...        ...                   ...
# 99995  CUS_0x942c     April   Mechanic       Good                    No
# 99996  CUS_0x942c       May   Mechanic       Good                    No
# 99997  CUS_0x942c      June   Mechanic       Good                    No
# 99998  CUS_0x942c      July   Mechanic       Good                    No
# 99999  CUS_0x942c    August   Mechanic       Good                    No
#
#                       Payment_Behaviour Credit_Score
# 0       High_spent_Small_value_payments         Good
# 1        Low_spent_Large_value_payments         Good
# 2       Low_spent_Medium_value_payments         Good
# 3        Low_spent_Small_value_payments         Good
# 4      High_spent_Medium_value_payments         Good
# ...                                 ...          ...
# 99995   High_spent_Large_value_payments         Poor
# 99996  High_spent_Medium_value_payments         Poor
# 99997   High_spent_Large_value_payments         Poor
# 99998    Low_spent_Large_value_payments     Standard
# 99999   High_spent_Large_value_payments         Poor
#
# [99522 rows x 7 columns]

# %%
df.isnull().sum()
#all these null values will be filled with KNN imputer after all the absurd or junk values are dealt with
# Out:
# Customer_ID                    0
# Month                          0
# Age                            0
# Occupation                     0
# Annual_Income                  0
# Num_Bank_Accounts              0
# Num_Credit_Card                0
# Interest_Rate                  0
# Delay_from_due_date            0
# Num_of_Delayed_Payment      6968
# Changed_Credit_Limit        2083
# Num_Credit_Inquiries        1954
# Credit_Mix                     0
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Credit_History_Age          8993
# Payment_of_Min_Amount          0
# Total_EMI_per_month            0
# Amount_invested_monthly     4451
# Payment_Behaviour              0
# Monthly_Balance             2856
# Credit_Score                   0
# Num_of_loan2                   0
# dtype: int64

# %%
df.head()
# Out:
#   Customer_ID     Month   Age Occupation  Annual_Income  Num_Bank_Accounts  \
# 0   CUS_0xd40   January  23.0  Scientist       19114.12                  3
# 1   CUS_0xd40  February  23.0  Scientist       19114.12                  3
# 2   CUS_0xd40     March  23.0  Scientist       19114.12                  3
# 3   CUS_0xd40     April  23.0  Scientist       19114.12                  3
# 4   CUS_0xd40       May  23.0  Scientist       19114.12                  3
#
#    Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 0                4              3                    3
# 1                4              3                   -1
# 2                4              3                    3
# 3                4              3                    5
# 4                4              3                    6
#
#    Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 0                     7.0                 11.27                   4.0
# 1                     NaN                 11.27                   4.0
# 2                     7.0                   NaN                   4.0
# 3                     4.0                  6.27                   4.0
# 4                     NaN                 11.27                   4.0
#
#   Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 0       Good            809.98                 26.822620                22.1
# 1       Good            809.98                 31.944960                 NaN
# 2       Good            809.98                 28.609352                22.3
# 3       Good            809.98                 31.377862                22.4
# 4       Good            809.98                 24.797347                22.5
#
#   Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 0                    No            49.574949                80.415295
# 1                    No            49.574949               118.280222
# 2                    No            49.574949                81.699521
# 3                    No            49.574949               199.458074
# 4                    No            49.574949                41.420153
#
#                   Payment_Behaviour  Monthly_Balance Credit_Score  \
# 0   High_spent_Small_value_payments       312.494089         Good
# 1    Low_spent_Large_value_payments       284.629162         Good
# 2   Low_spent_Medium_value_payments       331.209863         Good
# 3    Low_spent_Small_value_payments       223.451310         Good
# 4  High_spent_Medium_value_payments       341.489231         Good
#
#    Num_of_loan2
# 0           4.0
# 1           4.0
# 2           4.0
# 3           4.0
# 4           4.0

# %% [markdown]
# ## Garbage value treatment

# %%
num_cols = ['Age','Annual_Income','Interest_Rate','Delay_from_due_date','']

# %%
df.describe().T
# Out:
#                             count          mean           std           min  \
# Age                       99522.0  3.324098e+01  1.076372e+01  1.400000e+01
# Annual_Income             99522.0  1.763414e+05  1.429806e+06  7.005930e+03
# Num_Bank_Accounts         99522.0  1.706701e+01  1.172050e+02 -1.000000e+00
# Num_Credit_Card           99522.0  2.245962e+01  1.289731e+02  0.000000e+00
# Interest_Rate             99522.0  7.239539e+01  4.659099e+02  1.000000e+00
# Delay_from_due_date       99522.0  2.110218e+01  1.487707e+01 -5.000000e+00
# Num_of_Delayed_Payment    92554.0  3.093169e+01  2.261506e+02 -3.000000e+00
# Changed_Credit_Limit      97439.0  1.040234e+01  6.794521e+00 -6.490000e+00
# Num_Credit_Inquiries      97568.0  2.775336e+01  1.931907e+02  0.000000e+00
# Outstanding_Debt          99522.0  1.429373e+03  1.156621e+03  2.300000e-01
# Credit_Utilization_Ratio  99522.0  3.228032e+01  5.114569e+00  2.000000e+01
# Credit_History_Age        90529.0  1.833240e+01  8.317023e+00  1.000000e-01
# Total_EMI_per_month       99522.0  1.405185e+03  8.310992e+03  0.000000e+00
# Amount_invested_monthly   95071.0  6.384486e+02  2.045877e+03  0.000000e+00
# Monthly_Balance           96666.0 -3.103470e+22  3.216216e+24 -3.333333e+26
# Num_of_loan2              99522.0  3.549848e+00  2.439911e+00  0.000000e+00
#
#                                    25%           50%           75%  \
# Age                          24.000000     33.000000     42.000000
# Annual_Income             19433.480000  37550.740000  72699.660000
# Num_Bank_Accounts             3.000000      6.000000      7.000000
# Num_Credit_Card               4.000000      5.000000      7.000000
# Interest_Rate                 8.000000     14.000000     20.000000
# Delay_from_due_date          10.000000     18.000000     28.000000
# Num_of_Delayed_Payment        9.000000     14.000000     18.000000
# Changed_Credit_Limit          5.340000      9.410000     14.900000
# Num_Credit_Inquiries          3.000000      6.000000      9.000000
# Outstanding_Debt            566.860000   1167.860000   1954.620000
# Credit_Utilization_Ratio     28.047791     32.301553     36.491825
# Credit_History_Age           12.000000     18.110000     25.100000
# Total_EMI_per_month          30.759834     69.602920    161.978219
# Amount_invested_monthly      74.502130    135.788434    265.574429
# Monthly_Balance             269.726686    335.999912    468.764981
# Num_of_loan2                  2.000000      3.000000      5.000000
#
#                                    max
# Age                       5.600000e+01
# Annual_Income             2.419806e+07
# Num_Bank_Accounts         1.798000e+03
# Num_Credit_Card           1.499000e+03
# Interest_Rate             5.797000e+03
# Delay_from_due_date       6.700000e+01
# Num_of_Delayed_Payment    4.397000e+03
# Changed_Credit_Limit      3.697000e+01
# Num_Credit_Inquiries      2.597000e+03
# Outstanding_Debt          4.998070e+03
# Credit_Utilization_Ratio  5.000000e+01
# Credit_History_Age        3.380000e+01
# Total_EMI_per_month       8.233100e+04
# Amount_invested_monthly   1.000000e+04
# Monthly_Balance           1.602041e+03
# Num_of_loan2              9.000000e+00

# %%
# we have already done for num_of_loan2 , creadit_history_age,age in the above missing values segment.

# %%
## Annual_income

# %%
df.Annual_Income.value_counts()
#here people have some
# Out:
# 9141.63        16
# 17273.83       16
# 36585.12       16
# 40341.16       16
# 20867.67       16
#                ..
# 15048753.00     1
# 20056517.00     1
# 1724659.00      1
# 6397485.00      1
# 9389456.00      1
# Name: Annual_Income, Length: 13482, dtype: int64

# %%
df[df.Annual_Income < 0]
# Out:
# Empty DataFrame
# Columns: [Customer_ID, Month, Age, Occupation, Annual_Income, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score, Num_of_loan2]
# Index: []

# %%
#we will keep all these high values as people can earn such high incomes

# %%
df.Num_Bank_Accounts.value_counts()
#here we can see there are some junk values as a person cannot possibly have 887 or 1221 loans, so we will fix this
# Out:
# 6       12947
# 7       12774
# 8       12712
# 4       12111
# 5       12054
#         ...
# 887         1
# 211         1
# 1221        1
# 753         1
# 697         1
# Name: Num_Bank_Accounts, Length: 940, dtype: int64

# %%
df[df.Customer_ID == 'CUS_0x4004']
# Out:
#     Customer_ID     Month   Age Occupation  Annual_Income  Num_Bank_Accounts  \
# 264  CUS_0x4004   January  43.0     Writer        58317.0                  8
# 265  CUS_0x4004  February  43.0     Writer        58317.0                  8
# 266  CUS_0x4004     March  44.0     Writer        58317.0                  8
# 267  CUS_0x4004     April  44.0     Writer        58317.0               1414
# 268  CUS_0x4004       May  44.0     Writer        58317.0                  8
# 269  CUS_0x4004      June  44.0     Writer        58317.0                  8
# 270  CUS_0x4004      July  44.0     Writer        58317.0                  8
# 271  CUS_0x4004    August  44.0     Writer        58317.0                  8
#
#      Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 264                5              9                   18
# 265                5              9                   18
# 266                5              9                   16
# 267                5              9                   18
# 268                5              9                   18
# 269                5              9                   18
# 270                5              9                   18
# 271                5              9                   22
#
#      Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 264                    17.0                 16.58                   6.0
# 265                    20.0                 16.58                   6.0
# 266                    20.0                 10.58                   6.0
# 267                    23.0                 23.58                  10.0
# 268                    20.0                 22.58                   NaN
# 269                     NaN                 16.58                  10.0
# 270                    20.0                 21.58                  10.0
# 271                     NaN                 16.58                  10.0
#
#     Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 264   Standard             98.97                 40.411115
# 265   Standard             98.97                 27.806918
# 266   Standard             98.97                 25.832109
# 267   Standard             98.97                 29.766107
# 268   Standard             98.97                 34.192304
# 269   Standard             98.97                 24.665525
# 270   Standard             98.97                 28.260147
# 271   Standard             98.97                 36.763665
#
#      Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 264                13.1                   Yes           149.897199
# 265                13.2                   Yes           149.897199
# 266                13.3                   Yes           149.897199
# 267                 NaN                   Yes           149.897199
# 268                13.5                   Yes           149.897199
# 269                13.6                   Yes           149.897199
# 270                13.7                   Yes           149.897199
# 271                13.8                   Yes           149.897199
#
#      Amount_invested_monthly                 Payment_Behaviour  \
# 264               109.488950  High_spent_Medium_value_payments
# 265                83.300408  High_spent_Medium_value_payments
# 266                57.951223   High_spent_Large_value_payments
# 267               158.648276  High_spent_Medium_value_payments
# 268               180.830573   Low_spent_Medium_value_payments
# 269                98.880508  High_spent_Medium_value_payments
# 270               380.585701   Low_spent_Medium_value_payments
# 271                59.955987  High_spent_Medium_value_payments
#
#      Monthly_Balance Credit_Score  Num_of_loan2
# 264       467.088851     Standard           6.0
# 265       483.277392     Standard           6.0
# 266       498.626577     Standard           6.0
# 267       407.929525     Standard           6.0
# 268       415.747227     Standard           6.0
# 269       467.697293     Standard           6.0
# 270       215.992100     Standard           6.0
# 271       506.621813     Standard           6.0

# %%
df.Num_Bank_Accounts[(df.Num_Bank_Accounts > 10) | (df.Num_Bank_Accounts <0)] = np.nan
#The average number of accounts can vary, but many individuals might have a combination of savings and checking accounts, 
#along with one or two other specialized accounts. 
#Keep in mind that these are general observations, So we have considered 10 as maximum Number of bank accounts.

# %%
df.Num_Bank_Accounts.isnull().sum()
# Out:
# 1338

# %%
#now we will fill these values using customer id as done in above columns
df.Num_Bank_Accounts[(df.Customer_ID =='CUS_0x4004') & (df.Num_Bank_Accounts.notnull())]
# Out:
# 264    8.0
# 265    8.0
# 266    8.0
# 268    8.0
# 269    8.0
# 270    8.0
# 271    8.0
# Name: Num_Bank_Accounts, dtype: float64

# %%
nba=""
nba1=""
for i in df.Customer_ID[df.Num_Bank_Accounts.isnull()]:
    nba = df.Num_Bank_Accounts[(df.Customer_ID ==i) & (df.Num_Bank_Accounts.notnull())]
    nba1 = nba.to_list()
    df.Num_Bank_Accounts[df.Customer_ID == i] = nba1[0]

# %%
df[df.Customer_ID =='CUS_0x4004']
# Out:
#     Customer_ID     Month   Age Occupation  Annual_Income  Num_Bank_Accounts  \
# 264  CUS_0x4004   January  43.0     Writer        58317.0                8.0
# 265  CUS_0x4004  February  43.0     Writer        58317.0                8.0
# 266  CUS_0x4004     March  44.0     Writer        58317.0                8.0
# 267  CUS_0x4004     April  44.0     Writer        58317.0                8.0
# 268  CUS_0x4004       May  44.0     Writer        58317.0                8.0
# 269  CUS_0x4004      June  44.0     Writer        58317.0                8.0
# 270  CUS_0x4004      July  44.0     Writer        58317.0                8.0
# 271  CUS_0x4004    August  44.0     Writer        58317.0                8.0
#
#      Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 264                5              9                   18
# 265                5              9                   18
# 266                5              9                   16
# 267                5              9                   18
# 268                5              9                   18
# 269                5              9                   18
# 270                5              9                   18
# 271                5              9                   22
#
#      Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 264                    17.0                 16.58                   6.0
# 265                    20.0                 16.58                   6.0
# 266                    20.0                 10.58                   6.0
# 267                    23.0                 23.58                  10.0
# 268                    20.0                 22.58                   NaN
# 269                     NaN                 16.58                  10.0
# 270                    20.0                 21.58                  10.0
# 271                     NaN                 16.58                  10.0
#
#     Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 264   Standard             98.97                 40.411115
# 265   Standard             98.97                 27.806918
# 266   Standard             98.97                 25.832109
# 267   Standard             98.97                 29.766107
# 268   Standard             98.97                 34.192304
# 269   Standard             98.97                 24.665525
# 270   Standard             98.97                 28.260147
# 271   Standard             98.97                 36.763665
#
#      Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 264                13.1                   Yes           149.897199
# 265                13.2                   Yes           149.897199
# 266                13.3                   Yes           149.897199
# 267                 NaN                   Yes           149.897199
# 268                13.5                   Yes           149.897199
# 269                13.6                   Yes           149.897199
# 270                13.7                   Yes           149.897199
# 271                13.8                   Yes           149.897199
#
#      Amount_invested_monthly                 Payment_Behaviour  \
# 264               109.488950  High_spent_Medium_value_payments
# 265                83.300408  High_spent_Medium_value_payments
# 266                57.951223   High_spent_Large_value_payments
# 267               158.648276  High_spent_Medium_value_payments
# 268               180.830573   Low_spent_Medium_value_payments
# 269                98.880508  High_spent_Medium_value_payments
# 270               380.585701   Low_spent_Medium_value_payments
# 271                59.955987  High_spent_Medium_value_payments
#
#      Monthly_Balance Credit_Score  Num_of_loan2
# 264       467.088851     Standard           6.0
# 265       483.277392     Standard           6.0
# 266       498.626577     Standard           6.0
# 267       407.929525     Standard           6.0
# 268       415.747227     Standard           6.0
# 269       467.697293     Standard           6.0
# 270       215.992100     Standard           6.0
# 271       506.621813     Standard           6.0

# %%
df.Num_Bank_Accounts.value_counts()
#now we have fixed num bank accounts
# Out:
# 6.0     13122
# 7.0     12938
# 8.0     12906
# 4.0     12283
# 5.0     12245
# 3.0     11999
# 9.0      5485
# 10.0     5338
# 1.0      4514
# 0.0      4375
# 2.0      4317
# Name: Num_Bank_Accounts, dtype: int64

# %%
#now we will work on num of credit cards

# %%
df[df.Num_Credit_Card > 10]
#as we have taken 10 no of accounts so we will take 10 num of credit cards
# Out:
#       Customer_ID     Month   Age    Occupation  Annual_Income  \
# 10     CUS_0x21b1     March  28.0       Teacher       34847.84
# 40     CUS_0x95ee   January  31.0        Lawyer       73928.46
# 157    CUS_0x4100      June  32.0  Entrepreneur       19300.34
# 163    CUS_0x132f     April  41.0      Musician       19514.88
# 207    CUS_0x4d43    August  48.0  Entrepreneur       20787.69
# ...           ...       ...   ...           ...            ...
# 99605  CUS_0x5d6d      June  38.0        Writer      126514.72
# 99615  CUS_0x2829    August  32.0    Journalist       64901.37
# 99619  CUS_0xae66     April  30.0        Writer      142560.36
# 99769  CUS_0xc345  February  23.0     Architect       60015.32
# 99811  CUS_0x64f0     April  19.0     Architect       39977.21
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 10                   2.0             1385              6                    3
# 40                   4.0             1288              8                   12
# 157                  6.0             1029             17                   51
# 163                  7.0              488             17                   30
# 207                  8.0             1381             14                   22
# ...                  ...              ...            ...                  ...
# 99605                8.0             1255              5                   21
# 99615                3.0              232             20                   19
# 99619                6.0             1430             13                   23
# 99769                7.0              679             14                    8
# 99811                4.0              158             11                   13
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 10                       -1.0                  5.42                   2.0
# 40                       10.0                 10.14                   2.0
# 157                      17.0                  9.95                   8.0
# 163                      12.0                  4.17                   2.0
# 207                      14.0                  8.13                   3.0
# ...                       ...                   ...                   ...
# 99605                    19.0                 10.64                   0.0
# 99615                    18.0                  2.94                   3.0
# 99619                    15.0                 11.22                   0.0
# 99769                     8.0                 10.47                 310.0
# 99811                    10.0                  9.62                   4.0
#
#       Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 10          Good            605.03                 33.224951
# 40          Good            548.20                 39.962685
# 157          Bad           2430.21                 25.847791
# 163     Standard            881.40                 34.503707
# 207     Standard            614.60                 35.344188
# ...          ...               ...                       ...
# 99605   Standard            470.42                 29.696182
# 99615   Standard            442.06                 29.145534
# 99619   Standard            220.75                 34.671699
# 99769   Standard           1095.15                 35.864367
# 99811       Good            832.09                 39.587650
#
#        Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 10                   26.9                    No            18.816215
# 40                    NaN                    No         15015.000000
# 157                  18.7                   Yes            49.572062
# 163                  19.6                    No             0.000000
# 207                  18.5                    No            42.221993
# ...                   ...                   ...                  ...
# 99605                29.7                    No         61447.000000
# 99615                31.5                   Yes             0.000000
# 99619                17.6                    No            76.772094
# 99769                15.3                   Yes           187.008683
# 99811                30.4                    No             0.000000
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 10                   58.515976   High_spent_Large_value_payments
# 40                   98.674410   High_spent_Large_value_payments
# 157                  83.447449    Low_spent_Large_value_payments
# 163                  45.388820  High_spent_Medium_value_payments
# 207                  21.745531   High_spent_Large_value_payments
# ...                        ...                               ...
# 99605               902.340388    Low_spent_Small_value_payments
# 99615               126.263036   High_spent_Large_value_payments
# 99619               982.946968    Low_spent_Large_value_payments
# 99769               241.313632    Low_spent_Large_value_payments
# 99811               240.514534    Low_spent_Small_value_payments
#
#        Monthly_Balance Credit_Score  Num_of_loan2
# 10          466.466476     Standard           1.0
# 40          740.196090         Good           0.0
# 157         288.216656         Poor           5.0
# 163         387.435180         Poor           0.0
# 207         375.963226     Standard           3.0
# ...                ...          ...           ...
# 99605              NaN         Good           3.0
# 99615              NaN     Standard           0.0
# 99619              NaN     Standard           1.0
# 99769              NaN     Standard           7.0
# 99811              NaN     Standard           0.0
#
# [2293 rows x 23 columns]

# %%
df[df.Num_Credit_Card < 0]
#no person  havong credit card < 0
# Out:
# Empty DataFrame
# Columns: [Customer_ID, Month, Age, Occupation, Annual_Income, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score, Num_of_loan2]
# Index: []

# %%
df.Num_Credit_Card[df.Num_Credit_Card > 10] = np.nan

# %%
df.Num_Credit_Card.isnull().sum ()
# Out:
# 2293

# %%
ncc=""
ncc1=""
for i in df.Customer_ID[df.Num_Credit_Card.isnull()]:
    ncc = df.Num_Credit_Card[(df.Customer_ID ==i) & (df.Num_Credit_Card.notnull())]
    ncc1 = ncc.to_list()
    df.Num_Credit_Card[df.Customer_ID == i] = ncc1[0]

# %%
df.Num_Credit_Card.value_counts()
#now we have fixed the garbage values in num credit card
# Out:
# 5.0     18810
# 7.0     16961
# 6.0     16825
# 4.0     14289
# 3.0     13475
# 8.0      5068
# 10.0     4996
# 9.0      4749
# 1.0      2183
# 2.0      2156
# 0.0        10
# Name: Num_Credit_Card, dtype: int64

# %%
#now we will work oon interest rate
df.Interest_Rate.value_counts()
# Out:
# 8       4968
# 5       4944
# 6       4686
# 12      4520
# 10      4503
#         ...
# 1899       1
# 2120       1
# 5762       1
# 4372       1
# 5729       1
# Name: Interest_Rate, Length: 1744, dtype: int64

# %%
df[df.Interest_Rate > 32].shape[0]
# Out:
# 4992

# %%
df[df.Interest_Rate > 33].shape[0]
# Out:
# 3525

# %%
df[df.Interest_Rate > 34].shape[0]
# Out:
# 2023

# %%
df[df.Interest_Rate > 35].shape[0]
# Out:
# 2023

# %%
df[df.Interest_Rate > 36].shape[0]
# Out:
# 2023

# %%
# as we can see after 34% interst rate  the no of entries is constant so we will procedd with 34% and above it all are junk

# %%
df.Interest_Rate[df.Interest_Rate > 34] = np.nan

# %%
df.Interest_Rate.isnull().sum()
# Out:
# 2023

# %%
df[df.Interest_Rate.isnull()]
# Out:
#       Customer_ID     Month   Age     Occupation  Annual_Income  \
# 44     CUS_0x95ee       May  31.0         Lawyer       73928.46
# 89     CUS_0xc0ab  February  33.0       Engineer       88640.24
# 167    CUS_0x132f    August  41.0       Musician       19514.88
# 178    CUS_0xac86     March  20.0   Entrepreneur      106733.13
# 229    CUS_0xbffe      June  40.0      Architect       28572.39
# ...           ...       ...   ...            ...            ...
# 99791  CUS_0x62f5    August  54.0       Musician       99520.50
# 99801  CUS_0x1232  February  16.0      Developer       14937.49
# 99882  CUS_0x47fa     March  31.0       Mechanic    16884797.00
# 99914  CUS_0x1619     March  54.0  Media_Manager       20059.98
# 99997  CUS_0x942c      June  25.0       Mechanic       39628.99
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 44                   4.0              5.0            NaN                   11
# 89                   3.0              6.0            NaN                    4
# 167                  7.0              5.0            NaN                   26
# 178                  4.0              4.0            NaN                    2
# 229                  6.0              3.0            NaN                   25
# ...                  ...              ...            ...                  ...
# 99791                3.0              1.0            NaN                    8
# 99801                8.0              8.0            NaN                   42
# 99882                7.0              3.0            NaN                    7
# 99914                8.0              5.0            NaN                   25
# 99997                4.0              6.0            NaN                   27
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 44                        7.0                 10.14                   2.0
# 89                        2.0                  3.51                   3.0
# 167                      11.0                  4.17                   4.0
# 178                       6.0                  0.86                   0.0
# 229                      11.0                  4.89                   2.0
# ...                       ...                   ...                   ...
# 99791                     5.0                  4.08                   5.0
# 99801                    13.0                 21.17                   6.0
# 99882                     8.0                 12.57                   2.0
# 99914                     9.0                  2.97                   3.0
# 99997                     6.0                 11.50                   3.0
#
#       Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 44          Good            548.20                 26.333310
# 89          Good            950.36                 41.036168
# 167     Standard            881.40                 28.781888
# 178         Good             76.23                 42.070459
# 229     Standard            400.07                 35.693949
# ...          ...               ...                       ...
# 99791       Good            547.21                 38.798114
# 99801        Bad           3699.44                 35.964828
# 99882   Standard            330.60                 38.524095
# 99914       Good            909.01                 29.204711
# 99997       Good            502.38                 41.255522
#
#        Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 44                  32.30                    No             0.000000
# 89                  25.60                    NM           135.173371
# 167                 19.10                    No             0.000000
# 178                 32.11                    No             0.000000
# 229                 30.80                   Yes            69.602920
# ...                   ...                   ...                  ...
# 99791               16.80                    NM           196.528591
# 99801               13.30                   Yes            50.960878
# 99882               23.00                   Yes             0.000000
# 99914               16.50                    No            45.076827
# 99997               31.80                    No            35.104023
#
#        Amount_invested_monthly                Payment_Behaviour  \
# 44                  177.951836   Low_spent_Large_value_payments
# 89                  157.174788  High_spent_Large_value_payments
# 167                  99.141541  High_spent_Small_value_payments
# 178                 172.032829  High_spent_Large_value_payments
# 229                 129.264835   Low_spent_Small_value_payments
# ...                        ...                              ...
# 99791               147.563516  High_spent_Large_value_payments
# 99801               149.887864   Low_spent_Small_value_payments
# 99882             10000.000000  High_spent_Small_value_payments
# 99914               111.567139   Low_spent_Large_value_payments
# 99997                24.028477  High_spent_Large_value_payments
#
#        Monthly_Balance Credit_Score  Num_of_loan2
# 44          690.918664         Good           0.0
# 89          674.320507         Good           2.0
# 167         343.682459         Poor           0.0
# 178         955.309921         Good           0.0
# 229         312.135495     Standard           3.0
# ...                ...          ...           ...
# 99791              NaN         Good           3.0
# 99801              NaN     Standard           7.0
# 99882              NaN     Standard           0.0
# 99914              NaN         Poor           4.0
# 99997              NaN         Poor           2.0
#
# [2023 rows x 23 columns]

# %%
nic = ""
nic1 = ""
for i in df.Customer_ID[df.Interest_Rate.isnull()]:
    nic = df.Interest_Rate[(df.Customer_ID ==i) & (df.Interest_Rate.notnull())]
    nic1 = nic.to_list()
    df.Interest_Rate[df.Customer_ID == i] = nic1[0]

# %%
df.Interest_Rate.isnull().sum()
# Out:
# 0

# %%
df[df.Customer_ID == 'CUS_0x95ee']
# Out:
#    Customer_ID     Month   Age Occupation  Annual_Income  Num_Bank_Accounts  \
# 40  CUS_0x95ee   January  31.0     Lawyer       73928.46                4.0
# 41  CUS_0x95ee  February  31.0     Lawyer       73928.46                4.0
# 42  CUS_0x95ee     March  31.0     Lawyer       73928.46                4.0
# 43  CUS_0x95ee     April  31.0     Lawyer       73928.46                4.0
# 44  CUS_0x95ee       May  31.0     Lawyer       73928.46                4.0
# 45  CUS_0x95ee      June  31.0     Lawyer       73928.46                4.0
# 46  CUS_0x95ee      July  31.0     Lawyer       73928.46                4.0
# 47  CUS_0x95ee    August  31.0     Lawyer       73928.46                4.0
#
#     Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 40              5.0            8.0                   12
# 41              5.0            8.0                    8
# 42              5.0            8.0                    8
# 43              5.0            8.0                    8
# 44              5.0            8.0                   11
# 45              5.0            8.0                    7
# 46              5.0            8.0                    8
# 47              5.0            8.0                    8
#
#     Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 40                    10.0                 10.14                   2.0
# 41                     7.0                 10.14                   2.0
# 42                     7.0                 10.14                   2.0
# 43                     7.0                 10.14                   2.0
# 44                     7.0                 10.14                   2.0
# 45                     7.0                 10.14                   2.0
# 46                     4.0                  9.14                   2.0
# 47                     7.0                 10.14                   NaN
#
#    Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 40       Good             548.2                 39.962685                 NaN
# 41       Good             548.2                 42.769864                32.0
# 42       Good             548.2                 40.712187                 NaN
# 43       Good             548.2                 30.201658                32.2
# 44       Good             548.2                 26.333310                32.3
# 45       Good             548.2                 35.275437                 NaN
# 46       Good             548.2                 36.624791                32.5
# 47       Good             548.2                 31.580990                32.6
#
#    Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 40                    No              15015.0                98.674410
# 41                    NM                  0.0               172.939214
# 42                    No                  0.0               150.059734
# 43                    No                  0.0               618.202391
# 44                    No                  0.0               177.951836
# 45                    No              15515.0               235.790325
# 46                    No                  0.0               348.509400
# 47                    No                  0.0                42.635590
#
#                    Payment_Behaviour  Monthly_Balance Credit_Score  \
# 40   High_spent_Large_value_payments       740.196090         Good
# 41   Low_spent_Medium_value_payments       705.931286         Good
# 42  High_spent_Medium_value_payments       698.810766         Good
# 43    Low_spent_Small_value_payments       270.668109         Good
# 44    Low_spent_Large_value_payments       690.918664         Good
# 45    Low_spent_Large_value_payments       633.080175         Good
# 46   High_spent_Small_value_payments       510.361100     Standard
# 47    Low_spent_Large_value_payments       796.234910         Good
#
#     Num_of_loan2
# 40           0.0
# 41           0.0
# 42           0.0
# 43           0.0
# 44           0.0
# 45           0.0
# 46           0.0
# 47           0.0

# %%
df.Delay_from_due_date.value_counts()
# Out:
#  15    3578
#  13    3405
#  8     3296
#  14    3286
#  10    3256
#        ...
# -4       61
#  65      56
# -5       33
#  66      32
#  67      22
# Name: Delay_from_due_date, Length: 73, dtype: int64

# %%
df[df.Delay_from_due_date < 0]
# Out:
#       Customer_ID     Month   Age     Occupation  Annual_Income  \
# 1       CUS_0xd40  February  23.0      Scientist       19114.12
# 49     CUS_0x284a  February  34.0         Lawyer      131313.40
# 74     CUS_0xba08     March  44.0     Journalist       31370.80
# 78     CUS_0xba08      July  45.0     Journalist       31370.80
# 79     CUS_0xba08    August  45.0     Journalist       31370.80
# ...           ...       ...   ...            ...            ...
# 99198  CUS_0xb59b      July  34.0       Mechanic       96047.22
# 99358  CUS_0x870c      July  44.0        Manager       19631.26
# 99368  CUS_0x163c   January  31.0  Media_Manager       61465.78
# 99371  CUS_0x163c     April  31.0  Media_Manager       61465.78
# 99667   CUS_0xb09     April  31.0         Lawyer      146310.68
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 1                    3.0              4.0            3.0                   -1
# 49                   0.0              1.0            8.0                   -1
# 74                   1.0              6.0           12.0                   -2
# 78                   1.0              6.0           12.0                   -1
# 79                   1.0              6.0           12.0                   -2
# ...                  ...              ...            ...                  ...
# 99198                3.0              3.0            1.0                   -2
# 99358                2.0              4.0            9.0                   -1
# 99368                2.0              3.0           11.0                   -4
# 99371                2.0              3.0           11.0                   -5
# 99667                5.0              4.0            9.0                   -2
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 1                         NaN                 11.27                   4.0
# 49                        2.0                 15.34                   4.0
# 74                        0.0                  1.76                   5.0
# 78                        2.0                  5.76                   5.0
# 79                        2.0                  5.76                   5.0
# ...                       ...                   ...                   ...
# 99198                     6.0                  4.75                   NaN
# 99358                     4.0                 17.51                   9.0
# 99368                    10.0                  3.17                   0.0
# 99371                    10.0                  3.17                   2.0
# 99667                     7.0                 11.48                   1.0
#
#       Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 1           Good            809.98                 31.944960
# 49          Good            352.16                 31.983710
# 74          Good            421.43                 31.046418
# 78          Good            421.43                 22.762202
# 79          Good            421.43                 37.565053
# ...          ...               ...                       ...
# 99198       Good           1366.21                 34.080533
# 99358       Good            823.21                 39.130281
# 99368       Good            608.87                 26.846460
# 99371       Good            608.87                 25.443676
# 99667       Good            928.28                 35.389329
#
#        Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 1                     NaN                    No            49.574949
# 49                  30.80                    No           137.644605
# 74                  26.70                    No            46.616129
# 78                  26.11                    No            46.616129
# 79                  27.00                    No            46.616129
# ...                   ...                   ...                  ...
# 99198               17.10                    No            49.656727
# 99358               32.40                    No            65.051299
# 99368               17.10                    No            31.650737
# 99371               18.10                    No            31.650737
# 99667               22.40                    No            72.250125
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 1                   118.280222    Low_spent_Large_value_payments
# 49                  698.873271   High_spent_Small_value_payments
# 74                  140.820696   Low_spent_Medium_value_payments
# 78                  188.394900    Low_spent_Small_value_payments
# 79                  252.644827    Low_spent_Small_value_payments
# ...                        ...                               ...
# 99198               113.121623  High_spent_Medium_value_payments
# 99358               129.026936    Low_spent_Small_value_payments
# 99368             10000.000000   Low_spent_Medium_value_payments
# 99371               493.144096   Low_spent_Medium_value_payments
# 99667              1186.575073   Low_spent_Medium_value_payments
#
#        Monthly_Balance Credit_Score  Num_of_loan2
# 1           284.629162         Good           4.0
# 49          547.760457         Good           2.0
# 74          375.086508         Good           2.0
# 78          337.512304         Good           2.0
# 79          273.262377         Good           2.0
# ...                ...          ...           ...
# 99198              NaN         Good           1.0
# 99358              NaN         Good           4.0
# 99368              NaN     Standard           1.0
# 99371              NaN         Good           1.0
# 99667              NaN         Good           1.0
#
# [590 rows x 23 columns]

# %%
print(df.Delay_from_due_date.max())
print(df.Delay_from_due_date.min())
#This columns look good and all the values are justified so we will move ahead
# Out:
# 67
# -5

# %%
#now we will treat Num_of_Delayed_Payment

# %%
df[df.Num_of_Delayed_Payment == 0]
# Out:
#       Customer_ID     Month   Age     Occupation  Annual_Income  \
# 13     CUS_0x21b1      June  28.0        Teacher       34847.84
# 72     CUS_0xba08   January  44.0     Journalist       31370.80
# 73     CUS_0xba08  February  44.0     Journalist       31370.80
# 74     CUS_0xba08     March  44.0     Journalist       31370.80
# 75     CUS_0xba08     April  44.0     Journalist       31370.80
# ...           ...       ...   ...            ...            ...
# 99968   CUS_0xf16   January  44.0  Media_Manager       16680.35
# 99969   CUS_0xf16  February  44.0  Media_Manager       16680.35
# 99970   CUS_0xf16     March  44.0  Media_Manager       16680.35
# 99972   CUS_0xf16       May  44.0  Media_Manager       16680.35
# 99975   CUS_0xf16    August  44.0  Media_Manager       16680.35
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 13                   2.0              4.0            6.0                    3
# 72                   0.0              5.0           12.0                    4
# 73                   1.0              6.0           12.0                    2
# 74                   1.0              6.0           12.0                   -2
# 75                   1.0              6.0           12.0                    1
# ...                  ...              ...            ...                  ...
# 99968                1.0              1.0            5.0                    4
# 99969                1.0              1.0            5.0                    3
# 99970                1.0              1.0            5.0                    1
# 99972                1.0              1.0            5.0                    1
# 99975                1.0              1.0            5.0                    1
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 13                        0.0                  5.42                   2.0
# 72                        0.0                  5.76                   2.0
# 73                        0.0                 -1.24                   2.0
# 74                        0.0                  1.76                   5.0
# 75                        0.0                  5.76                   5.0
# ...                       ...                   ...                   ...
# 99968                     0.0                  5.69                   4.0
# 99969                     0.0                  5.69                   4.0
# 99970                     0.0                  5.69                   8.0
# 99972                     0.0                  5.69                   8.0
# 99975                     0.0                  5.69                   8.0
#
#       Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 13          Good            605.03                 33.381010
# 72          Good            421.43                 29.519353
# 73          Good            421.43                 28.220481
# 74          Good            421.43                 31.046418
# 75          Good            421.43                 30.168030
# ...          ...               ...                       ...
# 99968       Good            897.16                 39.868572
# 99969       Good            897.16                 34.085971
# 99970       Good            897.16                 30.472041
# 99972       Good            897.16                 37.788217
# 99975       Good            897.16                 41.212367
#
#        Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 13                   27.0                    No            18.816215
# 72                    NaN                    NM            46.616129
# 73                   26.6                    No            46.616129
# 74                   26.7                    No            46.616129
# 75                   26.8                    No            46.616129
# ...                   ...                   ...                  ...
# 99968                 NaN                    NM            41.113561
# 99969                21.2                    No            41.113561
# 99970                21.3                    No         75011.000000
# 99972                21.5                    No            41.113561
# 99975                 NaN                    No            41.113561
#
#        Amount_invested_monthly                Payment_Behaviour  \
# 13                   43.477190  High_spent_Large_value_payments
# 72                  154.352781  High_spent_Small_value_payments
# 73                  298.744469   Low_spent_Small_value_payments
# 74                  140.820696  Low_spent_Medium_value_payments
# 75                  233.605526   Low_spent_Small_value_payments
# ...                        ...                              ...
# 99968                52.951978  High_spent_Small_value_payments
# 99969               104.646237  High_spent_Small_value_payments
# 99970                75.504972  Low_spent_Medium_value_payments
# 99972                64.549748   Low_spent_Large_value_payments
# 99975                70.805550   Low_spent_Large_value_payments
#
#        Monthly_Balance Credit_Score  Num_of_loan2
# 13          481.505262         Good           1.0
# 72          341.554423         Good           2.0
# 73          227.162735         Good           2.0
# 74          375.086508         Good           2.0
# 75          292.301678         Good           2.0
# ...                ...          ...           ...
# 99968              NaN         Good           4.0
# 99969              NaN         Good           4.0
# 99970              NaN         Good           4.0
# 99972              NaN     Standard           4.0
# 99975              NaN         Good           4.0
#
# [1600 rows x 23 columns]

# %%
df.Num_of_Delayed_Payment.isnull().sum()
# Out:
# 6968

# %%
df.Num_of_Delayed_Payment.value_counts()
# Out:
# 19.0      5459
# 17.0      5394
# 16.0      5292
# 10.0      5284
# 15.0      5212
#           ...
# 1530.0       1
# 1502.0       1
# 4075.0       1
# 3845.0       1
# 2047.0       1
# Name: Num_of_Delayed_Payment, Length: 707, dtype: int64

# %%
df[df.Num_of_Delayed_Payment > 28]
#after this the number of entries is constant so we will make everything above this null and impute them later with KNN
# Out:
#       Customer_ID     Month   Age  Occupation  Annual_Income  \
# 252    CUS_0x6048       May  43.0    Musician      18627.640
# 284    CUS_0x9b94       May  36.0     Manager      71681.400
# 304    CUS_0x42ac   January  36.0    Musician      15566.020
# 409    CUS_0xb986  February  14.0   Developer      39887.220
# 643    CUS_0x78e0     April  47.0  Accountant      17787.340
# ...           ...       ...   ...         ...            ...
# 99133  CUS_0xbb53      June  31.0      Lawyer      77633.040
# 99402  CUS_0x7b65     March  27.0    Mechanic       8968.555
# 99562   CUS_0x650     March  28.0      Lawyer      21471.580
# 99563   CUS_0x650     April  28.0      Lawyer      21471.580
# 99825  CUS_0x2c0a  February  44.0      Doctor      32625.590
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 252                  7.0              7.0           19.0                   31
# 284                  3.0              6.0           15.0                    8
# 304                  8.0              5.0           32.0                   16
# 409                  9.0              9.0           16.0                   59
# 643                  8.0              4.0           16.0                    6
# ...                  ...              ...            ...                  ...
# 99133                7.0              5.0           34.0                   55
# 99402               10.0              8.0           30.0                   58
# 99562                7.0              3.0           16.0                   14
# 99563                7.0              3.0           16.0                   15
# 99825                0.0              5.0            8.0                    5
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 252                    3318.0                  5.07                   7.0
# 284                    3083.0                 10.44                   0.0
# 304                    1338.0                  9.24                   7.0
# 409                    3104.0                 11.25                   NaN
# 643                     183.0                  5.65                   0.0
# ...                       ...                   ...                   ...
# 99133                  3336.0                 15.48                   8.0
# 99402                  3392.0                 23.83                  12.0
# 99562                  3688.0                  2.00                   4.0
# 99563                   221.0                 11.00                   4.0
# 99825                  2047.0                  2.55                   3.0
#
#       Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 252          Bad           1793.54                 25.585205
# 284     Standard           1293.02                 40.791137
# 304     Standard           1693.95                 37.409934
# 409          Bad           3119.60                 26.112222
# 643     Standard            730.90                 34.903092
# ...          ...               ...                       ...
# 99133        Bad           3392.65                 32.025465
# 99402        Bad           2502.86                 38.044111
# 99562   Standard             68.06                 40.940335
# 99563   Standard             68.06                 31.039063
# 99825       Good            177.90                 33.861542
#
#        Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 252                 19.10                   Yes            65.139488
# 284                 25.11                   Yes            53.923514
# 304                  7.10                   Yes            43.070520
# 409                 12.60                   Yes           133.470845
# 643                 30.00                    NM            20.063634
# ...                   ...                   ...                  ...
# 99133                0.90                   Yes           227.777065
# 99402               11.50                   Yes            57.078833
# 99562               23.90                    No            23.498319
# 99563               23.10                    No            23.498319
# 99825               28.90                    No            73.125008
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 252                  24.346188   High_spent_Large_value_payments
# 284               10000.000000   High_spent_Large_value_payments
# 304                  65.986586    Low_spent_Small_value_payments
# 409                 153.270725  High_spent_Medium_value_payments
# 643                  28.516044  High_spent_Medium_value_payments
# ...                        ...                               ...
# 99133               106.015126   High_spent_Large_value_payments
# 99402                93.647887    Low_spent_Small_value_payments
# 99562                33.192490   High_spent_Small_value_payments
# 99563                12.340388  High_spent_Medium_value_payments
# 99825               350.806918    Low_spent_Small_value_payments
#
#        Monthly_Balance Credit_Score  Num_of_loan2
# 252         289.244657         Poor           6.0
# 284         358.095400         Good           1.0
# 304         323.259728         Poor           4.0
# 409         295.751929         Poor           5.0
# 643         325.648156     Standard           2.0
# ...                ...          ...           ...
# 99133              NaN         Poor           5.0
# 99402              NaN         Poor           8.0
# 99562              NaN     Standard           2.0
# 99563              NaN     Standard           2.0
# 99825              NaN     Standard           4.0
#
# [731 rows x 23 columns]

# %%
df.Num_of_Delayed_Payment[df.Num_of_Delayed_Payment > 28] = np.nan

# %%
# now we have fixed garbage values and rest nan will be filled by KNN

# %%
#now we will work on Changed credit limit

# %%
df[df.Changed_Credit_Limit < 0]
# Out:
#       Customer_ID     Month   Age    Occupation  Annual_Income  \
# 27     CUS_0xb891     April  55.0  Entrepreneur       30689.89
# 28     CUS_0xb891       May  55.0  Entrepreneur       30689.89
# 29     CUS_0xb891      June  55.0  Entrepreneur       30689.89
# 73     CUS_0xba08  February  44.0    Journalist       31370.80
# 179    CUS_0xac86     April  20.0  Entrepreneur      106733.13
# ...           ...       ...   ...           ...            ...
# 99787  CUS_0x62f5     April  54.0      Musician       99520.50
# 99826  CUS_0x2c0a     March  44.0        Doctor       32625.59
# 99900  CUS_0x4986       May  33.0  Entrepreneur       41329.56
# 99958  CUS_0x2084      July  21.0     Architect       38321.39
# 99961  CUS_0x372c  February  18.0        Lawyer       42903.79
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 27                   2.0              5.0            4.0                    7
# 28                   2.0              5.0            4.0                    5
# 29                   2.0              5.0            4.0                    5
# 73                   1.0              6.0           12.0                    2
# 179                  4.0              4.0            1.0                    5
# ...                  ...              ...            ...                  ...
# 99787                3.0              1.0            5.0                    8
# 99826                0.0              5.0            8.0                    5
# 99900                2.0              3.0            7.0                    1
# 99958                4.0              4.0            3.0                   11
# 99961                0.0              4.0            6.0                   14
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 27                        6.0                 -2.01                   4.0
# 28                        6.0                 -1.01                   4.0
# 29                        6.0                 -3.01                   4.0
# 73                        0.0                 -1.24                   2.0
# 179                       7.0                 -4.14                   0.0
# ...                       ...                   ...                   ...
# 99787                     5.0                 -1.92                   3.0
# 99826                    10.0                 -0.45                   3.0
# 99900                    10.0                 -0.34                   NaN
# 99958                    10.0                 -3.41                   3.0
# 99961                     0.0                 -0.90                   1.0
#
#       Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 27          Good            632.46                 38.132348
# 28          Good            632.46                 41.154317
# 29          Good            632.46                 27.445422
# 73          Good            421.43                 28.220481
# 179         Good             76.23                 25.842548
# ...          ...               ...                       ...
# 99787       Good            547.21                 37.945619
# 99826       Good            177.90                 39.101560
# 99900       Good           1245.01                 35.367709
# 99958       Good            678.57                 28.360351
# 99961       Good           1079.48                 33.494867
#
#        Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 27                   17.6                    No            16.415452
# 28                   17.7                    No            16.415452
# 29                   17.8                    No            16.415452
# 73                   26.6                    No            46.616129
# 179                  33.0                    No             0.000000
# ...                   ...                   ...                  ...
# 99787                16.4                    NM           196.528591
# 99826                28.1                    NM            73.125008
# 99900                 NaN                    No            20.553577
# 99958                17.5                    No           362.072453
# 99961                28.2                    No            34.975457
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 27                  272.334037    Low_spent_Small_value_payments
# 28                10000.000000    Low_spent_Large_value_payments
# 29                   84.952848   High_spent_Small_value_payments
# 73                  298.744469    Low_spent_Small_value_payments
# 179                 644.287394    Low_spent_Large_value_payments
# ...                        ...                               ...
# 99787               330.362769  High_spent_Medium_value_payments
# 99826               111.178599  High_spent_Medium_value_payments
# 99900               126.576130   Low_spent_Medium_value_payments
# 99958               182.067651    Low_spent_Large_value_payments
# 99961                      NaN  High_spent_Medium_value_payments
#
#        Monthly_Balance Credit_Score  Num_of_loan2
# 27          262.499594     Standard           1.0
# 28          359.374916     Standard           1.0
# 29          419.880784     Standard           1.0
# 73          227.162735         Good           2.0
# 179         513.055356         Good           0.0
# ...                ...          ...           ...
# 99787              NaN     Standard           3.0
# 99826              NaN     Standard           4.0
# 99900              NaN         Good           1.0
# 99958              NaN     Standard           4.0
# 99961              NaN         Good           1.0
#
# [1577 rows x 23 columns]

# %%
df.Changed_Credit_Limit.value_counts()
# Out:
#  8.22     135
#  11.32    126
#  11.50    126
#  10.06    121
#  7.35     120
#          ...
#  34.49      1
#  36.49      1
#  35.69      1
# -4.11       1
#  21.17      1
# Name: Changed_Credit_Limit, Length: 3633, dtype: int64

# %%
df.Changed_Credit_Limit.max()
# Out:
# 36.97

# %%
df.Changed_Credit_Limit.min()
#it looks good and we will proceed with it and move on
# Out:
# -6.49

# %%
df.describe().T
# Out:
#                             count          mean           std           min  \
# Age                       99522.0  3.324098e+01  1.076372e+01  1.400000e+01
# Annual_Income             99522.0  1.763414e+05  1.429806e+06  7.005930e+03
# Num_Bank_Accounts         99522.0  5.373616e+00  2.592869e+00  0.000000e+00
# Num_Credit_Card           99522.0  5.536947e+00  2.067098e+00  0.000000e+00
# Interest_Rate             99522.0  1.455778e+01  8.747120e+00  1.000000e+00
# Delay_from_due_date       99522.0  2.110218e+01  1.487707e+01 -5.000000e+00
# Num_of_Delayed_Payment    91823.0  1.332714e+01  6.312858e+00 -3.000000e+00
# Changed_Credit_Limit      97439.0  1.040234e+01  6.794521e+00 -6.490000e+00
# Num_Credit_Inquiries      97568.0  2.775336e+01  1.931907e+02  0.000000e+00
# Outstanding_Debt          99522.0  1.429373e+03  1.156621e+03  2.300000e-01
# Credit_Utilization_Ratio  99522.0  3.228032e+01  5.114569e+00  2.000000e+01
# Credit_History_Age        90529.0  1.833240e+01  8.317023e+00  1.000000e-01
# Total_EMI_per_month       99522.0  1.405185e+03  8.310992e+03  0.000000e+00
# Amount_invested_monthly   95071.0  6.384486e+02  2.045877e+03  0.000000e+00
# Monthly_Balance           96666.0 -3.103470e+22  3.216216e+24 -3.333333e+26
# Num_of_loan2              99522.0  3.549848e+00  2.439911e+00  0.000000e+00
#
#                                    25%           50%           75%  \
# Age                          24.000000     33.000000     42.000000
# Annual_Income             19433.480000  37550.740000  72699.660000
# Num_Bank_Accounts             3.000000      6.000000      7.000000
# Num_Credit_Card               4.000000      5.000000      7.000000
# Interest_Rate                 7.000000     13.000000     20.000000
# Delay_from_due_date          10.000000     18.000000     28.000000
# Num_of_Delayed_Payment        9.000000     14.000000     18.000000
# Changed_Credit_Limit          5.340000      9.410000     14.900000
# Num_Credit_Inquiries          3.000000      6.000000      9.000000
# Outstanding_Debt            566.860000   1167.860000   1954.620000
# Credit_Utilization_Ratio     28.047791     32.301553     36.491825
# Credit_History_Age           12.000000     18.110000     25.100000
# Total_EMI_per_month          30.759834     69.602920    161.978219
# Amount_invested_monthly      74.502130    135.788434    265.574429
# Monthly_Balance             269.726686    335.999912    468.764981
# Num_of_loan2                  2.000000      3.000000      5.000000
#
#                                    max
# Age                       5.600000e+01
# Annual_Income             2.419806e+07
# Num_Bank_Accounts         1.000000e+01
# Num_Credit_Card           1.000000e+01
# Interest_Rate             3.400000e+01
# Delay_from_due_date       6.700000e+01
# Num_of_Delayed_Payment    2.800000e+01
# Changed_Credit_Limit      3.697000e+01
# Num_Credit_Inquiries      2.597000e+03
# Outstanding_Debt          4.998070e+03
# Credit_Utilization_Ratio  5.000000e+01
# Credit_History_Age        3.380000e+01
# Total_EMI_per_month       8.233100e+04
# Amount_invested_monthly   1.000000e+04
# Monthly_Balance           1.602041e+03
# Num_of_loan2              9.000000e+00

# %%
# now we will work on Num_Credit_Inquiries

# %%
df[df.Num_Credit_Inquiries < 0]
# Out:
# Empty DataFrame
# Columns: [Customer_ID, Month, Age, Occupation, Annual_Income, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score, Num_of_loan2]
# Index: []

# %%
df.Num_Credit_Inquiries.value_counts()
# Out:
# 4.0       11194
# 3.0        8810
# 6.0        8084
# 7.0        8034
# 2.0        7958
#           ...
# 2245.0        1
# 470.0         1
# 1662.0        1
# 1312.0        1
# 74.0          1
# Name: Num_Credit_Inquiries, Length: 1215, dtype: int64

# %%
df.Num_Credit_Inquiries.max()
# Out:
# 2597.0

# %%
df[df.Num_Credit_Inquiries > 17]
#after 17 the change in number of entries is almost constant so we will proceed with it and make other null
# Out:
#       Customer_ID     Month   Age     Occupation  Annual_Income  \
# 173    CUS_0xa16e      June  42.0  Media_Manager      10183.015
# 193    CUS_0xa5f9  February  34.0       Mechanic      57983.120
# 198    CUS_0xa5f9      July  34.0       Mechanic      57983.120
# 234    CUS_0xb681     March  37.0        Manager      39641.540
# 312    CUS_0x571f   January  18.0      Developer      66567.320
# ...           ...       ...   ...            ...            ...
# 99717  CUS_0xadbd      June  26.0         Doctor      35793.970
# 99769  CUS_0xc345  February  23.0      Architect      60015.320
# 99789  CUS_0x62f5      June  54.0       Musician      99520.500
# 99800  CUS_0x1232   January  16.0      Developer      14937.490
# 99872  CUS_0x3855   January  27.0      Scientist     118677.540
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 173                  7.0              5.0           17.0                   48
# 193                  9.0              8.0           31.0                   53
# 198                  9.0              8.0           31.0                   49
# 234                 10.0              8.0           25.0                   61
# 312                  5.0              7.0            5.0                    7
# ...                  ...              ...            ...                  ...
# 99717                5.0              6.0            8.0                   10
# 99769                7.0              4.0           14.0                    8
# 99789                3.0              1.0            5.0                    8
# 99800                8.0              8.0           22.0                   44
# 99872                4.0              4.0            6.0                    4
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 173                      24.0                 10.97                1050.0
# 193                      21.0                  7.27                1044.0
# 198                      21.0                  7.27                1936.0
# 234                      15.0                  1.54                 568.0
# 312                      15.0                  7.67                1618.0
# ...                       ...                   ...                   ...
# 99717                    11.0                  9.92                1361.0
# 99769                     8.0                 10.47                 310.0
# 99789                     8.0                  4.08                  93.0
# 99800                    12.0                   NaN                2209.0
# 99872                    13.0                  9.59                  74.0
#
#       Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 173          Bad           1672.43                 25.105403
# 193          Bad           3532.83                 37.873642
# 198          Bad           3532.83                 24.631497
# 234          Bad           2258.73                 27.572863
# 312     Standard            233.79                 34.456272
# ...          ...               ...                       ...
# 99717       Good             82.15                 25.363971
# 99769   Standard           1095.15                 35.864367
# 99789       Good            547.21                 32.224773
# 99800        Bad           3699.44                 23.574545
# 99872       Good            995.47                 36.238303
#
#        Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 173                 10.60                   Yes            37.588073
# 193                 12.30                   Yes           200.432613
# 198                 12.80                   Yes           200.432613
# 234                  8.10                   Yes           172.382527
# 312                 24.30                    No         37602.000000
# ...                   ...                   ...                  ...
# 99717               23.40                    No           113.833391
# 99769               15.30                   Yes           187.008683
# 99789               16.60                    No           196.528591
# 99800               13.20                   Yes            50.960878
# 99872               29.11                    No         38424.000000
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 173                  73.899861    Low_spent_Small_value_payments
# 193                 193.873375  High_spent_Medium_value_payments
# 198                 234.732040   Low_spent_Medium_value_payments
# 234                 198.042123   High_spent_Small_value_payments
# 312                 251.647422    Low_spent_Small_value_payments
# ...                        ...                               ...
# 99717               131.207947   Low_spent_Medium_value_payments
# 99769               241.313632    Low_spent_Large_value_payments
# 99789                      NaN   High_spent_Large_value_payments
# 99800                97.586933    Low_spent_Small_value_payments
# 99872                      NaN   High_spent_Large_value_payments
#
#        Monthly_Balance Credit_Score  Num_of_loan2
# 173         285.970524         Poor           5.0
# 193         327.786678     Standard           8.0
# 198         316.928013     Standard           8.0
# 234         190.321516         Poor           6.0
# 312         518.190884     Standard           2.0
# ...                ...          ...           ...
# 99717              NaN     Standard           4.0
# 99769              NaN     Standard           7.0
# 99789              NaN         Good           3.0
# 99800              NaN     Standard           7.0
# 99872              NaN         Good           4.0
#
# [1640 rows x 23 columns]

# %%
df.Num_Credit_Inquiries[df.Num_Credit_Inquiries > 17] = np.nan
#now we have fixed garbage values and will impute them later with knn

# %%
##Now we will fix Outstanding Debt
df[df.Outstanding_Debt < 0]
# Out:
# Empty DataFrame
# Columns: [Customer_ID, Month, Age, Occupation, Annual_Income, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score, Num_of_loan2]
# Index: []

# %%
df.Outstanding_Debt.value_counts()
# Out:
# 1151.70    24
# 1109.03    24
# 460.46     24
# 1360.45    24
# 217.92     16
#            ..
# 39.68       6
# 80.09       6
# 936.59      5
# 581.67      5
# 1041.07     5
# Name: Outstanding_Debt, Length: 12203, dtype: int64

# %%
df.Outstanding_Debt.min()
# Out:
# 0.23

# %%
df.Outstanding_Debt.max()
#this column is fine and we will proceed
# Out:
# 4998.07

# %%
#now we will work on Credit_Utilization_Ratio

df[df.Credit_Utilization_Ratio < 0]
# Out:
# Empty DataFrame
# Columns: [Customer_ID, Month, Age, Occupation, Annual_Income, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score, Num_of_loan2]
# Index: []

# %%
df.Credit_Utilization_Ratio.value_counts()
# Out:
# 26.822620    1
# 31.921515    1
# 36.526143    1
# 33.109420    1
# 37.089624    1
#             ..
# 35.914328    1
# 25.815759    1
# 27.490871    1
# 24.987371    1
# 34.192463    1
# Name: Credit_Utilization_Ratio, Length: 99522, dtype: int64

# %%
df.Credit_Utilization_Ratio.min()
# Out:
# 20.0

# %%
df.Credit_Utilization_Ratio.max()
#this is fine and we will proceed further
# Out:
# 50.00000000000001

# %%
# now we will work on Credit_History_Age

df[df.Credit_History_Age < 0]
# Out:
# Empty DataFrame
# Columns: [Customer_ID, Month, Age, Occupation, Annual_Income, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score, Num_of_loan2]
# Index: []

# %%
df.Credit_History_Age.value_counts()
# Out:
# 18.1    769
# 17.1    766
# 19.1    747
# 16.1    736
# 15.1    602
#        ...
# 0.4      35
# 0.3      20
# 0.2      15
# 33.7     14
# 33.8     12
# Name: Credit_History_Age, Length: 371, dtype: int64

# %%
df.Credit_History_Age.min()
# Out:
# 0.1

# %%
df.Credit_History_Age.max()
#this is fine and we will proceed furter
# Out:
# 33.8

# %%
#now we will work on Total_EMI_per_month

df[df.Total_EMI_per_month < 0]
# Out:
# Empty DataFrame
# Columns: [Customer_ID, Month, Age, Occupation, Annual_Income, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score, Num_of_loan2]
# Index: []

# %%
df.Total_EMI_per_month.value_counts()
# Out:
# 0.000000        10169
# 49.574949           8
# 64.008959           8
# 69.020960           8
# 250.408881          8
#                 ...
# 22898.000000        1
# 65311.000000        1
# 79218.000000        1
# 18859.000000        1
# 58638.000000        1
# Name: Total_EMI_per_month, Length: 14938, dtype: int64

# %%
df.Total_EMI_per_month.min()
# Out:
# 0.0

# %%
df.Total_EMI_per_month.max()
# Out:
# 82331.0

# %%
df[df.Total_EMI_per_month > 58638.000000]
# Out:
#       Customer_ID    Month   Age     Occupation  Annual_Income  \
# 94     CUS_0xc0ab     July  33.0       Engineer       88640.24
# 307    CUS_0x42ac    April  37.0       Musician       15566.02
# 359    CUS_0xaedb   August  19.0       Musician       85554.03
# 440    CUS_0x4315  January  22.0   Entrepreneur       36822.29
# 548    CUS_0x74f2      May  30.0      Architect       30390.44
# ...           ...      ...   ...            ...            ...
# 99485  CUS_0x862b     June  44.0        Manager      145282.24
# 99605  CUS_0x5d6d     June  38.0         Writer      126514.72
# 99903  CUS_0x4986   August  34.0   Entrepreneur       41329.56
# 99908  CUS_0xa053      May  39.0         Writer       87695.34
# 99970   CUS_0xf16    March  44.0  Media_Manager       16680.35
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 94                   3.0              6.0            1.0                    4
# 307                  8.0              5.0           32.0                   17
# 359                  4.0              2.0            3.0                   12
# 440                  8.0              7.0            6.0                   14
# 548                  5.0              6.0            5.0                   15
# ...                  ...              ...            ...                  ...
# 99485                5.0              7.0           10.0                   30
# 99605                8.0              7.0            5.0                   21
# 99903                2.0              3.0            7.0                    2
# 99908                2.0              7.0            7.0                    5
# 99970                1.0              1.0            5.0                    1
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 94                        2.0                  3.51                   3.0
# 307                      20.0                  9.24                   NaN
# 359                       7.0                  6.43                   3.0
# 440                      19.0                  5.79                   4.0
# 548                      18.0                  8.36                   4.0
# ...                       ...                   ...                   ...
# 99485                    13.0                  1.55                   4.0
# 99605                    19.0                 10.64                   0.0
# 99903                    10.0                  6.66                   2.0
# 99908                    10.0                  6.52                   6.0
# 99970                     0.0                  5.69                   8.0
#
#       Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 94          Good            950.36                 25.979173
# 307     Standard           1693.95                 25.038052
# 359         Good           1095.73                 41.513288
# 440     Standard            125.25                 26.612872
# 548     Standard            580.31                 38.001565
# ...          ...               ...                       ...
# 99485       Good           1417.24                 35.210768
# 99605   Standard            470.42                 29.696182
# 99903       Good           1245.01                 39.866030
# 99908       Good            361.68                 28.147193
# 99970       Good            897.16                 30.472041
#
#        Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 94                  25.11                    No              80357.0
# 307                  8.10                   Yes              62073.0
# 359                   NaN                    No              81050.0
# 440                   NaN                    No              81441.0
# 548                 24.70                    No              64504.0
# ...                   ...                   ...                  ...
# 99485               23.70                    No              79861.0
# 99605               29.70                    No              61447.0
# 99903               23.10                    No              81751.0
# 99908               19.50                    No              65671.0
# 99970               21.30                    No              75011.0
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 94                  164.074822   High_spent_Large_value_payments
# 307                  94.299317    Low_spent_Small_value_payments
# 359                  78.798183   High_spent_Large_value_payments
# 440                 121.408376    Low_spent_Small_value_payments
# 548                 169.876374    Low_spent_Large_value_payments
# ...                        ...                               ...
# 99485               252.587910  High_spent_Medium_value_payments
# 99605               902.340388    Low_spent_Small_value_payments
# 99903                92.127237  High_spent_Medium_value_payments
# 99908               168.798784   High_spent_Large_value_payments
# 99970                75.504972   Low_spent_Medium_value_payments
#
#        Monthly_Balance Credit_Score  Num_of_loan2
# 94          667.420474         Good           2.0
# 307         294.946997     Standard           4.0
# 359         879.752067         Good           0.0
# 440         386.043328     Standard           4.0
# 548         307.429254     Standard           4.0
# ...                ...          ...           ...
# 99485              NaN         Poor           1.0
# 99605              NaN         Good           3.0
# 99903              NaN         Good           1.0
# 99908              NaN     Standard           0.0
# 99970              NaN         Good           4.0
#
# [885 rows x 23 columns]

# %%
df[df.Customer_ID == 'CUS_0x942c']
# Out:
#       Customer_ID     Month   Age Occupation  Annual_Income  \
# 99992  CUS_0x942c   January  24.0   Mechanic       39628.99
# 99993  CUS_0x942c  February  25.0   Mechanic       39628.99
# 99994  CUS_0x942c     March  25.0   Mechanic       39628.99
# 99995  CUS_0x942c     April  25.0   Mechanic       39628.99
# 99996  CUS_0x942c       May  25.0   Mechanic       39628.99
# 99997  CUS_0x942c      June  25.0   Mechanic       39628.99
# 99998  CUS_0x942c      July  25.0   Mechanic       39628.99
# 99999  CUS_0x942c    August  25.0   Mechanic       39628.99
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 99992                4.0              6.0            7.0                   23
# 99993                4.0              6.0            7.0                   23
# 99994                4.0              6.0            7.0                   20
# 99995                4.0              6.0            7.0                   23
# 99996                4.0              6.0            7.0                   18
# 99997                4.0              6.0            7.0                   27
# 99998                4.0              6.0            7.0                   20
# 99999                4.0              6.0            7.0                   18
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 99992                     NaN                   9.5                   3.0
# 99993                     NaN                  11.5                   3.0
# 99994                     6.0                   9.5                   3.0
# 99995                     7.0                  11.5                   3.0
# 99996                     7.0                  11.5                   3.0
# 99997                     6.0                  11.5                   3.0
# 99998                     NaN                  11.5                   3.0
# 99999                     6.0                  11.5                   3.0
#
#       Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 99992       Good            502.38                 32.991333
# 99993       Good            502.38                 29.135447
# 99994       Good            502.38                 39.323569
# 99995       Good            502.38                 34.663572
# 99996       Good            502.38                 40.565631
# 99997       Good            502.38                 41.255522
# 99998       Good            502.38                 33.638208
# 99999       Good            502.38                 34.192463
#
#        Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 99992                31.3                    No            35.104023
# 99993                31.4                    No         58638.000000
# 99994                31.5                    No            35.104023
# 99995                31.6                    No            35.104023
# 99996                31.7                    No            35.104023
# 99997                31.8                    No            35.104023
# 99998                31.9                    No            35.104023
# 99999                31.1                    No            35.104023
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 99992               401.196481    Low_spent_Small_value_payments
# 99993               180.733095   Low_spent_Medium_value_payments
# 99994               140.581403  High_spent_Medium_value_payments
# 99995                60.971333   High_spent_Large_value_payments
# 99996                54.185950  High_spent_Medium_value_payments
# 99997                24.028477   High_spent_Large_value_payments
# 99998               251.672582    Low_spent_Large_value_payments
# 99999               167.163865   High_spent_Large_value_payments
#
#        Monthly_Balance Credit_Score  Num_of_loan2
# 99992              NaN         Poor           2.0
# 99993              NaN     Standard           2.0
# 99994              NaN         Poor           2.0
# 99995              NaN         Poor           2.0
# 99996              NaN         Poor           2.0
# 99997              NaN         Poor           2.0
# 99998              NaN     Standard           2.0
# 99999              NaN         Poor           2.0

# %%
df[df.Customer_ID == 'CUS_0xc0ab']
# Out:
#    Customer_ID     Month   Age Occupation  Annual_Income  Num_Bank_Accounts  \
# 88  CUS_0xc0ab   January  32.0   Engineer       88640.24                3.0
# 89  CUS_0xc0ab  February  33.0   Engineer       88640.24                3.0
# 90  CUS_0xc0ab     March  33.0   Engineer       88640.24                3.0
# 91  CUS_0xc0ab     April  33.0   Engineer       88640.24                3.0
# 92  CUS_0xc0ab       May  33.0   Engineer       88640.24                3.0
# 93  CUS_0xc0ab      June  33.0   Engineer       88640.24                3.0
# 94  CUS_0xc0ab      July  33.0   Engineer       88640.24                3.0
# 95  CUS_0xc0ab    August  33.0   Engineer       88640.24                3.0
#
#     Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 88              6.0            1.0                   -1
# 89              6.0            1.0                    4
# 90              6.0            1.0                    4
# 91              6.0            1.0                    4
# 92              6.0            1.0                    4
# 93              6.0            1.0                    4
# 94              6.0            1.0                    4
# 95              6.0            1.0                   -1
#
#     Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 88                     0.0                  3.51                   3.0
# 89                     2.0                  3.51                   3.0
# 90                     0.0                  3.51                   3.0
# 91                     2.0                  3.51                   3.0
# 92                     2.0                  3.51                   3.0
# 93                     0.0                  3.51                   3.0
# 94                     2.0                  3.51                   3.0
# 95                     NaN                  3.51                   3.0
#
#    Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 88       Good            950.36                 28.210617               25.50
# 89       Good            950.36                 41.036168               25.60
# 90       Good            950.36                 34.670194               25.70
# 91       Good            950.36                 31.828536               25.80
# 92       Good            950.36                 34.702837               25.90
# 93       Good            950.36                 38.323639               25.10
# 94       Good            950.36                 25.979173               25.11
# 95       Good            950.36                 30.870799               26.00
#
#    Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 88                    No           135.173371                98.931764
# 89                    NM           135.173371               157.174788
# 90                    No           135.173371               298.188911
# 91                    No           135.173371                      NaN
# 92                    No           135.173371               279.618622
# 93                    No           135.173371               686.126217
# 94                    No         80357.000000               164.074822
# 95                    No           135.173371                98.441951
#
#                    Payment_Behaviour  Monthly_Balance Credit_Score  \
# 88   High_spent_Large_value_payments       732.563532     Standard
# 89   High_spent_Large_value_payments       674.320507         Good
# 90  High_spent_Medium_value_payments       543.306384     Standard
# 91    Low_spent_Small_value_payments        86.636120     Standard
# 92  High_spent_Medium_value_payments       561.876674         Good
# 93    Low_spent_Small_value_payments       195.369079         Good
# 94   High_spent_Large_value_payments       667.420474         Good
# 95   High_spent_Large_value_payments       733.053344         Good
#
#     Num_of_loan2
# 88           2.0
# 89           2.0
# 90           2.0
# 91           2.0
# 92           2.0
# 93           2.0
# 94           2.0
# 95           2.0

# %%
df[df.Customer_ID == 'CUS_0x5d6d']
# Out:
#       Customer_ID     Month   Age Occupation  Annual_Income  \
# 99600  CUS_0x5d6d   January  38.0     Writer      126514.72
# 99601  CUS_0x5d6d  February  38.0     Writer      126514.72
# 99602  CUS_0x5d6d     March  38.0     Writer      126514.72
# 99603  CUS_0x5d6d     April  38.0     Writer      126514.72
# 99604  CUS_0x5d6d       May  38.0     Writer      126514.72
# 99605  CUS_0x5d6d      June  38.0     Writer      126514.72
# 99606  CUS_0x5d6d      July  38.0     Writer      126514.72
# 99607  CUS_0x5d6d    August  39.0     Writer      126514.72
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 99600                8.0              7.0            5.0                   21
# 99601                8.0              7.0            5.0                   21
# 99602                8.0              7.0            5.0                   26
# 99603                8.0              7.0            5.0                   21
# 99604                8.0              7.0            5.0                   21
# 99605                8.0              7.0            5.0                   21
# 99606                8.0              7.0            5.0                   21
# 99607                8.0              7.0            5.0                   16
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 99600                     NaN                 10.64                   0.0
# 99601                    18.0                 10.64                   0.0
# 99602                    21.0                 17.64                   0.0
# 99603                    19.0                 10.64                   NaN
# 99604                    18.0                 10.64                   0.0
# 99605                    19.0                 10.64                   0.0
# 99606                    17.0                 10.64                   0.0
# 99607                    18.0                 10.64                   2.0
#
#       Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 99600   Standard            470.42                 39.388005
# 99601   Standard            470.42                 31.521136
# 99602   Standard            470.42                 38.404222
# 99603   Standard            470.42                 40.446888
# 99604   Standard            470.42                 24.720156
# 99605   Standard            470.42                 29.696182
# 99606   Standard            470.42                 35.433181
# 99607   Standard            470.42                 27.048564
#
#        Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 99600                 NaN                    No           312.032853
# 99601                29.3                    No           312.032853
# 99602                29.4                    No           312.032853
# 99603                29.5                    No           312.032853
# 99604                29.6                    No           312.032853
# 99605                29.7                    No         61447.000000
# 99606                29.8                    No           312.032853
# 99607                 NaN                    No           312.032853
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 99600               267.774185    Low_spent_Small_value_payments
# 99601               232.074065   High_spent_Small_value_payments
# 99602               105.667799    Low_spent_Small_value_payments
# 99603               314.042671  High_spent_Medium_value_payments
# 99604               804.418057    Low_spent_Small_value_payments
# 99605               902.340388    Low_spent_Small_value_payments
# 99606               130.270479  High_spent_Medium_value_payments
# 99607               416.269711    Low_spent_Small_value_payments
#
#        Monthly_Balance Credit_Score  Num_of_loan2
# 99600              NaN     Standard           3.0
# 99601              NaN     Standard           3.0
# 99602              NaN     Standard           3.0
# 99603              NaN         Good           3.0
# 99604              NaN         Good           3.0
# 99605              NaN         Good           3.0
# 99606              NaN     Standard           3.0
# 99607              NaN     Standard           3.0

# %%
df[df.Total_EMI_per_month > 1000]
# Out:
#       Customer_ID     Month   Age     Occupation  Annual_Income  \
# 40     CUS_0x95ee   January  31.0         Lawyer       73928.46
# 45     CUS_0x95ee      June  31.0         Lawyer       73928.46
# 51     CUS_0x284a     April  34.0         Lawyer      131313.40
# 52     CUS_0x284a       May  34.0         Lawyer      131313.40
# 76     CUS_0xba08       May  44.0     Journalist       31370.80
# ...           ...       ...   ...            ...            ...
# 99921  CUS_0x2654  February  38.0  Media_Manager      139664.96
# 99960  CUS_0x372c   January  18.0         Lawyer       42903.79
# 99970   CUS_0xf16     March  44.0  Media_Manager       16680.35
# 99985  CUS_0x8600  February  28.0      Architect       20002.88
# 99993  CUS_0x942c  February  25.0       Mechanic       39628.99
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 40                   4.0              5.0            8.0                   12
# 45                   4.0              5.0            8.0                    7
# 51                   0.0              1.0            8.0                    0
# 52                   0.0              1.0            8.0                    0
# 76                   1.0              6.0           12.0                    1
# ...                  ...              ...            ...                  ...
# 99921                3.0              6.0           12.0                   14
# 99960                0.0              4.0            6.0                   14
# 99970                1.0              1.0            5.0                    1
# 99985               10.0              8.0           29.0                   33
# 99993                4.0              6.0            7.0                   23
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 40                       10.0                 10.14                   2.0
# 45                        7.0                 10.14                   2.0
# 51                        2.0                  8.34                   4.0
# 52                        4.0                  9.34                   4.0
# 76                        0.0                  5.76                   5.0
# ...                       ...                   ...                   ...
# 99921                    12.0                 12.39                   8.0
# 99960                     0.0                  4.10                   1.0
# 99970                     0.0                  5.69                   8.0
# 99985                    25.0                 23.31                   9.0
# 99993                     NaN                 11.50                   3.0
#
#       Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 40          Good            548.20                 39.962685
# 45          Good            548.20                 35.275437
# 51          Good            352.16                 42.645785
# 52          Good            352.16                 40.902517
# 76          Good            421.43                 25.189232
# ...          ...               ...                       ...
# 99921   Standard            365.66                 40.171095
# 99960       Good           1079.48                 27.289440
# 99970       Good            897.16                 30.472041
# 99985        Bad           3571.70                 39.772607
# 99993       Good            502.38                 29.135447
#
#        Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 40                    NaN                    No              15015.0
# 45                    NaN                    No              15515.0
# 51                  30.10                    No              23834.0
# 52                  30.11                    No              32662.0
# 76                  26.90                    No              16415.0
# ...                   ...                   ...                  ...
# 99921               29.80                   Yes              20563.0
# 99960               28.10                    No              50894.0
# 99970               21.30                    No              75011.0
# 99985                5.90                   Yes              12112.0
# 99993               31.40                    No              58638.0
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 40                   98.674410   High_spent_Large_value_payments
# 45                  235.790325    Low_spent_Large_value_payments
# 51                  337.434956  High_spent_Medium_value_payments
# 52                  263.378909   High_spent_Large_value_payments
# 76                  184.700572    Low_spent_Small_value_payments
# ...                        ...                               ...
# 99921               421.318866  High_spent_Medium_value_payments
# 99960                78.514945   High_spent_Small_value_payments
# 99970                75.504972   Low_spent_Medium_value_payments
# 99985               148.275233    Low_spent_Small_value_payments
# 99993               180.733095   Low_spent_Medium_value_payments
#
#        Monthly_Balance Credit_Score  Num_of_loan2
# 40          740.196090         Good           0.0
# 45          633.080175         Good           0.0
# 51          899.198772         Good           2.0
# 52          963.254819         Good           2.0
# 76          341.206633         Good           2.0
# ...                ...          ...           ...
# 99921              NaN     Standard           4.0
# 99960              NaN         Good           1.0
# 99970              NaN         Good           4.0
# 99985              NaN         Poor           5.0
# 99993              NaN     Standard           2.0
#
# [3396 rows x 23 columns]

# %%
df[df.Customer_ID == 'CUS_0x95ee']
# Out:
#    Customer_ID     Month   Age Occupation  Annual_Income  Num_Bank_Accounts  \
# 40  CUS_0x95ee   January  31.0     Lawyer       73928.46                4.0
# 41  CUS_0x95ee  February  31.0     Lawyer       73928.46                4.0
# 42  CUS_0x95ee     March  31.0     Lawyer       73928.46                4.0
# 43  CUS_0x95ee     April  31.0     Lawyer       73928.46                4.0
# 44  CUS_0x95ee       May  31.0     Lawyer       73928.46                4.0
# 45  CUS_0x95ee      June  31.0     Lawyer       73928.46                4.0
# 46  CUS_0x95ee      July  31.0     Lawyer       73928.46                4.0
# 47  CUS_0x95ee    August  31.0     Lawyer       73928.46                4.0
#
#     Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 40              5.0            8.0                   12
# 41              5.0            8.0                    8
# 42              5.0            8.0                    8
# 43              5.0            8.0                    8
# 44              5.0            8.0                   11
# 45              5.0            8.0                    7
# 46              5.0            8.0                    8
# 47              5.0            8.0                    8
#
#     Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 40                    10.0                 10.14                   2.0
# 41                     7.0                 10.14                   2.0
# 42                     7.0                 10.14                   2.0
# 43                     7.0                 10.14                   2.0
# 44                     7.0                 10.14                   2.0
# 45                     7.0                 10.14                   2.0
# 46                     4.0                  9.14                   2.0
# 47                     7.0                 10.14                   NaN
#
#    Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 40       Good             548.2                 39.962685                 NaN
# 41       Good             548.2                 42.769864                32.0
# 42       Good             548.2                 40.712187                 NaN
# 43       Good             548.2                 30.201658                32.2
# 44       Good             548.2                 26.333310                32.3
# 45       Good             548.2                 35.275437                 NaN
# 46       Good             548.2                 36.624791                32.5
# 47       Good             548.2                 31.580990                32.6
#
#    Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 40                    No              15015.0                98.674410
# 41                    NM                  0.0               172.939214
# 42                    No                  0.0               150.059734
# 43                    No                  0.0               618.202391
# 44                    No                  0.0               177.951836
# 45                    No              15515.0               235.790325
# 46                    No                  0.0               348.509400
# 47                    No                  0.0                42.635590
#
#                    Payment_Behaviour  Monthly_Balance Credit_Score  \
# 40   High_spent_Large_value_payments       740.196090         Good
# 41   Low_spent_Medium_value_payments       705.931286         Good
# 42  High_spent_Medium_value_payments       698.810766         Good
# 43    Low_spent_Small_value_payments       270.668109         Good
# 44    Low_spent_Large_value_payments       690.918664         Good
# 45    Low_spent_Large_value_payments       633.080175         Good
# 46   High_spent_Small_value_payments       510.361100     Standard
# 47    Low_spent_Large_value_payments       796.234910         Good
#
#     Num_of_loan2
# 40           0.0
# 41           0.0
# 42           0.0
# 43           0.0
# 44           0.0
# 45           0.0
# 46           0.0
# 47           0.0

# %%
df[df.Customer_ID == 'CUS_0x284a']

###do later
# Out:
#    Customer_ID     Month   Age Occupation  Annual_Income  Num_Bank_Accounts  \
# 48  CUS_0x284a   January  33.0     Lawyer       131313.4                0.0
# 49  CUS_0x284a  February  34.0     Lawyer       131313.4                0.0
# 50  CUS_0x284a     March  34.0     Lawyer       131313.4                0.0
# 51  CUS_0x284a     April  34.0     Lawyer       131313.4                0.0
# 52  CUS_0x284a       May  34.0     Lawyer       131313.4                0.0
# 53  CUS_0x284a      June  34.0     Lawyer       131313.4                0.0
# 54  CUS_0x284a      July  34.0     Lawyer     10909427.0                0.0
# 55  CUS_0x284a    August  34.0     Lawyer       131313.4                0.0
#
#     Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 48              1.0            8.0                    0
# 49              1.0            8.0                   -1
# 50              1.0            8.0                    0
# 51              1.0            8.0                    0
# 52              1.0            8.0                    0
# 53              1.0            8.0                    0
# 54              1.0            8.0                    0
# 55              1.0            8.0                    0
#
#     Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 48                     3.0                  9.34                   2.0
# 49                     2.0                 15.34                   4.0
# 50                     3.0                  9.34                   4.0
# 51                     2.0                  8.34                   4.0
# 52                     4.0                  9.34                   4.0
# 53                     3.0                 11.34                   4.0
# 54                     2.0                  9.34                   4.0
# 55                     2.0                  9.34                   4.0
#
#    Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 48       Good            352.16                 32.200509               30.70
# 49       Good            352.16                 31.983710               30.80
# 50       Good            352.16                 31.803134               30.90
# 51       Good            352.16                 42.645785               30.10
# 52       Good            352.16                 40.902517               30.11
# 53       Good            352.16                 41.980170               31.00
# 54       Good            352.16                 26.947565               31.10
# 55       Good            352.16                 29.187913               31.20
#
#    Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 48                    NM           137.644605               378.171254
# 49                    No           137.644605               698.873271
# 50                    NM           911.220179               188.064321
# 51                    No         23834.000000               337.434956
# 52                    No         32662.000000               263.378909
# 53                    No           911.220179                86.566388
# 54                    No           911.220179               930.391898
# 55                    No           911.220179               870.522382
#
#                    Payment_Behaviour  Monthly_Balance Credit_Score  \
# 48  High_spent_Medium_value_payments       858.462474         Good
# 49   High_spent_Small_value_payments       547.760457         Good
# 50   High_spent_Large_value_payments      1038.569407         Good
# 51  High_spent_Medium_value_payments       899.198772         Good
# 52   High_spent_Large_value_payments       963.254819         Good
# 53   High_spent_Large_value_payments      1140.067340     Standard
# 54   High_spent_Large_value_payments       326.241830         Good
# 55   Low_spent_Medium_value_payments       396.111346         Good
#
#     Num_of_loan2
# 48           2.0
# 49           2.0
# 50           2.0
# 51           2.0
# 52           2.0
# 53           2.0
# 54           2.0
# 55           2.0

# %%
#now we will fix amount inversted monthly
df[df.Amount_invested_monthly < 0]
# Out:
# Empty DataFrame
# Columns: [Customer_ID, Month, Age, Occupation, Annual_Income, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score, Num_of_loan2]
# Index: []

# %%
df.Amount_invested_monthly.value_counts()
# Out:
# 10000.000000    4296
# 0.000000         169
# 80.415295          1
# 81.773408          1
# 195.593832         1
#                 ...
# 33.609881          1
# 76.870010          1
# 908.693910         1
# 458.552411         1
# 167.163865         1
# Name: Amount_invested_monthly, Length: 90608, dtype: int64

# %%
df.Amount_invested_monthly.max()
# Out:
# 10000.0

# %%
df.Amount_invested_monthly.min()
# Out:
# 0.0

# %%
df[df.Amount_invested_monthly == 10000]
# Out:
#       Customer_ID     Month   Age     Occupation  Annual_Income  \
# 18     CUS_0x2dbc     March  34.0       Engineer      143162.64
# 23     CUS_0x2dbc    August  34.0       Engineer      143162.64
# 28     CUS_0xb891       May  55.0   Entrepreneur       30689.89
# 121    CUS_0x33d2  February  30.0      Scientist       31993.78
# 142     CUS_0xfdb      July  46.0        Teacher       32284.62
# ...           ...       ...   ...            ...            ...
# 99879  CUS_0x3855    August  27.0      Scientist      118677.54
# 99882  CUS_0x47fa     March  31.0       Mechanic    16884797.00
# 99919  CUS_0x1619    August  54.0  Media_Manager       20059.98
# 99951  CUS_0x51b3    August  33.0  Media_Manager       59146.36
# 99973   CUS_0xf16      June  44.0  Media_Manager       16680.35
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 18                   1.0              5.0            8.0                    8
# 23                   1.0              5.0            8.0                    8
# 28                   2.0              5.0            4.0                    5
# 121                  6.0              6.0            7.0                   12
# 142                  6.0              7.0           17.0                    7
# ...                  ...              ...            ...                  ...
# 99879                4.0              4.0            6.0                    3
# 99882                7.0              3.0           15.0                    7
# 99919                8.0              5.0           12.0                   25
# 99951                3.0              6.0            6.0                    8
# 99973                1.0              1.0            5.0                    1
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 18                        7.0                 11.10                   NaN
# 23                        6.0                  7.10                   3.0
# 28                        6.0                 -1.01                   4.0
# 121                      14.0                  6.28                   0.0
# 142                       NaN                  9.22                  10.0
# ...                       ...                   ...                   ...
# 99879                    11.0                  9.59                   5.0
# 99882                     8.0                 12.57                   2.0
# 99919                    11.0                  2.97                   8.0
# 99951                     6.0                  6.68                   5.0
# 99973                     NaN                  0.69                   8.0
#
#       Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 18          Good           1303.01                 26.519815
# 23          Good           1303.01                 38.374753
# 28          Good            632.46                 41.154317
# 121     Standard            818.22                 37.958569
# 142     Standard           1283.37                 24.205533
# ...          ...               ...                       ...
# 99879       Good            995.47                 39.747228
# 99882   Standard            330.60                 38.524095
# 99919       Good            909.01                 32.473773
# 99951       Good            418.03                 27.682186
# 99973       Good            897.16                 24.972853
#
#        Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 18                  17.11                    No           246.992319
# 23                  18.40                    No           246.992319
# 28                  17.70                    No            16.415452
# 121                 16.11                   Yes            45.141298
# 142                  6.11                   Yes           103.037560
# ...                   ...                   ...                  ...
# 99879               30.60                    No           237.106366
# 99882               23.00                   Yes             0.000000
# 99919               16.10                    No            45.076827
# 99951               20.80                    No            26.778419
# 99973               21.60                    No            41.113561
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 18                     10000.0   High_spent_Small_value_payments
# 23                     10000.0   High_spent_Small_value_payments
# 28                     10000.0    Low_spent_Large_value_payments
# 121                    10000.0    Low_spent_Small_value_payments
# 142                    10000.0    Low_spent_Small_value_payments
# ...                        ...                               ...
# 99879                  10000.0  High_spent_Medium_value_payments
# 99882                  10000.0   High_spent_Small_value_payments
# 99919                  10000.0    Low_spent_Small_value_payments
# 99951                  10000.0    Low_spent_Large_value_payments
# 99973                  10000.0    Low_spent_Small_value_payments
#
#        Monthly_Balance Credit_Score  Num_of_loan2
# 18          715.741367         Good           3.0
# 23          895.494583     Standard           3.0
# 28          359.374916     Standard           1.0
# 121         157.869804     Standard           2.0
# 142          85.902095     Standard           6.0
# ...                ...          ...           ...
# 99879              NaN         Good           4.0
# 99882              NaN     Standard           0.0
# 99919              NaN         Poor           4.0
# 99951              NaN     Standard           1.0
# 99973              NaN         Good           4.0
#
# [4296 rows x 23 columns]

# %%
df[df.Customer_ID == 'CUS_0x33d2']
# Out:
#     Customer_ID     Month   Age Occupation  Annual_Income  Num_Bank_Accounts  \
# 120  CUS_0x33d2   January  30.0  Scientist       31993.78                6.0
# 121  CUS_0x33d2  February  30.0  Scientist       31993.78                6.0
# 122  CUS_0x33d2     March  30.0  Scientist       31993.78                6.0
# 123  CUS_0x33d2     April  30.0  Scientist       31993.78                6.0
# 124  CUS_0x33d2       May  30.0  Scientist       31993.78                6.0
# 125  CUS_0x33d2      June  30.0  Scientist       31993.78                6.0
# 126  CUS_0x33d2      July  30.0  Scientist       31993.78                6.0
# 127  CUS_0x33d2    August  30.0  Scientist       31993.78                6.0
#
#      Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 120              6.0            7.0                    8
# 121              6.0            7.0                   12
# 122              6.0            7.0                    8
# 123              6.0            7.0                    8
# 124              6.0            7.0                    8
# 125              6.0            7.0                    8
# 126              6.0            7.0                    8
# 127              6.0            7.0                    8
#
#      Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 120                    14.0                  6.28                   0.0
# 121                    14.0                  6.28                   0.0
# 122                    14.0                 10.28                   1.0
# 123                    14.0                  6.28                   1.0
# 124                    14.0                  6.28                   1.0
# 125                    14.0                  6.28                   1.0
# 126                    16.0                  6.28                   1.0
# 127                    16.0                  6.28                   1.0
#
#     Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 120   Standard            818.22                 25.369597
# 121   Standard            818.22                 37.958569
# 122   Standard            818.22                 27.380109
# 123   Standard            818.22                 34.158262
# 124   Standard            818.22                 30.788039
# 125   Standard            818.22                 34.280969
# 126   Standard            818.22                 29.503454
# 127   Standard            818.22                 36.012794
#
#      Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 120               16.10                   Yes            45.141298
# 121               16.11                   Yes            45.141298
# 122               17.00                   Yes            45.141298
# 123               17.10                   Yes            45.141298
# 124               17.20                   Yes            45.141298
# 125               17.30                   Yes            45.141298
# 126               17.40                   Yes            45.141298
# 127               17.50                   Yes            45.141298
#
#      Amount_invested_monthly                 Payment_Behaviour  \
# 120                81.998835   Low_spent_Medium_value_payments
# 121             10000.000000    Low_spent_Small_value_payments
# 122               264.257089    Low_spent_Small_value_payments
# 123               152.452326   Low_spent_Medium_value_payments
# 124                43.470409  High_spent_Medium_value_payments
# 125               112.723887   High_spent_Small_value_payments
# 126               104.557236   High_spent_Small_value_payments
# 127                97.588203    Low_spent_Large_value_payments
#
#      Monthly_Balance Credit_Score  Num_of_loan2
# 120       447.074700     Standard           2.0
# 121       157.869804     Standard           2.0
# 122       274.816447     Standard           2.0
# 123       376.621209     Standard           2.0
# 124       455.603126     Standard           2.0
# 125       396.349648     Standard           2.0
# 126       404.516299     Standard           2.0
# 127       421.485332     Standard           2.0

# %%
df[df.Customer_ID == 'CUS_0x1619']
#it look's and we will procceed further
# Out:
#       Customer_ID     Month   Age     Occupation  Annual_Income  \
# 99912  CUS_0x1619   January  54.0  Media_Manager       20059.98
# 99913  CUS_0x1619  February  54.0  Media_Manager       20059.98
# 99914  CUS_0x1619     March  54.0  Media_Manager       20059.98
# 99915  CUS_0x1619     April  54.0  Media_Manager       20059.98
# 99916  CUS_0x1619       May  54.0  Media_Manager       20059.98
# 99917  CUS_0x1619      June  54.0  Media_Manager       20059.98
# 99918  CUS_0x1619      July  54.0  Media_Manager       20059.98
# 99919  CUS_0x1619    August  54.0  Media_Manager       20059.98
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 99912                8.0              5.0           12.0                   25
# 99913                8.0              5.0           12.0                   25
# 99914                8.0              5.0           12.0                   25
# 99915                8.0              5.0           12.0                   25
# 99916                8.0              5.0           12.0                   25
# 99917                8.0              5.0           12.0                   23
# 99918                8.0              5.0           12.0                   25
# 99919                8.0              5.0           12.0                   25
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 99912                    11.0                  2.97                   3.0
# 99913                    11.0                  2.97                   3.0
# 99914                     9.0                  2.97                   3.0
# 99915                    11.0                  2.97                   3.0
# 99916                    11.0                  2.97                   3.0
# 99917                    11.0                  2.97                   8.0
# 99918                     8.0                  2.97                   8.0
# 99919                    11.0                  2.97                   8.0
#
#       Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 99912       Good            909.01                 30.568185
# 99913       Good            909.01                 25.982154
# 99914       Good            909.01                 29.204711
# 99915       Good            909.01                 27.341526
# 99916       Good            909.01                 29.808796
# 99917       Good            909.01                 34.413070
# 99918       Good            909.01                 37.619516
# 99919       Good            909.01                 32.473773
#
#        Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 99912                16.3                    No          6980.000000
# 99913                16.4                    No            45.076827
# 99914                16.5                    No            45.076827
# 99915                 NaN                    No            45.076827
# 99916                 NaN                    NM            45.076827
# 99917                16.8                    No            45.076827
# 99918                16.9                    No            45.076827
# 99919                16.1                    No            45.076827
#
#        Amount_invested_monthly                Payment_Behaviour  \
# 99912               151.214086  Low_spent_Medium_value_payments
# 99913                74.713580  High_spent_Small_value_payments
# 99914               111.567139   Low_spent_Large_value_payments
# 99915                83.694307   Low_spent_Small_value_payments
# 99916                49.712994  Low_spent_Medium_value_payments
# 99917               118.116365   Low_spent_Small_value_payments
# 99918                72.166230   Low_spent_Small_value_payments
# 99919             10000.000000   Low_spent_Small_value_payments
#
#        Monthly_Balance Credit_Score  Num_of_loan2
# 99912              NaN         Poor           4.0
# 99913              NaN         Poor           4.0
# 99914              NaN         Poor           4.0
# 99915              NaN         Poor           4.0
# 99916              NaN         Poor           4.0
# 99917              NaN         Poor           4.0
# 99918              NaN         Poor           4.0
# 99919              NaN         Poor           4.0

# %%
##now we will work on Monthly_Balance

df.Monthly_Balance[df.Monthly_Balance < 0] = np.nan

# %%
df.Monthly_Balance.value_counts()
# Out:
# 312.494089    1
# 486.540234    1
# 251.473894    1
# 462.584060    1
# 427.282350    1
#              ..
# 246.551679    1
# 354.803619    1
# 258.404434    1
# 201.276174    1
# 214.614934    1
# Name: Monthly_Balance, Length: 96657, dtype: int64

# %%
df.Monthly_Balance.min()
# Out:
# 0.007759664775335295

# %%
df.Monthly_Balance.max()
#this is fine and we will proceed further
# Out:
# 1602.0405189622518

# %%
# now we will work on num of loan

# %%
df[df.Num_of_loan2 < 0]
# Out:
# Empty DataFrame
# Columns: [Customer_ID, Month, Age, Occupation, Annual_Income, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score, Num_of_loan2]
# Index: []

# %%
df.Num_of_loan2.value_counts()
#this is fine and we will proceed futher
# Out:
# 3.0    15752
# 2.0    15712
# 4.0    15456
# 1.0    11128
# 0.0    10930
# 6.0     8144
# 7.0     7680
# 5.0     7528
# 9.0     3856
# 8.0     3336
# Name: Num_of_loan2, dtype: int64

# %%
#now we will work on categorical columns

# %%
df.describe(include = object).T
# Out:
#                        count unique                             top   freq
# Customer_ID            99522  12500                       CUS_0xd40      8
# Month                  99522      8                            July  12451
# Occupation             99522     15                          Lawyer   7070
# Credit_Mix             99522      3                        Standard  45957
# Payment_of_Min_Amount  99522      3                             Yes  52203
# Payment_Behaviour      99522      6  Low_spent_Small_value_payments  29128
# Credit_Score           99522      3                        Standard  52891

# %%
#Customer id is unique and we will delete it later so no work on it

# %%
#now we will work on month

# %%
df.Month.value_counts()
#fine and no garbage values
# Out:
# July        12451
# February    12443
# April       12440
# May         12440
# June        12440
# August      12437
# January     12436
# March       12435
# Name: Month, dtype: int64

# %%
df.Occupation.value_counts()
#we already worked and fixed this so we will procedd
# Out:
# Lawyer           7070
# Engineer         6826
# Architect        6794
# Mechanic         6755
# Scientist        6714
# Accountant       6708
# Media_Manager    6689
# Developer        6680
# Teacher          6639
# Entrepreneur     6617
# Doctor           6548
# Journalist       6501
# Manager          6399
# Musician         6310
# Writer           6272
# Name: Occupation, dtype: int64

# %%
df.Credit_Mix.value_counts()
#we already worked and fixed this so we will procedd
# Out:
# Standard    45957
# Good        29960
# Bad         23605
# Name: Credit_Mix, dtype: int64

# %%
df.Payment_of_Min_Amount.value_counts(normalize= True)
# Out:
# Yes    0.524537
# No     0.355409
# NM     0.120054
# Name: Payment_of_Min_Amount, dtype: float64

# %%
df[df.Payment_of_Min_Amount == 'NM']
# Out:
#       Customer_ID     Month   Age     Occupation  Annual_Income  \
# 14     CUS_0x21b1      July  28.0        Teacher       34847.84
# 26     CUS_0xb891     March  55.0   Entrepreneur       30689.89
# 33     CUS_0x1cdb  February  21.0      Developer       35547.71
# 41     CUS_0x95ee  February  31.0         Lawyer       73928.46
# 48     CUS_0x284a   January  33.0         Lawyer      131313.40
# ...           ...       ...   ...            ...            ...
# 99939  CUS_0xad4f     April  47.0      Developer       22620.79
# 99949  CUS_0x51b3      June  33.0  Media_Manager       59146.36
# 99968   CUS_0xf16   January  44.0  Media_Manager       16680.35
# 99979  CUS_0xaf61     April  49.0         Writer       37188.10
# 99981  CUS_0xaf61      June  50.0         Writer       37188.10
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 14                   2.0              4.0            6.0                    3
# 26                   2.0              5.0            4.0                    3
# 33                   7.0              5.0            5.0                    9
# 41                   4.0              5.0            8.0                    8
# 48                   0.0              1.0            8.0                    0
# ...                  ...              ...            ...                  ...
# 99939                7.0              3.0            9.0                   27
# 99949                3.0              6.0            6.0                    6
# 99968                1.0              1.0            5.0                    4
# 99979                1.0              4.0            5.0                    3
# 99981                1.0              4.0            5.0                    5
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 14                        4.0                  5.42                   2.0
# 26                        9.0                  1.99                   4.0
# 33                        NaN                  2.58                   4.0
# 41                        7.0                 10.14                   2.0
# 48                        3.0                  9.34                   2.0
# ...                       ...                   ...                   ...
# 99939                    19.0                  5.31                   2.0
# 99949                     6.0                  6.68                   5.0
# 99968                     0.0                  5.69                   4.0
# 99979                    12.0                  5.38                   3.0
# 99981                    12.0                  5.38                   3.0
#
#       Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 14          Good            605.03                 31.131702
# 26          Good            632.46                 32.301163
# 33      Standard            943.86                 27.020360
# 41          Good            548.20                 42.769864
# 48          Good            352.16                 32.200509
# ...          ...               ...                       ...
# 99939   Standard            642.46                 26.730863
# 99949       Good            418.03                 24.975531
# 99968       Good            897.16                 39.868572
# 99979       Good            620.64                 36.979007
# 99981       Good            620.64                 37.753013
#
#        Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 14                   27.1                    NM            18.816215
# 26                   17.5                    NM            16.415452
# 33                   30.9                    NM             0.000000
# 41                   32.0                    NM             0.000000
# 48                   30.7                    NM           137.644605
# ...                   ...                   ...                  ...
# 99939                29.6                    NM             0.000000
# 99949                20.6                    NM            26.778419
# 99968                 NaN                    NM            41.113561
# 99979                30.0                    NM            84.205949
# 99981                30.2                    NM            84.205949
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 14                   70.101774  High_spent_Medium_value_payments
# 26                   83.406509  High_spent_Medium_value_payments
# 33                   74.443641  High_spent_Medium_value_payments
# 41                  172.939214   Low_spent_Medium_value_payments
# 48                  378.171254  High_spent_Medium_value_payments
# ...                        ...                               ...
# 99939               205.756074    Low_spent_Small_value_payments
# 99949                91.321664  High_spent_Medium_value_payments
# 99968                52.951978   High_spent_Small_value_payments
# 99979               215.486386    Low_spent_Small_value_payments
# 99981               147.339908    Low_spent_Small_value_payments
#
#        Monthly_Balance Credit_Score  Num_of_loan2
# 14          464.880678         Good           1.0
# 26          411.427123     Standard           1.0
# 33          460.887276     Standard           0.0
# 41          705.931286         Good           0.0
# 48          858.462474         Good           2.0
# ...                ...          ...           ...
# 99939              NaN         Poor           0.0
# 99949              NaN     Standard           1.0
# 99968              NaN         Good           4.0
# 99979              NaN         Good           3.0
# 99981              NaN         Good           3.0
#
# [11948 rows x 23 columns]

# %%
df[df.Customer_ID == 'CUS_0x21b1']
# Out:
#    Customer_ID     Month   Age Occupation  Annual_Income  Num_Bank_Accounts  \
# 8   CUS_0x21b1   January  28.0    Teacher       34847.84                2.0
# 9   CUS_0x21b1  February  28.0    Teacher       34847.84                2.0
# 10  CUS_0x21b1     March  28.0    Teacher       34847.84                2.0
# 11  CUS_0x21b1     April  28.0    Teacher       34847.84                2.0
# 12  CUS_0x21b1       May  28.0    Teacher       34847.84                2.0
# 13  CUS_0x21b1      June  28.0    Teacher       34847.84                2.0
# 14  CUS_0x21b1      July  28.0    Teacher       34847.84                2.0
# 15  CUS_0x21b1    August  28.0    Teacher       34847.84                2.0
#
#     Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 8               4.0            6.0                    3
# 9               4.0            6.0                    7
# 10              4.0            6.0                    3
# 11              4.0            6.0                    3
# 12              4.0            6.0                    3
# 13              4.0            6.0                    3
# 14              4.0            6.0                    3
# 15              4.0            6.0                    3
#
#     Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 8                      4.0                  5.42                   2.0
# 9                      1.0                  7.42                   2.0
# 10                    -1.0                  5.42                   2.0
# 11                     3.0                  5.42                   2.0
# 12                     1.0                  6.42                   2.0
# 13                     0.0                  5.42                   2.0
# 14                     4.0                  5.42                   2.0
# 15                     4.0                  5.42                   2.0
#
#    Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 8        Good            605.03                 24.464031               26.70
# 9        Good            605.03                 38.550848               26.80
# 10       Good            605.03                 33.224951               26.90
# 11       Good            605.03                 39.182656               26.10
# 12       Good            605.03                 34.977895               26.11
# 13       Good            605.03                 33.381010               27.00
# 14       Good            605.03                 31.131702               27.10
# 15       Good            605.03                 32.933856               27.20
#
#    Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 8                     No            18.816215               104.291825
# 9                     No            18.816215                40.391238
# 10                    No            18.816215                58.515976
# 11                    No            18.816215                99.306228
# 12                    No            18.816215               130.115420
# 13                    No            18.816215                43.477190
# 14                    NM            18.816215                70.101774
# 15                    No            18.816215               218.904344
#
#                    Payment_Behaviour  Monthly_Balance Credit_Score  \
# 8     Low_spent_Small_value_payments       470.690627     Standard
# 9    High_spent_Large_value_payments       484.591214         Good
# 10   High_spent_Large_value_payments       466.466476     Standard
# 11   Low_spent_Medium_value_payments       465.676224         Good
# 12    Low_spent_Small_value_payments       444.867032         Good
# 13   High_spent_Large_value_payments       481.505262         Good
# 14  High_spent_Medium_value_payments       464.880678         Good
# 15    Low_spent_Small_value_payments       356.078109         Good
#
#     Num_of_loan2
# 8            1.0
# 9            1.0
# 10           1.0
# 11           1.0
# 12           1.0
# 13           1.0
# 14           1.0
# 15           1.0

# %%
df[df.Customer_ID == 'CUS_0xaf61']
# Out:
#       Customer_ID     Month   Age Occupation  Annual_Income  \
# 99976  CUS_0xaf61   January  49.0     Writer        37188.1
# 99977  CUS_0xaf61  February  49.0     Writer        37188.1
# 99978  CUS_0xaf61     March  49.0     Writer        37188.1
# 99979  CUS_0xaf61     April  49.0     Writer        37188.1
# 99980  CUS_0xaf61       May  49.0     Writer        37188.1
# 99981  CUS_0xaf61      June  50.0     Writer        37188.1
# 99982  CUS_0xaf61      July  50.0     Writer        37188.1
# 99983  CUS_0xaf61    August  50.0     Writer        37188.1
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 99976                1.0              4.0            5.0                    7
# 99977                1.0              4.0            5.0                    7
# 99978                1.0              4.0            5.0                    4
# 99979                1.0              4.0            5.0                    3
# 99980                1.0              4.0            5.0                    7
# 99981                1.0              4.0            5.0                    5
# 99982                1.0              4.0            5.0                    7
# 99983                1.0              4.0            5.0                    7
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 99976                    12.0                  5.38                   3.0
# 99977                    12.0                  5.38                   3.0
# 99978                    11.0                  5.38                   3.0
# 99979                    12.0                  5.38                   3.0
# 99980                    12.0                  5.38                   3.0
# 99981                    12.0                  5.38                   3.0
# 99982                    13.0                  5.38                   3.0
# 99983                     9.0                  5.38                   3.0
#
#       Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 99976       Good            620.64                 39.080823
# 99977       Good            620.64                 32.803431
# 99978       Good            620.64                 24.540510
# 99979       Good            620.64                 36.979007
# 99980       Good            620.64                 27.495263
# 99981       Good            620.64                 37.753013
# 99982       Good            620.64                 38.850680
# 99983       Good            620.64                 39.300980
#
#        Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 99976               29.90                    No            84.205949
# 99977               29.10                    No            84.205949
# 99978               29.11                    No            84.205949
# 99979               30.00                    NM            84.205949
# 99980               30.10                    No            84.205949
# 99981               30.20                    NM            84.205949
# 99982               30.30                    No            84.205949
# 99983               30.40                    No            84.205949
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 99976               223.875018    Low_spent_Small_value_payments
# 99977                70.869970   High_spent_Large_value_payments
# 99978               125.956592   Low_spent_Medium_value_payments
# 99979               215.486386    Low_spent_Small_value_payments
# 99980                78.497727    Low_spent_Small_value_payments
# 99981               147.339908    Low_spent_Small_value_payments
# 99982                82.825572    Low_spent_Small_value_payments
# 99983                42.935566  High_spent_Medium_value_payments
#
#        Monthly_Balance Credit_Score  Num_of_loan2
# 99976              NaN         Good           3.0
# 99977              NaN         Good           3.0
# 99978              NaN         Good           3.0
# 99979              NaN         Good           3.0
# 99980              NaN     Standard           3.0
# 99981              NaN         Good           3.0
# 99982              NaN         Good           3.0
# 99983              NaN         Good           3.0

# %%
df[df.Customer_ID == 'CUS_0x1cdb']
# Out:
#    Customer_ID     Month   Age Occupation  Annual_Income  Num_Bank_Accounts  \
# 32  CUS_0x1cdb   January  21.0  Developer       35547.71                7.0
# 33  CUS_0x1cdb  February  21.0  Developer       35547.71                7.0
# 35  CUS_0x1cdb     April  21.0  Developer       35547.71                7.0
# 36  CUS_0x1cdb       May  21.0  Developer       35547.71                7.0
# 37  CUS_0x1cdb      June  21.0  Developer       35547.71                7.0
# 38  CUS_0x1cdb      July  21.0  Developer       35547.71                7.0
#
#     Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 32              5.0            5.0                    5
# 33              5.0            5.0                    9
# 35              5.0            5.0                    1
# 36              5.0            5.0                    9
# 37              5.0            5.0                    5
# 38              5.0            5.0                   10
#
#     Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 32                     NaN                  2.58                   4.0
# 33                     NaN                  2.58                   4.0
# 35                    15.0                  2.58                   4.0
# 36                    17.0                  2.58                   4.0
# 37                    15.0                  2.58                   4.0
# 38                    15.0                  2.58                   4.0
#
#    Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 32   Standard            943.86                 39.797764               30.80
# 33   Standard            943.86                 27.020360               30.90
# 35   Standard            943.86                 28.924954               30.11
# 36   Standard            943.86                 41.776187               31.00
# 37   Standard            943.86                 29.217556               31.10
# 38   Standard            943.86                 26.263823               31.20
#
#    Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 32                   Yes                  0.0               276.725394
# 33                    NM                  0.0                74.443641
# 35                   Yes                  0.0                96.785485
# 36                   Yes                  0.0                62.723278
# 37                   Yes                  0.0                37.643638
# 38                   Yes                  0.0               181.011983
#
#                    Payment_Behaviour  Monthly_Balance Credit_Score  \
# 32  High_spent_Medium_value_payments       288.605522     Standard
# 33  High_spent_Medium_value_payments       460.887276     Standard
# 35  High_spent_Medium_value_payments       438.545432     Standard
# 36   High_spent_Small_value_payments       482.607638     Standard
# 37  High_spent_Medium_value_payments       497.687279     Standard
# 38    Low_spent_Small_value_payments       394.318934     Standard
#
#     Num_of_loan2
# 32           0.0
# 33           0.0
# 35           0.0
# 36           0.0
# 37           0.0
# 38           0.0

# %%
df.Payment_of_Min_Amount[df.Payment_of_Min_Amount == 'NM'] = np.nan

# %%
df.Payment_of_Min_Amount.isnull().sum()
# Out:
# 11948

# %%
df[df.Payment_of_Min_Amount.isnull()]
# Out:
#       Customer_ID     Month   Age     Occupation  Annual_Income  \
# 14     CUS_0x21b1      July  28.0        Teacher       34847.84
# 26     CUS_0xb891     March  55.0   Entrepreneur       30689.89
# 33     CUS_0x1cdb  February  21.0      Developer       35547.71
# 41     CUS_0x95ee  February  31.0         Lawyer       73928.46
# 48     CUS_0x284a   January  33.0         Lawyer      131313.40
# ...           ...       ...   ...            ...            ...
# 99939  CUS_0xad4f     April  47.0      Developer       22620.79
# 99949  CUS_0x51b3      June  33.0  Media_Manager       59146.36
# 99968   CUS_0xf16   January  44.0  Media_Manager       16680.35
# 99979  CUS_0xaf61     April  49.0         Writer       37188.10
# 99981  CUS_0xaf61      June  50.0         Writer       37188.10
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 14                   2.0              4.0            6.0                    3
# 26                   2.0              5.0            4.0                    3
# 33                   7.0              5.0            5.0                    9
# 41                   4.0              5.0            8.0                    8
# 48                   0.0              1.0            8.0                    0
# ...                  ...              ...            ...                  ...
# 99939                7.0              3.0            9.0                   27
# 99949                3.0              6.0            6.0                    6
# 99968                1.0              1.0            5.0                    4
# 99979                1.0              4.0            5.0                    3
# 99981                1.0              4.0            5.0                    5
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 14                        4.0                  5.42                   2.0
# 26                        9.0                  1.99                   4.0
# 33                        NaN                  2.58                   4.0
# 41                        7.0                 10.14                   2.0
# 48                        3.0                  9.34                   2.0
# ...                       ...                   ...                   ...
# 99939                    19.0                  5.31                   2.0
# 99949                     6.0                  6.68                   5.0
# 99968                     0.0                  5.69                   4.0
# 99979                    12.0                  5.38                   3.0
# 99981                    12.0                  5.38                   3.0
#
#       Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 14          Good            605.03                 31.131702
# 26          Good            632.46                 32.301163
# 33      Standard            943.86                 27.020360
# 41          Good            548.20                 42.769864
# 48          Good            352.16                 32.200509
# ...          ...               ...                       ...
# 99939   Standard            642.46                 26.730863
# 99949       Good            418.03                 24.975531
# 99968       Good            897.16                 39.868572
# 99979       Good            620.64                 36.979007
# 99981       Good            620.64                 37.753013
#
#        Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 14                   27.1                   NaN            18.816215
# 26                   17.5                   NaN            16.415452
# 33                   30.9                   NaN             0.000000
# 41                   32.0                   NaN             0.000000
# 48                   30.7                   NaN           137.644605
# ...                   ...                   ...                  ...
# 99939                29.6                   NaN             0.000000
# 99949                20.6                   NaN            26.778419
# 99968                 NaN                   NaN            41.113561
# 99979                30.0                   NaN            84.205949
# 99981                30.2                   NaN            84.205949
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 14                   70.101774  High_spent_Medium_value_payments
# 26                   83.406509  High_spent_Medium_value_payments
# 33                   74.443641  High_spent_Medium_value_payments
# 41                  172.939214   Low_spent_Medium_value_payments
# 48                  378.171254  High_spent_Medium_value_payments
# ...                        ...                               ...
# 99939               205.756074    Low_spent_Small_value_payments
# 99949                91.321664  High_spent_Medium_value_payments
# 99968                52.951978   High_spent_Small_value_payments
# 99979               215.486386    Low_spent_Small_value_payments
# 99981               147.339908    Low_spent_Small_value_payments
#
#        Monthly_Balance Credit_Score  Num_of_loan2
# 14          464.880678         Good           1.0
# 26          411.427123     Standard           1.0
# 33          460.887276     Standard           0.0
# 41          705.931286         Good           0.0
# 48          858.462474         Good           2.0
# ...                ...          ...           ...
# 99939              NaN         Poor           0.0
# 99949              NaN     Standard           1.0
# 99968              NaN         Good           4.0
# 99979              NaN         Good           3.0
# 99981              NaN         Good           3.0
#
# [11948 rows x 23 columns]

# %%
pma = ""
pma1 = ""
for i in df.Customer_ID[df.Payment_of_Min_Amount.isnull()]:
    pma = df.Payment_of_Min_Amount[(df.Customer_ID ==i) & (df.Payment_of_Min_Amount.notnull())]
    pma1 = pma.to_list()
    df.Payment_of_Min_Amount[df.Customer_ID == i] = pma1[0]

# %%
df.Payment_of_Min_Amount.isnull().sum()
# Out:
# 0

# %%
df[df.Customer_ID == 'CUS_0x284a']
#now its fixedd and we will proceed ahead
# Out:
#    Customer_ID     Month   Age Occupation  Annual_Income  Num_Bank_Accounts  \
# 48  CUS_0x284a   January  33.0     Lawyer       131313.4                0.0
# 49  CUS_0x284a  February  34.0     Lawyer       131313.4                0.0
# 50  CUS_0x284a     March  34.0     Lawyer       131313.4                0.0
# 51  CUS_0x284a     April  34.0     Lawyer       131313.4                0.0
# 52  CUS_0x284a       May  34.0     Lawyer       131313.4                0.0
# 53  CUS_0x284a      June  34.0     Lawyer       131313.4                0.0
# 54  CUS_0x284a      July  34.0     Lawyer     10909427.0                0.0
# 55  CUS_0x284a    August  34.0     Lawyer       131313.4                0.0
#
#     Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 48              1.0            8.0                    0
# 49              1.0            8.0                   -1
# 50              1.0            8.0                    0
# 51              1.0            8.0                    0
# 52              1.0            8.0                    0
# 53              1.0            8.0                    0
# 54              1.0            8.0                    0
# 55              1.0            8.0                    0
#
#     Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 48                     3.0                  9.34                   2.0
# 49                     2.0                 15.34                   4.0
# 50                     3.0                  9.34                   4.0
# 51                     2.0                  8.34                   4.0
# 52                     4.0                  9.34                   4.0
# 53                     3.0                 11.34                   4.0
# 54                     2.0                  9.34                   4.0
# 55                     2.0                  9.34                   4.0
#
#    Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 48       Good            352.16                 32.200509               30.70
# 49       Good            352.16                 31.983710               30.80
# 50       Good            352.16                 31.803134               30.90
# 51       Good            352.16                 42.645785               30.10
# 52       Good            352.16                 40.902517               30.11
# 53       Good            352.16                 41.980170               31.00
# 54       Good            352.16                 26.947565               31.10
# 55       Good            352.16                 29.187913               31.20
#
#    Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 48                    No           137.644605               378.171254
# 49                    No           137.644605               698.873271
# 50                    No           911.220179               188.064321
# 51                    No         23834.000000               337.434956
# 52                    No         32662.000000               263.378909
# 53                    No           911.220179                86.566388
# 54                    No           911.220179               930.391898
# 55                    No           911.220179               870.522382
#
#                    Payment_Behaviour  Monthly_Balance Credit_Score  \
# 48  High_spent_Medium_value_payments       858.462474         Good
# 49   High_spent_Small_value_payments       547.760457         Good
# 50   High_spent_Large_value_payments      1038.569407         Good
# 51  High_spent_Medium_value_payments       899.198772         Good
# 52   High_spent_Large_value_payments       963.254819         Good
# 53   High_spent_Large_value_payments      1140.067340     Standard
# 54   High_spent_Large_value_payments       326.241830         Good
# 55   Low_spent_Medium_value_payments       396.111346         Good
#
#     Num_of_loan2
# 48           2.0
# 49           2.0
# 50           2.0
# 51           2.0
# 52           2.0
# 53           2.0
# 54           2.0
# 55           2.0

# %%
df.Payment_Behaviour.value_counts()
#we already worked and fixed this so we will procedd
# Out:
# Low_spent_Small_value_payments      29128
# High_spent_Medium_value_payments    18817
# High_spent_Large_value_payments     14808
# Low_spent_Medium_value_payments     14346
# High_spent_Small_value_payments     11705
# Low_spent_Large_value_payments      10718
# Name: Payment_Behaviour, dtype: int64

# %%
df.Credit_Score.value_counts()
#we already worked and fixed this so we will procedd
# Out:
# Standard    52891
# Poor        28953
# Good        17678
# Name: Credit_Score, dtype: int64

# %%
df.select_dtypes(object).columns
# Out:
# Index(['Customer_ID', 'Month', 'Occupation', 'Credit_Mix',
#        'Payment_of_Min_Amount', 'Payment_Behaviour', 'Credit_Score'],
#       dtype='object')

# %%
df.select_dtypes(include='number').columns
# Out:
# Index(['Age', 'Annual_Income', 'Num_Bank_Accounts', 'Num_Credit_Card',
#        'Interest_Rate', 'Delay_from_due_date', 'Num_of_Delayed_Payment',
#        'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Monthly_Balance', 'Num_of_loan2'],
#       dtype='object')

# %%
df.Annual_Income.value_counts().sort_index(ascending=False)
# Out:
# 2.419806e+07    1
# 2.418881e+07    1
# 2.417715e+07    1
# 2.416001e+07    1
# 2.410537e+07    1
#                ..
# 7.012310e+03    8
# 7.011685e+03    8
# 7.006520e+03    8
# 7.006035e+03    8
# 7.005930e+03    8
# Name: Annual_Income, Length: 13482, dtype: int64

# %%
cat_cols = ['Customer_ID','Month','Occupation','Credit_Mix','Payment_of_Min_Amount','Payment_Behaviour','Credit_Score',
            'Num_Bank_Accounts','Num_Credit_Card','Interest_Rate','Num_of_Delayed_Payment','Num_Credit_Inquiries',
           'Num_of_loan2']

# %%
cat_cols
# Out:
# ['Customer_ID',
#  'Month',
#  'Occupation',
#  'Credit_Mix',
#  'Payment_of_Min_Amount',
#  'Payment_Behaviour',
#  'Credit_Score',
#  'Num_Bank_Accounts',
#  'Num_Credit_Card',
#  'Interest_Rate',
#  'Num_of_Delayed_Payment',
#  'Num_Credit_Inquiries',
#  'Num_of_loan2']

# %%
num_cols = ['Age', 'Annual_Income', 'Delay_from_due_date','Changed_Credit_Limit','Outstanding_Debt',
           'Credit_Utilization_Ratio', 'Credit_History_Age', 'Total_EMI_per_month',
           'Amount_invested_monthly', 'Monthly_Balance']

# %%
num_cols
# Out:
# ['Age',
#  'Annual_Income',
#  'Delay_from_due_date',
#  'Changed_Credit_Limit',
#  'Outstanding_Debt',
#  'Credit_Utilization_Ratio',
#  'Credit_History_Age',
#  'Total_EMI_per_month',
#  'Amount_invested_monthly',
#  'Monthly_Balance']

# %%
t=1
plt.figure(figsize=(12,10))
for i in num_cols:
    if i!= 'Customer_ID':
        plt.subplot(4,3,t)
        sns.boxplot(df[i], orient='h')
        plt.title(i)
        t+=1
    
plt.tight_layout()
plt.show()

# %%
t=1
plt.figure(figsize=(50,40))
for i in cat_cols:
    plt.subplot(12,3,t)
    sns.countplot(x=df[i])
    plt.title(i)
    t+=1
    
plt.tight_layout()
plt.show()

# %%
df["Amount_invested_monthly"][df["Amount_invested_monthly"]==10000] = np.nan

# %%
df[df["Amount_invested_monthly"].isnull()]
# Out:
#       Customer_ID     Month   Age     Occupation  Annual_Income  \
# 18     CUS_0x2dbc     March  34.0       Engineer      143162.64
# 23     CUS_0x2dbc    August  34.0       Engineer      143162.64
# 28     CUS_0xb891       May  55.0   Entrepreneur       30689.89
# 60     CUS_0x5407       May  30.0  Media_Manager       34081.38
# 61     CUS_0x5407      June  30.0  Media_Manager       34081.38
# ...           ...       ...   ...            ...            ...
# 99925  CUS_0x2654      June  38.0  Media_Manager      139664.96
# 99951  CUS_0x51b3    August  33.0  Media_Manager       59146.36
# 99961  CUS_0x372c  February  18.0         Lawyer       42903.79
# 99973   CUS_0xf16      June  44.0  Media_Manager       16680.35
# 99974   CUS_0xf16      July  44.0  Media_Manager       16680.35
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 18                   1.0              5.0            8.0                    8
# 23                   1.0              5.0            8.0                    8
# 28                   2.0              5.0            4.0                    5
# 60                   8.0              7.0           15.0                   27
# 61                   8.0              7.0           15.0                   30
# ...                  ...              ...            ...                  ...
# 99925                3.0              6.0           12.0                   14
# 99951                3.0              6.0            6.0                    8
# 99961                0.0              4.0            6.0                   14
# 99973                1.0              1.0            5.0                    1
# 99974                1.0              1.0            5.0                    1
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 18                        7.0                 11.10                   NaN
# 23                        6.0                  7.10                   3.0
# 28                        6.0                 -1.01                   4.0
# 60                       14.0                 17.13                   5.0
# 61                       14.0                 18.13                   5.0
# ...                       ...                   ...                   ...
# 99925                    12.0                 17.39                   8.0
# 99951                     6.0                  6.68                   5.0
# 99961                     0.0                 -0.90                   1.0
# 99973                     NaN                  0.69                   8.0
# 99974                     NaN                 11.69                   8.0
#
#       Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 18          Good           1303.01                 26.519815
# 23          Good           1303.01                 38.374753
# 28          Good            632.46                 41.154317
# 60      Standard           1704.18                 30.206214
# 61      Standard           1704.18                 31.170872
# ...          ...               ...                       ...
# 99925   Standard            365.66                 27.714375
# 99951       Good            418.03                 27.682186
# 99961       Good           1079.48                 33.494867
# 99973       Good            897.16                 24.972853
# 99974       Good            897.16                 36.166925
#
#        Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 18                  17.11                    No           246.992319
# 23                  18.40                    No           246.992319
# 28                  17.70                    No            16.415452
# 60                  14.11                   Yes            70.478333
# 61                  15.00                   Yes            70.478333
# ...                   ...                   ...                  ...
# 99925               30.00                   Yes           423.731016
# 99951               20.80                    No            26.778419
# 99961               28.20                    No            34.975457
# 99973               21.60                    No            41.113561
# 99974               21.70                    No            41.113561
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 18                         NaN   High_spent_Small_value_payments
# 23                         NaN   High_spent_Small_value_payments
# 28                         NaN    Low_spent_Large_value_payments
# 60                         NaN   High_spent_Large_value_payments
# 61                         NaN   High_spent_Large_value_payments
# ...                        ...                               ...
# 99925                      NaN    Low_spent_Large_value_payments
# 99951                      NaN    Low_spent_Large_value_payments
# 99961                      NaN  High_spent_Medium_value_payments
# 99973                      NaN    Low_spent_Small_value_payments
# 99974                      NaN    Low_spent_Small_value_payments
#
#        Monthly_Balance Credit_Score  Num_of_loan2
# 18          715.741367         Good           3.0
# 23          895.494583     Standard           3.0
# 28          359.374916     Standard           1.0
# 60          397.228355     Standard           3.0
# 61          410.674366     Standard           3.0
# ...                ...          ...           ...
# 99925              NaN     Standard           4.0
# 99951              NaN     Standard           1.0
# 99961              NaN         Good           1.0
# 99973              NaN         Good           4.0
# 99974              NaN         Good           4.0
#
# [8747 rows x 23 columns]

# %%
aim = ""
for i in df.Customer_ID[df.Amount_invested_monthly.isnull()]:
    aim = df.Amount_invested_monthly[(df.Customer_ID ==i) & (df.Amount_invested_monthly.notnull())]
    df.Amount_invested_monthly[(df.Customer_ID == i) & (df.Amount_invested_monthly.isnull())] = aim.mean()

# %%
df[df.Customer_ID == 'CUS_0x2dbc']
# Out:
#    Customer_ID     Month   Age Occupation  Annual_Income  Num_Bank_Accounts  \
# 16  CUS_0x2dbc   January  34.0   Engineer      143162.64                1.0
# 17  CUS_0x2dbc  February  34.0   Engineer      143162.64                1.0
# 18  CUS_0x2dbc     March  34.0   Engineer      143162.64                1.0
# 19  CUS_0x2dbc     April  34.0   Engineer      143162.64                1.0
# 20  CUS_0x2dbc       May  34.0   Engineer      143162.64                1.0
# 21  CUS_0x2dbc      June  34.0   Engineer      143162.64                1.0
# 22  CUS_0x2dbc      July  34.0   Engineer      143162.64                1.0
# 23  CUS_0x2dbc    August  34.0   Engineer      143162.64                1.0
#
#     Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 16              5.0            8.0                    5
# 17              5.0            8.0                   13
# 18              5.0            8.0                    8
# 19              5.0            8.0                    8
# 20              5.0            8.0                   10
# 21              5.0            8.0                    8
# 22              5.0            8.0                    8
# 23              5.0            8.0                    8
#
#     Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 16                     8.0                   7.1                   3.0
# 17                     6.0                   7.1                   3.0
# 18                     7.0                  11.1                   NaN
# 19                     5.0                   9.1                   3.0
# 20                     5.0                   7.1                   3.0
# 21                     6.0                   7.1                   3.0
# 22                     6.0                   7.1                   3.0
# 23                     6.0                   7.1                   3.0
#
#    Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 16       Good           1303.01                 28.616735               17.90
# 17       Good           1303.01                 41.702573               17.10
# 18       Good           1303.01                 26.519815               17.11
# 19       Good           1303.01                 39.501648                 NaN
# 20       Good           1303.01                 31.376150               18.10
# 21       Good           1303.01                 39.783993               18.20
# 22       Good           1303.01                 38.068624               18.30
# 23       Good           1303.01                 38.374753               18.40
#
#    Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 16                    No           246.992319               168.413703
# 17                    No           246.992319               232.860384
# 18                    No           246.992319               363.070024
# 19                    No           246.992319               825.216270
# 20                    No           246.992319               430.947528
# 21                    No           246.992319               257.808099
# 22                    No           246.992319               263.174163
# 23                    No           246.992319               363.070024
#
#                    Payment_Behaviour  Monthly_Balance Credit_Score  \
# 16   High_spent_Small_value_payments      1043.315978         Good
# 17   High_spent_Small_value_payments       998.869297         Good
# 18   High_spent_Small_value_payments       715.741367         Good
# 19   Low_spent_Medium_value_payments       426.513411         Good
# 20    Low_spent_Large_value_payments       810.782153         Good
# 21  High_spent_Medium_value_payments       963.921581         Good
# 22   High_spent_Small_value_payments       968.555517     Standard
# 23   High_spent_Small_value_payments       895.494583     Standard
#
#     Num_of_loan2
# 16           3.0
# 17           3.0
# 18           3.0
# 19           3.0
# 20           3.0
# 21           3.0
# 22           3.0
# 23           3.0

# %%
df["Amount_invested_monthly"].max()
# Out:
# 1977.326102249349

# %%
df[df["Customer_ID"]=="CUS_0xb891"]
# Out:
#    Customer_ID     Month   Age    Occupation  Annual_Income  \
# 24  CUS_0xb891   January  54.0  Entrepreneur       30689.89
# 25  CUS_0xb891  February  54.0  Entrepreneur       30689.89
# 26  CUS_0xb891     March  55.0  Entrepreneur       30689.89
# 27  CUS_0xb891     April  55.0  Entrepreneur       30689.89
# 28  CUS_0xb891       May  55.0  Entrepreneur       30689.89
# 29  CUS_0xb891      June  55.0  Entrepreneur       30689.89
# 30  CUS_0xb891      July  55.0  Entrepreneur       30689.89
# 31  CUS_0xb891    August  55.0  Entrepreneur       30689.89
#
#     Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 24                2.0              5.0            4.0                    0
# 25                2.0              5.0            4.0                    5
# 26                2.0              5.0            4.0                    3
# 27                2.0              5.0            4.0                    7
# 28                2.0              5.0            4.0                    5
# 29                2.0              5.0            4.0                    5
# 30                2.0              5.0            4.0                    5
# 31                2.0              5.0            4.0                    4
#
#     Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 24                     6.0                  1.99                   4.0
# 25                     3.0                  1.99                   4.0
# 26                     9.0                  1.99                   4.0
# 27                     6.0                 -2.01                   4.0
# 28                     6.0                 -1.01                   4.0
# 29                     6.0                 -3.01                   4.0
# 30                     NaN                  1.99                   4.0
# 31                     9.0                  1.99                   4.0
#
#    Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 24       Good            632.46                 26.544229                17.3
# 25       Good            632.46                 35.279982                17.4
# 26       Good            632.46                 32.301163                17.5
# 27       Good            632.46                 38.132348                17.6
# 28       Good            632.46                 41.154317                17.7
# 29       Good            632.46                 27.445422                17.8
# 30       Good            632.46                 26.056395                17.9
# 31       Good            632.46                 27.332515                17.1
#
#    Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 24                    No            16.415452                81.228859
# 25                    No            16.415452               124.881820
# 26                    No            16.415452                83.406509
# 27                    No            16.415452               272.334037
# 28                    No            16.415452               120.529285
# 29                    No            16.415452                84.952848
# 30                    No            16.415452                71.283675
# 31                    No            16.415452               125.617251
#
#                    Payment_Behaviour  Monthly_Balance Credit_Score  \
# 24    Low_spent_Large_value_payments       433.604773     Standard
# 25    Low_spent_Small_value_payments       409.951812     Standard
# 26  High_spent_Medium_value_payments       411.427123     Standard
# 27    Low_spent_Small_value_payments       262.499594     Standard
# 28    Low_spent_Large_value_payments       359.374916     Standard
# 29   High_spent_Small_value_payments       419.880784     Standard
# 30    Low_spent_Large_value_payments       443.549957     Standard
# 31   High_spent_Small_value_payments       379.216381     Standard
#
#     Num_of_loan2
# 24           1.0
# 25           1.0
# 26           1.0
# 27           1.0
# 28           1.0
# 29           1.0
# 30           1.0
# 31           1.0

# %%
df.Annual_Income[df.Customer_ID =="CUS_0xb891"].mode()[0]
# Out:
# 30689.89

# %%
df[df["Customer_ID"]=="CUS_0xbffe"] #CUS_0xd40 # CUS_0x942c #CUS_0x21b1
# Out:
#     Customer_ID     Month   Age Occupation  Annual_Income  Num_Bank_Accounts  \
# 224  CUS_0xbffe   January  40.0  Architect       28572.39                6.0
# 225  CUS_0xbffe  February  40.0  Architect       28572.39                6.0
# 226  CUS_0xbffe     March  40.0  Architect       28572.39                6.0
# 227  CUS_0xbffe     April  40.0  Architect       28572.39                6.0
# 228  CUS_0xbffe       May  40.0  Architect       28572.39                6.0
# 229  CUS_0xbffe      June  40.0  Architect       28572.39                6.0
# 230  CUS_0xbffe      July  40.0  Architect       28572.39                6.0
# 231  CUS_0xbffe    August  40.0  Architect     6515990.00                6.0
#
#      Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 224              3.0           15.0                   25
# 225              3.0           15.0                   25
# 226              3.0           15.0                   28
# 227              3.0           15.0                   25
# 228              3.0           15.0                   25
# 229              3.0           15.0                   25
# 230              3.0           15.0                   25
# 231              3.0           15.0                   25
#
#      Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 224                    12.0                  4.89                   0.0
# 225                     9.0                  4.89                   0.0
# 226                    10.0                  4.89                   0.0
# 227                    14.0                  4.89                   0.0
# 228                    12.0                  4.89                   2.0
# 229                    11.0                  4.89                   2.0
# 230                    13.0                  4.89                   2.0
# 231                    12.0                  4.89                   2.0
#
#     Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 224   Standard            400.07                 24.422251
# 225   Standard            400.07                 36.437870
# 226   Standard            400.07                 29.323517
# 227   Standard            400.07                 34.714561
# 228   Standard            400.07                 37.504552
# 229   Standard            400.07                 35.693949
# 230   Standard            400.07                 35.025883
# 231   Standard            400.07                 23.177617
#
#      Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 224                30.3                   Yes             69.60292
# 225                30.4                   Yes             69.60292
# 226                30.5                   Yes             69.60292
# 227                30.6                   Yes             69.60292
# 228                30.7                   Yes             69.60292
# 229                30.8                   Yes             69.60292
# 230                 NaN                   Yes             69.60292
# 231                30.1                   Yes             69.60292
#
#      Amount_invested_monthly                 Payment_Behaviour  \
# 224                42.850507   High_spent_Large_value_payments
# 225                83.044209  High_spent_Medium_value_payments
# 226                53.484203  High_spent_Medium_value_payments
# 227                25.993462  High_spent_Medium_value_payments
# 228                61.628109  High_spent_Medium_value_payments
# 229               129.264835    Low_spent_Small_value_payments
# 230                76.607809    Low_spent_Small_value_payments
# 231                51.830859   High_spent_Large_value_payments
#
#      Monthly_Balance Credit_Score  Num_of_loan2
# 224       348.549822     Standard           3.0
# 225       358.356121     Standard           3.0
# 226       347.916126     Standard           3.0
# 227       375.406867     Standard           3.0
# 228       339.772220     Standard           3.0
# 229       312.135495     Standard           3.0
# 230       364.792521     Standard           3.0
# 231       339.569471     Standard           3.0

# %%
df[df["Customer_ID"]=="CUS_0x51b3"]
# Out:
#       Customer_ID     Month   Age     Occupation  Annual_Income  \
# 99944  CUS_0x51b3   January  33.0  Media_Manager       59146.36
# 99945  CUS_0x51b3  February  33.0  Media_Manager    10152115.00
# 99946  CUS_0x51b3     March  33.0  Media_Manager       59146.36
# 99947  CUS_0x51b3     April  33.0  Media_Manager       59146.36
# 99948  CUS_0x51b3       May  33.0  Media_Manager       59146.36
# 99949  CUS_0x51b3      June  33.0  Media_Manager       59146.36
# 99950  CUS_0x51b3      July  33.0  Media_Manager       59146.36
# 99951  CUS_0x51b3    August  33.0  Media_Manager       59146.36
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 99944                2.0              5.0            6.0                    8
# 99945                2.0              5.0            6.0                    8
# 99946                2.0              5.0            6.0                    8
# 99947                2.0              5.0            6.0                    8
# 99948                2.0              5.0            6.0                    8
# 99949                3.0              6.0            6.0                    6
# 99950                3.0              6.0            6.0                    8
# 99951                3.0              6.0            6.0                    8
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 99944                     6.0                  6.68                   2.0
# 99945                     6.0                  6.68                   2.0
# 99946                     7.0                  6.68                   2.0
# 99947                     6.0                  6.68                   5.0
# 99948                     6.0                  6.68                   5.0
# 99949                     6.0                  6.68                   5.0
# 99950                     6.0                  6.68                   5.0
# 99951                     6.0                  6.68                   5.0
#
#       Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 99944       Good            418.03                 34.720661
# 99945       Good            418.03                 28.287481
# 99946       Good            418.03                 35.750925
# 99947       Good            418.03                 28.091458
# 99948       Good            418.03                 36.813875
# 99949       Good            418.03                 24.975531
# 99950       Good            418.03                 38.199635
# 99951       Good            418.03                 27.682186
#
#        Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 99944                 NaN                    No            26.778419
# 99945                20.2                    No            26.778419
# 99946                20.3                    No            26.778419
# 99947                20.4                    No            26.778419
# 99948                20.5                    No            26.778419
# 99949                20.6                    No            26.778419
# 99950                20.7                    No            26.778419
# 99951                20.8                    No            26.778419
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 99944               606.436542    Low_spent_Small_value_payments
# 99945                77.794586   High_spent_Large_value_payments
# 99946               188.544697  High_spent_Medium_value_payments
# 99947               183.584149    Low_spent_Small_value_payments
# 99948               463.834256    Low_spent_Small_value_payments
# 99949                91.321664  High_spent_Medium_value_payments
# 99950               502.376320    Low_spent_Small_value_payments
# 99951               301.984602    Low_spent_Large_value_payments
#
#        Monthly_Balance Credit_Score  Num_of_loan2
# 99944              NaN     Standard           1.0
# 99945              NaN     Standard           1.0
# 99946              NaN     Standard           1.0
# 99947              NaN     Standard           1.0
# 99948              NaN     Standard           1.0
# 99949              NaN     Standard           1.0
# 99950              NaN     Standard           1.0
# 99951              NaN     Standard           1.0

# %%
df[df["Customer_ID"]=="CUS_0x284a"]
# Out:
#    Customer_ID     Month   Age Occupation  Annual_Income  Num_Bank_Accounts  \
# 48  CUS_0x284a   January  33.0     Lawyer       131313.4                0.0
# 49  CUS_0x284a  February  34.0     Lawyer       131313.4                0.0
# 50  CUS_0x284a     March  34.0     Lawyer       131313.4                0.0
# 51  CUS_0x284a     April  34.0     Lawyer       131313.4                0.0
# 52  CUS_0x284a       May  34.0     Lawyer       131313.4                0.0
# 53  CUS_0x284a      June  34.0     Lawyer       131313.4                0.0
# 54  CUS_0x284a      July  34.0     Lawyer     10909427.0                0.0
# 55  CUS_0x284a    August  34.0     Lawyer       131313.4                0.0
#
#     Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 48              1.0            8.0                    0
# 49              1.0            8.0                   -1
# 50              1.0            8.0                    0
# 51              1.0            8.0                    0
# 52              1.0            8.0                    0
# 53              1.0            8.0                    0
# 54              1.0            8.0                    0
# 55              1.0            8.0                    0
#
#     Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 48                     3.0                  9.34                   2.0
# 49                     2.0                 15.34                   4.0
# 50                     3.0                  9.34                   4.0
# 51                     2.0                  8.34                   4.0
# 52                     4.0                  9.34                   4.0
# 53                     3.0                 11.34                   4.0
# 54                     2.0                  9.34                   4.0
# 55                     2.0                  9.34                   4.0
#
#    Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 48       Good            352.16                 32.200509               30.70
# 49       Good            352.16                 31.983710               30.80
# 50       Good            352.16                 31.803134               30.90
# 51       Good            352.16                 42.645785               30.10
# 52       Good            352.16                 40.902517               30.11
# 53       Good            352.16                 41.980170               31.00
# 54       Good            352.16                 26.947565               31.10
# 55       Good            352.16                 29.187913               31.20
#
#    Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 48                    No           137.644605               378.171254
# 49                    No           137.644605               698.873271
# 50                    No           911.220179               188.064321
# 51                    No         23834.000000               337.434956
# 52                    No         32662.000000               263.378909
# 53                    No           911.220179                86.566388
# 54                    No           911.220179               930.391898
# 55                    No           911.220179               870.522382
#
#                    Payment_Behaviour  Monthly_Balance Credit_Score  \
# 48  High_spent_Medium_value_payments       858.462474         Good
# 49   High_spent_Small_value_payments       547.760457         Good
# 50   High_spent_Large_value_payments      1038.569407         Good
# 51  High_spent_Medium_value_payments       899.198772         Good
# 52   High_spent_Large_value_payments       963.254819         Good
# 53   High_spent_Large_value_payments      1140.067340     Standard
# 54   High_spent_Large_value_payments       326.241830         Good
# 55   Low_spent_Medium_value_payments       396.111346         Good
#
#     Num_of_loan2
# 48           2.0
# 49           2.0
# 50           2.0
# 51           2.0
# 52           2.0
# 53           2.0
# 54           2.0
# 55           2.0

# %%
ai = ""
for i in df.Customer_ID.unique():
    ai = df.Annual_Income[df.Customer_ID ==i]
    df.Annual_Income[df.Customer_ID == i] = ai.mode()[0]

# %%
df[df["Customer_ID"]=="CUS_0xbffe"]
# Out:
#     Customer_ID     Month   Age Occupation  Annual_Income  Num_Bank_Accounts  \
# 224  CUS_0xbffe   January  40.0  Architect       28572.39                6.0
# 225  CUS_0xbffe  February  40.0  Architect       28572.39                6.0
# 226  CUS_0xbffe     March  40.0  Architect       28572.39                6.0
# 227  CUS_0xbffe     April  40.0  Architect       28572.39                6.0
# 228  CUS_0xbffe       May  40.0  Architect       28572.39                6.0
# 229  CUS_0xbffe      June  40.0  Architect       28572.39                6.0
# 230  CUS_0xbffe      July  40.0  Architect       28572.39                6.0
# 231  CUS_0xbffe    August  40.0  Architect       28572.39                6.0
#
#      Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 224              3.0           15.0                   25
# 225              3.0           15.0                   25
# 226              3.0           15.0                   28
# 227              3.0           15.0                   25
# 228              3.0           15.0                   25
# 229              3.0           15.0                   25
# 230              3.0           15.0                   25
# 231              3.0           15.0                   25
#
#      Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 224                    12.0                  4.89                   0.0
# 225                     9.0                  4.89                   0.0
# 226                    10.0                  4.89                   0.0
# 227                    14.0                  4.89                   0.0
# 228                    12.0                  4.89                   2.0
# 229                    11.0                  4.89                   2.0
# 230                    13.0                  4.89                   2.0
# 231                    12.0                  4.89                   2.0
#
#     Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 224   Standard            400.07                 24.422251
# 225   Standard            400.07                 36.437870
# 226   Standard            400.07                 29.323517
# 227   Standard            400.07                 34.714561
# 228   Standard            400.07                 37.504552
# 229   Standard            400.07                 35.693949
# 230   Standard            400.07                 35.025883
# 231   Standard            400.07                 23.177617
#
#      Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 224                30.3                   Yes             69.60292
# 225                30.4                   Yes             69.60292
# 226                30.5                   Yes             69.60292
# 227                30.6                   Yes             69.60292
# 228                30.7                   Yes             69.60292
# 229                30.8                   Yes             69.60292
# 230                 NaN                   Yes             69.60292
# 231                30.1                   Yes             69.60292
#
#      Amount_invested_monthly                 Payment_Behaviour  \
# 224                42.850507   High_spent_Large_value_payments
# 225                83.044209  High_spent_Medium_value_payments
# 226                53.484203  High_spent_Medium_value_payments
# 227                25.993462  High_spent_Medium_value_payments
# 228                61.628109  High_spent_Medium_value_payments
# 229               129.264835    Low_spent_Small_value_payments
# 230                76.607809    Low_spent_Small_value_payments
# 231                51.830859   High_spent_Large_value_payments
#
#      Monthly_Balance Credit_Score  Num_of_loan2
# 224       348.549822     Standard           3.0
# 225       358.356121     Standard           3.0
# 226       347.916126     Standard           3.0
# 227       375.406867     Standard           3.0
# 228       339.772220     Standard           3.0
# 229       312.135495     Standard           3.0
# 230       364.792521     Standard           3.0
# 231       339.569471     Standard           3.0

# %%
df[df["Customer_ID"]=="CUS_0x51b3"]
# Out:
#       Customer_ID     Month   Age     Occupation  Annual_Income  \
# 99944  CUS_0x51b3   January  33.0  Media_Manager       59146.36
# 99945  CUS_0x51b3  February  33.0  Media_Manager       59146.36
# 99946  CUS_0x51b3     March  33.0  Media_Manager       59146.36
# 99947  CUS_0x51b3     April  33.0  Media_Manager       59146.36
# 99948  CUS_0x51b3       May  33.0  Media_Manager       59146.36
# 99949  CUS_0x51b3      June  33.0  Media_Manager       59146.36
# 99950  CUS_0x51b3      July  33.0  Media_Manager       59146.36
# 99951  CUS_0x51b3    August  33.0  Media_Manager       59146.36
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 99944                2.0              5.0            6.0                    8
# 99945                2.0              5.0            6.0                    8
# 99946                2.0              5.0            6.0                    8
# 99947                2.0              5.0            6.0                    8
# 99948                2.0              5.0            6.0                    8
# 99949                3.0              6.0            6.0                    6
# 99950                3.0              6.0            6.0                    8
# 99951                3.0              6.0            6.0                    8
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 99944                     6.0                  6.68                   2.0
# 99945                     6.0                  6.68                   2.0
# 99946                     7.0                  6.68                   2.0
# 99947                     6.0                  6.68                   5.0
# 99948                     6.0                  6.68                   5.0
# 99949                     6.0                  6.68                   5.0
# 99950                     6.0                  6.68                   5.0
# 99951                     6.0                  6.68                   5.0
#
#       Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 99944       Good            418.03                 34.720661
# 99945       Good            418.03                 28.287481
# 99946       Good            418.03                 35.750925
# 99947       Good            418.03                 28.091458
# 99948       Good            418.03                 36.813875
# 99949       Good            418.03                 24.975531
# 99950       Good            418.03                 38.199635
# 99951       Good            418.03                 27.682186
#
#        Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 99944                 NaN                    No            26.778419
# 99945                20.2                    No            26.778419
# 99946                20.3                    No            26.778419
# 99947                20.4                    No            26.778419
# 99948                20.5                    No            26.778419
# 99949                20.6                    No            26.778419
# 99950                20.7                    No            26.778419
# 99951                20.8                    No            26.778419
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 99944               606.436542    Low_spent_Small_value_payments
# 99945                77.794586   High_spent_Large_value_payments
# 99946               188.544697  High_spent_Medium_value_payments
# 99947               183.584149    Low_spent_Small_value_payments
# 99948               463.834256    Low_spent_Small_value_payments
# 99949                91.321664  High_spent_Medium_value_payments
# 99950               502.376320    Low_spent_Small_value_payments
# 99951               301.984602    Low_spent_Large_value_payments
#
#        Monthly_Balance Credit_Score  Num_of_loan2
# 99944              NaN     Standard           1.0
# 99945              NaN     Standard           1.0
# 99946              NaN     Standard           1.0
# 99947              NaN     Standard           1.0
# 99948              NaN     Standard           1.0
# 99949              NaN     Standard           1.0
# 99950              NaN     Standard           1.0
# 99951              NaN     Standard           1.0

# %%
df[df["Customer_ID"]=="CUS_0x284a"]
# Out:
#    Customer_ID     Month   Age Occupation  Annual_Income  Num_Bank_Accounts  \
# 48  CUS_0x284a   January  33.0     Lawyer       131313.4                0.0
# 49  CUS_0x284a  February  34.0     Lawyer       131313.4                0.0
# 50  CUS_0x284a     March  34.0     Lawyer       131313.4                0.0
# 51  CUS_0x284a     April  34.0     Lawyer       131313.4                0.0
# 52  CUS_0x284a       May  34.0     Lawyer       131313.4                0.0
# 53  CUS_0x284a      June  34.0     Lawyer       131313.4                0.0
# 54  CUS_0x284a      July  34.0     Lawyer       131313.4                0.0
# 55  CUS_0x284a    August  34.0     Lawyer       131313.4                0.0
#
#     Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 48              1.0            8.0                    0
# 49              1.0            8.0                   -1
# 50              1.0            8.0                    0
# 51              1.0            8.0                    0
# 52              1.0            8.0                    0
# 53              1.0            8.0                    0
# 54              1.0            8.0                    0
# 55              1.0            8.0                    0
#
#     Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 48                     3.0                  9.34                   2.0
# 49                     2.0                 15.34                   4.0
# 50                     3.0                  9.34                   4.0
# 51                     2.0                  8.34                   4.0
# 52                     4.0                  9.34                   4.0
# 53                     3.0                 11.34                   4.0
# 54                     2.0                  9.34                   4.0
# 55                     2.0                  9.34                   4.0
#
#    Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 48       Good            352.16                 32.200509               30.70
# 49       Good            352.16                 31.983710               30.80
# 50       Good            352.16                 31.803134               30.90
# 51       Good            352.16                 42.645785               30.10
# 52       Good            352.16                 40.902517               30.11
# 53       Good            352.16                 41.980170               31.00
# 54       Good            352.16                 26.947565               31.10
# 55       Good            352.16                 29.187913               31.20
#
#    Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 48                    No           137.644605               378.171254
# 49                    No           137.644605               698.873271
# 50                    No           911.220179               188.064321
# 51                    No         23834.000000               337.434956
# 52                    No         32662.000000               263.378909
# 53                    No           911.220179                86.566388
# 54                    No           911.220179               930.391898
# 55                    No           911.220179               870.522382
#
#                    Payment_Behaviour  Monthly_Balance Credit_Score  \
# 48  High_spent_Medium_value_payments       858.462474         Good
# 49   High_spent_Small_value_payments       547.760457         Good
# 50   High_spent_Large_value_payments      1038.569407         Good
# 51  High_spent_Medium_value_payments       899.198772         Good
# 52   High_spent_Large_value_payments       963.254819         Good
# 53   High_spent_Large_value_payments      1140.067340     Standard
# 54   High_spent_Large_value_payments       326.241830         Good
# 55   Low_spent_Medium_value_payments       396.111346         Good
#
#     Num_of_loan2
# 48           2.0
# 49           2.0
# 50           2.0
# 51           2.0
# 52           2.0
# 53           2.0
# 54           2.0
# 55           2.0

# %%
sns.boxplot(df["Annual_Income"], orient='h')
# Out:
# <Axes: >

# %%
df["Total_EMI_per_month"].max()
# Out:
# 82331.0

# %%
df["Total_EMI_per_month"].value_counts()
# Out:
# 0.000000        10169
# 49.574949           8
# 64.008959           8
# 69.020960           8
# 250.408881          8
#                 ...
# 22898.000000        1
# 65311.000000        1
# 79218.000000        1
# 18859.000000        1
# 58638.000000        1
# Name: Total_EMI_per_month, Length: 14938, dtype: int64

# %%
df[df["Total_EMI_per_month"]>1000]
# Out:
#       Customer_ID     Month   Age     Occupation  Annual_Income  \
# 40     CUS_0x95ee   January  31.0         Lawyer       73928.46
# 45     CUS_0x95ee      June  31.0         Lawyer       73928.46
# 51     CUS_0x284a     April  34.0         Lawyer      131313.40
# 52     CUS_0x284a       May  34.0         Lawyer      131313.40
# 76     CUS_0xba08       May  44.0     Journalist       31370.80
# ...           ...       ...   ...            ...            ...
# 99921  CUS_0x2654  February  38.0  Media_Manager      139664.96
# 99960  CUS_0x372c   January  18.0         Lawyer       42903.79
# 99970   CUS_0xf16     March  44.0  Media_Manager       16680.35
# 99985  CUS_0x8600  February  28.0      Architect       20002.88
# 99993  CUS_0x942c  February  25.0       Mechanic       39628.99
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 40                   4.0              5.0            8.0                   12
# 45                   4.0              5.0            8.0                    7
# 51                   0.0              1.0            8.0                    0
# 52                   0.0              1.0            8.0                    0
# 76                   1.0              6.0           12.0                    1
# ...                  ...              ...            ...                  ...
# 99921                3.0              6.0           12.0                   14
# 99960                0.0              4.0            6.0                   14
# 99970                1.0              1.0            5.0                    1
# 99985               10.0              8.0           29.0                   33
# 99993                4.0              6.0            7.0                   23
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 40                       10.0                 10.14                   2.0
# 45                        7.0                 10.14                   2.0
# 51                        2.0                  8.34                   4.0
# 52                        4.0                  9.34                   4.0
# 76                        0.0                  5.76                   5.0
# ...                       ...                   ...                   ...
# 99921                    12.0                 12.39                   8.0
# 99960                     0.0                  4.10                   1.0
# 99970                     0.0                  5.69                   8.0
# 99985                    25.0                 23.31                   9.0
# 99993                     NaN                 11.50                   3.0
#
#       Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 40          Good            548.20                 39.962685
# 45          Good            548.20                 35.275437
# 51          Good            352.16                 42.645785
# 52          Good            352.16                 40.902517
# 76          Good            421.43                 25.189232
# ...          ...               ...                       ...
# 99921   Standard            365.66                 40.171095
# 99960       Good           1079.48                 27.289440
# 99970       Good            897.16                 30.472041
# 99985        Bad           3571.70                 39.772607
# 99993       Good            502.38                 29.135447
#
#        Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 40                    NaN                    No              15015.0
# 45                    NaN                    No              15515.0
# 51                  30.10                    No              23834.0
# 52                  30.11                    No              32662.0
# 76                  26.90                    No              16415.0
# ...                   ...                   ...                  ...
# 99921               29.80                   Yes              20563.0
# 99960               28.10                    No              50894.0
# 99970               21.30                    No              75011.0
# 99985                5.90                   Yes              12112.0
# 99993               31.40                    No              58638.0
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 40                   98.674410   High_spent_Large_value_payments
# 45                  235.790325    Low_spent_Large_value_payments
# 51                  337.434956  High_spent_Medium_value_payments
# 52                  263.378909   High_spent_Large_value_payments
# 76                  184.700572    Low_spent_Small_value_payments
# ...                        ...                               ...
# 99921               421.318866  High_spent_Medium_value_payments
# 99960                78.514945   High_spent_Small_value_payments
# 99970                75.504972   Low_spent_Medium_value_payments
# 99985               148.275233    Low_spent_Small_value_payments
# 99993               180.733095   Low_spent_Medium_value_payments
#
#        Monthly_Balance Credit_Score  Num_of_loan2
# 40          740.196090         Good           0.0
# 45          633.080175         Good           0.0
# 51          899.198772         Good           2.0
# 52          963.254819         Good           2.0
# 76          341.206633         Good           2.0
# ...                ...          ...           ...
# 99921              NaN     Standard           4.0
# 99960              NaN         Good           1.0
# 99970              NaN         Good           4.0
# 99985              NaN         Poor           5.0
# 99993              NaN     Standard           2.0
#
# [3396 rows x 23 columns]

# %%
df[df["Customer_ID"]=="CUS_0x95ee"]
# Out:
#    Customer_ID     Month   Age Occupation  Annual_Income  Num_Bank_Accounts  \
# 40  CUS_0x95ee   January  31.0     Lawyer       73928.46                4.0
# 41  CUS_0x95ee  February  31.0     Lawyer       73928.46                4.0
# 42  CUS_0x95ee     March  31.0     Lawyer       73928.46                4.0
# 43  CUS_0x95ee     April  31.0     Lawyer       73928.46                4.0
# 44  CUS_0x95ee       May  31.0     Lawyer       73928.46                4.0
# 45  CUS_0x95ee      June  31.0     Lawyer       73928.46                4.0
# 46  CUS_0x95ee      July  31.0     Lawyer       73928.46                4.0
# 47  CUS_0x95ee    August  31.0     Lawyer       73928.46                4.0
#
#     Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 40              5.0            8.0                   12
# 41              5.0            8.0                    8
# 42              5.0            8.0                    8
# 43              5.0            8.0                    8
# 44              5.0            8.0                   11
# 45              5.0            8.0                    7
# 46              5.0            8.0                    8
# 47              5.0            8.0                    8
#
#     Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 40                    10.0                 10.14                   2.0
# 41                     7.0                 10.14                   2.0
# 42                     7.0                 10.14                   2.0
# 43                     7.0                 10.14                   2.0
# 44                     7.0                 10.14                   2.0
# 45                     7.0                 10.14                   2.0
# 46                     4.0                  9.14                   2.0
# 47                     7.0                 10.14                   NaN
#
#    Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 40       Good             548.2                 39.962685                 NaN
# 41       Good             548.2                 42.769864                32.0
# 42       Good             548.2                 40.712187                 NaN
# 43       Good             548.2                 30.201658                32.2
# 44       Good             548.2                 26.333310                32.3
# 45       Good             548.2                 35.275437                 NaN
# 46       Good             548.2                 36.624791                32.5
# 47       Good             548.2                 31.580990                32.6
#
#    Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 40                    No              15015.0                98.674410
# 41                    No                  0.0               172.939214
# 42                    No                  0.0               150.059734
# 43                    No                  0.0               618.202391
# 44                    No                  0.0               177.951836
# 45                    No              15515.0               235.790325
# 46                    No                  0.0               348.509400
# 47                    No                  0.0                42.635590
#
#                    Payment_Behaviour  Monthly_Balance Credit_Score  \
# 40   High_spent_Large_value_payments       740.196090         Good
# 41   Low_spent_Medium_value_payments       705.931286         Good
# 42  High_spent_Medium_value_payments       698.810766         Good
# 43    Low_spent_Small_value_payments       270.668109         Good
# 44    Low_spent_Large_value_payments       690.918664         Good
# 45    Low_spent_Large_value_payments       633.080175         Good
# 46   High_spent_Small_value_payments       510.361100     Standard
# 47    Low_spent_Large_value_payments       796.234910         Good
#
#     Num_of_loan2
# 40           0.0
# 41           0.0
# 42           0.0
# 43           0.0
# 44           0.0
# 45           0.0
# 46           0.0
# 47           0.0

# %%
df[df["Customer_ID"]=="CUS_0x284a"]
# Out:
#    Customer_ID     Month   Age Occupation  Annual_Income  Num_Bank_Accounts  \
# 48  CUS_0x284a   January  33.0     Lawyer       131313.4                0.0
# 49  CUS_0x284a  February  34.0     Lawyer       131313.4                0.0
# 50  CUS_0x284a     March  34.0     Lawyer       131313.4                0.0
# 51  CUS_0x284a     April  34.0     Lawyer       131313.4                0.0
# 52  CUS_0x284a       May  34.0     Lawyer       131313.4                0.0
# 53  CUS_0x284a      June  34.0     Lawyer       131313.4                0.0
# 54  CUS_0x284a      July  34.0     Lawyer       131313.4                0.0
# 55  CUS_0x284a    August  34.0     Lawyer       131313.4                0.0
#
#     Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 48              1.0            8.0                    0
# 49              1.0            8.0                   -1
# 50              1.0            8.0                    0
# 51              1.0            8.0                    0
# 52              1.0            8.0                    0
# 53              1.0            8.0                    0
# 54              1.0            8.0                    0
# 55              1.0            8.0                    0
#
#     Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 48                     3.0                  9.34                   2.0
# 49                     2.0                 15.34                   4.0
# 50                     3.0                  9.34                   4.0
# 51                     2.0                  8.34                   4.0
# 52                     4.0                  9.34                   4.0
# 53                     3.0                 11.34                   4.0
# 54                     2.0                  9.34                   4.0
# 55                     2.0                  9.34                   4.0
#
#    Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 48       Good            352.16                 32.200509               30.70
# 49       Good            352.16                 31.983710               30.80
# 50       Good            352.16                 31.803134               30.90
# 51       Good            352.16                 42.645785               30.10
# 52       Good            352.16                 40.902517               30.11
# 53       Good            352.16                 41.980170               31.00
# 54       Good            352.16                 26.947565               31.10
# 55       Good            352.16                 29.187913               31.20
#
#    Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 48                    No           137.644605               378.171254
# 49                    No           137.644605               698.873271
# 50                    No           911.220179               188.064321
# 51                    No         23834.000000               337.434956
# 52                    No         32662.000000               263.378909
# 53                    No           911.220179                86.566388
# 54                    No           911.220179               930.391898
# 55                    No           911.220179               870.522382
#
#                    Payment_Behaviour  Monthly_Balance Credit_Score  \
# 48  High_spent_Medium_value_payments       858.462474         Good
# 49   High_spent_Small_value_payments       547.760457         Good
# 50   High_spent_Large_value_payments      1038.569407         Good
# 51  High_spent_Medium_value_payments       899.198772         Good
# 52   High_spent_Large_value_payments       963.254819         Good
# 53   High_spent_Large_value_payments      1140.067340     Standard
# 54   High_spent_Large_value_payments       326.241830         Good
# 55   Low_spent_Medium_value_payments       396.111346         Good
#
#     Num_of_loan2
# 48           2.0
# 49           2.0
# 50           2.0
# 51           2.0
# 52           2.0
# 53           2.0
# 54           2.0
# 55           2.0

# %%
df.Total_EMI_per_month.describe().T
# Out:
# count    99522.000000
# mean      1405.185237
# std       8310.992210
# min          0.000000
# 25%         30.759834
# 50%         69.602920
# 75%        161.978219
# max      82331.000000
# Name: Total_EMI_per_month, dtype: float64

# %%
q1 = df.Total_EMI_per_month.quantile(0.25)
q3 = df.Total_EMI_per_month.quantile(0.75)

iqr =q3-q1

ul = iqr+5.0*q3
#ll = iqr+1.5*q3
ul
# Out:
# 941.1094814848659

# %%
df.Total_EMI_per_month[df.Total_EMI_per_month > ul]=np.nan

# %%
tpm = ""
for i in df.Customer_ID[df.Total_EMI_per_month.isnull()]:
    tpm = df.Total_EMI_per_month[(df.Customer_ID ==i) & (df.Total_EMI_per_month.notnull())]
    df.Total_EMI_per_month[(df.Customer_ID == i) & (df.Total_EMI_per_month.isnull())] = tpm.mean()

# %%
df.Total_EMI_per_month.isnull().sum()
# Out:
# 8

# %%
df[df.Total_EMI_per_month.isnull()]
# Out:
#       Customer_ID     Month   Age Occupation  Annual_Income  \
# 39984  CUS_0x72c0   January  16.0    Teacher      116522.68
# 39985  CUS_0x72c0  February  16.0    Teacher      116522.68
# 39986  CUS_0x72c0     March  16.0    Teacher      116522.68
# 39987  CUS_0x72c0     April  16.0    Teacher      116522.68
# 39988  CUS_0x72c0       May  16.0    Teacher      116522.68
# 39989  CUS_0x72c0      June  16.0    Teacher      116522.68
# 39990  CUS_0x72c0      July  16.0    Teacher      116522.68
# 39991  CUS_0x72c0    August  16.0    Teacher      116522.68
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 39984                3.0              4.0           16.0                   26
# 39985                3.0              4.0           16.0                   26
# 39986                3.0              4.0           16.0                   26
# 39987                3.0              4.0           16.0                   26
# 39988                3.0              4.0           16.0                   31
# 39989                3.0              4.0           16.0                   26
# 39990                3.0              4.0           16.0                   29
# 39991                3.0              4.0           16.0                   26
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 39984                     8.0                 16.74                   7.0
# 39985                     8.0                 16.74                   7.0
# 39986                     8.0                 16.74                   7.0
# 39987                     8.0                 16.74                   7.0
# 39988                     6.0                 16.74                  11.0
# 39989                    10.0                 17.74                  11.0
# 39990                    11.0                 16.74                  11.0
# 39991                     7.0                 16.74                  11.0
#
#       Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 39984   Standard             272.6                 39.529611
# 39985   Standard             272.6                 39.811663
# 39986   Standard             272.6                 28.952960
# 39987   Standard             272.6                 27.560149
# 39988   Standard             272.6                 37.759572
# 39989   Standard             272.6                 25.035876
# 39990   Standard             272.6                 25.712128
# 39991   Standard             272.6                 26.254382
#
#        Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 39984                5.40                   Yes                  NaN
# 39985                5.50                   Yes                  NaN
# 39986                5.60                   Yes                  NaN
# 39987                5.70                   Yes                  NaN
# 39988                5.80                   Yes                  NaN
# 39989                5.90                   Yes                  NaN
# 39990                5.10                   Yes                  NaN
# 39991                5.11                   Yes                  NaN
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 39984               178.255077   High_spent_Large_value_payments
# 39985               575.146069   Low_spent_Medium_value_payments
# 39986               395.154127    Low_spent_Large_value_payments
# 39987               225.284670  High_spent_Medium_value_payments
# 39988               319.891283  High_spent_Medium_value_payments
# 39989               718.439984    Low_spent_Large_value_payments
# 39990               177.362071   High_spent_Small_value_payments
# 39991               571.699736   Low_spent_Medium_value_payments
#
#        Monthly_Balance Credit_Score  Num_of_loan2
# 39984       646.900427     Standard           6.0
# 39985       290.009435     Standard           6.0
# 39986       343.622426     Standard           6.0
# 39987       609.870834     Standard           6.0
# 39988       515.264221         Good           6.0
# 39989       136.715520     Standard           6.0
# 39990       667.793433     Standard           6.0
# 39991       293.455767     Standard           6.0

# %%
df.shape
# Out:
# (99522, 23)

# %%
df.dropna(subset= ['Total_EMI_per_month'],inplace= True)

# %%
df.shape
# Out:
# (99514, 23)

# %%
t=1
plt.figure(figsize=(12,10))
for i in num_cols:
    plt.subplot(4,3,t)
    sns.boxplot(df[i], orient='h')
    plt.title(i)
    t+=1
    
plt.tight_layout()
plt.show()

# %%
t=1
plt.figure(figsize=(50,40))
for i in cat_cols:
    if i!= 'Customer_ID':
        plt.subplot(4,3,t)
        sns.countplot(x=df[i])
        plt.title(i)
        t+=1
    
plt.tight_layout()
plt.show()

# %%
df.isnull().sum()
# Out:
# Customer_ID                    0
# Month                          0
# Age                            0
# Occupation                     0
# Annual_Income                  0
# Num_Bank_Accounts              0
# Num_Credit_Card                0
# Interest_Rate                  0
# Delay_from_due_date            0
# Num_of_Delayed_Payment      7699
# Changed_Credit_Limit        2083
# Num_Credit_Inquiries        3594
# Credit_Mix                     0
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Credit_History_Age          8993
# Payment_of_Min_Amount          0
# Total_EMI_per_month            0
# Amount_invested_monthly        0
# Payment_Behaviour              0
# Monthly_Balance             2865
# Credit_Score                   0
# Num_of_loan2                   0
# dtype: int64

# %%
###########above this all good

# %%
##KNN imputer to fill num values

# %%
#num_cols.remove('Customer_ID')

# %%
sc = StandardScaler()

# %%
scaled_data = pd.DataFrame(sc.fit_transform(df[num_cols]),columns = num_cols)

# %%
scaled_data.isnull().sum()
# Out:
# Age                            0
# Annual_Income                  0
# Delay_from_due_date            0
# Changed_Credit_Limit        2083
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Credit_History_Age          8993
# Total_EMI_per_month            0
# Amount_invested_monthly        0
# Monthly_Balance             2865
# dtype: int64

# %%
from sklearn.impute import KNNImputer

# %%
kn = KNNImputer()

# %%
knn_imputer = pd.DataFrame(kn.fit_transform(scaled_data), columns = scaled_data.columns)

# %%
knn_imputer.isnull().sum()
# Out:
# Age                         0
# Annual_Income               0
# Delay_from_due_date         0
# Changed_Credit_Limit        0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Monthly_Balance             0
# dtype: int64

# %%
new_data = pd.DataFrame(sc.inverse_transform(knn_imputer), columns = knn_imputer.columns)

# %%
new_data.isnull().sum()
# Out:
# Age                         0
# Annual_Income               0
# Delay_from_due_date         0
# Changed_Credit_Limit        0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Monthly_Balance             0
# dtype: int64

# %%
cat_data = df[cat_cols]
cat_data.shape
# Out:
# (99514, 13)

# %%
new_data.reset_index(drop=True, inplace=True)
cat_data.reset_index(drop=True, inplace=True)

# Concatenate them along columns (axis=1)
df1 = pd.concat([new_data,cat_data], axis=1)

# %%
df1.isnull().sum()
# Out:
# Age                            0
# Annual_Income                  0
# Delay_from_due_date            0
# Changed_Credit_Limit           0
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Credit_History_Age             0
# Total_EMI_per_month            0
# Amount_invested_monthly        0
# Monthly_Balance                0
# Customer_ID                    0
# Month                          0
# Occupation                     0
# Credit_Mix                     0
# Payment_of_Min_Amount          0
# Payment_Behaviour              0
# Credit_Score                   0
# Num_Bank_Accounts              0
# Num_Credit_Card                0
# Interest_Rate                  0
# Num_of_Delayed_Payment      7699
# Num_Credit_Inquiries        3594
# Num_of_loan2                   0
# dtype: int64

# %%
#now we will fix num_credit_inquiries

# %%
df1.Num_Credit_Inquiries.value_counts()
# Out:
# 4.0     11194
# 3.0      8810
# 6.0      8084
# 7.0      8030
# 2.0      7958
# 8.0      7851
# 1.0      7520
# 0.0      6917
# 5.0      5662
# 9.0      5279
# 11.0     5047
# 10.0     4930
# 12.0     4571
# 13.0     1480
# 14.0     1039
# 15.0      808
# 16.0      456
# 17.0      284
# Name: Num_Credit_Inquiries, dtype: int64

# %%
df[df["Customer_ID"]=="CUS_0x95ee"]
# Out:
#    Customer_ID     Month   Age Occupation  Annual_Income  Num_Bank_Accounts  \
# 40  CUS_0x95ee   January  31.0     Lawyer       73928.46                4.0
# 41  CUS_0x95ee  February  31.0     Lawyer       73928.46                4.0
# 42  CUS_0x95ee     March  31.0     Lawyer       73928.46                4.0
# 43  CUS_0x95ee     April  31.0     Lawyer       73928.46                4.0
# 44  CUS_0x95ee       May  31.0     Lawyer       73928.46                4.0
# 45  CUS_0x95ee      June  31.0     Lawyer       73928.46                4.0
# 46  CUS_0x95ee      July  31.0     Lawyer       73928.46                4.0
# 47  CUS_0x95ee    August  31.0     Lawyer       73928.46                4.0
#
#     Num_Credit_Card  Interest_Rate  Delay_from_due_date  \
# 40              5.0            8.0                   12
# 41              5.0            8.0                    8
# 42              5.0            8.0                    8
# 43              5.0            8.0                    8
# 44              5.0            8.0                   11
# 45              5.0            8.0                    7
# 46              5.0            8.0                    8
# 47              5.0            8.0                    8
#
#     Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# 40                    10.0                 10.14                   2.0
# 41                     7.0                 10.14                   2.0
# 42                     7.0                 10.14                   2.0
# 43                     7.0                 10.14                   2.0
# 44                     7.0                 10.14                   2.0
# 45                     7.0                 10.14                   2.0
# 46                     4.0                  9.14                   2.0
# 47                     7.0                 10.14                   NaN
#
#    Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 40       Good             548.2                 39.962685                 NaN
# 41       Good             548.2                 42.769864                32.0
# 42       Good             548.2                 40.712187                 NaN
# 43       Good             548.2                 30.201658                32.2
# 44       Good             548.2                 26.333310                32.3
# 45       Good             548.2                 35.275437                 NaN
# 46       Good             548.2                 36.624791                32.5
# 47       Good             548.2                 31.580990                32.6
#
#    Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 40                    No                  0.0                98.674410
# 41                    No                  0.0               172.939214
# 42                    No                  0.0               150.059734
# 43                    No                  0.0               618.202391
# 44                    No                  0.0               177.951836
# 45                    No                  0.0               235.790325
# 46                    No                  0.0               348.509400
# 47                    No                  0.0                42.635590
#
#                    Payment_Behaviour  Monthly_Balance Credit_Score  \
# 40   High_spent_Large_value_payments       740.196090         Good
# 41   Low_spent_Medium_value_payments       705.931286         Good
# 42  High_spent_Medium_value_payments       698.810766         Good
# 43    Low_spent_Small_value_payments       270.668109         Good
# 44    Low_spent_Large_value_payments       690.918664         Good
# 45    Low_spent_Large_value_payments       633.080175         Good
# 46   High_spent_Small_value_payments       510.361100     Standard
# 47    Low_spent_Large_value_payments       796.234910         Good
#
#     Num_of_loan2
# 40           0.0
# 41           0.0
# 42           0.0
# 43           0.0
# 44           0.0
# 45           0.0
# 46           0.0
# 47           0.0

# %%
nci = ""
for i in df1.Customer_ID[df1.Num_Credit_Inquiries.isnull()]:
    nci = df1.Num_Credit_Inquiries[(df1.Customer_ID ==i) & (df1.Num_Credit_Inquiries.notnull())]
    df1.Num_Credit_Inquiries[(df1.Customer_ID == i) & (df1.Num_Credit_Inquiries.isnull())] = nci.mode()[0]

# %%
df1[df1.Customer_ID == 'CUS_0x2dbc']
# Out:
#      Age  Annual_Income  Delay_from_due_date  Changed_Credit_Limit  \
# 16  34.0      143162.64                  5.0                   7.1
# 17  34.0      143162.64                 13.0                   7.1
# 18  34.0      143162.64                  8.0                  11.1
# 19  34.0      143162.64                  8.0                   9.1
# 20  34.0      143162.64                 10.0                   7.1
# 21  34.0      143162.64                  8.0                   7.1
# 22  34.0      143162.64                  8.0                   7.1
# 23  34.0      143162.64                  8.0                   7.1
#
#     Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# 16           1303.01                 28.616735               17.90
# 17           1303.01                 41.702573               17.10
# 18           1303.01                 26.519815               17.11
# 19           1303.01                 39.501648               24.26
# 20           1303.01                 31.376150               18.10
# 21           1303.01                 39.783993               18.20
# 22           1303.01                 38.068624               18.30
# 23           1303.01                 38.374753               18.40
#
#     Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance Customer_ID  \
# 16           246.992319               168.413703      1043.315978  CUS_0x2dbc
# 17           246.992319               232.860384       998.869297  CUS_0x2dbc
# 18           246.992319               363.070024       715.741367  CUS_0x2dbc
# 19           246.992319               825.216270       426.513411  CUS_0x2dbc
# 20           246.992319               430.947528       810.782153  CUS_0x2dbc
# 21           246.992319               257.808099       963.921581  CUS_0x2dbc
# 22           246.992319               263.174163       968.555517  CUS_0x2dbc
# 23           246.992319               363.070024       895.494583  CUS_0x2dbc
#
#        Month Occupation Credit_Mix Payment_of_Min_Amount  \
# 16   January   Engineer       Good                    No
# 17  February   Engineer       Good                    No
# 18     March   Engineer       Good                    No
# 19     April   Engineer       Good                    No
# 20       May   Engineer       Good                    No
# 21      June   Engineer       Good                    No
# 22      July   Engineer       Good                    No
# 23    August   Engineer       Good                    No
#
#                    Payment_Behaviour Credit_Score  Num_Bank_Accounts  \
# 16   High_spent_Small_value_payments         Good                1.0
# 17   High_spent_Small_value_payments         Good                1.0
# 18   High_spent_Small_value_payments         Good                1.0
# 19   Low_spent_Medium_value_payments         Good                1.0
# 20    Low_spent_Large_value_payments         Good                1.0
# 21  High_spent_Medium_value_payments         Good                1.0
# 22   High_spent_Small_value_payments     Standard                1.0
# 23   High_spent_Small_value_payments     Standard                1.0
#
#     Num_Credit_Card  Interest_Rate  Num_of_Delayed_Payment  \
# 16              5.0            8.0                     8.0
# 17              5.0            8.0                     6.0
# 18              5.0            8.0                     7.0
# 19              5.0            8.0                     5.0
# 20              5.0            8.0                     5.0
# 21              5.0            8.0                     6.0
# 22              5.0            8.0                     6.0
# 23              5.0            8.0                     6.0
#
#     Num_Credit_Inquiries  Num_of_loan2
# 16                   3.0           3.0
# 17                   3.0           3.0
# 18                   3.0           3.0
# 19                   3.0           3.0
# 20                   3.0           3.0
# 21                   3.0           3.0
# 22                   3.0           3.0
# 23                   3.0           3.0

# %%
df1.Num_of_Delayed_Payment.value_counts()
#now we will treat delayed payment
# Out:
#  19.0    5459
#  17.0    5394
#  16.0    5292
#  10.0    5283
#  15.0    5212
#  18.0    5196
#  20.0    5081
#  12.0    5022
#  9.0     4939
#  8.0     4835
#  11.0    4781
#  14.0    4175
#  13.0    4023
#  21.0    2547
#  7.0     2369
#  22.0    2337
#  6.0     2297
#  5.0     2073
#  23.0    2026
#  3.0     1923
#  4.0     1825
#  2.0     1791
#  24.0    1701
#  25.0    1665
#  1.0     1627
#  0.0     1600
#  26.0     322
# -1.0      314
#  27.0     250
# -2.0      231
#  28.0     131
# -3.0       94
# Name: Num_of_Delayed_Payment, dtype: int64

# %%
ndp = ""
for i in df1.Customer_ID[df1.Num_of_Delayed_Payment.isnull()]:
    ndp = df1.Num_of_Delayed_Payment[(df1.Customer_ID ==i) & (df1.Num_of_Delayed_Payment.notnull())]
    df1.Num_of_Delayed_Payment[(df1.Customer_ID == i) & (df1.Num_of_Delayed_Payment.isnull())] = ndp.mode()[0]

# %%
df1.isnull().sum()
# Out:
# Age                         0
# Annual_Income               0
# Delay_from_due_date         0
# Changed_Credit_Limit        0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Monthly_Balance             0
# Customer_ID                 0
# Month                       0
# Occupation                  0
# Credit_Mix                  0
# Payment_of_Min_Amount       0
# Payment_Behaviour           0
# Credit_Score                0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Delayed_Payment      0
# Num_Credit_Inquiries        0
# Num_of_loan2                0
# dtype: int64

# %%
#now we have fixed aLL THE VALUES and we will proceed with bivariate and univariate analysis

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ### Numerical Columns

# %%
t=1
plt.figure(figsize=(12,10))
for i in num_cols:
    plt.subplot(4,3,t)
    sns.boxplot(df[i], orient='h')
    plt.xticks(rotation=90)
    plt.title(i)
    t+=1
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Categorical Columns

# %%
t=1
plt.figure(figsize=(50,40))
for i in cat_cols:
    if i!= 'Customer_ID':
        plt.subplot(4,3,t)
        sns.countplot(x=df[i])
        plt.title(i)
        t+=1
    
plt.tight_layout()
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# ## Numerical with Categorical(Target) columns

# %%
j=1
plt.figure(figsize=(20,30))
for i in num_cols:
    plt.subplot(5,2,j)
    sns.boxplot(x=df1[i], y=df1["Credit_Score"])
    plt.title(i)
    j+=1
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Categorical with Categorical(Target) column

# %%
plt.figure(figsize=(20,40))
t = 1
for i in cat_cols:
    if i!="Customer_ID":
        plt.subplot(6,2,t)
        sns.countplot(data=df1, x=i, hue='Credit_Score')
        t+=1
        plt.title(i)
        plt.xticks(rotation=60)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Encoding

# %%
df1.select_dtypes(include=object)
# Out:
#       Customer_ID     Month Occupation Credit_Mix Payment_of_Min_Amount  \
# 0       CUS_0xd40   January  Scientist       Good                    No
# 1       CUS_0xd40  February  Scientist       Good                    No
# 2       CUS_0xd40     March  Scientist       Good                    No
# 3       CUS_0xd40     April  Scientist       Good                    No
# 4       CUS_0xd40       May  Scientist       Good                    No
# ...           ...       ...        ...        ...                   ...
# 99509  CUS_0x942c     April   Mechanic       Good                    No
# 99510  CUS_0x942c       May   Mechanic       Good                    No
# 99511  CUS_0x942c      June   Mechanic       Good                    No
# 99512  CUS_0x942c      July   Mechanic       Good                    No
# 99513  CUS_0x942c    August   Mechanic       Good                    No
#
#                       Payment_Behaviour Credit_Score
# 0       High_spent_Small_value_payments         Good
# 1        Low_spent_Large_value_payments         Good
# 2       Low_spent_Medium_value_payments         Good
# 3        Low_spent_Small_value_payments         Good
# 4      High_spent_Medium_value_payments         Good
# ...                                 ...          ...
# 99509   High_spent_Large_value_payments         Poor
# 99510  High_spent_Medium_value_payments         Poor
# 99511   High_spent_Large_value_payments         Poor
# 99512    Low_spent_Large_value_payments     Standard
# 99513   High_spent_Large_value_payments         Poor
#
# [99514 rows x 7 columns]

# %%
df1["Credit_Score"].value_counts()
# Out:
# Standard    52884
# Poor        28953
# Good        17677
# Name: Credit_Score, dtype: int64

# %%
import category_encoders as ce

# %%
cat_cols.remove("Credit_Score")
cat_cols.remove("Customer_ID")

# %%
# 'Standard':1,'Poor':0,'Good':2

df1['Credit_Score'] = df1['Credit_Score'].map({'Standard':1,'Poor':0,'Good':2})

# %%
df1["Credit_Score"].value_counts()
# Out:
# Series([], Name: Credit_Score, dtype: int64)

# %%
encoder = ce.WOEEncoder(cols = cat_cols)

# %%
encode_data = encoder.fit_transform(df[cat_cols],df['Credit_Score'])
